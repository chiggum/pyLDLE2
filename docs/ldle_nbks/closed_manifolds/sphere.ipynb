# %% [markdown]
# ### Sphere

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
save_dir_root = '../data/pyLDLE2/sphere/'

# %%
X, labelsMat, ddX = datasets.Datasets().sphere()
# Out:
# X.shape =  (10000, 3)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LDLE'},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  intermed_opts={'eta_min': 10},
                  global_opts={
                      'max_iter': 10,
                      'init_algo_align_w_parent_only': True # Set this True for low noise
                  },
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 875 is created.

# %%
ldle.fit(X=X)
# Out:
# Constructing unnorm graph Laplacian + its eigendecomposition.
# Done.
# ##############################
# Time elapsed from last time log: 2.3 seconds
# Total time elapsed: 2.3 seconds
# ##############################
# Computing Atilde: Inner Prod of Grad of EigFuncs.
# FEM for Atilde.
# Atilde: 0 points processed...
# Atilde: 2500 points processed...
# Atilde: 5000 points processed...
# Atilde: 7500 points processed...
# Atilde: all points processed...
# Done.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 3.0 seconds
# ##############################
# Computing LDLE.
# local_param: all 10000 points processed...
# max distortion is 107.656009
# Done.
# ##############################
# Time elapsed from last time log: 1.2 seconds
# Total time elapsed: 4.3 seconds
# ##############################
# Posprocessing local parameterizations.
# #Param replaced: 9199, max distortion: 3.237484
# #Param replaced: 3117, max distortion: 2.539771
# #Param replaced: 1067, max distortion: 2.539771
# #Param replaced: 869, max distortion: 2.539771
# #Param replaced: 887, max distortion: 2.539771
# #Param replaced: 679, max distortion: 2.539771
# #Param replaced: 799, max distortion: 2.539771
# #Param replaced: 886, max distortion: 1.868254
# #Param replaced: 446, max distortion: 1.815354
# #Param replaced: 192, max distortion: 1.812023
# #Param replaced: 124, max distortion: 1.812023
# #Param replaced: 128, max distortion: 1.812023
# #Param replaced: 84, max distortion: 1.812023
# #Param replaced: 34, max distortion: 1.812023
# #Param replaced: 30, max distortion: 1.812023
# #Param replaced: 46, max distortion: 1.812023
# #Param replaced: 34, max distortion: 1.812023
# #Param replaced: 14, max distortion: 1.812023
# #Param replaced: 6, max distortion: 1.812023
# #Param replaced: 0, max distortion: 1.812023
# Max local distortion after postprocessing: 1.812023078599863
# Done.
# ##############################
# Time elapsed from last time log: 19.0 seconds
# Total time elapsed: 23.3 seconds
# ##############################
# Max local distortion = 1.812023078599863
# Constructing intermediate views.
# eta = 2.
# # non-empty views with sz < 2 = 10000
# #nodes in views with sz < 2 = 10000
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 20.3 seconds
# Total time elapsed: 20.4 seconds
# ##############################
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 260.5 seconds
# Total time elapsed: 280.9 seconds
# ##############################
# eta = 3.
# # non-empty views with sz < 3 = 320
# #nodes in views with sz < 3 = 640
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 1.0 seconds
# Total time elapsed: 282.0 seconds
# ##############################
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 7.2 seconds
# Total time elapsed: 289.2 seconds
# ##############################
# eta = 4.
# # non-empty views with sz < 4 = 244
# #nodes in views with sz < 4 = 732
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 1.0 seconds
# Total time elapsed: 290.1 seconds
# ##############################
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 14.1 seconds
# Total time elapsed: 304.2 seconds
# ##############################
# eta = 5.
# # non-empty views with sz < 5 = 180
# #nodes in views with sz < 5 = 720
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 1.1 seconds
# Total time elapsed: 305.3 seconds
# ##############################
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 18.3 seconds
# Total time elapsed: 323.6 seconds
# ##############################
# eta = 6.
# # non-empty views with sz < 6 = 150
# #nodes in views with sz < 6 = 750
# Costs computed when eta = 6.
# ##############################
# Time elapsed from last time log: 1.1 seconds
# Total time elapsed: 324.7 seconds
# ##############################
# Remaining #nodes in views with sz < 6 = 0
# Done with eta = 6.
# ##############################
# Time elapsed from last time log: 20.3 seconds
# Total time elapsed: 345.0 seconds
# ##############################
# eta = 7.
# # non-empty views with sz < 7 = 95
# #nodes in views with sz < 7 = 570
# Costs computed when eta = 7.
# ##############################
# Time elapsed from last time log: 0.9 seconds
# Total time elapsed: 345.9 seconds
# ##############################
# Remaining #nodes in views with sz < 7 = 0
# Done with eta = 7.
# ##############################
# Time elapsed from last time log: 18.1 seconds
# Total time elapsed: 364.0 seconds
# ##############################
# eta = 8.
# # non-empty views with sz < 8 = 99
# #nodes in views with sz < 8 = 693
# Costs computed when eta = 8.
# ##############################
# Time elapsed from last time log: 1.0 seconds
# Total time elapsed: 365.0 seconds
# ##############################
# Remaining #nodes in views with sz < 8 = 0
# Done with eta = 8.
# ##############################
# Time elapsed from last time log: 22.7 seconds
# Total time elapsed: 387.7 seconds
# ##############################
# eta = 9.
# # non-empty views with sz < 9 = 70
# #nodes in views with sz < 9 = 560
# Costs computed when eta = 9.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 388.5 seconds
# ##############################
# Remaining #nodes in views with sz < 9 = 0
# Done with eta = 9.
# ##############################
# Time elapsed from last time log: 17.8 seconds
# Total time elapsed: 406.3 seconds
# ##############################
# eta = 10.
# # non-empty views with sz < 10 = 80
# #nodes in views with sz < 10 = 720
# Costs computed when eta = 10.
# ##############################
# Time elapsed from last time log: 0.9 seconds
# Total time elapsed: 407.2 seconds
# ##############################
# Remaining #nodes in views with sz < 10 = 0
# Done with eta = 10.
# ##############################
# Time elapsed from last time log: 30.1 seconds
# Total time elapsed: 437.3 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 0.6 seconds
# Total time elapsed: 437.9 seconds
# ##############################
# After clustering, max distortion is 26.002032
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 149 intermediate views
# Ambiguous overlaps checked for 298 intermediate views
# Ambiguous overlaps checked for 447 intermediate views
# Ambiguous overlaps checked for 596 points
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 1
# Computing initial embedding using: sequential algorithm
# ##############################
# Time elapsed from last time log: 3.5 seconds
# Total time elapsed: 3.5 seconds
# ##############################
# Initial alignment of 149 views completed
# Initial alignment of 298 views completed
# Initial alignment of 447 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 3.9 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 6.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10596 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.1 seconds
# Total time elapsed: 8.3 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 10.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10596 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.1 seconds
# Total time elapsed: 12.3 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 14.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10596 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.1 seconds
# Total time elapsed: 16.1 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 17.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10596 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.0 seconds
# Total time elapsed: 19.8 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 21.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10596 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.1 seconds
# Total time elapsed: 23.4 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 5
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 24.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10596 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.1 seconds
# Total time elapsed: 26.9 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 6
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 28.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10596 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.3 seconds
# Total time elapsed: 30.6 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 7
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 32.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10596 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 34.2 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 8
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 35.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10596 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.1 seconds
# Total time elapsed: 37.6 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 9
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 39.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10596 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.1 seconds
# Total time elapsed: 41.0 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 10596 multiplied with B
# Alignment error: 67.329
# ##############################
# Time elapsed from last time log: 1.0 seconds
# Total time elapsed: 42.0 seconds
# ##############################
# array([[ 0.03173812,  0.35510682],
#        [ 0.02203342,  0.35760308],
#        [ 0.03549353,  0.36374256],
#        ...,
#        [-0.05004709, -0.251065  ],
#        [-0.0377081 , -0.24290307],
#        [-0.04768324, -0.24194955]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/sphere//ldle.dat
