# %% [markdown]
# ### Sphere

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
save_dir_root = '../data/pyLDLE2/sphere/'

# %%
X, labelsMat, ddX = datasets.Datasets().sphere()
# Out:
# X.shape =  (10000, 3)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LDLE'},
                  intermed_opts={'eta_min': 5},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 700 is created.
# Options provided:
# local_opts:
# {
#     "Atilde_method": "LDLE_1",
#     "N": 100,
#     "algo": "LDLE",
#     "alpha": 1,
#     "debug": true,
#     "delta": 0.9,
#     "gl_type": "unnorm",
#     "k": 28,
#     "k_nn": 49,
#     "k_nn0": 700,
#     "k_tune": 7,
#     "max_iter": 300,
#     "n_proc": 32,
#     "no_gamma": false,
#     "p": 0.99,
#     "pp_n_thresh": 32,
#     "reg": 0.0,
#     "tau": 50,
#     "to_postprocess": true,
#     "verbose": true
# }
# intermed_opts:
# {
#     "algo": "best",
#     "debug": true,
#     "eta_max": 25,
#     "eta_min": 5,
#     "len_S_thresh": 256,
#     "local_algo": "LDLE",
#     "n_proc": 32,
#     "n_times": 4,
#     "verbose": true
# }
# global_opts:
# {
#     "align_w_parent_only": true,
#     "alpha": 0.3,
#     "color_tear": true,
#     "compute_error": false,
#     "debug": true,
#     "eps": 1e-08,
#     "init_algo_name": "procrustes",
#     "k": 28,
#     "main_algo": "LDLE",
#     "max_internal_iter": 100,
#     "max_iter": 20,
#     "n_proc": 32,
#     "nu": 3,
#     "refine_algo_name": "rgd",
#     "to_tear": true,
#     "verbose": true,
#     "vis_before_init": false
# }

# %%
ldle.fit(X=X)
# Out:
# Constructing unnorm graph Laplacian + its eigendecomposition.
# Done.
# ##############################
# Time elapsed from last time log: 3.5 seconds
# Total time elapsed: 3.5 seconds
# ##############################
# Computing Atilde: Inner Prod of Grad of EigFuncs.
# FEM for Atilde.
# Atilde: 0 points processed...
# Atilde: 2500 points processed...
# Atilde: 5000 points processed...
# Atilde: 7500 points processed...
# Atilde: all points processed...
# Done.
# ##############################
# Time elapsed from last time log: 1.2 seconds
# Total time elapsed: 4.7 seconds
# ##############################
# Computing LDLE.
# local_param: all 10000 points processed...
# max distortion is 97.457831
# Done.
# ##############################
# Time elapsed from last time log: 1.6 seconds
# Total time elapsed: 6.3 seconds
# ##############################
# Posprocessing local parameterizations.
# #Param replaced: 9039, max distortion: 4.410566
# #Param replaced: 3065, max distortion: 2.513654
# #Param replaced: 1115, max distortion: 2.199853
# #Param replaced: 677, max distortion: 2.199853
# #Param replaced: 667, max distortion: 2.199371
# #Param replaced: 532, max distortion: 2.199371
# #Param replaced: 312, max distortion: 2.199371
# #Param replaced: 384, max distortion: 2.199371
# #Param replaced: 632, max distortion: 1.822182
# #Param replaced: 360, max distortion: 1.736012
# #Param replaced: 196, max distortion: 1.736012
# #Param replaced: 160, max distortion: 1.736012
# #Param replaced: 130, max distortion: 1.736012
# #Param replaced: 110, max distortion: 1.736012
# #Param replaced: 66, max distortion: 1.736012
# #Param replaced: 14, max distortion: 1.736012
# #Param replaced: 0, max distortion: 1.736012
# Max local distortion after postprocessing: 1.7360119917812438
# Done.
# ##############################
# Time elapsed from last time log: 10.1 seconds
# Total time elapsed: 16.4 seconds
# ##############################
# Max local distortion = 1.7360119917812438
# Constructing intermediate views.
# eta = 2.
# #non-empty views with sz < 2 = 10000
# #nodes in views with sz < 2 = 10000
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 8.4 seconds
# Total time elapsed: 9.0 seconds
# ##############################
# ctr=8167, total_len_S=70439, avg_len_S=8.625
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 239.6 seconds
# Total time elapsed: 248.6 seconds
# ##############################
# eta = 3.
# #non-empty views with sz < 3 = 342
# #nodes in views with sz < 3 = 684
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 1.4 seconds
# Total time elapsed: 250.0 seconds
# ##############################
# ctr=616, total_len_S=11835, avg_len_S=19.213
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 5.7 seconds
# Total time elapsed: 255.7 seconds
# ##############################
# eta = 4.
# #non-empty views with sz < 4 = 315
# #nodes in views with sz < 4 = 945
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 1.6 seconds
# Total time elapsed: 257.3 seconds
# ##############################
# ctr=858, total_len_S=23359, avg_len_S=27.225
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 13.5 seconds
# Total time elapsed: 270.7 seconds
# ##############################
# eta = 5.
# #non-empty views with sz < 5 = 207
# #nodes in views with sz < 5 = 828
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 1.6 seconds
# Total time elapsed: 272.3 seconds
# ##############################
# ctr=747, total_len_S=24713, avg_len_S=33.083
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 13.6 seconds
# Total time elapsed: 285.9 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 286.7 seconds
# ##############################
# After clustering, max distortion is 2.017937
# Computing laterations scores for overlaps b/w intermed views
# Done
# ##############################
# Time elapsed from last time log: 1.6 seconds
# Total time elapsed: 1.6 seconds
# ##############################
# Computing a lateration.
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 1
# Done.
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 1.7 seconds
# ##############################
# Computing initial embedding using: procrustes algorithm
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 1.7 seconds
# ##############################
# Initial alignment of 265 views completed
# Initial alignment of 530 views completed
# Initial alignment of 795 views completed
# Initial alignment of 1060 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 1.1 seconds
# Total time elapsed: 2.7 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 6.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10000 + 1062 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 5.8 seconds
# Total time elapsed: 12.6 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 16.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10000 + 1062 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 5.6 seconds
# Total time elapsed: 21.8 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 24.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10000 + 1062 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 5.9 seconds
# Total time elapsed: 30.8 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 33.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10000 + 1062 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 5.7 seconds
# Total time elapsed: 39.5 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 42.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10000 + 1062 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 5.8 seconds
# Total time elapsed: 47.8 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 5
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 50.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10000 + 1062 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 5.9 seconds
# Total time elapsed: 56.3 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 6
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 58.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10000 + 1062 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 5.8 seconds
# Total time elapsed: 64.6 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 7
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 66.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10000 + 1062 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 5.9 seconds
# Total time elapsed: 72.8 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 8
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 75.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10000 + 1062 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 5.9 seconds
# Total time elapsed: 80.9 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 9
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 83.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10000 + 1062 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 5.9 seconds
# Total time elapsed: 89.1 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 10
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 91.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10000 + 1062 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 6.0 seconds
# Total time elapsed: 97.2 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 11
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 99.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10000 + 1062 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 5.7 seconds
# Total time elapsed: 105.0 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 12
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 107.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10000 + 1062 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 5.8 seconds
# Total time elapsed: 112.7 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 13
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 114.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10000 + 1062 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 5.8 seconds
# Total time elapsed: 120.8 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 14
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 122.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10000 + 1062 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 5.8 seconds
# Total time elapsed: 128.6 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 15
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 130.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10000 + 1062 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 5.9 seconds
# Total time elapsed: 136.4 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 16
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 138.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10000 + 1062 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 5.7 seconds
# Total time elapsed: 144.0 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 17
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 145.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10000 + 1062 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 5.7 seconds
# Total time elapsed: 151.6 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 18
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 153.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10000 + 1062 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 5.9 seconds
# Total time elapsed: 159.4 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 19
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 161.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10000 + 1062 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 5.9 seconds
# Total time elapsed: 167.4 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 10000 + 1062 multiplied with B
# Computing svd
# Done
# Alignment error: 49.220
# ##############################
# Time elapsed from last time log: 2.8 seconds
# Total time elapsed: 170.1 seconds
# ##############################
# array([[-0.08724011, -0.2296081 ],
#        [-0.07764694, -0.22650214],
#        [-0.09081294, -0.22124067],
#        ...,
#        [ 0.07289221,  0.34606876],
#        [ 0.06005983,  0.35250052],
#        [ 0.06960744,  0.35512669]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/sphere//ldle.dat
