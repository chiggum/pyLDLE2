# %% [markdown]
# ### Sphere

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
save_dir_root = '../data/pyLDLE2/sphere/'

# %%
X, labelsMat, ddX = datasets.Datasets().sphere()
# Out:
# X.shape =  (10000, 3)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LDLE'},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  intermed_opts={'eta_min': 5},
                  global_opts={
                      'max_iter': 12,
                      'init_algo_align_w_parent_only': True # Set this True for low noise
                  },
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 600 is created.

# %%
ldle.fit(X=X)
# Out:
# Constructing unnorm graph Laplacian + its eigendecomposition.
# Done.
# ##############################
# Time elapsed from last time log: 2.1 seconds
# Total time elapsed: 2.1 seconds
# ##############################
# Computing Atilde: Inner Prod of Grad of EigFuncs.
# FEM for Atilde.
# Atilde: 0 points processed...
# Atilde: 2500 points processed...
# Atilde: 5000 points processed...
# Atilde: 7500 points processed...
# Atilde: all points processed...
# Done.
# ##############################
# Time elapsed from last time log: 0.7 seconds
# Total time elapsed: 2.8 seconds
# ##############################
# Computing LDLE.
# local_param: all 10000 points processed...
# max distortion is 967.275855
# Done.
# ##############################
# Time elapsed from last time log: 1.2 seconds
# Total time elapsed: 4.1 seconds
# ##############################
# Posprocessing LDLE.
# Iter 1, Param replaced: 9122, max distortion: 15.900866
# Iter 2, Param replaced: 3872, max distortion: 3.788582
# Iter 3, Param replaced: 1509, max distortion: 2.961875
# Iter 4, Param replaced: 854, max distortion: 2.877639
# Iter 5, Param replaced: 909, max distortion: 2.877639
# Iter 6, Param replaced: 864, max distortion: 2.877639
# Iter 7, Param replaced: 698, max distortion: 2.877639
# Iter 8, Param replaced: 665, max distortion: 2.877639
# Iter 9, Param replaced: 780, max distortion: 2.877639
# Iter 10, Param replaced: 824, max distortion: 2.307866
# Iter 11, Param replaced: 414, max distortion: 2.307866
# Iter 12, Param replaced: 234, max distortion: 2.307866
# Iter 13, Param replaced: 138, max distortion: 2.307866
# Iter 14, Param replaced: 96, max distortion: 2.307866
# Iter 15, Param replaced: 36, max distortion: 2.307866
# Iter 16, Param replaced: 8, max distortion: 2.307866
# Iter 17, Param replaced: 6, max distortion: 2.307866
# Iter 18, Param replaced: 2, max distortion: 2.307866
# Iter 19, Param replaced: 4, max distortion: 2.307866
# Iter 20, Param replaced: 2, max distortion: 2.307866
# Iter 21, Param replaced: 0, max distortion: 2.307866
# Done.
# ##############################
# Time elapsed from last time log: 34.1 seconds
# Total time elapsed: 38.1 seconds
# ##############################
# Max local distortion = 2.3078656130790964
# Constructing intermediate views.
# eta = 2.
# # non-empty views with sz < 2 = 10000
# #nodes in views with sz < 2 = 10000
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 10.4 seconds
# Total time elapsed: 10.4 seconds
# ##############################
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 124.8 seconds
# Total time elapsed: 135.2 seconds
# ##############################
# eta = 3.
# # non-empty views with sz < 3 = 232
# #nodes in views with sz < 3 = 464
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 135.7 seconds
# ##############################
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 2.4 seconds
# Total time elapsed: 138.1 seconds
# ##############################
# eta = 4.
# # non-empty views with sz < 4 = 246
# #nodes in views with sz < 4 = 738
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 0.7 seconds
# Total time elapsed: 138.7 seconds
# ##############################
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 6.2 seconds
# Total time elapsed: 145.0 seconds
# ##############################
# eta = 5.
# # non-empty views with sz < 5 = 194
# #nodes in views with sz < 5 = 776
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 0.7 seconds
# Total time elapsed: 145.6 seconds
# ##############################
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 6.9 seconds
# Total time elapsed: 152.5 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 0.7 seconds
# Total time elapsed: 153.3 seconds
# ##############################
# After clustering, max distortion is 1.780022
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 278 intermediate views
# Ambiguous overlaps checked for 556 intermediate views
# Ambiguous overlaps checked for 834 intermediate views
# Ambiguous overlaps checked for 1112 intermediate views
# Ambiguous overlaps checked for 1113 points
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 1
# Computing initial embedding using: sequential algorithm
# ##############################
# Time elapsed from last time log: 7.2 seconds
# Total time elapsed: 7.2 seconds
# ##############################
# Initial alignment of 278 views completed
# Initial alignment of 556 views completed
# Initial alignment of 834 views completed
# Initial alignment of 1112 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 0.4 seconds
# Total time elapsed: 7.6 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 24.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11113
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 27.8 seconds
# Total time elapsed: 51.8 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 60.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11113
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 28.8 seconds
# Total time elapsed: 89.0 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 97.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11113
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 32.9 seconds
# Total time elapsed: 130.8 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 140.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11113
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 32.8 seconds
# Total time elapsed: 173.4 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 182.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11113
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 33.6 seconds
# Total time elapsed: 216.0 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 5
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 225.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11113
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 32.9 seconds
# Total time elapsed: 258.1 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 6
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 267.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11113
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 33.1 seconds
# Total time elapsed: 300.3 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 7
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 309.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11113
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 32.8 seconds
# Total time elapsed: 342.4 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 8
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 351.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11113
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 33.1 seconds
# Total time elapsed: 384.4 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 9
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 393.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11113
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 33.5 seconds
# Total time elapsed: 426.8 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 10
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 435.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11113
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 34.3 seconds
# Total time elapsed: 469.8 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 11
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 478.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11113
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 31.5 seconds
# Total time elapsed: 510.1 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 11113
# Alignment error: 37.018
# ##############################
# Time elapsed from last time log: 3.9 seconds
# Total time elapsed: 514.0 seconds
# ##############################
# array([[ 0.29283952, -0.04900024],
#        [ 0.28310246, -0.04891211],
#        [ 0.29427983, -0.03978465],
#        ...,
#        [-0.31732817,  0.05751733],
#        [-0.33165493,  0.05578867],
#        [-0.32347673,  0.05050329]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/sphere//ldle.dat
