# %% [markdown]
# ### Flat Torus

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
save_dir_root = '../data/pyLDLE2/flattorus4d/'

# %%
X, labelsMat, ddX = datasets.Datasets().flattorus4d()
# Out:
# X.shape =  (10000, 4)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LDLE'},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  intermed_opts={'eta_min': 15},
                  global_opts={
                      'max_iter': 5,
                      'init_algo_align_w_parent_only': True # Set this True for low noise
                  },
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 875 is created.

# %%
ldle.fit(X=X)
# Out:
# Constructing unnorm graph Laplacian + its eigendecomposition.
# Done.
# ##############################
# Time elapsed from last time log: 2.3 seconds
# Total time elapsed: 2.3 seconds
# ##############################
# Computing Atilde: Inner Prod of Grad of EigFuncs.
# FEM for Atilde.
# Atilde: 0 points processed...
# Atilde: 2500 points processed...
# Atilde: 5000 points processed...
# Atilde: 7500 points processed...
# Atilde: all points processed...
# Done.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 3.1 seconds
# ##############################
# Computing LDLE.
# local_param: all 10000 points processed...
# max distortion is 39.874271
# Done.
# ##############################
# Time elapsed from last time log: 1.2 seconds
# Total time elapsed: 4.3 seconds
# ##############################
# Posprocessing local parameterizations.
# #Param replaced: 8782, max distortion: 2.075803
# #Param replaced: 701, max distortion: 1.990375
# #Param replaced: 3, max distortion: 1.990375
# #Param replaced: 0, max distortion: 1.990375
# Max local distortion after postprocessing: 1.99037541071448
# Done.
# ##############################
# Time elapsed from last time log: 7.6 seconds
# Total time elapsed: 11.9 seconds
# ##############################
# Max local distortion = 1.99037541071448
# Constructing intermediate views.
# eta = 2.
# # non-empty views with sz < 2 = 10000
# #nodes in views with sz < 2 = 10000
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 19.2 seconds
# Total time elapsed: 19.3 seconds
# ##############################
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 226.7 seconds
# Total time elapsed: 246.0 seconds
# ##############################
# eta = 3.
# # non-empty views with sz < 3 = 471
# #nodes in views with sz < 3 = 942
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 1.2 seconds
# Total time elapsed: 247.1 seconds
# ##############################
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 9.6 seconds
# Total time elapsed: 256.7 seconds
# ##############################
# eta = 4.
# # non-empty views with sz < 4 = 345
# #nodes in views with sz < 4 = 1035
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 1.2 seconds
# Total time elapsed: 257.9 seconds
# ##############################
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 18.7 seconds
# Total time elapsed: 276.6 seconds
# ##############################
# eta = 5.
# # non-empty views with sz < 5 = 234
# #nodes in views with sz < 5 = 936
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 1.0 seconds
# Total time elapsed: 277.7 seconds
# ##############################
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 18.2 seconds
# Total time elapsed: 295.9 seconds
# ##############################
# eta = 6.
# # non-empty views with sz < 6 = 173
# #nodes in views with sz < 6 = 865
# Costs computed when eta = 6.
# ##############################
# Time elapsed from last time log: 1.1 seconds
# Total time elapsed: 297.1 seconds
# ##############################
# Remaining #nodes in views with sz < 6 = 0
# Done with eta = 6.
# ##############################
# Time elapsed from last time log: 17.3 seconds
# Total time elapsed: 314.3 seconds
# ##############################
# eta = 7.
# # non-empty views with sz < 7 = 133
# #nodes in views with sz < 7 = 798
# Costs computed when eta = 7.
# ##############################
# Time elapsed from last time log: 1.0 seconds
# Total time elapsed: 315.3 seconds
# ##############################
# Remaining #nodes in views with sz < 7 = 0
# Done with eta = 7.
# ##############################
# Time elapsed from last time log: 16.1 seconds
# Total time elapsed: 331.5 seconds
# ##############################
# eta = 8.
# # non-empty views with sz < 8 = 114
# #nodes in views with sz < 8 = 798
# Costs computed when eta = 8.
# ##############################
# Time elapsed from last time log: 1.0 seconds
# Total time elapsed: 332.4 seconds
# ##############################
# Remaining #nodes in views with sz < 8 = 0
# Done with eta = 8.
# ##############################
# Time elapsed from last time log: 19.9 seconds
# Total time elapsed: 352.3 seconds
# ##############################
# eta = 9.
# # non-empty views with sz < 9 = 60
# #nodes in views with sz < 9 = 480
# Costs computed when eta = 9.
# ##############################
# Time elapsed from last time log: 0.7 seconds
# Total time elapsed: 353.0 seconds
# ##############################
# Remaining #nodes in views with sz < 9 = 0
# Done with eta = 9.
# ##############################
# Time elapsed from last time log: 12.6 seconds
# Total time elapsed: 365.6 seconds
# ##############################
# eta = 10.
# # non-empty views with sz < 10 = 58
# #nodes in views with sz < 10 = 522
# Costs computed when eta = 10.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 366.4 seconds
# ##############################
# Remaining #nodes in views with sz < 10 = 0
# Done with eta = 10.
# ##############################
# Time elapsed from last time log: 12.8 seconds
# Total time elapsed: 379.3 seconds
# ##############################
# eta = 11.
# # non-empty views with sz < 11 = 44
# #nodes in views with sz < 11 = 440
# Costs computed when eta = 11.
# ##############################
# Time elapsed from last time log: 0.6 seconds
# Total time elapsed: 379.8 seconds
# ##############################
# Remaining #nodes in views with sz < 11 = 0
# Done with eta = 11.
# ##############################
# Time elapsed from last time log: 12.0 seconds
# Total time elapsed: 391.8 seconds
# ##############################
# eta = 12.
# # non-empty views with sz < 12 = 29
# #nodes in views with sz < 12 = 319
# Costs computed when eta = 12.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 392.3 seconds
# ##############################
# Remaining #nodes in views with sz < 12 = 0
# Done with eta = 12.
# ##############################
# Time elapsed from last time log: 8.2 seconds
# Total time elapsed: 400.5 seconds
# ##############################
# eta = 13.
# # non-empty views with sz < 13 = 32
# #nodes in views with sz < 13 = 384
# Costs computed when eta = 13.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 401.0 seconds
# ##############################
# Remaining #nodes in views with sz < 13 = 0
# Done with eta = 13.
# ##############################
# Time elapsed from last time log: 8.1 seconds
# Total time elapsed: 409.1 seconds
# ##############################
# eta = 14.
# # non-empty views with sz < 14 = 19
# #nodes in views with sz < 14 = 247
# Costs computed when eta = 14.
# ##############################
# Time elapsed from last time log: 0.3 seconds
# Total time elapsed: 409.4 seconds
# ##############################
# Remaining #nodes in views with sz < 14 = 9
# Done with eta = 14.
# ##############################
# Time elapsed from last time log: 4.6 seconds
# Total time elapsed: 414.0 seconds
# ##############################
# eta = 15.
# # non-empty views with sz < 15 = 30
# #nodes in views with sz < 15 = 359
# Costs computed when eta = 15.
# ##############################
# Time elapsed from last time log: 0.4 seconds
# Total time elapsed: 414.5 seconds
# ##############################
# Remaining #nodes in views with sz < 15 = 21
# Done with eta = 15.
# ##############################
# Time elapsed from last time log: 6.2 seconds
# Total time elapsed: 420.7 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 0.4 seconds
# Total time elapsed: 421.1 seconds
# ##############################
# After clustering, max distortion is 1416.615371
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 114 intermediate views
# Ambiguous overlaps checked for 228 intermediate views
# Ambiguous overlaps checked for 342 intermediate views
# Ambiguous overlaps checked for 456 intermediate views
# Ambiguous overlaps checked for 459 points
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 1
# Computing initial embedding using: sequential algorithm
# ##############################
# Time elapsed from last time log: 2.0 seconds
# Total time elapsed: 2.0 seconds
# ##############################
# Initial alignment of 114 views completed
# Initial alignment of 228 views completed
# Initial alignment of 342 views completed
# Initial alignment of 456 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 0.4 seconds
# Total time elapsed: 2.4 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 4.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10459 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.7 seconds
# Total time elapsed: 5.9 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 7.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10459 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.6 seconds
# Total time elapsed: 9.2 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 10.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10459 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.6 seconds
# Total time elapsed: 12.5 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 14.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10459 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.6 seconds
# Total time elapsed: 15.8 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 17.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10459 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.6 seconds
# Total time elapsed: 19.1 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 10459 multiplied with B
# Alignment error: 98.601
# ##############################
# Time elapsed from last time log: 0.7 seconds
# Total time elapsed: 19.8 seconds
# ##############################
# array([[0.4441196 , 0.59217436],
#        [0.43312077, 0.59405257],
#        [0.42319957, 0.59364391],
#        ...,
#        [0.47395991, 0.59578977],
#        [0.46372456, 0.59584319],
#        [0.45426804, 0.60048171]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/flattorus4d//ldle.dat
