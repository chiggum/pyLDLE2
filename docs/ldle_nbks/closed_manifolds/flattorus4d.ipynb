# %% [markdown]
# ### Flat Torus

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
save_dir_root = '../data/pyLDLE2/flattorus4d/'

# %%
X, labelsMat, ddX = datasets.Datasets().flattorus4d()
# Out:
# X.shape =  (10000, 4)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LDLE'},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  intermed_opts={'eta_min': 10},
                  global_opts={
                      'max_iter': 5,
                      'init_algo_align_w_parent_only': True # Set this True for low noise
                  },
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 600 is created.

# %%
ldle.fit(X=X)
# Out:
# Constructing unnorm graph Laplacian + its eigendecomposition.
# Done.
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 2.2 seconds
# ##############################
# Computing Atilde: Inner Prod of Grad of EigFuncs.
# FEM for Atilde.
# Atilde: 0 points processed...
# Atilde: 2500 points processed...
# Atilde: 5000 points processed...
# Atilde: 7500 points processed...
# Atilde: all points processed...
# Done.
# ##############################
# Time elapsed from last time log: 0.7 seconds
# Total time elapsed: 2.9 seconds
# ##############################
# Computing LDLE.
# local_param: all 10000 points processed...
# max distortion is 1194.742657
# Done.
# ##############################
# Time elapsed from last time log: 1.1 seconds
# Total time elapsed: 4.1 seconds
# ##############################
# Posprocessing LDLE.
# Iter 1, Param replaced: 8809, max distortion: 3.286889
# Iter 2, Param replaced: 2503, max distortion: 2.622908
# Iter 3, Param replaced: 104, max distortion: 2.622908
# Iter 4, Param replaced: 0, max distortion: 2.622908
# Done.
# ##############################
# Time elapsed from last time log: 8.1 seconds
# Total time elapsed: 12.2 seconds
# ##############################
# Max local distortion = 2.622907940445103
# Constructing intermediate views.
# eta = 2.
# # non-empty views with sz < 2 = 10000
# #nodes in views with sz < 2 = 10000
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 11.9 seconds
# Total time elapsed: 12.0 seconds
# ##############################
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 140.2 seconds
# Total time elapsed: 152.2 seconds
# ##############################
# eta = 3.
# # non-empty views with sz < 3 = 251
# #nodes in views with sz < 3 = 502
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 0.4 seconds
# Total time elapsed: 152.6 seconds
# ##############################
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 1.8 seconds
# Total time elapsed: 154.4 seconds
# ##############################
# eta = 4.
# # non-empty views with sz < 4 = 228
# #nodes in views with sz < 4 = 684
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 154.9 seconds
# ##############################
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 4.3 seconds
# Total time elapsed: 159.2 seconds
# ##############################
# eta = 5.
# # non-empty views with sz < 5 = 196
# #nodes in views with sz < 5 = 784
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 159.8 seconds
# ##############################
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 6.2 seconds
# Total time elapsed: 165.9 seconds
# ##############################
# eta = 6.
# # non-empty views with sz < 6 = 151
# #nodes in views with sz < 6 = 755
# Costs computed when eta = 6.
# ##############################
# Time elapsed from last time log: 0.6 seconds
# Total time elapsed: 166.5 seconds
# ##############################
# Remaining #nodes in views with sz < 6 = 0
# Done with eta = 6.
# ##############################
# Time elapsed from last time log: 6.3 seconds
# Total time elapsed: 172.8 seconds
# ##############################
# eta = 7.
# # non-empty views with sz < 7 = 122
# #nodes in views with sz < 7 = 732
# Costs computed when eta = 7.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 173.3 seconds
# ##############################
# Remaining #nodes in views with sz < 7 = 0
# Done with eta = 7.
# ##############################
# Time elapsed from last time log: 7.3 seconds
# Total time elapsed: 180.6 seconds
# ##############################
# eta = 8.
# # non-empty views with sz < 8 = 79
# #nodes in views with sz < 8 = 553
# Costs computed when eta = 8.
# ##############################
# Time elapsed from last time log: 0.4 seconds
# Total time elapsed: 180.9 seconds
# ##############################
# Remaining #nodes in views with sz < 8 = 0
# Done with eta = 8.
# ##############################
# Time elapsed from last time log: 5.5 seconds
# Total time elapsed: 186.5 seconds
# ##############################
# eta = 9.
# # non-empty views with sz < 9 = 74
# #nodes in views with sz < 9 = 592
# Costs computed when eta = 9.
# ##############################
# Time elapsed from last time log: 0.4 seconds
# Total time elapsed: 186.8 seconds
# ##############################
# Remaining #nodes in views with sz < 9 = 0
# Done with eta = 9.
# ##############################
# Time elapsed from last time log: 6.3 seconds
# Total time elapsed: 193.1 seconds
# ##############################
# eta = 10.
# # non-empty views with sz < 10 = 62
# #nodes in views with sz < 10 = 558
# Costs computed when eta = 10.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 193.6 seconds
# ##############################
# Remaining #nodes in views with sz < 10 = 0
# Done with eta = 10.
# ##############################
# Time elapsed from last time log: 6.1 seconds
# Total time elapsed: 199.7 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 0.4 seconds
# Total time elapsed: 200.1 seconds
# ##############################
# After clustering, max distortion is 3.151002
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 152 intermediate views
# Ambiguous overlaps checked for 304 intermediate views
# Ambiguous overlaps checked for 456 intermediate views
# Ambiguous overlaps checked for 608 intermediate views
# Ambiguous overlaps checked for 609 points
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 1
# Computing initial embedding using: sequential algorithm
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 2.2 seconds
# ##############################
# Initial alignment of 152 views completed
# Initial alignment of 304 views completed
# Initial alignment of 456 views completed
# Initial alignment of 608 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 0.2 seconds
# Total time elapsed: 2.4 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 9.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10609
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 24.3 seconds
# Total time elapsed: 34.0 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 37.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10609
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 25.5 seconds
# Total time elapsed: 63.3 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 67.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10609
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 26.8 seconds
# Total time elapsed: 94.0 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 97.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10609
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 26.5 seconds
# Total time elapsed: 124.4 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 128.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10609
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 26.2 seconds
# Total time elapsed: 154.5 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 10609
# Alignment error: 54.304
# ##############################
# Time elapsed from last time log: 2.8 seconds
# Total time elapsed: 157.3 seconds
# ##############################
# array([[0.4358773 , 0.2014287 ],
#        [0.43653162, 0.19373851],
#        [0.43715756, 0.18419143],
#        ...,
#        [0.44502583, 0.23221644],
#        [0.44572828, 0.22146799],
#        [0.44511388, 0.2120968 ]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/flattorus4d//ldle.dat
