# %% [markdown]
# ### Curved Torus

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
save_dir_root = '../data/pyLDLE2/curvedtorus3d/'

# %%
X, labelsMat, ddX = datasets.Datasets().curvedtorus3d()
# Out:
# X.shape =  (10000, 3)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LDLE'},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  intermed_opts={'eta_min': 10},
                  global_opts={
                      'max_iter': 10,
                      'init_algo_align_w_parent_only': True # Set this True for low noise
                  },
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 600 is created.

# %%
ldle.fit(X=X)
# Out:
# Constructing unnorm graph Laplacian + its eigendecomposition.
# Done.
# ##############################
# Time elapsed from last time log: 2.6 seconds
# Total time elapsed: 2.6 seconds
# ##############################
# Computing Atilde: Inner Prod of Grad of EigFuncs.
# FEM for Atilde.
# Atilde: 0 points processed...
# Atilde: 2500 points processed...
# Atilde: 5000 points processed...
# Atilde: 7500 points processed...
# Atilde: all points processed...
# Done.
# ##############################
# Time elapsed from last time log: 0.9 seconds
# Total time elapsed: 3.4 seconds
# ##############################
# Computing LDLE.
# local_param: all 10000 points processed...
# max distortion is 2185.760967
# Done.
# ##############################
# Time elapsed from last time log: 1.3 seconds
# Total time elapsed: 4.8 seconds
# ##############################
# Posprocessing LDLE.
# Iter 1, Param replaced: 9411, max distortion: 28.084400
# Iter 2, Param replaced: 3577, max distortion: 26.558506
# Iter 3, Param replaced: 983, max distortion: 26.558506
# Iter 4, Param replaced: 235, max distortion: 26.558506
# Iter 5, Param replaced: 32, max distortion: 26.558506
# Iter 6, Param replaced: 12, max distortion: 26.558506
# Iter 7, Param replaced: 5, max distortion: 22.887191
# Iter 8, Param replaced: 5, max distortion: 22.887191
# Iter 9, Param replaced: 0, max distortion: 22.887191
# Done.
# ##############################
# Time elapsed from last time log: 20.9 seconds
# Total time elapsed: 25.7 seconds
# ##############################
# Max local distortion = 22.887190578652888
# Constructing intermediate views.
# eta = 2.
# # non-empty views with sz < 2 = 10000
# #nodes in views with sz < 2 = 10000
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 11.3 seconds
# Total time elapsed: 11.4 seconds
# ##############################
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 129.9 seconds
# Total time elapsed: 141.3 seconds
# ##############################
# eta = 3.
# # non-empty views with sz < 3 = 387
# #nodes in views with sz < 3 = 774
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 0.6 seconds
# Total time elapsed: 141.9 seconds
# ##############################
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 2.9 seconds
# Total time elapsed: 144.8 seconds
# ##############################
# eta = 4.
# # non-empty views with sz < 4 = 306
# #nodes in views with sz < 4 = 918
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 0.6 seconds
# Total time elapsed: 145.4 seconds
# ##############################
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 5.8 seconds
# Total time elapsed: 151.2 seconds
# ##############################
# eta = 5.
# # non-empty views with sz < 5 = 230
# #nodes in views with sz < 5 = 920
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 0.6 seconds
# Total time elapsed: 151.8 seconds
# ##############################
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 7.6 seconds
# Total time elapsed: 159.4 seconds
# ##############################
# eta = 6.
# # non-empty views with sz < 6 = 172
# #nodes in views with sz < 6 = 860
# Costs computed when eta = 6.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 159.9 seconds
# ##############################
# Remaining #nodes in views with sz < 6 = 0
# Done with eta = 6.
# ##############################
# Time elapsed from last time log: 8.3 seconds
# Total time elapsed: 168.2 seconds
# ##############################
# eta = 7.
# # non-empty views with sz < 7 = 110
# #nodes in views with sz < 7 = 660
# Costs computed when eta = 7.
# ##############################
# Time elapsed from last time log: 0.4 seconds
# Total time elapsed: 168.6 seconds
# ##############################
# Remaining #nodes in views with sz < 7 = 0
# Done with eta = 7.
# ##############################
# Time elapsed from last time log: 6.4 seconds
# Total time elapsed: 175.0 seconds
# ##############################
# eta = 8.
# # non-empty views with sz < 8 = 133
# #nodes in views with sz < 8 = 931
# Costs computed when eta = 8.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 175.5 seconds
# ##############################
# Remaining #nodes in views with sz < 8 = 0
# Done with eta = 8.
# ##############################
# Time elapsed from last time log: 11.8 seconds
# Total time elapsed: 187.3 seconds
# ##############################
# eta = 9.
# # non-empty views with sz < 9 = 81
# #nodes in views with sz < 9 = 648
# Costs computed when eta = 9.
# ##############################
# Time elapsed from last time log: 0.4 seconds
# Total time elapsed: 187.7 seconds
# ##############################
# Remaining #nodes in views with sz < 9 = 0
# Done with eta = 9.
# ##############################
# Time elapsed from last time log: 8.1 seconds
# Total time elapsed: 195.9 seconds
# ##############################
# eta = 10.
# # non-empty views with sz < 10 = 81
# #nodes in views with sz < 10 = 729
# Costs computed when eta = 10.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 196.4 seconds
# ##############################
# Remaining #nodes in views with sz < 10 = 0
# Done with eta = 10.
# ##############################
# Time elapsed from last time log: 12.0 seconds
# Total time elapsed: 208.3 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 208.8 seconds
# ##############################
# After clustering, max distortion is 22.527986
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 158 intermediate views
# Ambiguous overlaps checked for 316 intermediate views
# Ambiguous overlaps checked for 474 intermediate views
# Ambiguous overlaps checked for 632 points
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 1
# Computing initial embedding using: sequential algorithm
# ##############################
# Time elapsed from last time log: 2.6 seconds
# Total time elapsed: 2.6 seconds
# ##############################
# Initial alignment of 158 views completed
# Initial alignment of 316 views completed
# Initial alignment of 474 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 0.2 seconds
# Total time elapsed: 2.8 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 12.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10632
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 27.5 seconds
# Total time elapsed: 39.6 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 44.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10632
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 29.2 seconds
# Total time elapsed: 73.6 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 78.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10632
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 29.1 seconds
# Total time elapsed: 107.5 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 112.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10632
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 29.4 seconds
# Total time elapsed: 141.6 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 146.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10632
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 29.2 seconds
# Total time elapsed: 175.6 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 5
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 180.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10632
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 29.4 seconds
# Total time elapsed: 209.8 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 6
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 214.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10632
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 29.1 seconds
# Total time elapsed: 243.5 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 7
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 248.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10632
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 29.3 seconds
# Total time elapsed: 277.5 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 8
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 282.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10632
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 29.6 seconds
# Total time elapsed: 311.9 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 9
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 316.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10632
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 29.3 seconds
# Total time elapsed: 345.9 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 10632
# Alignment error: 43.423
# ##############################
# Time elapsed from last time log: 2.8 seconds
# Total time elapsed: 348.8 seconds
# ##############################
# array([[-0.55881269,  0.15247572],
#        [-0.11624044, -0.11585968],
#        [-0.18647654,  0.48155077],
#        ...,
#        [-0.46262467, -0.12894847],
#        [ 0.26404845, -0.24967435],
#        [-0.06079223, -0.10081476]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/curvedtorus3d//ldle.dat
