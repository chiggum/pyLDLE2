# %% [markdown]
# ### Curved Torus

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
save_dir_root = '../data/pyLDLE2/curvedtorus3d/'

# %%
X, labelsMat, ddX = datasets.Datasets().curvedtorus3d()
# Out:
# X.shape =  (10000, 3)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LDLE'},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  intermed_opts={'eta_min': 15},
                  global_opts={
                      'max_iter': 10,
                      'init_algo_align_w_parent_only': True # Set this True for low noise
                  },
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 875 is created.

# %%
ldle.fit(X=X)
# Out:
# Constructing unnorm graph Laplacian + its eigendecomposition.
# Done.
# ##############################
# Time elapsed from last time log: 2.6 seconds
# Total time elapsed: 2.6 seconds
# ##############################
# Computing Atilde: Inner Prod of Grad of EigFuncs.
# FEM for Atilde.
# Atilde: 0 points processed...
# Atilde: 2500 points processed...
# Atilde: 5000 points processed...
# Atilde: 7500 points processed...
# Atilde: all points processed...
# Done.
# ##############################
# Time elapsed from last time log: 0.9 seconds
# Total time elapsed: 3.5 seconds
# ##############################
# Computing LDLE.
# local_param: all 10000 points processed...
# max distortion is 436.597472
# Done.
# ##############################
# Time elapsed from last time log: 1.2 seconds
# Total time elapsed: 4.8 seconds
# ##############################
# Posprocessing local parameterizations.
# #Param replaced: 9475, max distortion: 26.440858
# #Param replaced: 2389, max distortion: 25.733252
# #Param replaced: 497, max distortion: 23.369867
# #Param replaced: 82, max distortion: 23.369867
# #Param replaced: 16, max distortion: 23.369867
# #Param replaced: 1, max distortion: 23.369867
# #Param replaced: 0, max distortion: 23.369867
# Max local distortion after postprocessing: 23.369866827234926
# Done.
# ##############################
# Time elapsed from last time log: 9.0 seconds
# Total time elapsed: 13.8 seconds
# ##############################
# Max local distortion = 23.369866827234926
# Constructing intermediate views.
# eta = 2.
# # non-empty views with sz < 2 = 10000
# #nodes in views with sz < 2 = 10000
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 21.0 seconds
# Total time elapsed: 21.1 seconds
# ##############################
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 159.5 seconds
# Total time elapsed: 180.6 seconds
# ##############################
# eta = 3.
# # non-empty views with sz < 3 = 835
# #nodes in views with sz < 3 = 1670
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 2.1 seconds
# Total time elapsed: 182.7 seconds
# ##############################
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 23.1 seconds
# Total time elapsed: 205.7 seconds
# ##############################
# eta = 4.
# # non-empty views with sz < 4 = 514
# #nodes in views with sz < 4 = 1542
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 1.7 seconds
# Total time elapsed: 207.4 seconds
# ##############################
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 31.9 seconds
# Total time elapsed: 239.4 seconds
# ##############################
# eta = 5.
# # non-empty views with sz < 5 = 290
# #nodes in views with sz < 5 = 1160
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 1.3 seconds
# Total time elapsed: 240.7 seconds
# ##############################
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 24.7 seconds
# Total time elapsed: 265.4 seconds
# ##############################
# eta = 6.
# # non-empty views with sz < 6 = 250
# #nodes in views with sz < 6 = 1250
# Costs computed when eta = 6.
# ##############################
# Time elapsed from last time log: 1.3 seconds
# Total time elapsed: 266.7 seconds
# ##############################
# Remaining #nodes in views with sz < 6 = 0
# Done with eta = 6.
# ##############################
# Time elapsed from last time log: 37.4 seconds
# Total time elapsed: 304.1 seconds
# ##############################
# eta = 7.
# # non-empty views with sz < 7 = 171
# #nodes in views with sz < 7 = 1026
# Costs computed when eta = 7.
# ##############################
# Time elapsed from last time log: 1.1 seconds
# Total time elapsed: 305.2 seconds
# ##############################
# Remaining #nodes in views with sz < 7 = 0
# Done with eta = 7.
# ##############################
# Time elapsed from last time log: 29.3 seconds
# Total time elapsed: 334.5 seconds
# ##############################
# eta = 8.
# # non-empty views with sz < 8 = 126
# #nodes in views with sz < 8 = 882
# Costs computed when eta = 8.
# ##############################
# Time elapsed from last time log: 1.0 seconds
# Total time elapsed: 335.5 seconds
# ##############################
# Remaining #nodes in views with sz < 8 = 0
# Done with eta = 8.
# ##############################
# Time elapsed from last time log: 26.1 seconds
# Total time elapsed: 361.7 seconds
# ##############################
# eta = 9.
# # non-empty views with sz < 9 = 88
# #nodes in views with sz < 9 = 704
# Costs computed when eta = 9.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 362.5 seconds
# ##############################
# Remaining #nodes in views with sz < 9 = 0
# Done with eta = 9.
# ##############################
# Time elapsed from last time log: 19.9 seconds
# Total time elapsed: 382.4 seconds
# ##############################
# eta = 10.
# # non-empty views with sz < 10 = 73
# #nodes in views with sz < 10 = 657
# Costs computed when eta = 10.
# ##############################
# Time elapsed from last time log: 0.7 seconds
# Total time elapsed: 383.2 seconds
# ##############################
# Remaining #nodes in views with sz < 10 = 0
# Done with eta = 10.
# ##############################
# Time elapsed from last time log: 20.1 seconds
# Total time elapsed: 403.2 seconds
# ##############################
# eta = 11.
# # non-empty views with sz < 11 = 53
# #nodes in views with sz < 11 = 530
# Costs computed when eta = 11.
# ##############################
# Time elapsed from last time log: 0.7 seconds
# Total time elapsed: 403.9 seconds
# ##############################
# Remaining #nodes in views with sz < 11 = 6
# Done with eta = 11.
# ##############################
# Time elapsed from last time log: 18.1 seconds
# Total time elapsed: 422.0 seconds
# ##############################
# eta = 12.
# # non-empty views with sz < 12 = 52
# #nodes in views with sz < 12 = 567
# Costs computed when eta = 12.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 422.6 seconds
# ##############################
# Remaining #nodes in views with sz < 12 = 6
# Done with eta = 12.
# ##############################
# Time elapsed from last time log: 13.4 seconds
# Total time elapsed: 435.9 seconds
# ##############################
# eta = 13.
# # non-empty views with sz < 13 = 44
# #nodes in views with sz < 13 = 522
# Costs computed when eta = 13.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 436.5 seconds
# ##############################
# Remaining #nodes in views with sz < 13 = 6
# Done with eta = 13.
# ##############################
# Time elapsed from last time log: 14.9 seconds
# Total time elapsed: 451.4 seconds
# ##############################
# eta = 14.
# # non-empty views with sz < 14 = 33
# #nodes in views with sz < 14 = 422
# Costs computed when eta = 14.
# ##############################
# Time elapsed from last time log: 0.4 seconds
# Total time elapsed: 451.8 seconds
# ##############################
# Remaining #nodes in views with sz < 14 = 21
# Done with eta = 14.
# ##############################
# Time elapsed from last time log: 10.9 seconds
# Total time elapsed: 462.7 seconds
# ##############################
# eta = 15.
# # non-empty views with sz < 15 = 24
# #nodes in views with sz < 15 = 287
# Costs computed when eta = 15.
# ##############################
# Time elapsed from last time log: 0.3 seconds
# Total time elapsed: 463.1 seconds
# ##############################
# Remaining #nodes in views with sz < 15 = 23
# Done with eta = 15.
# ##############################
# Time elapsed from last time log: 5.6 seconds
# Total time elapsed: 468.7 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 469.3 seconds
# ##############################
# After clustering, max distortion is 1295.180222
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 112 intermediate views
# Ambiguous overlaps checked for 224 intermediate views
# Ambiguous overlaps checked for 336 intermediate views
# Ambiguous overlaps checked for 448 points
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 1
# Computing initial embedding using: sequential algorithm
# ##############################
# Time elapsed from last time log: 2.0 seconds
# Total time elapsed: 2.0 seconds
# ##############################
# Initial alignment of 112 views completed
# Initial alignment of 224 views completed
# Initial alignment of 336 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 0.4 seconds
# Total time elapsed: 2.4 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 4.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10448 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.0 seconds
# Total time elapsed: 6.3 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 7.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10448 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.1 seconds
# Total time elapsed: 9.8 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 11.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10448 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.0 seconds
# Total time elapsed: 13.1 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 14.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10448 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.0 seconds
# Total time elapsed: 16.5 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 17.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10448 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.0 seconds
# Total time elapsed: 19.8 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 5
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 21.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10448 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.0 seconds
# Total time elapsed: 23.0 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 6
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 24.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10448 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.0 seconds
# Total time elapsed: 26.3 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 7
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 27.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10448 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.9 seconds
# Total time elapsed: 29.5 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 8
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 30.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10448 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.9 seconds
# Total time elapsed: 32.7 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 9
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 34.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10448 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.9 seconds
# Total time elapsed: 36.0 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 10448 multiplied with B
# Alignment error: 85.577
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 36.8 seconds
# ##############################
# array([[ 0.23065465, -0.00499743],
#        [-0.16005411,  0.2662353 ],
#        [ 0.35717107,  0.08732575],
#        ...,
#        [-0.12755679, -0.01966095],
#        [-0.41213606, -0.05758172],
#        [-0.1609931 ,  0.20625455]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/curvedtorus3d//ldle.dat
