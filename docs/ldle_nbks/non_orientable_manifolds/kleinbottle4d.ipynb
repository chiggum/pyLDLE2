# %% [markdown]
# ### Klein Bottle

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
save_dir_root = '../data/pyLDLE2/kleinbottle4d/'

# %%
X, labelsMat, ddX = datasets.Datasets().kleinbottle4d()
# Out:
# X.shape =  (10000, 4)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LDLE'},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 700 is created.
# Options provided:
# local_opts:
# {
#     "Atilde_method": "LDLE_1",
#     "N": 100,
#     "algo": "LDLE",
#     "delta": 0.9,
#     "gl_type": "unnorm",
#     "k": 28,
#     "k_nn": 49,
#     "k_nn0": 700,
#     "k_tune": 7,
#     "n_proc": 32,
#     "no_gamma": false,
#     "p": 0.99,
#     "pp_n_thresh": 32,
#     "tau": 50,
#     "to_postprocess": true
# }
# intermed_opts:
# {
#     "algo": "best",
#     "eta_max": 25,
#     "eta_min": 5,
#     "len_S_thresh": 256,
#     "local_algo": "LDLE",
#     "n_proc": 32,
#     "n_times": 4
# }
# global_opts:
# {
#     "color_tear": true,
#     "compute_error": false,
#     "init_algo_align_w_parent_only": true,
#     "init_algo_name": "procrustes",
#     "k": 28,
#     "main_algo": "LDLE",
#     "max_iter": 20,
#     "n_proc": 32,
#     "nu": 3,
#     "refine_algo_alpha": 0.3,
#     "refine_algo_max_internal_iter": 100,
#     "refine_algo_name": "rgd",
#     "to_tear": true,
#     "vis_before_init": false
# }

# %%
ldle.fit(X=X)
# Out:
# Constructing unnorm graph Laplacian + its eigendecomposition.
# Done.
# ##############################
# Time elapsed from last time log: 15.0 seconds
# Total time elapsed: 15.0 seconds
# ##############################
# Computing Atilde: Inner Prod of Grad of EigFuncs.
# FEM for Atilde.
# Atilde: 0 points processed...
# Atilde: 2500 points processed...
# Atilde: 5000 points processed...
# Atilde: 7500 points processed...
# Atilde: all points processed...
# Done.
# ##############################
# Time elapsed from last time log: 12.5 seconds
# Total time elapsed: 27.6 seconds
# ##############################
# Computing LDLE.
# local_param: all 10000 points processed...
# max distortion is 92050.382795
# Done.
# ##############################
# Time elapsed from last time log: 3.6 seconds
# Total time elapsed: 31.3 seconds
# ##############################
# Posprocessing local parameterizations.
# #Param replaced: 9261, max distortion: 2.740028
# #Param replaced: 3459, max distortion: 2.129033
# #Param replaced: 801, max distortion: 1.995604
# #Param replaced: 24, max distortion: 1.995604
# #Param replaced: 0, max distortion: 1.995604
# Max local distortion after postprocessing: 1.9956039243893615
# Done.
# ##############################
# Time elapsed from last time log: 14.6 seconds
# Total time elapsed: 45.9 seconds
# ##############################
# Max local distortion = 1.9956039243893615
# Constructing intermediate views.
# eta = 2.
# # non-empty views with sz < 2 = 10000
# #nodes in views with sz < 2 = 10000
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 26.8 seconds
# Total time elapsed: 29.5 seconds
# ##############################
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 502.2 seconds
# Total time elapsed: 531.7 seconds
# ##############################
# eta = 3.
# # non-empty views with sz < 3 = 568
# #nodes in views with sz < 3 = 1136
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 4.8 seconds
# Total time elapsed: 536.5 seconds
# ##############################
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 34.3 seconds
# Total time elapsed: 570.8 seconds
# ##############################
# eta = 4.
# # non-empty views with sz < 4 = 451
# #nodes in views with sz < 4 = 1353
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 5.3 seconds
# Total time elapsed: 576.1 seconds
# ##############################
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 61.8 seconds
# Total time elapsed: 637.9 seconds
# ##############################
# eta = 5.
# # non-empty views with sz < 5 = 268
# #nodes in views with sz < 5 = 1072
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 3.6 seconds
# Total time elapsed: 641.4 seconds
# ##############################
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 61.4 seconds
# Total time elapsed: 702.9 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 1.9 seconds
# Total time elapsed: 704.8 seconds
# ##############################
# After clustering, max distortion is 2.420915
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 299 intermediate views
# Ambiguous overlaps checked for 598 intermediate views
# Ambiguous overlaps checked for 897 intermediate views
# Ambiguous overlaps checked for 1196 intermediate views
# Ambiguous overlaps checked for 1197 points
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 1
# Computing initial embedding using: procrustes algorithm
# ##############################
# Time elapsed from last time log: 19.7 seconds
# Total time elapsed: 19.7 seconds
# ##############################
# Initial alignment of 299 views completed
# Initial alignment of 598 views completed
# Initial alignment of 897 views completed
# Initial alignment of 1196 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 2.5 seconds
# Total time elapsed: 22.2 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 44.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11197 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 31.5 seconds
# Total time elapsed: 75.6 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 89.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11197 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 32.5 seconds
# Total time elapsed: 122.2 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 136.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11197 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 27.8 seconds
# Total time elapsed: 163.8 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 178.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11197 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 27.6 seconds
# Total time elapsed: 205.6 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 220.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11197 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 23.9 seconds
# Total time elapsed: 244.0 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 5
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 254.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11197 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 22.3 seconds
# Total time elapsed: 277.1 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 6
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 290.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11197 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 23.8 seconds
# Total time elapsed: 314.1 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 7
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 328.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11197 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 20.1 seconds
# Total time elapsed: 348.7 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 8
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 359.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11197 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 30.7 seconds
# Total time elapsed: 390.1 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 9
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 404.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11197 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 19.9 seconds
# Total time elapsed: 424.0 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 10
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 435.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11197 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 28.9 seconds
# Total time elapsed: 464.9 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 11
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 477.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11197 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 23.2 seconds
# Total time elapsed: 501.0 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 12
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 513.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11197 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 28.5 seconds
# Total time elapsed: 541.8 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 13
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 557.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11197 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 25.2 seconds
# Total time elapsed: 582.3 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 14
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 591.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11197 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 24.4 seconds
# Total time elapsed: 615.7 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 15
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 629.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11197 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 21.5 seconds
# Total time elapsed: 651.0 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 16
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 659.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11197 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 26.0 seconds
# Total time elapsed: 685.2 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 17
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 699.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11197 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 25.2 seconds
# Total time elapsed: 724.5 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 18
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 735.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11197 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 27.8 seconds
# Total time elapsed: 762.7 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 19
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 775.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11197 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 31.1 seconds
# Total time elapsed: 806.3 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 11197 multiplied with B
# Alignment error: 66.425
# ##############################
# Time elapsed from last time log: 12.3 seconds
# Total time elapsed: 818.5 seconds
# ##############################
# array([[ 0.10808582, -0.47006116],
#        [ 0.09977224, -0.47518058],
#        [ 0.0903278 , -0.47895346],
#        ...,
#        [ 0.08800839, -0.49507361],
#        [ 0.09681011, -0.4896042 ],
#        [ 0.10680354, -0.48635248]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/kleinbottle4d//ldle.dat
