# %% [markdown]
# ### Klein Bottle

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
save_dir_root = '../data/pyLDLE2/kleinbottle4d/'

# %%
X, labelsMat, ddX = datasets.Datasets().kleinbottle4d()
# Out:
# X.shape =  (10000, 4)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LDLE'},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  intermed_opts={'eta_min': 10},
                  global_opts={
                      'max_iter': 15,
                      'init_algo_align_w_parent_only': True # Set this True for low noise
                  },
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 875 is created.

# %%
ldle.fit(X=X)
# Out:
# Constructing unnorm graph Laplacian + its eigendecomposition.
# Done.
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 2.2 seconds
# ##############################
# Computing Atilde: Inner Prod of Grad of EigFuncs.
# FEM for Atilde.
# Atilde: 0 points processed...
# Atilde: 2500 points processed...
# Atilde: 5000 points processed...
# Atilde: 7500 points processed...
# Atilde: all points processed...
# Done.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 3.0 seconds
# ##############################
# Computing LDLE.
# local_param: all 10000 points processed...
# max distortion is 278218.131950
# Done.
# ##############################
# Time elapsed from last time log: 1.2 seconds
# Total time elapsed: 4.3 seconds
# ##############################
# Posprocessing local parameterizations.
# #Param replaced: 9263, max distortion: 3.684795
# #Param replaced: 3276, max distortion: 2.305823
# #Param replaced: 316, max distortion: 2.155462
# #Param replaced: 14, max distortion: 2.155462
# #Param replaced: 0, max distortion: 2.155462
# Max local distortion after postprocessing: 2.1554624414163297
# Done.
# ##############################
# Time elapsed from last time log: 9.0 seconds
# Total time elapsed: 13.3 seconds
# ##############################
# Max local distortion = 2.1554624414163297
# Constructing intermediate views.
# eta = 2.
# # non-empty views with sz < 2 = 10000
# #nodes in views with sz < 2 = 10000
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 20.0 seconds
# Total time elapsed: 20.1 seconds
# ##############################
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 256.2 seconds
# Total time elapsed: 276.3 seconds
# ##############################
# eta = 3.
# # non-empty views with sz < 3 = 402
# #nodes in views with sz < 3 = 804
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 1.4 seconds
# Total time elapsed: 277.6 seconds
# ##############################
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 10.2 seconds
# Total time elapsed: 287.8 seconds
# ##############################
# eta = 4.
# # non-empty views with sz < 4 = 357
# #nodes in views with sz < 4 = 1071
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 1.3 seconds
# Total time elapsed: 289.1 seconds
# ##############################
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 21.2 seconds
# Total time elapsed: 310.4 seconds
# ##############################
# eta = 5.
# # non-empty views with sz < 5 = 274
# #nodes in views with sz < 5 = 1096
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 1.5 seconds
# Total time elapsed: 311.9 seconds
# ##############################
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 28.4 seconds
# Total time elapsed: 340.3 seconds
# ##############################
# eta = 6.
# # non-empty views with sz < 6 = 168
# #nodes in views with sz < 6 = 840
# Costs computed when eta = 6.
# ##############################
# Time elapsed from last time log: 1.2 seconds
# Total time elapsed: 341.4 seconds
# ##############################
# Remaining #nodes in views with sz < 6 = 0
# Done with eta = 6.
# ##############################
# Time elapsed from last time log: 21.7 seconds
# Total time elapsed: 363.2 seconds
# ##############################
# eta = 7.
# # non-empty views with sz < 7 = 141
# #nodes in views with sz < 7 = 846
# Costs computed when eta = 7.
# ##############################
# Time elapsed from last time log: 1.1 seconds
# Total time elapsed: 364.3 seconds
# ##############################
# Remaining #nodes in views with sz < 7 = 0
# Done with eta = 7.
# ##############################
# Time elapsed from last time log: 33.3 seconds
# Total time elapsed: 397.6 seconds
# ##############################
# eta = 8.
# # non-empty views with sz < 8 = 88
# #nodes in views with sz < 8 = 616
# Costs computed when eta = 8.
# ##############################
# Time elapsed from last time log: 0.9 seconds
# Total time elapsed: 398.5 seconds
# ##############################
# Remaining #nodes in views with sz < 8 = 0
# Done with eta = 8.
# ##############################
# Time elapsed from last time log: 18.7 seconds
# Total time elapsed: 417.2 seconds
# ##############################
# eta = 9.
# # non-empty views with sz < 9 = 89
# #nodes in views with sz < 9 = 712
# Costs computed when eta = 9.
# ##############################
# Time elapsed from last time log: 0.9 seconds
# Total time elapsed: 418.2 seconds
# ##############################
# Remaining #nodes in views with sz < 9 = 0
# Done with eta = 9.
# ##############################
# Time elapsed from last time log: 23.5 seconds
# Total time elapsed: 441.7 seconds
# ##############################
# eta = 10.
# # non-empty views with sz < 10 = 77
# #nodes in views with sz < 10 = 693
# Costs computed when eta = 10.
# ##############################
# Time elapsed from last time log: 1.0 seconds
# Total time elapsed: 442.7 seconds
# ##############################
# Remaining #nodes in views with sz < 10 = 0
# Done with eta = 10.
# ##############################
# Time elapsed from last time log: 27.4 seconds
# Total time elapsed: 470.0 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 0.7 seconds
# Total time elapsed: 470.7 seconds
# ##############################
# After clustering, max distortion is 3.532966
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 155 intermediate views
# Ambiguous overlaps checked for 310 intermediate views
# Ambiguous overlaps checked for 465 intermediate views
# Ambiguous overlaps checked for 620 points
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 1
# Computing initial embedding using: sequential algorithm
# ##############################
# Time elapsed from last time log: 3.6 seconds
# Total time elapsed: 3.6 seconds
# ##############################
# Initial alignment of 155 views completed
# Initial alignment of 310 views completed
# Initial alignment of 465 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 4.1 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 8.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10620 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.6 seconds
# Total time elapsed: 10.8 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 14.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10620 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.3 seconds
# Total time elapsed: 16.3 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 19.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10620 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.1 seconds
# Total time elapsed: 21.4 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 24.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10620 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.8 seconds
# Total time elapsed: 27.1 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 30.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10620 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.8 seconds
# Total time elapsed: 32.8 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 5
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 35.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10620 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.8 seconds
# Total time elapsed: 38.3 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 6
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 41.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10620 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.4 seconds
# Total time elapsed: 43.5 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 7
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 46.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10620 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.1 seconds
# Total time elapsed: 48.2 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 8
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 50.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10620 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.1 seconds
# Total time elapsed: 52.8 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 9
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 55.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10620 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.1 seconds
# Total time elapsed: 57.5 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 10
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 60.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10620 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.1 seconds
# Total time elapsed: 62.1 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 11
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 64.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10620 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 66.8 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 12
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 69.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10620 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.1 seconds
# Total time elapsed: 71.4 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 13
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 73.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10620 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 76.1 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 14
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 78.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10620 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.1 seconds
# Total time elapsed: 80.7 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 10620 multiplied with B
# Alignment error: 99.508
# ##############################
# Time elapsed from last time log: 1.0 seconds
# Total time elapsed: 81.7 seconds
# ##############################
# array([[-0.61926769, -0.07193095],
#        [-0.61679027, -0.06341838],
#        [-0.61570797, -0.05310401],
#        ...,
#        [-0.62622784, -0.04155212],
#        [-0.62739641, -0.05177433],
#        [-0.6285196 , -0.06217081]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/kleinbottle4d//ldle.dat
