# %% [markdown]
# ### Mobius strip

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
save_dir_root = '../data/pyLDLE2/mobiusstrip3d/'

# %%
X, labelsMat, ddX = datasets.Datasets().mobiusstrip3d()
# Out:
# X.shape =  (10580, 3)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LDLE'},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  intermed_opts={'eta_min': 10},
                  global_opts={
                      'max_iter': 10,
                      'init_algo_align_w_parent_only': True # Set this True for low noise
                  },
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 600 is created.

# %%
ldle.fit(X=X)
# Out:
# Constructing unnorm graph Laplacian + its eigendecomposition.
# Done.
# ##############################
# Time elapsed from last time log: 2.8 seconds
# Total time elapsed: 2.8 seconds
# ##############################
# Computing Atilde: Inner Prod of Grad of EigFuncs.
# FEM for Atilde.
# Atilde: 0 points processed...
# Atilde: 2645 points processed...
# Atilde: 5290 points processed...
# Atilde: 7935 points processed...
# Atilde: all points processed...
# Done.
# ##############################
# Time elapsed from last time log: 0.7 seconds
# Total time elapsed: 3.5 seconds
# ##############################
# Computing LDLE.
# local_param: all 10580 points processed...
# max distortion is 4082.394383
# Done.
# ##############################
# Time elapsed from last time log: 1.3 seconds
# Total time elapsed: 4.8 seconds
# ##############################
# Posprocessing LDLE.
# Iter 1, Param replaced: 10300, max distortion: 120.943213
# Iter 2, Param replaced: 6696, max distortion: 62.553453
# Iter 3, Param replaced: 4241, max distortion: 47.382537
# Iter 4, Param replaced: 2546, max distortion: 38.658587
# Iter 5, Param replaced: 833, max distortion: 34.621797
# Iter 6, Param replaced: 115, max distortion: 34.621797
# Iter 7, Param replaced: 17, max distortion: 34.621797
# Iter 8, Param replaced: 5, max distortion: 34.621797
# Iter 9, Param replaced: 0, max distortion: 34.621797
# Done.
# ##############################
# Time elapsed from last time log: 18.2 seconds
# Total time elapsed: 23.0 seconds
# ##############################
# Max local distortion = 34.62179658186803
# Constructing intermediate views.
# eta = 2.
# # non-empty views with sz < 2 = 10580
# #nodes in views with sz < 2 = 10580
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 10.7 seconds
# Total time elapsed: 10.8 seconds
# ##############################
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 109.6 seconds
# Total time elapsed: 120.4 seconds
# ##############################
# eta = 3.
# # non-empty views with sz < 3 = 423
# #nodes in views with sz < 3 = 846
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 0.6 seconds
# Total time elapsed: 121.0 seconds
# ##############################
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 3.9 seconds
# Total time elapsed: 125.0 seconds
# ##############################
# eta = 4.
# # non-empty views with sz < 4 = 255
# #nodes in views with sz < 4 = 765
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 0.6 seconds
# Total time elapsed: 125.6 seconds
# ##############################
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 5.1 seconds
# Total time elapsed: 130.6 seconds
# ##############################
# eta = 5.
# # non-empty views with sz < 5 = 362
# #nodes in views with sz < 5 = 1448
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 131.4 seconds
# ##############################
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 11.1 seconds
# Total time elapsed: 142.6 seconds
# ##############################
# eta = 6.
# # non-empty views with sz < 6 = 142
# #nodes in views with sz < 6 = 710
# Costs computed when eta = 6.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 143.1 seconds
# ##############################
# Remaining #nodes in views with sz < 6 = 0
# Done with eta = 6.
# ##############################
# Time elapsed from last time log: 6.8 seconds
# Total time elapsed: 149.8 seconds
# ##############################
# eta = 7.
# # non-empty views with sz < 7 = 201
# #nodes in views with sz < 7 = 1206
# Costs computed when eta = 7.
# ##############################
# Time elapsed from last time log: 0.6 seconds
# Total time elapsed: 150.4 seconds
# ##############################
# Remaining #nodes in views with sz < 7 = 0
# Done with eta = 7.
# ##############################
# Time elapsed from last time log: 12.9 seconds
# Total time elapsed: 163.3 seconds
# ##############################
# eta = 8.
# # non-empty views with sz < 8 = 125
# #nodes in views with sz < 8 = 875
# Costs computed when eta = 8.
# ##############################
# Time elapsed from last time log: 0.6 seconds
# Total time elapsed: 163.9 seconds
# ##############################
# Remaining #nodes in views with sz < 8 = 0
# Done with eta = 8.
# ##############################
# Time elapsed from last time log: 11.0 seconds
# Total time elapsed: 174.9 seconds
# ##############################
# eta = 9.
# # non-empty views with sz < 9 = 96
# #nodes in views with sz < 9 = 768
# Costs computed when eta = 9.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 175.3 seconds
# ##############################
# Remaining #nodes in views with sz < 9 = 0
# Done with eta = 9.
# ##############################
# Time elapsed from last time log: 9.9 seconds
# Total time elapsed: 185.2 seconds
# ##############################
# eta = 10.
# # non-empty views with sz < 10 = 68
# #nodes in views with sz < 10 = 612
# Costs computed when eta = 10.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 185.7 seconds
# ##############################
# Remaining #nodes in views with sz < 10 = 0
# Done with eta = 10.
# ##############################
# Time elapsed from last time log: 7.3 seconds
# Total time elapsed: 193.0 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 0.4 seconds
# Total time elapsed: 193.5 seconds
# ##############################
# After clustering, max distortion is 27.692286
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 160 intermediate views
# Ambiguous overlaps checked for 320 intermediate views
# Ambiguous overlaps checked for 480 intermediate views
# Ambiguous overlaps checked for 640 points
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 1
# Computing initial embedding using: sequential algorithm
# ##############################
# Time elapsed from last time log: 2.4 seconds
# Total time elapsed: 2.4 seconds
# ##############################
# Initial alignment of 160 views completed
# Initial alignment of 320 views completed
# Initial alignment of 480 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 0.2 seconds
# Total time elapsed: 2.6 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 10.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11220
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 27.4 seconds
# Total time elapsed: 38.0 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 42.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11220
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 27.6 seconds
# Total time elapsed: 69.8 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 73.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11220
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 27.3 seconds
# Total time elapsed: 101.1 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 105.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11220
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 28.2 seconds
# Total time elapsed: 133.3 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 137.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11220
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 30.1 seconds
# Total time elapsed: 167.4 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 5
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 171.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11220
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 31.3 seconds
# Total time elapsed: 203.0 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 6
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 210.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11220
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 30.8 seconds
# Total time elapsed: 241.3 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 7
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 245.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11220
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 30.0 seconds
# Total time elapsed: 275.3 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 8
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 279.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11220
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 28.6 seconds
# Total time elapsed: 308.0 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 9
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 312.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11220
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 29.0 seconds
# Total time elapsed: 341.1 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 11220
# Alignment error: 11.236
# ##############################
# Time elapsed from last time log: 3.2 seconds
# Total time elapsed: 344.3 seconds
# ##############################
# array([[0.27080962, 0.80030428],
#        [0.2707261 , 0.80129   ],
#        [0.27058785, 0.80292714],
#        ...,
#        [0.25039844, 0.79534119],
#        [0.25138643, 0.79386109],
#        [0.25198883, 0.79296864]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/mobiusstrip3d//ldle.dat
