# %% [markdown]
# # Barbell - further visualizations

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

from pyLDLE2 import visualize_all
visualize_all.visualize('../data/pyLDLE2/barbell/ldle.dat')
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline
# ##################################################
# Data
# ##################################################
# Eigenvalues
# ##################################################
# Eigenvectors on data
# ##################################################
# ##################################################
# Eigenvectors on embedding
# ##################################################
# ##################################################
# gamma on  data
# ##################################################
# ##################################################
# gamma on embedding
# ##################################################
# ##################################################
# No. of eigenvectors with small gradients at each point - possibly identifies boundary
# ##################################################
# ##################################################
# ...
