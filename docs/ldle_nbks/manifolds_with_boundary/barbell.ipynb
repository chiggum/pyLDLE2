# %% [markdown]
# ### Barbell

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import buml_, util_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
save_dir_root = '../data/pyLDLE2/barbell/'

# %%
X, labelsMat, ddX = datasets.Datasets().barbell()
# Out:
# X.shape =  (10227, 2)

# %%
# The supplied options would override the default options
buml_obj = buml_.BUML(local_opts={'algo':'LDLE'},
                  intermed_opts={'algo': 'best', 'eta_min': 5},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 700 is created.
# Options provided:
# local_opts:
# {
#     "Atilde_method": "LDLE_1",
#     "N": 100,
#     "U_method": "k_nn",
#     "algo": "LDLE",
#     "alpha": 1,
#     "debug": true,
#     "delta": 0.9,
#     "gl_type": "unnorm",
#     "k": 28,
#     "k_nn": 49,
#     "k_nn0": 700,
#     "k_tune": 7,
#     "lambda1_decay": 0.75,
#     "lambda1_init": 8,
#     "lambda1_min": 0.001,
#     "max_iter": 300,
#     "max_sparsity": 0.9,
#     "metric": "euclidean",
#     "n_proc": 32,
#     "p": 0.99,
#     "power": 5,
#     "pp_n_thresh": 32,
#     "radius": 0.5,
#     "reg": 0.0,
#     "scale_by": "gamma",
#     "tau": 50,
#     "to_postprocess": true,
#     "verbose": true
# }
# intermed_opts:
# {
#     "algo": "best",
#     "debug": true,
#     "eta_max": 25,
#     "eta_min": 5,
#     "len_S_thresh": 256,
#     "local_algo": "LDLE",
#     "metric": "euclidean",
#     "n_proc": 32,
#     "n_times": 4,
#     "verbose": true
# }
# global_opts:
# {
#     "add_dim": false,
#     "align_transform": "rigid",
#     "align_w_parent_only": true,
#     "alpha": 0.3,
#     "beta": {
#         "align": null,
#         "repel": 1
#     },
#     "color_tear": true,
#     "compute_error": false,
#     "debug": true,
#     "eps": 1e-08,
#     "err_tol": 0.0001,
#     "far_off_points_type": "reuse_fixed",
#     "init_algo_name": "procrustes",
#     "k": 28,
#     "max_internal_iter": 100,
#     "max_iter": 20,
#     "metric": "euclidean",
#     "n_proc": 32,
#     "n_repel": 0,
#     "nu": 3,
#     "patience": 5,
#     "refine_algo_name": "rgd",
#     "repel_by": 0.0,
#     "to_tear": true,
#     "verbose": true,
#     "vis_before_init": false
# }

# %%
buml_obj.fit(X=X)
# Out:
# Computing local views using LDLE
# Constructing unnorm graph Laplacian + its eigendecomposition.
# Done.
# ##############################
# Time elapsed from last time log: 3.9 seconds
# Total time elapsed: 3.9 seconds
# ##############################
# Computing Atilde: Inner Prod of Grad of EigFuncs.
# FEM for Atilde.
# Atilde: 0 points processed...
# Atilde: 2556 points processed...
# Atilde: 5112 points processed...
# Atilde: 7668 points processed...
# Atilde: 10224 points processed...
# Atilde: all points processed...
# Done.
# ##############################
# Time elapsed from last time log: 1.0 seconds
# Total time elapsed: 4.9 seconds
# ##############################
# Computing LDLE.
# local_param: all 10227 points processed...
# max distortion is 390786.338681
# Done.
# ##############################
# Time elapsed from last time log: 1.7 seconds
# Total time elapsed: 6.7 seconds
# ##############################
# Posprocessing local parameterizations.
# #Param replaced: 9718, max distortion: 18.237181
# #Param replaced: 4665, max distortion: 11.938901
# #Param replaced: 2251, max distortion: 10.418145
# #Param replaced: 1117, max distortion: 10.418145
# #Param replaced: 801, max distortion: 10.418145
# #Param replaced: 595, max distortion: 10.418145
# #Param replaced: 303, max distortion: 10.418145
# #Param replaced: 96, max distortion: 10.418145
# #Param replaced: 37, max distortion: 10.418145
# #Param replaced: 11, max distortion: 10.418145
# #Param replaced: 0, max distortion: 10.418145
# Max local distortion after postprocessing: 10.418145099911678
# Done.
# ##############################
# Time elapsed from last time log: 10.6 seconds
# Total time elapsed: 17.3 seconds
# ##############################
# Max local distortion = 10.418145099911678
# Constructing intermediate views.
# eta = 2.
# #non-empty views with sz < 2 = 10227
# #nodes in views with sz < 2 = 10227
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 11.9 seconds
# Total time elapsed: 12.9 seconds
# ##############################
# ctr=8049, total_len_S=58257, avg_len_S=7.238
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 274.4 seconds
# Total time elapsed: 287.3 seconds
# ##############################
# eta = 3.
# #non-empty views with sz < 3 = 485
# #nodes in views with sz < 3 = 970
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 1.9 seconds
# Total time elapsed: 289.1 seconds
# ##############################
# ctr=866, total_len_S=16195, avg_len_S=18.701
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 11.1 seconds
# Total time elapsed: 300.3 seconds
# ##############################
# eta = 4.
# #non-empty views with sz < 4 = 386
# #nodes in views with sz < 4 = 1158
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 1.9 seconds
# Total time elapsed: 302.1 seconds
# ##############################
# ctr=1090, total_len_S=30005, avg_len_S=27.528
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 25.0 seconds
# Total time elapsed: 327.1 seconds
# ##############################
# eta = 5.
# #non-empty views with sz < 5 = 242
# #nodes in views with sz < 5 = 968
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 1.5 seconds
# Total time elapsed: 328.6 seconds
# ##############################
# ctr=895, total_len_S=30930, avg_len_S=34.559
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 21.5 seconds
# Total time elapsed: 350.2 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 1.2 seconds
# Total time elapsed: 351.5 seconds
# ##############################
# After clustering, max distortion is 14.056371
# Using rigid transforms for alignment.
# Computing laterations scores for overlaps b/w intermed views
# Done
# ##############################
# Time elapsed from last time log: 1.8 seconds
# Total time elapsed: 1.8 seconds
# ##############################
# Computing a lateration.
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 1
# Done.
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 1.8 seconds
# ##############################
# Computing initial embedding using: procrustes algorithm
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 1.8 seconds
# ##############################
# Initial alignment of 293 views completed
# Initial alignment of 586 views completed
# Initial alignment of 879 views completed
# Initial alignment of 1172 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 1.4 seconds
# Total time elapsed: 3.2 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 6.9 seconds
# ##############################
# min and max weights: 1.0 1.0
# Computing Pseudoinverse of a matrix of L of size 10227 + 1174 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 8.9 seconds
# Total time elapsed: 15.9 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 17.8 seconds
# ##############################
# min and max weights: 1.0 1.0
# Computing Pseudoinverse of a matrix of L of size 10227 + 1174 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 8.9 seconds
# Total time elapsed: 26.7 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 28.6 seconds
# ##############################
# min and max weights: 1.0 1.0
# Computing Pseudoinverse of a matrix of L of size 10227 + 1174 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 9.0 seconds
# Total time elapsed: 37.5 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 39.3 seconds
# ##############################
# min and max weights: 1.0 1.0
# Computing Pseudoinverse of a matrix of L of size 10227 + 1174 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 8.8 seconds
# Total time elapsed: 48.0 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 49.7 seconds
# ##############################
# min and max weights: 1.0 1.0
# Computing Pseudoinverse of a matrix of L of size 10227 + 1174 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 8.8 seconds
# Total time elapsed: 58.6 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 5
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 60.4 seconds
# ##############################
# min and max weights: 1.0 1.0
# Computing Pseudoinverse of a matrix of L of size 10227 + 1174 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 9.1 seconds
# Total time elapsed: 69.4 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 6
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 71.1 seconds
# ##############################
# min and max weights: 1.0 1.0
# Computing Pseudoinverse of a matrix of L of size 10227 + 1174 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 8.7 seconds
# Total time elapsed: 79.9 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 7
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 81.5 seconds
# ##############################
# min and max weights: 1.0 1.0
# Computing Pseudoinverse of a matrix of L of size 10227 + 1174 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 9.0 seconds
# Total time elapsed: 90.5 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 8
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 92.3 seconds
# ##############################
# min and max weights: 1.0 1.0
# Computing Pseudoinverse of a matrix of L of size 10227 + 1174 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 8.7 seconds
# Total time elapsed: 101.0 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 9
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 102.9 seconds
# ##############################
# min and max weights: 1.0 1.0
# Computing Pseudoinverse of a matrix of L of size 10227 + 1174 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 9.3 seconds
# Total time elapsed: 112.2 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 10
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 114.2 seconds
# ##############################
# min and max weights: 1.0 1.0
# Computing Pseudoinverse of a matrix of L of size 10227 + 1174 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 8.9 seconds
# Total time elapsed: 123.2 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 11
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 124.9 seconds
# ##############################
# min and max weights: 1.0 1.0
# Computing Pseudoinverse of a matrix of L of size 10227 + 1174 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 8.9 seconds
# Total time elapsed: 133.8 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 12
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 135.5 seconds
# ##############################
# min and max weights: 1.0 1.0
# Computing Pseudoinverse of a matrix of L of size 10227 + 1174 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 9.2 seconds
# Total time elapsed: 144.7 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 13
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 146.7 seconds
# ##############################
# min and max weights: 1.0 1.0
# Computing Pseudoinverse of a matrix of L of size 10227 + 1174 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 9.0 seconds
# Total time elapsed: 155.7 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 14
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 157.4 seconds
# ##############################
# min and max weights: 1.0 1.0
# Computing Pseudoinverse of a matrix of L of size 10227 + 1174 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 9.0 seconds
# Total time elapsed: 166.4 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 15
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 168.3 seconds
# ##############################
# min and max weights: 1.0 1.0
# Computing Pseudoinverse of a matrix of L of size 10227 + 1174 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 9.0 seconds
# Total time elapsed: 177.3 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 16
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 179.1 seconds
# ##############################
# min and max weights: 1.0 1.0
# Computing Pseudoinverse of a matrix of L of size 10227 + 1174 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 9.2 seconds
# Total time elapsed: 188.3 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 17
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 190.4 seconds
# ##############################
# min and max weights: 1.0 1.0
# Computing Pseudoinverse of a matrix of L of size 10227 + 1174 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 9.2 seconds
# Total time elapsed: 199.6 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 18
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 201.4 seconds
# ##############################
# min and max weights: 1.0 1.0
# Computing Pseudoinverse of a matrix of L of size 10227 + 1174 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 8.8 seconds
# Total time elapsed: 210.2 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 19
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 211.9 seconds
# ##############################
# min and max weights: 1.0 1.0
# Computing Pseudoinverse of a matrix of L of size 10227 + 1174 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 8.6 seconds
# Total time elapsed: 220.4 seconds
# ##############################
# Computing error.
# min and max weights: 1.0 1.0
# Computing Pseudoinverse of a matrix of L of size 10227 + 1174 multiplied with B
# Computing svd
# Done
# Alignment error: 1.660484
# ##############################
# Time elapsed from last time log: 4.9 seconds
# Total time elapsed: 225.3 seconds
# ##############################
# array([[-1.4876382 , -0.0335363 ],
#        [-1.48672438, -0.04312191],
#        [-1.48826444, -0.05136269],
#        ...,
#        [ 0.76074449, -0.0553601 ],
#        [ 0.76483297, -0.06285258],
#        [ 0.76982294, -0.07335605]])

# %%
buml_obj.GlobalViews.vis_embedding(buml_obj.GlobalViews.y_final, buml_obj.vis, buml_obj.vis_opts,
                                   buml_obj.GlobalViews.color_of_pts_on_tear_final,
                                   title='Final global embedding', )

# %%
util_.save(save_dir_root, 'ldle.dat', [X, labelsMat, buml_obj])
