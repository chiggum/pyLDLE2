# %% [markdown]
# ### Sphere with hole

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
save_dir_root = '../data/pyLDLE2/spherewithhole/'

# %%
X, labelsMat, ddX = datasets.Datasets().spherewithhole()
# Out:
# X.shape =  (9931, 3)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LDLE'},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  intermed_opts={'eta_min': 10},
                  global_opts={
                      'max_iter': 10,
                      'init_algo_align_w_parent_only': True # Set this True for low noise
                  },
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 875 is created.

# %%
ldle.fit(X=X)
# Out:
# Constructing unnorm graph Laplacian + its eigendecomposition.
# Done.
# ##############################
# Time elapsed from last time log: 2.1 seconds
# Total time elapsed: 2.1 seconds
# ##############################
# Computing Atilde: Inner Prod of Grad of EigFuncs.
# FEM for Atilde.
# Atilde: 0 points processed...
# Atilde: 2482 points processed...
# Atilde: 4964 points processed...
# Atilde: 7446 points processed...
# Atilde: 9928 points processed...
# Atilde: all points processed...
# Done.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 2.9 seconds
# ##############################
# Computing LDLE.
# local_param: all 9931 points processed...
# max distortion is 738.713371
# Done.
# ##############################
# Time elapsed from last time log: 1.2 seconds
# Total time elapsed: 4.2 seconds
# ##############################
# Posprocessing local parameterizations.
# #Param replaced: 9055, max distortion: 6.483730
# #Param replaced: 2221, max distortion: 5.473027
# #Param replaced: 536, max distortion: 5.473027
# #Param replaced: 407, max distortion: 5.473027
# #Param replaced: 326, max distortion: 5.473027
# #Param replaced: 210, max distortion: 5.473027
# #Param replaced: 252, max distortion: 5.473027
# #Param replaced: 399, max distortion: 5.473027
# #Param replaced: 218, max distortion: 5.473027
# #Param replaced: 77, max distortion: 5.473027
# #Param replaced: 103, max distortion: 5.473027
# #Param replaced: 86, max distortion: 5.473027
# #Param replaced: 63, max distortion: 5.473027
# #Param replaced: 54, max distortion: 5.473027
# #Param replaced: 23, max distortion: 5.473027
# #Param replaced: 9, max distortion: 5.473027
# #Param replaced: 19, max distortion: 5.473027
# #Param replaced: 6, max distortion: 5.473027
# #Param replaced: 4, max distortion: 5.473027
# #Param replaced: 1, max distortion: 5.473027
# #Param replaced: 0, max distortion: 5.473027
# Max local distortion after postprocessing: 5.473026946664492e+00
# Done.
# ##############################
# Time elapsed from last time log: 16.8 seconds
# Total time elapsed: 21.0 seconds
# ##############################
# Max local distortion = 5.473026946664492
# Constructing intermediate views.
# eta = 2.
# # non-empty views with sz < 2 = 9931
# #nodes in views with sz < 2 = 9931
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 19.3 seconds
# Total time elapsed: 19.4 seconds
# ##############################
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 231.5 seconds
# Total time elapsed: 250.9 seconds
# ##############################
# eta = 3.
# # non-empty views with sz < 3 = 313
# #nodes in views with sz < 3 = 626
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 1.0 seconds
# Total time elapsed: 251.9 seconds
# ##############################
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 6.7 seconds
# Total time elapsed: 258.5 seconds
# ##############################
# eta = 4.
# # non-empty views with sz < 4 = 308
# #nodes in views with sz < 4 = 924
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 1.6 seconds
# Total time elapsed: 260.2 seconds
# ##############################
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 17.8 seconds
# Total time elapsed: 277.9 seconds
# ##############################
# eta = 5.
# # non-empty views with sz < 5 = 234
# #nodes in views with sz < 5 = 936
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 1.2 seconds
# Total time elapsed: 279.2 seconds
# ##############################
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 22.6 seconds
# Total time elapsed: 301.7 seconds
# ##############################
# eta = 6.
# # non-empty views with sz < 6 = 157
# #nodes in views with sz < 6 = 785
# Costs computed when eta = 6.
# ##############################
# Time elapsed from last time log: 1.4 seconds
# Total time elapsed: 303.1 seconds
# ##############################
# Remaining #nodes in views with sz < 6 = 0
# Done with eta = 6.
# ##############################
# Time elapsed from last time log: 20.7 seconds
# Total time elapsed: 323.8 seconds
# ##############################
# eta = 7.
# # non-empty views with sz < 7 = 126
# #nodes in views with sz < 7 = 756
# Costs computed when eta = 7.
# ##############################
# Time elapsed from last time log: 1.3 seconds
# Total time elapsed: 325.0 seconds
# ##############################
# Remaining #nodes in views with sz < 7 = 0
# Done with eta = 7.
# ##############################
# Time elapsed from last time log: 21.5 seconds
# Total time elapsed: 346.6 seconds
# ##############################
# eta = 8.
# # non-empty views with sz < 8 = 112
# #nodes in views with sz < 8 = 784
# Costs computed when eta = 8.
# ##############################
# Time elapsed from last time log: 1.2 seconds
# Total time elapsed: 347.7 seconds
# ##############################
# Remaining #nodes in views with sz < 8 = 0
# Done with eta = 8.
# ##############################
# Time elapsed from last time log: 30.0 seconds
# Total time elapsed: 377.7 seconds
# ##############################
# eta = 9.
# # non-empty views with sz < 9 = 59
# #nodes in views with sz < 9 = 472
# Costs computed when eta = 9.
# ##############################
# Time elapsed from last time log: 0.9 seconds
# Total time elapsed: 378.6 seconds
# ##############################
# Remaining #nodes in views with sz < 9 = 0
# Done with eta = 9.
# ##############################
# Time elapsed from last time log: 16.1 seconds
# Total time elapsed: 394.7 seconds
# ##############################
# eta = 10.
# # non-empty views with sz < 10 = 70
# #nodes in views with sz < 10 = 630
# Costs computed when eta = 10.
# ##############################
# Time elapsed from last time log: 1.0 seconds
# Total time elapsed: 395.8 seconds
# ##############################
# Remaining #nodes in views with sz < 10 = 0
# Done with eta = 10.
# ##############################
# Time elapsed from last time log: 21.3 seconds
# Total time elapsed: 417.0 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 0.6 seconds
# Total time elapsed: 417.6 seconds
# ##############################
# After clustering, max distortion is 10.018298
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 151 intermediate views
# Ambiguous overlaps checked for 302 intermediate views
# Ambiguous overlaps checked for 453 intermediate views
# Ambiguous overlaps checked for 604 intermediate views
# Ambiguous overlaps checked for 605 points
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 1
# Computing initial embedding using: sequential algorithm
# ##############################
# Time elapsed from last time log: 3.1 seconds
# Total time elapsed: 3.1 seconds
# ##############################
# Initial alignment of 151 views completed
# Initial alignment of 302 views completed
# Initial alignment of 453 views completed
# Initial alignment of 604 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 3.6 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 5.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10536 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 7.8 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 9.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10536 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.1 seconds
# Total time elapsed: 11.3 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 12.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10536 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 14.9 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 16.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10536 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.1 seconds
# Total time elapsed: 18.3 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 19.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10536 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.1 seconds
# Total time elapsed: 21.8 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 5
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 23.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10536 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 25.2 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 6
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 26.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10536 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.1 seconds
# Total time elapsed: 28.5 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 7
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 29.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10536 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.1 seconds
# Total time elapsed: 31.7 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 8
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 32.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10536 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 35.1 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 9
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 36.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10536 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.1 seconds
# Total time elapsed: 38.3 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 10536 multiplied with B
# Alignment error: 54.381
# ##############################
# Time elapsed from last time log: 1.0 seconds
# Total time elapsed: 39.3 seconds
# ##############################
# array([[-0.38950547,  0.40654903],
#        [-0.04563903, -0.56442326],
#        [-0.41855689,  0.48556923],
#        ...,
#        [ 0.10151108,  0.0608209 ],
#        [ 0.11254793,  0.05140537],
#        [ 0.11073192,  0.0611902 ]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/spherewithhole//ldle.dat
