# %% [markdown]
# ### Sphere with hole

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
save_dir_root = '../data/pyLDLE2/spherewithhole/'

# %%
X, labelsMat, ddX = datasets.Datasets().spherewithhole()
# Out:
# X.shape =  (9931, 3)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LDLE'},
                  intermed_opts={'eta_min': 10},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 700 is created.
# Options provided:
# local_opts:
# {
#     "Atilde_method": "LDLE_1",
#     "N": 100,
#     "algo": "LDLE",
#     "alpha": 1,
#     "debug": true,
#     "delta": 0.9,
#     "gl_type": "unnorm",
#     "k": 28,
#     "k_nn": 49,
#     "k_nn0": 700,
#     "k_tune": 7,
#     "max_iter": 300,
#     "n_proc": 32,
#     "no_gamma": false,
#     "p": 0.99,
#     "pp_n_thresh": 32,
#     "reg": 0.0,
#     "tau": 50,
#     "to_postprocess": true,
#     "verbose": true
# }
# intermed_opts:
# {
#     "algo": "best",
#     "debug": true,
#     "eta_max": 25,
#     "eta_min": 10,
#     "len_S_thresh": 256,
#     "local_algo": "LDLE",
#     "n_proc": 32,
#     "n_times": 4,
#     "verbose": true
# }
# global_opts:
# {
#     "align_w_parent_only": true,
#     "alpha": 0.3,
#     "color_tear": true,
#     "compute_error": false,
#     "debug": true,
#     "eps": 1e-08,
#     "init_algo_name": "procrustes",
#     "k": 28,
#     "main_algo": "LDLE",
#     "max_internal_iter": 100,
#     "max_iter": 20,
#     "n_proc": 32,
#     "nu": 3,
#     "refine_algo_name": "rgd",
#     "to_tear": true,
#     "verbose": true,
#     "vis_before_init": false
# }

# %%
ldle.fit(X=X)
# Out:
# Constructing unnorm graph Laplacian + its eigendecomposition.
# Done.
# ##############################
# Time elapsed from last time log: 3.6 seconds
# Total time elapsed: 3.6 seconds
# ##############################
# Computing Atilde: Inner Prod of Grad of EigFuncs.
# FEM for Atilde.
# Atilde: 0 points processed...
# Atilde: 2482 points processed...
# Atilde: 4964 points processed...
# Atilde: 7446 points processed...
# Atilde: 9928 points processed...
# Atilde: all points processed...
# Done.
# ##############################
# Time elapsed from last time log: 1.3 seconds
# Total time elapsed: 5.0 seconds
# ##############################
# Computing LDLE.
# local_param: all 9931 points processed...
# max distortion is 218.203338
# Done.
# ##############################
# Time elapsed from last time log: 1.7 seconds
# Total time elapsed: 6.8 seconds
# ##############################
# Posprocessing local parameterizations.
# #Param replaced: 8941, max distortion: 6.012715
# #Param replaced: 2559, max distortion: 5.239490
# #Param replaced: 630, max distortion: 5.094905
# #Param replaced: 374, max distortion: 4.693018
# #Param replaced: 312, max distortion: 4.693018
# #Param replaced: 228, max distortion: 4.693018
# #Param replaced: 183, max distortion: 4.693018
# #Param replaced: 218, max distortion: 4.693018
# #Param replaced: 322, max distortion: 4.693018
# #Param replaced: 221, max distortion: 4.693018
# #Param replaced: 165, max distortion: 4.693018
# #Param replaced: 101, max distortion: 4.693018
# #Param replaced: 62, max distortion: 4.693018
# #Param replaced: 40, max distortion: 4.693018
# #Param replaced: 23, max distortion: 4.693018
# #Param replaced: 16, max distortion: 4.693018
# #Param replaced: 2, max distortion: 4.693018
# #Param replaced: 0, max distortion: 4.693018
# Max local distortion after postprocessing: 4.69301823354583e+00
# Done.
# ##############################
# Time elapsed from last time log: 8.9 seconds
# Total time elapsed: 15.6 seconds
# ##############################
# Max local distortion = 4.69301823354583
# Constructing intermediate views.
# eta = 2.
# #non-empty views with sz < 2 = 9931
# #nodes in views with sz < 2 = 9931
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 8.7 seconds
# Total time elapsed: 9.4 seconds
# ##############################
# ctr=8043, total_len_S=63207, avg_len_S=7.859
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 198.6 seconds
# Total time elapsed: 208.0 seconds
# ##############################
# eta = 3.
# #non-empty views with sz < 3 = 333
# #nodes in views with sz < 3 = 666
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 1.5 seconds
# Total time elapsed: 209.5 seconds
# ##############################
# ctr=595, total_len_S=11375, avg_len_S=19.118
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 4.6 seconds
# Total time elapsed: 214.2 seconds
# ##############################
# eta = 4.
# #non-empty views with sz < 4 = 306
# #nodes in views with sz < 4 = 918
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 1.5 seconds
# Total time elapsed: 215.7 seconds
# ##############################
# ctr=840, total_len_S=22832, avg_len_S=27.181
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 13.5 seconds
# Total time elapsed: 229.1 seconds
# ##############################
# eta = 5.
# #non-empty views with sz < 5 = 233
# #nodes in views with sz < 5 = 932
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 1.6 seconds
# Total time elapsed: 230.7 seconds
# ##############################
# ctr=863, total_len_S=28910, avg_len_S=33.499
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 18.2 seconds
# Total time elapsed: 248.9 seconds
# ##############################
# eta = 6.
# #non-empty views with sz < 6 = 186
# #nodes in views with sz < 6 = 930
# Costs computed when eta = 6.
# ##############################
# Time elapsed from last time log: 1.9 seconds
# Total time elapsed: 250.8 seconds
# ##############################
# ctr=880, total_len_S=34517, avg_len_S=39.224
# Remaining #nodes in views with sz < 6 = 0
# Done with eta = 6.
# ##############################
# Time elapsed from last time log: 25.4 seconds
# Total time elapsed: 276.1 seconds
# ##############################
# eta = 7.
# #non-empty views with sz < 7 = 111
# #nodes in views with sz < 7 = 666
# Costs computed when eta = 7.
# ##############################
# Time elapsed from last time log: 1.7 seconds
# Total time elapsed: 277.8 seconds
# ##############################
# ctr=614, total_len_S=26707, avg_len_S=43.497
# Remaining #nodes in views with sz < 7 = 0
# Done with eta = 7.
# ##############################
# Time elapsed from last time log: 18.4 seconds
# Total time elapsed: 296.2 seconds
# ##############################
# eta = 8.
# #non-empty views with sz < 8 = 106
# #nodes in views with sz < 8 = 742
# Costs computed when eta = 8.
# ##############################
# Time elapsed from last time log: 1.6 seconds
# Total time elapsed: 297.9 seconds
# ##############################
# ctr=706, total_len_S=33340, avg_len_S=47.224
# Remaining #nodes in views with sz < 8 = 0
# Done with eta = 8.
# ##############################
# Time elapsed from last time log: 20.7 seconds
# Total time elapsed: 318.6 seconds
# ##############################
# eta = 9.
# #non-empty views with sz < 9 = 75
# #nodes in views with sz < 9 = 600
# Costs computed when eta = 9.
# ##############################
# Time elapsed from last time log: 1.7 seconds
# Total time elapsed: 320.2 seconds
# ##############################
# ctr=565, total_len_S=29777, avg_len_S=52.703
# Remaining #nodes in views with sz < 9 = 0
# Done with eta = 9.
# ##############################
# Time elapsed from last time log: 17.3 seconds
# Total time elapsed: 337.6 seconds
# ##############################
# eta = 10.
# #non-empty views with sz < 10 = 57
# #nodes in views with sz < 10 = 513
# Costs computed when eta = 10.
# ##############################
# Time elapsed from last time log: 1.7 seconds
# Total time elapsed: 339.3 seconds
# ##############################
# ctr=487, total_len_S=29010, avg_len_S=59.569
# Remaining #nodes in views with sz < 10 = 0
# Done with eta = 10.
# ##############################
# Time elapsed from last time log: 18.6 seconds
# Total time elapsed: 357.8 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 0.7 seconds
# Total time elapsed: 358.5 seconds
# ##############################
# After clustering, max distortion is 8.014977
# Computing laterations scores for overlaps b/w intermed views
# Done
# ##############################
# Time elapsed from last time log: 1.6 seconds
# Total time elapsed: 1.6 seconds
# ##############################
# Computing a lateration.
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 1
# Done.
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 1.6 seconds
# ##############################
# Computing initial embedding using: procrustes algorithm
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 1.6 seconds
# ##############################
# Initial alignment of 153 views completed
# Initial alignment of 306 views completed
# Initial alignment of 459 views completed
# Initial alignment of 612 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 2.4 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 5.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9931 + 614 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.3 seconds
# Total time elapsed: 9.7 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 12.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9931 + 614 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.2 seconds
# Total time elapsed: 16.2 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 18.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9931 + 614 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.1 seconds
# Total time elapsed: 22.5 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 24.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9931 + 614 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.0 seconds
# Total time elapsed: 28.4 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 30.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9931 + 614 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.1 seconds
# Total time elapsed: 34.4 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 5
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 36.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9931 + 614 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.4 seconds
# Total time elapsed: 40.6 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 6
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 42.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9931 + 614 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.3 seconds
# Total time elapsed: 46.7 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 7
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 48.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9931 + 614 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.3 seconds
# Total time elapsed: 52.8 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 8
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 54.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9931 + 614 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.3 seconds
# Total time elapsed: 58.8 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 9
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 60.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9931 + 614 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.3 seconds
# Total time elapsed: 65.0 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 10
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 66.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9931 + 614 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.3 seconds
# Total time elapsed: 71.0 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 11
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 72.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9931 + 614 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.2 seconds
# Total time elapsed: 76.7 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 12
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 78.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9931 + 614 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.3 seconds
# Total time elapsed: 82.6 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 13
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 84.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9931 + 614 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.4 seconds
# Total time elapsed: 88.5 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 14
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 90.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9931 + 614 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.3 seconds
# Total time elapsed: 94.4 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 15
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 95.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9931 + 614 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.3 seconds
# Total time elapsed: 100.2 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 16
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 101.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9931 + 614 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.4 seconds
# Total time elapsed: 106.1 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 17
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 107.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9931 + 614 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.3 seconds
# Total time elapsed: 111.8 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 18
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 113.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9931 + 614 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.3 seconds
# Total time elapsed: 117.7 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 19
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 119.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9931 + 614 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.2 seconds
# Total time elapsed: 123.5 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 9931 + 614 multiplied with B
# Computing svd
# Done
# Alignment error: 41.817
# ##############################
# Time elapsed from last time log: 1.7 seconds
# Total time elapsed: 125.2 seconds
# ##############################
# array([[-0.62304604,  0.19620393],
#        [-0.50765042,  0.20191593],
#        [ 0.33213754,  0.31931972],
#        ...,
#        [ 0.01196938, -0.10479422],
#        [ 0.00673262, -0.09116747],
#        [ 0.01538536, -0.09616074]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/spherewithhole//ldle.dat
