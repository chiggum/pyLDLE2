# %% [markdown]
# ### Sphere with hole

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
save_dir_root = '../data/pyLDLE2/spherewithhole/'

# %%
X, labelsMat, ddX = datasets.Datasets().spherewithhole()
# Out:
# X.shape =  (9931, 3)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LDLE'},
                  intermed_opts={'eta_min': 5, 'algo':'best'},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 700 is created.
# Options provided:
# local_opts:
# {
#     "Atilde_method": "LDLE_1",
#     "N": 100,
#     "algo": "LDLE",
#     "delta": 0.9,
#     "gl_type": "unnorm",
#     "k": 28,
#     "k_nn": 49,
#     "k_nn0": 700,
#     "k_tune": 7,
#     "n_proc": 32,
#     "no_gamma": false,
#     "p": 0.99,
#     "pp_n_thresh": 32,
#     "tau": 50,
#     "to_postprocess": true
# }
# intermed_opts:
# {
#     "algo": "best",
#     "eta_max": 25,
#     "eta_min": 5,
#     "len_S_thresh": 256,
#     "local_algo": "LDLE",
#     "n_proc": 32,
#     "n_times": 4
# }
# global_opts:
# {
#     "color_tear": true,
#     "compute_error": false,
#     "init_algo_align_w_parent_only": true,
#     "init_algo_name": "procrustes",
#     "k": 28,
#     "main_algo": "LDLE",
#     "max_iter": 20,
#     "n_proc": 32,
#     "nu": 3,
#     "refine_algo_alpha": 0.3,
#     "refine_algo_max_internal_iter": 100,
#     "refine_algo_name": "rgd",
#     "to_tear": true,
#     "vis_before_init": false
# }

# %%
ldle.fit(X=X)
# Out:
# Constructing unnorm graph Laplacian + its eigendecomposition.
# Done.
# ##############################
# Time elapsed from last time log: 7.1 seconds
# Total time elapsed: 7.1 seconds
# ##############################
# Computing Atilde: Inner Prod of Grad of EigFuncs.
# FEM for Atilde.
# Atilde: 0 points processed...
# Atilde: 2482 points processed...
# Atilde: 4964 points processed...
# Atilde: 7446 points processed...
# Atilde: 9928 points processed...
# Atilde: all points processed...
# Done.
# ##############################
# Time elapsed from last time log: 3.9 seconds
# Total time elapsed: 11.0 seconds
# ##############################
# Computing LDLE.
# local_param: all 9931 points processed...
# max distortion is 218.203338
# Done.
# ##############################
# Time elapsed from last time log: 2.3 seconds
# Total time elapsed: 13.4 seconds
# ##############################
# Posprocessing local parameterizations.
# #Param replaced: 8941, max distortion: 6.012715
# #Param replaced: 2559, max distortion: 5.239490
# #Param replaced: 630, max distortion: 5.094905
# #Param replaced: 374, max distortion: 4.693018
# #Param replaced: 312, max distortion: 4.693018
# #Param replaced: 228, max distortion: 4.693018
# #Param replaced: 183, max distortion: 4.693018
# #Param replaced: 218, max distortion: 4.693018
# #Param replaced: 322, max distortion: 4.693018
# #Param replaced: 221, max distortion: 4.693018
# #Param replaced: 165, max distortion: 4.693018
# #Param replaced: 101, max distortion: 4.693018
# #Param replaced: 62, max distortion: 4.693018
# #Param replaced: 40, max distortion: 4.693018
# #Param replaced: 23, max distortion: 4.693018
# #Param replaced: 16, max distortion: 4.693018
# #Param replaced: 2, max distortion: 4.693018
# #Param replaced: 0, max distortion: 4.693018
# Max local distortion after postprocessing: 4.69301823354583e+00
# Done.
# ##############################
# Time elapsed from last time log: 10.7 seconds
# Total time elapsed: 24.1 seconds
# ##############################
# Max local distortion = 4.69301823354583
# Constructing intermediate views.
# eta = 2.
# # non-empty views with sz < 2 = 9931
# #nodes in views with sz < 2 = 9931
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 9.3 seconds
# Total time elapsed: 10.1 seconds
# ##############################
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 291.8 seconds
# Total time elapsed: 301.9 seconds
# ##############################
# eta = 3.
# # non-empty views with sz < 3 = 337
# #nodes in views with sz < 3 = 674
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 2.4 seconds
# Total time elapsed: 304.3 seconds
# ##############################
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 8.9 seconds
# Total time elapsed: 313.2 seconds
# ##############################
# eta = 4.
# # non-empty views with sz < 4 = 310
# #nodes in views with sz < 4 = 930
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 2.0 seconds
# Total time elapsed: 315.2 seconds
# ##############################
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 23.0 seconds
# Total time elapsed: 338.2 seconds
# ##############################
# eta = 5.
# # non-empty views with sz < 5 = 238
# #nodes in views with sz < 5 = 952
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 2.0 seconds
# Total time elapsed: 340.3 seconds
# ##############################
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 32.7 seconds
# Total time elapsed: 372.9 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 1.7 seconds
# Total time elapsed: 374.7 seconds
# ##############################
# After clustering, max distortion is 6.808002
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 278 intermediate views
# Ambiguous overlaps checked for 556 intermediate views
# Ambiguous overlaps checked for 834 intermediate views
# Ambiguous overlaps checked for 1112 points
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 1
# Computing initial embedding using: procrustes algorithm
# ##############################
# Time elapsed from last time log: 13.1 seconds
# Total time elapsed: 13.1 seconds
# ##############################
# Initial alignment of 278 views completed
# Initial alignment of 556 views completed
# Initial alignment of 834 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 1.7 seconds
# Total time elapsed: 14.8 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 22.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11043 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 10.7 seconds
# Total time elapsed: 33.3 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 40.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11043 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 9.4 seconds
# Total time elapsed: 49.7 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 52.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11043 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 7.1 seconds
# Total time elapsed: 60.0 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 62.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11043 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 7.1 seconds
# Total time elapsed: 70.0 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 72.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11043 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 6.8 seconds
# Total time elapsed: 79.6 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 5
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 82.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11043 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 7.3 seconds
# Total time elapsed: 89.7 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 6
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 92.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11043 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 6.9 seconds
# Total time elapsed: 99.2 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 7
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 101.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11043 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 7.2 seconds
# Total time elapsed: 108.8 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 8
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 111.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11043 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 7.2 seconds
# Total time elapsed: 118.6 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 9
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 120.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11043 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 7.3 seconds
# Total time elapsed: 128.2 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 10
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 130.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11043 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 7.2 seconds
# Total time elapsed: 137.6 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 11
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 139.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11043 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 7.1 seconds
# Total time elapsed: 147.0 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 12
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 149.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11043 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 7.8 seconds
# Total time elapsed: 157.0 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 13
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 159.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11043 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 7.7 seconds
# Total time elapsed: 166.9 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 14
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 169.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11043 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 7.7 seconds
# Total time elapsed: 176.9 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 15
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 179.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11043 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 7.3 seconds
# Total time elapsed: 186.5 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 16
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 188.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11043 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 7.5 seconds
# Total time elapsed: 196.1 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 17
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 198.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11043 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 7.4 seconds
# Total time elapsed: 205.7 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 18
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 207.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11043 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 7.6 seconds
# Total time elapsed: 215.2 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 19
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 217.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11043 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 7.8 seconds
# Total time elapsed: 225.1 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 11043 multiplied with B
# Alignment error: 40.177
# ##############################
# Time elapsed from last time log: 4.1 seconds
# Total time elapsed: 229.2 seconds
# ##############################
# array([[ 0.47886997, -0.14021864],
#        [-0.29640058,  0.6098184 ],
#        [ 0.49549333, -0.22382267],
#        ...,
#        [-0.0613917 ,  0.01694155],
#        [-0.07042958,  0.00547731],
#        [-0.06068614,  0.00768368]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/spherewithhole//ldle.dat
