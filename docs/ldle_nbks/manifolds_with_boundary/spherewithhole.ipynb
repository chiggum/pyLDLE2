# %% [markdown]
# ### Sphere with hole

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
save_dir_root = '../data/pyLDLE2/spherewithhole/'

# %%
X, labelsMat, ddX = datasets.Datasets().spherewithhole()
# Out:
# X.shape =  (9931, 3)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LDLE'},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  intermed_opts={'eta_min': 10},
                  global_opts={
                      'max_iter': 10,
                      'init_algo_align_w_parent_only': True # Set this True for low noise
                  },
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 600 is created.

# %%
ldle.fit(X=X)
# Out:
# Constructing unnorm graph Laplacian + its eigendecomposition.
# Done.
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 2.2 seconds
# ##############################
# Computing Atilde: Inner Prod of Grad of EigFuncs.
# FEM for Atilde.
# Atilde: 0 points processed...
# Atilde: 2482 points processed...
# Atilde: 4964 points processed...
# Atilde: 7446 points processed...
# Atilde: 9928 points processed...
# Atilde: all points processed...
# Done.
# ##############################
# Time elapsed from last time log: 0.7 seconds
# Total time elapsed: 2.9 seconds
# ##############################
# Computing LDLE.
# local_param: all 9931 points processed...
# max distortion is 386.913377
# Done.
# ##############################
# Time elapsed from last time log: 1.2 seconds
# Total time elapsed: 4.2 seconds
# ##############################
# Posprocessing LDLE.
# Iter 1, Param replaced: 9079, max distortion: 20.741565
# Iter 2, Param replaced: 3423, max distortion: 11.917912
# Iter 3, Param replaced: 901, max distortion: 10.361537
# Iter 4, Param replaced: 391, max distortion: 10.361537
# Iter 5, Param replaced: 370, max distortion: 10.361537
# Iter 6, Param replaced: 353, max distortion: 10.361537
# Iter 7, Param replaced: 286, max distortion: 10.361537
# Iter 8, Param replaced: 272, max distortion: 10.361537
# Iter 9, Param replaced: 394, max distortion: 10.361537
# Iter 10, Param replaced: 385, max distortion: 10.361537
# Iter 11, Param replaced: 191, max distortion: 10.361537
# Iter 12, Param replaced: 102, max distortion: 10.361537
# Iter 13, Param replaced: 69, max distortion: 10.361537
# Iter 14, Param replaced: 52, max distortion: 10.361537
# Iter 15, Param replaced: 34, max distortion: 10.361537
# Iter 16, Param replaced: 14, max distortion: 10.361537
# Iter 17, Param replaced: 3, max distortion: 10.361537
# Iter 18, Param replaced: 0, max distortion: 10.361537
# Done.
# ##############################
# Time elapsed from last time log: 27.0 seconds
# Total time elapsed: 31.2 seconds
# ##############################
# Max local distortion = 1.0361537137368135e+01
# Constructing intermediate views.
# eta = 2.
# # non-empty views with sz < 2 = 9931
# #nodes in views with sz < 2 = 9931
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 10.5 seconds
# Total time elapsed: 10.6 seconds
# ##############################
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 119.4 seconds
# Total time elapsed: 129.9 seconds
# ##############################
# eta = 3.
# # non-empty views with sz < 3 = 297
# #nodes in views with sz < 3 = 594
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 0.6 seconds
# Total time elapsed: 130.6 seconds
# ##############################
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 2.9 seconds
# Total time elapsed: 133.4 seconds
# ##############################
# eta = 4.
# # non-empty views with sz < 4 = 269
# #nodes in views with sz < 4 = 807
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 0.9 seconds
# Total time elapsed: 134.3 seconds
# ##############################
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 7.4 seconds
# Total time elapsed: 141.7 seconds
# ##############################
# eta = 5.
# # non-empty views with sz < 5 = 219
# #nodes in views with sz < 5 = 876
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 0.7 seconds
# Total time elapsed: 142.4 seconds
# ##############################
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 9.6 seconds
# Total time elapsed: 152.0 seconds
# ##############################
# eta = 6.
# # non-empty views with sz < 6 = 206
# #nodes in views with sz < 6 = 1030
# Costs computed when eta = 6.
# ##############################
# Time elapsed from last time log: 0.9 seconds
# Total time elapsed: 152.9 seconds
# ##############################
# Remaining #nodes in views with sz < 6 = 0
# Done with eta = 6.
# ##############################
# Time elapsed from last time log: 14.5 seconds
# Total time elapsed: 167.4 seconds
# ##############################
# eta = 7.
# # non-empty views with sz < 7 = 119
# #nodes in views with sz < 7 = 714
# Costs computed when eta = 7.
# ##############################
# Time elapsed from last time log: 0.6 seconds
# Total time elapsed: 168.0 seconds
# ##############################
# Remaining #nodes in views with sz < 7 = 0
# Done with eta = 7.
# ##############################
# Time elapsed from last time log: 10.2 seconds
# Total time elapsed: 178.2 seconds
# ##############################
# eta = 8.
# # non-empty views with sz < 8 = 103
# #nodes in views with sz < 8 = 721
# Costs computed when eta = 8.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 178.7 seconds
# ##############################
# Remaining #nodes in views with sz < 8 = 0
# Done with eta = 8.
# ##############################
# Time elapsed from last time log: 11.8 seconds
# Total time elapsed: 190.5 seconds
# ##############################
# eta = 9.
# # non-empty views with sz < 9 = 75
# #nodes in views with sz < 9 = 600
# Costs computed when eta = 9.
# ##############################
# Time elapsed from last time log: 0.7 seconds
# Total time elapsed: 191.3 seconds
# ##############################
# Remaining #nodes in views with sz < 9 = 0
# Done with eta = 9.
# ##############################
# Time elapsed from last time log: 10.3 seconds
# Total time elapsed: 201.5 seconds
# ##############################
# eta = 10.
# # non-empty views with sz < 10 = 63
# #nodes in views with sz < 10 = 567
# Costs computed when eta = 10.
# ##############################
# Time elapsed from last time log: 0.7 seconds
# Total time elapsed: 202.2 seconds
# ##############################
# Remaining #nodes in views with sz < 10 = 0
# Done with eta = 10.
# ##############################
# Time elapsed from last time log: 11.4 seconds
# Total time elapsed: 213.6 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 214.1 seconds
# ##############################
# After clustering, max distortion is 17.035826
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 157 intermediate views
# Ambiguous overlaps checked for 314 intermediate views
# Ambiguous overlaps checked for 471 intermediate views
# Ambiguous overlaps checked for 628 intermediate views
# Ambiguous overlaps checked for 631 points
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 1
# Computing initial embedding using: sequential algorithm
# ##############################
# Time elapsed from last time log: 2.5 seconds
# Total time elapsed: 2.5 seconds
# ##############################
# Initial alignment of 157 views completed
# Initial alignment of 314 views completed
# Initial alignment of 471 views completed
# Initial alignment of 628 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 0.2 seconds
# Total time elapsed: 2.8 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 10.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10562 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 13.1 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 17.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10562 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.9 seconds
# Total time elapsed: 19.2 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 23.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10562 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.1 seconds
# Total time elapsed: 25.6 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 29.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10562 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.0 seconds
# Total time elapsed: 31.9 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 36.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10562 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.0 seconds
# Total time elapsed: 38.1 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 5
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 42.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10562 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.0 seconds
# Total time elapsed: 44.3 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 6
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 48.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10562 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.1 seconds
# Total time elapsed: 50.6 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 7
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 54.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10562 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.0 seconds
# Total time elapsed: 56.8 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 8
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 61.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10562 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.1 seconds
# Total time elapsed: 63.0 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 9
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 67.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10562 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.1 seconds
# Total time elapsed: 69.2 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 10562 multiplied with B
# Alignment error: 33.926
# ##############################
# Time elapsed from last time log: 1.0 seconds
# Total time elapsed: 70.2 seconds
# ##############################
# array([[ 0.5230109 ,  0.15747381],
#        [ 0.59141233, -0.04104424],
#        [ 0.57055088,  0.23608194],
#        ...,
#        [-0.08467799,  0.07242089],
#        [-0.09924672,  0.07135632],
#        [-0.09202752,  0.0780928 ]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/spherewithhole//ldle.dat
