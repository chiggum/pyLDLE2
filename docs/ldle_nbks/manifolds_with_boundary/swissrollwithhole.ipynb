# %% [markdown]
# ### Swissroll with hole

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
save_dir_root = '../data/pyLDLE2/swissrollwithhole/'

# %%
X, labelsMat, ddX = datasets.Datasets().swissrollwithhole()
# Out:
# X.shape =  (9946, 3)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LDLE'},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  intermed_opts={'eta_min': 10},
                  global_opts={
                      'max_iter': 10,
                      'init_algo_align_w_parent_only': True # Set this True for low noise
                  },
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 600 is created.

# %%
ldle.fit(X=X)
# Out:
# Constructing unnorm graph Laplacian + its eigendecomposition.
# Done.
# ##############################
# Time elapsed from last time log: 2.4 seconds
# Total time elapsed: 2.4 seconds
# ##############################
# Computing Atilde: Inner Prod of Grad of EigFuncs.
# FEM for Atilde.
# Atilde: 0 points processed...
# Atilde: 2486 points processed...
# Atilde: 4972 points processed...
# Atilde: 7458 points processed...
# Atilde: 9944 points processed...
# Atilde: all points processed...
# Done.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 3.2 seconds
# ##############################
# Computing LDLE.
# local_param: all 9946 points processed...
# max distortion is 1017999.472211
# Done.
# ##############################
# Time elapsed from last time log: 1.2 seconds
# Total time elapsed: 4.4 seconds
# ##############################
# Posprocessing LDLE.
# Iter 1, Param replaced: 9309, max distortion: 14.643088
# Iter 2, Param replaced: 3769, max distortion: 12.346364
# Iter 3, Param replaced: 755, max distortion: 11.795455
# Iter 4, Param replaced: 90, max distortion: 11.795455
# Iter 5, Param replaced: 31, max distortion: 11.795455
# Iter 6, Param replaced: 14, max distortion: 11.795455
# Iter 7, Param replaced: 4, max distortion: 11.795455
# Iter 8, Param replaced: 0, max distortion: 11.795455
# Done.
# ##############################
# Time elapsed from last time log: 16.2 seconds
# Total time elapsed: 20.7 seconds
# ##############################
# Max local distortion = 1.1795455295619739e+01
# Constructing intermediate views.
# eta = 2.
# # non-empty views with sz < 2 = 9946
# #nodes in views with sz < 2 = 9946
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 10.5 seconds
# Total time elapsed: 10.5 seconds
# ##############################
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 124.9 seconds
# Total time elapsed: 135.4 seconds
# ##############################
# eta = 3.
# # non-empty views with sz < 3 = 317
# #nodes in views with sz < 3 = 634
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 0.6 seconds
# Total time elapsed: 136.0 seconds
# ##############################
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 2.9 seconds
# Total time elapsed: 138.8 seconds
# ##############################
# eta = 4.
# # non-empty views with sz < 4 = 329
# #nodes in views with sz < 4 = 987
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 139.6 seconds
# ##############################
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 9.3 seconds
# Total time elapsed: 148.9 seconds
# ##############################
# eta = 5.
# # non-empty views with sz < 5 = 266
# #nodes in views with sz < 5 = 1064
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 149.7 seconds
# ##############################
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 11.1 seconds
# Total time elapsed: 160.8 seconds
# ##############################
# eta = 6.
# # non-empty views with sz < 6 = 187
# #nodes in views with sz < 6 = 935
# Costs computed when eta = 6.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 161.6 seconds
# ##############################
# Remaining #nodes in views with sz < 6 = 0
# Done with eta = 6.
# ##############################
# Time elapsed from last time log: 11.4 seconds
# Total time elapsed: 173.0 seconds
# ##############################
# eta = 7.
# # non-empty views with sz < 7 = 124
# #nodes in views with sz < 7 = 744
# Costs computed when eta = 7.
# ##############################
# Time elapsed from last time log: 0.7 seconds
# Total time elapsed: 173.6 seconds
# ##############################
# Remaining #nodes in views with sz < 7 = 0
# Done with eta = 7.
# ##############################
# Time elapsed from last time log: 10.7 seconds
# Total time elapsed: 184.3 seconds
# ##############################
# eta = 8.
# # non-empty views with sz < 8 = 111
# #nodes in views with sz < 8 = 777
# Costs computed when eta = 8.
# ##############################
# Time elapsed from last time log: 0.6 seconds
# Total time elapsed: 184.9 seconds
# ##############################
# Remaining #nodes in views with sz < 8 = 0
# Done with eta = 8.
# ##############################
# Time elapsed from last time log: 10.8 seconds
# Total time elapsed: 195.7 seconds
# ##############################
# eta = 9.
# # non-empty views with sz < 9 = 90
# #nodes in views with sz < 9 = 720
# Costs computed when eta = 9.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 196.2 seconds
# ##############################
# Remaining #nodes in views with sz < 9 = 0
# Done with eta = 9.
# ##############################
# Time elapsed from last time log: 10.5 seconds
# Total time elapsed: 206.7 seconds
# ##############################
# eta = 10.
# # non-empty views with sz < 10 = 64
# #nodes in views with sz < 10 = 576
# Costs computed when eta = 10.
# ##############################
# Time elapsed from last time log: 0.4 seconds
# Total time elapsed: 207.2 seconds
# ##############################
# Remaining #nodes in views with sz < 10 = 0
# Done with eta = 10.
# ##############################
# Time elapsed from last time log: 9.9 seconds
# Total time elapsed: 217.0 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 217.5 seconds
# ##############################
# After clustering, max distortion is 11.687065
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 156 intermediate views
# Ambiguous overlaps checked for 312 intermediate views
# Ambiguous overlaps checked for 468 intermediate views
# Ambiguous overlaps checked for 624 intermediate views
# Ambiguous overlaps checked for 625 points
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 1
# Computing initial embedding using: sequential algorithm
# ##############################
# Time elapsed from last time log: 2.3 seconds
# Total time elapsed: 2.3 seconds
# ##############################
# Initial alignment of 156 views completed
# Initial alignment of 312 views completed
# Initial alignment of 468 views completed
# Initial alignment of 624 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 0.2 seconds
# Total time elapsed: 2.6 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 10.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10571
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 29.1 seconds
# Total time elapsed: 39.7 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 44.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10571
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 30.1 seconds
# Total time elapsed: 74.1 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 78.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10571
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 29.9 seconds
# Total time elapsed: 108.0 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 111.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10571
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 30.3 seconds
# Total time elapsed: 142.3 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 146.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10571
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 30.7 seconds
# Total time elapsed: 176.8 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 5
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 180.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10571
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 34.5 seconds
# Total time elapsed: 215.4 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 6
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 219.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10571
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 32.7 seconds
# Total time elapsed: 252.2 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 7
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 256.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10571
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 27.8 seconds
# Total time elapsed: 284.2 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 8
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 288.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10571
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 27.5 seconds
# Total time elapsed: 315.6 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 9
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 319.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10571
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 27.7 seconds
# Total time elapsed: 347.3 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 10571
# Alignment error: 0.984
# ##############################
# Time elapsed from last time log: 2.9 seconds
# Total time elapsed: 350.3 seconds
# ##############################
# array([[ 0.78868002, -0.30351106],
#        [ 0.78764075, -0.30661099],
#        [ 0.78576488, -0.31212193],
#        ...,
#        [-0.71000744,  0.56698645],
#        [-0.71491291,  0.56537563],
#        [-0.71771322,  0.56443576]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/swissrollwithhole//ldle.dat
