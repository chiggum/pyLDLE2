# %% [markdown]
# ### Swissroll with hole

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
save_dir_root = '../data/pyLDLE2/swissrollwithhole/'

# %%
X, labelsMat, ddX = datasets.Datasets().swissrollwithhole()
# Out:
# X.shape =  (9946, 3)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LDLE'},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  intermed_opts={'eta_min': 15},
                  global_opts={
                      'max_iter': 10,
                      'init_algo_align_w_parent_only': True # Set this True for low noise
                  },
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 875 is created.

# %%
ldle.fit(X=X)
# Out:
# Constructing unnorm graph Laplacian + its eigendecomposition.
# Done.
# ##############################
# Time elapsed from last time log: 2.1 seconds
# Total time elapsed: 2.1 seconds
# ##############################
# Computing Atilde: Inner Prod of Grad of EigFuncs.
# FEM for Atilde.
# Atilde: 0 points processed...
# Atilde: 2486 points processed...
# Atilde: 4972 points processed...
# Atilde: 7458 points processed...
# Atilde: 9944 points processed...
# Atilde: all points processed...
# Done.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 2.9 seconds
# ##############################
# Computing LDLE.
# local_param: all 9946 points processed...
# max distortion is 79472.037695
# Done.
# ##############################
# Time elapsed from last time log: 1.3 seconds
# Total time elapsed: 4.2 seconds
# ##############################
# Posprocessing local parameterizations.
# #Param replaced: 9398, max distortion: 11.953777
# #Param replaced: 2371, max distortion: 10.196717
# #Param replaced: 266, max distortion: 10.196717
# #Param replaced: 45, max distortion: 10.196717
# #Param replaced: 2, max distortion: 10.196717
# #Param replaced: 0, max distortion: 10.196717
# Max local distortion after postprocessing: 1.0196717497296316e+01
# Done.
# ##############################
# Time elapsed from last time log: 9.1 seconds
# Total time elapsed: 13.3 seconds
# ##############################
# Max local distortion = 10.196717497296316
# Constructing intermediate views.
# eta = 2.
# # non-empty views with sz < 2 = 9946
# #nodes in views with sz < 2 = 9946
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 20.5 seconds
# Total time elapsed: 20.6 seconds
# ##############################
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 195.4 seconds
# Total time elapsed: 216.0 seconds
# ##############################
# eta = 3.
# # non-empty views with sz < 3 = 520
# #nodes in views with sz < 3 = 1040
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 1.5 seconds
# Total time elapsed: 217.5 seconds
# ##############################
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 12.6 seconds
# Total time elapsed: 230.1 seconds
# ##############################
# eta = 4.
# # non-empty views with sz < 4 = 401
# #nodes in views with sz < 4 = 1203
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 1.8 seconds
# Total time elapsed: 231.9 seconds
# ##############################
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 26.0 seconds
# Total time elapsed: 257.8 seconds
# ##############################
# eta = 5.
# # non-empty views with sz < 5 = 306
# #nodes in views with sz < 5 = 1224
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 1.7 seconds
# Total time elapsed: 259.6 seconds
# ##############################
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 31.0 seconds
# Total time elapsed: 290.6 seconds
# ##############################
# eta = 6.
# # non-empty views with sz < 6 = 184
# #nodes in views with sz < 6 = 920
# Costs computed when eta = 6.
# ##############################
# Time elapsed from last time log: 1.2 seconds
# Total time elapsed: 291.8 seconds
# ##############################
# Remaining #nodes in views with sz < 6 = 0
# Done with eta = 6.
# ##############################
# Time elapsed from last time log: 21.0 seconds
# Total time elapsed: 312.8 seconds
# ##############################
# eta = 7.
# # non-empty views with sz < 7 = 167
# #nodes in views with sz < 7 = 1002
# Costs computed when eta = 7.
# ##############################
# Time elapsed from last time log: 1.1 seconds
# Total time elapsed: 313.9 seconds
# ##############################
# Remaining #nodes in views with sz < 7 = 0
# Done with eta = 7.
# ##############################
# Time elapsed from last time log: 26.6 seconds
# Total time elapsed: 340.6 seconds
# ##############################
# eta = 8.
# # non-empty views with sz < 8 = 131
# #nodes in views with sz < 8 = 917
# Costs computed when eta = 8.
# ##############################
# Time elapsed from last time log: 1.3 seconds
# Total time elapsed: 341.9 seconds
# ##############################
# Remaining #nodes in views with sz < 8 = 0
# Done with eta = 8.
# ##############################
# Time elapsed from last time log: 28.9 seconds
# Total time elapsed: 370.8 seconds
# ##############################
# eta = 9.
# # non-empty views with sz < 9 = 79
# #nodes in views with sz < 9 = 632
# Costs computed when eta = 9.
# ##############################
# Time elapsed from last time log: 1.0 seconds
# Total time elapsed: 371.8 seconds
# ##############################
# Remaining #nodes in views with sz < 9 = 0
# Done with eta = 9.
# ##############################
# Time elapsed from last time log: 21.8 seconds
# Total time elapsed: 393.6 seconds
# ##############################
# eta = 10.
# # non-empty views with sz < 10 = 72
# #nodes in views with sz < 10 = 648
# Costs computed when eta = 10.
# ##############################
# Time elapsed from last time log: 1.0 seconds
# Total time elapsed: 394.6 seconds
# ##############################
# Remaining #nodes in views with sz < 10 = 0
# Done with eta = 10.
# ##############################
# Time elapsed from last time log: 21.0 seconds
# Total time elapsed: 415.6 seconds
# ##############################
# eta = 11.
# # non-empty views with sz < 11 = 64
# #nodes in views with sz < 11 = 640
# Costs computed when eta = 11.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 416.4 seconds
# ##############################
# Remaining #nodes in views with sz < 11 = 0
# Done with eta = 11.
# ##############################
# Time elapsed from last time log: 24.0 seconds
# Total time elapsed: 440.3 seconds
# ##############################
# eta = 12.
# # non-empty views with sz < 12 = 31
# #nodes in views with sz < 12 = 341
# Costs computed when eta = 12.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 440.8 seconds
# ##############################
# Remaining #nodes in views with sz < 12 = 0
# Done with eta = 12.
# ##############################
# Time elapsed from last time log: 10.5 seconds
# Total time elapsed: 451.3 seconds
# ##############################
# eta = 13.
# # non-empty views with sz < 13 = 29
# #nodes in views with sz < 13 = 348
# Costs computed when eta = 13.
# ##############################
# Time elapsed from last time log: 0.6 seconds
# Total time elapsed: 451.9 seconds
# ##############################
# Remaining #nodes in views with sz < 13 = 3
# Done with eta = 13.
# ##############################
# Time elapsed from last time log: 8.0 seconds
# Total time elapsed: 459.9 seconds
# ##############################
# eta = 14.
# # non-empty views with sz < 14 = 36
# #nodes in views with sz < 14 = 458
# Costs computed when eta = 14.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 460.4 seconds
# ##############################
# Remaining #nodes in views with sz < 14 = 23
# Done with eta = 14.
# ##############################
# Time elapsed from last time log: 9.0 seconds
# Total time elapsed: 469.4 seconds
# ##############################
# eta = 15.
# # non-empty views with sz < 15 = 23
# #nodes in views with sz < 15 = 247
# Costs computed when eta = 15.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 469.9 seconds
# ##############################
# Remaining #nodes in views with sz < 15 = 35
# Done with eta = 15.
# ##############################
# Time elapsed from last time log: 3.2 seconds
# Total time elapsed: 473.1 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 473.6 seconds
# ##############################
# After clustering, max distortion is 163.349102
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 113 intermediate views
# Ambiguous overlaps checked for 226 intermediate views
# Ambiguous overlaps checked for 339 intermediate views
# Ambiguous overlaps checked for 452 intermediate views
# Ambiguous overlaps checked for 455 points
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 1
# Computing initial embedding using: sequential algorithm
# ##############################
# Time elapsed from last time log: 1.9 seconds
# Total time elapsed: 1.9 seconds
# ##############################
# Initial alignment of 113 views completed
# Initial alignment of 226 views completed
# Initial alignment of 339 views completed
# Initial alignment of 452 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 0.4 seconds
# Total time elapsed: 2.3 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 3.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10401 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.6 seconds
# Total time elapsed: 5.0 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 5.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10401 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.6 seconds
# Total time elapsed: 7.4 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 8.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10401 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.7 seconds
# Total time elapsed: 9.7 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 10.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10401 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.7 seconds
# Total time elapsed: 11.9 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 12.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10401 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.7 seconds
# Total time elapsed: 14.2 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 5
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 14.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10401 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.7 seconds
# Total time elapsed: 16.3 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 6
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 16.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10401 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.7 seconds
# Total time elapsed: 18.4 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 7
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 18.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10401 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.7 seconds
# Total time elapsed: 20.5 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 8
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 21.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10401 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.7 seconds
# Total time elapsed: 22.6 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 9
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 23.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10401 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.6 seconds
# Total time elapsed: 24.7 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 10401 multiplied with B
# Alignment error: 2.417
# ##############################
# Time elapsed from last time log: 0.7 seconds
# Total time elapsed: 25.4 seconds
# ##############################
# array([[ 0.77625235,  0.34363103],
#        [ 0.77525165,  0.34635099],
#        [ 0.77339628,  0.35119407],
#        ...,
#        [-0.77972545, -0.3996585 ],
#        [-0.78324854, -0.39479052],
#        [-0.78524968, -0.39199161]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/swissrollwithhole//ldle.dat
