# %% [markdown]
# ### Square with two holes

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
save_dir_root = '../data/pyLDLE2/squarewithtwoholes/'

# %%
X, labelsMat, ddX = datasets.Datasets().squarewithtwoholes()
# Out:
# X.shape =  (9169, 2)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LDLE', 'k': 35},
                  intermed_opts={'algo':'best', 'eta_min': 15},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 875 is created.
# Options provided:
# local_opts:
# {
#     "Atilde_method": "LDLE_1",
#     "N": 100,
#     "algo": "LDLE",
#     "delta": 0.9,
#     "gl_type": "unnorm",
#     "k": 35,
#     "k_nn": 49,
#     "k_nn0": 875,
#     "k_tune": 7,
#     "n_proc": 32,
#     "no_gamma": false,
#     "p": 0.99,
#     "pp_n_thresh": 32,
#     "tau": 50,
#     "to_postprocess": true
# }
# intermed_opts:
# {
#     "algo": "best",
#     "eta_max": 25,
#     "eta_min": 15,
#     "len_S_thresh": 256,
#     "local_algo": "LDLE",
#     "n_proc": 32,
#     "n_times": 4
# }
# global_opts:
# {
#     "color_tear": true,
#     "compute_error": false,
#     "init_algo_align_w_parent_only": true,
#     "init_algo_name": "procrustes",
#     "k": 35,
#     "main_algo": "LDLE",
#     "max_iter": 20,
#     "n_proc": 32,
#     "nu": 3,
#     "refine_algo_alpha": 0.3,
#     "refine_algo_max_internal_iter": 100,
#     "refine_algo_name": "rgd",
#     "to_tear": true,
#     "vis_before_init": false
# }

# %%
ldle.fit(X=X)
# Out:
# Constructing unnorm graph Laplacian + its eigendecomposition.
# Done.
# ##############################
# Time elapsed from last time log: 7.2 seconds
# Total time elapsed: 7.2 seconds
# ##############################
# Computing Atilde: Inner Prod of Grad of EigFuncs.
# FEM for Atilde.
# Atilde: 0 points processed...
# Atilde: 2292 points processed...
# Atilde: 4584 points processed...
# Atilde: 6876 points processed...
# Atilde: 9168 points processed...
# Atilde: all points processed...
# Done.
# ##############################
# Time elapsed from last time log: 5.4 seconds
# Total time elapsed: 12.6 seconds
# ##############################
# Computing LDLE.
# local_param: all 9169 points processed...
# max distortion is 23254.764580
# Done.
# ##############################
# Time elapsed from last time log: 2.3 seconds
# Total time elapsed: 15.0 seconds
# ##############################
# Posprocessing local parameterizations.
# #Param replaced: 8646, max distortion: 11.273144
# #Param replaced: 2027, max distortion: 9.858051
# #Param replaced: 200, max distortion: 9.858051
# #Param replaced: 13, max distortion: 9.858051
# #Param replaced: 0, max distortion: 9.858051
# Max local distortion after postprocessing: 9.858051170232223e+00
# Done.
# ##############################
# Time elapsed from last time log: 8.0 seconds
# Total time elapsed: 23.0 seconds
# ##############################
# Max local distortion = 9.858051170232223
# Constructing intermediate views.
# eta = 2.
# # non-empty views with sz < 2 = 9169
# #nodes in views with sz < 2 = 9169
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 13.3 seconds
# Total time elapsed: 14.1 seconds
# ##############################
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 319.1 seconds
# Total time elapsed: 333.2 seconds
# ##############################
# eta = 3.
# # non-empty views with sz < 3 = 522
# #nodes in views with sz < 3 = 1044
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 2.9 seconds
# Total time elapsed: 336.1 seconds
# ##############################
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 28.2 seconds
# Total time elapsed: 364.3 seconds
# ##############################
# eta = 4.
# # non-empty views with sz < 4 = 379
# #nodes in views with sz < 4 = 1137
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 2.7 seconds
# Total time elapsed: 367.0 seconds
# ##############################
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 43.4 seconds
# Total time elapsed: 410.4 seconds
# ##############################
# eta = 5.
# # non-empty views with sz < 5 = 260
# #nodes in views with sz < 5 = 1040
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 2.3 seconds
# Total time elapsed: 412.7 seconds
# ##############################
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 46.5 seconds
# Total time elapsed: 459.3 seconds
# ##############################
# eta = 6.
# # non-empty views with sz < 6 = 205
# #nodes in views with sz < 6 = 1025
# Costs computed when eta = 6.
# ##############################
# Time elapsed from last time log: 2.3 seconds
# Total time elapsed: 461.6 seconds
# ##############################
# Remaining #nodes in views with sz < 6 = 0
# Done with eta = 6.
# ##############################
# Time elapsed from last time log: 54.4 seconds
# Total time elapsed: 516.0 seconds
# ##############################
# eta = 7.
# # non-empty views with sz < 7 = 148
# #nodes in views with sz < 7 = 888
# Costs computed when eta = 7.
# ##############################
# Time elapsed from last time log: 2.5 seconds
# Total time elapsed: 518.5 seconds
# ##############################
# Remaining #nodes in views with sz < 7 = 0
# Done with eta = 7.
# ##############################
# Time elapsed from last time log: 41.7 seconds
# Total time elapsed: 560.2 seconds
# ##############################
# eta = 8.
# # non-empty views with sz < 8 = 92
# #nodes in views with sz < 8 = 644
# Costs computed when eta = 8.
# ##############################
# Time elapsed from last time log: 1.8 seconds
# Total time elapsed: 562.0 seconds
# ##############################
# Remaining #nodes in views with sz < 8 = 0
# Done with eta = 8.
# ##############################
# Time elapsed from last time log: 34.7 seconds
# Total time elapsed: 596.8 seconds
# ##############################
# eta = 9.
# # non-empty views with sz < 9 = 95
# #nodes in views with sz < 9 = 760
# Costs computed when eta = 9.
# ##############################
# Time elapsed from last time log: 2.0 seconds
# Total time elapsed: 598.8 seconds
# ##############################
# Remaining #nodes in views with sz < 9 = 0
# Done with eta = 9.
# ##############################
# Time elapsed from last time log: 48.9 seconds
# Total time elapsed: 647.7 seconds
# ##############################
# eta = 10.
# # non-empty views with sz < 10 = 50
# #nodes in views with sz < 10 = 450
# Costs computed when eta = 10.
# ##############################
# Time elapsed from last time log: 1.8 seconds
# Total time elapsed: 649.4 seconds
# ##############################
# Remaining #nodes in views with sz < 10 = 0
# Done with eta = 10.
# ##############################
# Time elapsed from last time log: 23.4 seconds
# Total time elapsed: 672.8 seconds
# ##############################
# eta = 11.
# # non-empty views with sz < 11 = 58
# #nodes in views with sz < 11 = 580
# Costs computed when eta = 11.
# ##############################
# Time elapsed from last time log: 1.7 seconds
# Total time elapsed: 674.5 seconds
# ##############################
# Remaining #nodes in views with sz < 11 = 0
# Done with eta = 11.
# ##############################
# Time elapsed from last time log: 28.0 seconds
# Total time elapsed: 702.5 seconds
# ##############################
# eta = 12.
# # non-empty views with sz < 12 = 37
# #nodes in views with sz < 12 = 407
# Costs computed when eta = 12.
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 704.7 seconds
# ##############################
# Remaining #nodes in views with sz < 12 = 0
# Done with eta = 12.
# ##############################
# Time elapsed from last time log: 20.4 seconds
# Total time elapsed: 725.0 seconds
# ##############################
# eta = 13.
# # non-empty views with sz < 13 = 27
# #nodes in views with sz < 13 = 324
# Costs computed when eta = 13.
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 727.2 seconds
# ##############################
# Remaining #nodes in views with sz < 13 = 0
# Done with eta = 13.
# ##############################
# Time elapsed from last time log: 14.5 seconds
# Total time elapsed: 741.8 seconds
# ##############################
# eta = 14.
# # non-empty views with sz < 14 = 21
# #nodes in views with sz < 14 = 273
# Costs computed when eta = 14.
# ##############################
# Time elapsed from last time log: 2.1 seconds
# Total time elapsed: 743.9 seconds
# ##############################
# Remaining #nodes in views with sz < 14 = 1
# Done with eta = 14.
# ##############################
# Time elapsed from last time log: 13.0 seconds
# Total time elapsed: 756.8 seconds
# ##############################
# eta = 15.
# # non-empty views with sz < 15 = 22
# #nodes in views with sz < 15 = 295
# Costs computed when eta = 15.
# ##############################
# Time elapsed from last time log: 2.0 seconds
# Total time elapsed: 758.9 seconds
# ##############################
# Remaining #nodes in views with sz < 15 = 16
# Done with eta = 15.
# ##############################
# Time elapsed from last time log: 9.3 seconds
# Total time elapsed: 768.2 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 0.9 seconds
# Total time elapsed: 769.2 seconds
# ##############################
# After clustering, max distortion is 14981.959652
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 105 intermediate views
# Ambiguous overlaps checked for 210 intermediate views
# Ambiguous overlaps checked for 315 intermediate views
# Ambiguous overlaps checked for 420 intermediate views
# Ambiguous overlaps checked for 422 points
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 1
# Computing initial embedding using: procrustes algorithm
# ##############################
# Time elapsed from last time log: 3.6 seconds
# Total time elapsed: 3.6 seconds
# ##############################
# Initial alignment of 105 views completed
# Initial alignment of 210 views completed
# Initial alignment of 315 views completed
# Initial alignment of 420 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 0.6 seconds
# Total time elapsed: 4.3 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 6.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9591 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 5.4 seconds
# Total time elapsed: 11.8 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 12.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9591 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.9 seconds
# Total time elapsed: 17.6 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 18.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9591 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.7 seconds
# Total time elapsed: 23.0 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 23.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9591 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.9 seconds
# Total time elapsed: 28.6 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 29.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9591 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.9 seconds
# Total time elapsed: 34.3 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 5
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 35.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9591 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 5.0 seconds
# Total time elapsed: 40.2 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 6
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 41.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9591 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 5.0 seconds
# Total time elapsed: 46.1 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 7
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 46.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9591 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.5 seconds
# Total time elapsed: 51.4 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 8
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 52.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9591 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.4 seconds
# Total time elapsed: 56.7 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 9
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 57.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9591 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.3 seconds
# Total time elapsed: 61.7 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 10
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 62.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9591 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 3.7 seconds
# Total time elapsed: 66.4 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 11
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 67.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9591 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 3.8 seconds
# Total time elapsed: 70.9 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 12
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 71.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9591 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.0 seconds
# Total time elapsed: 75.5 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 13
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 76.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9591 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.1 seconds
# Total time elapsed: 80.4 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 14
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 81.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9591 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.9 seconds
# Total time elapsed: 86.2 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 15
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 87.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9591 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.7 seconds
# Total time elapsed: 91.8 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 16
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 92.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9591 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.8 seconds
# Total time elapsed: 97.3 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 17
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 98.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9591 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.5 seconds
# Total time elapsed: 102.6 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 18
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 103.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9591 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 3.5 seconds
# Total time elapsed: 106.9 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 19
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 107.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9591 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.7 seconds
# Total time elapsed: 112.6 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 9591 multiplied with B
# Alignment error: 3.402
# ##############################
# Time elapsed from last time log: 1.6 seconds
# Total time elapsed: 114.2 seconds
# ##############################
# array([[-0.59556004, -0.21894323],
#        [-0.594241  , -0.21573258],
#        [-0.59183488, -0.20997076],
#        ...,
#        [ 0.60675209,  0.20877711],
#        [ 0.60832427,  0.21481667],
#        [ 0.60926321,  0.21822485]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/squarewithtwoholes//ldle.dat
