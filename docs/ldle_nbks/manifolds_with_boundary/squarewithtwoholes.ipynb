# %% [markdown]
# ### Square with two holes

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
save_dir_root = '../data/pyLDLE2/squarewithtwoholes/'

# %%
X, labelsMat, ddX = datasets.Datasets().squarewithtwoholes()
# Out:
# X.shape =  (9169, 2)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LDLE'},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  intermed_opts={'eta_min': 10},
                  global_opts={
                      'max_iter': 10,
                      'init_algo_align_w_parent_only': True # Set this True for low noise
                  },
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 600 is created.

# %%
ldle.fit(X=X)
# Out:
# Constructing unnorm graph Laplacian + its eigendecomposition.
# Done.
# ##############################
# Time elapsed from last time log: 3.1 seconds
# Total time elapsed: 3.1 seconds
# ##############################
# Computing Atilde: Inner Prod of Grad of EigFuncs.
# FEM for Atilde.
# Atilde: 0 points processed...
# Atilde: 2292 points processed...
# Atilde: 4584 points processed...
# Atilde: 6876 points processed...
# Atilde: 9168 points processed...
# Atilde: all points processed...
# Done.
# ##############################
# Time elapsed from last time log: 0.9 seconds
# Total time elapsed: 4.1 seconds
# ##############################
# Computing LDLE.
# local_param: all 9169 points processed...
# max distortion is 233938.083767
# Done.
# ##############################
# Time elapsed from last time log: 1.4 seconds
# Total time elapsed: 5.5 seconds
# ##############################
# Posprocessing LDLE.
# Iter 1, Param replaced: 8645, max distortion: 24.938572
# Iter 2, Param replaced: 3072, max distortion: 14.311533
# Iter 3, Param replaced: 579, max distortion: 13.531850
# Iter 4, Param replaced: 74, max distortion: 12.434801
# Iter 5, Param replaced: 8, max distortion: 12.434801
# Iter 6, Param replaced: 0, max distortion: 12.434801
# Done.
# ##############################
# Time elapsed from last time log: 13.1 seconds
# Total time elapsed: 18.5 seconds
# ##############################
# Max local distortion = 1.2434801338841467e+01
# Constructing intermediate views.
# eta = 2.
# # non-empty views with sz < 2 = 9169
# #nodes in views with sz < 2 = 9169
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 12.0 seconds
# Total time elapsed: 12.1 seconds
# ##############################
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 132.8 seconds
# Total time elapsed: 144.8 seconds
# ##############################
# eta = 3.
# # non-empty views with sz < 3 = 403
# #nodes in views with sz < 3 = 806
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 0.7 seconds
# Total time elapsed: 145.5 seconds
# ##############################
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 4.3 seconds
# Total time elapsed: 149.8 seconds
# ##############################
# eta = 4.
# # non-empty views with sz < 4 = 368
# #nodes in views with sz < 4 = 1104
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 1.0 seconds
# Total time elapsed: 150.8 seconds
# ##############################
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 11.6 seconds
# Total time elapsed: 162.4 seconds
# ##############################
# eta = 5.
# # non-empty views with sz < 5 = 225
# #nodes in views with sz < 5 = 900
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 0.7 seconds
# Total time elapsed: 163.1 seconds
# ##############################
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 10.6 seconds
# Total time elapsed: 173.7 seconds
# ##############################
# eta = 6.
# # non-empty views with sz < 6 = 191
# #nodes in views with sz < 6 = 955
# Costs computed when eta = 6.
# ##############################
# Time elapsed from last time log: 0.7 seconds
# Total time elapsed: 174.4 seconds
# ##############################
# Remaining #nodes in views with sz < 6 = 0
# Done with eta = 6.
# ##############################
# Time elapsed from last time log: 16.2 seconds
# Total time elapsed: 190.6 seconds
# ##############################
# eta = 7.
# # non-empty views with sz < 7 = 137
# #nodes in views with sz < 7 = 822
# Costs computed when eta = 7.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 191.4 seconds
# ##############################
# Remaining #nodes in views with sz < 7 = 0
# Done with eta = 7.
# ##############################
# Time elapsed from last time log: 14.6 seconds
# Total time elapsed: 206.0 seconds
# ##############################
# eta = 8.
# # non-empty views with sz < 8 = 103
# #nodes in views with sz < 8 = 721
# Costs computed when eta = 8.
# ##############################
# Time elapsed from last time log: 0.7 seconds
# Total time elapsed: 206.7 seconds
# ##############################
# Remaining #nodes in views with sz < 8 = 0
# Done with eta = 8.
# ##############################
# Time elapsed from last time log: 13.7 seconds
# Total time elapsed: 220.4 seconds
# ##############################
# eta = 9.
# # non-empty views with sz < 9 = 88
# #nodes in views with sz < 9 = 704
# Costs computed when eta = 9.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 221.2 seconds
# ##############################
# Remaining #nodes in views with sz < 9 = 0
# Done with eta = 9.
# ##############################
# Time elapsed from last time log: 15.7 seconds
# Total time elapsed: 236.9 seconds
# ##############################
# eta = 10.
# # non-empty views with sz < 10 = 77
# #nodes in views with sz < 10 = 693
# Costs computed when eta = 10.
# ##############################
# Time elapsed from last time log: 0.7 seconds
# Total time elapsed: 237.6 seconds
# ##############################
# Remaining #nodes in views with sz < 10 = 0
# Done with eta = 10.
# ##############################
# Time elapsed from last time log: 13.7 seconds
# Total time elapsed: 251.3 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 251.8 seconds
# ##############################
# After clustering, max distortion is 13.569148
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 144 intermediate views
# Ambiguous overlaps checked for 288 intermediate views
# Ambiguous overlaps checked for 432 intermediate views
# Ambiguous overlaps checked for 576 points
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 1
# Computing initial embedding using: sequential algorithm
# ##############################
# Time elapsed from last time log: 3.4 seconds
# Total time elapsed: 3.4 seconds
# ##############################
# Initial alignment of 144 views completed
# Initial alignment of 288 views completed
# Initial alignment of 432 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 0.3 seconds
# Total time elapsed: 3.7 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 13.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9745
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 31.9 seconds
# Total time elapsed: 45.7 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 51.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9745
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 33.4 seconds
# Total time elapsed: 84.4 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 90.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9745
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 32.7 seconds
# Total time elapsed: 122.7 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 128.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9745
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 38.1 seconds
# Total time elapsed: 166.2 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 171.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9745
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 36.9 seconds
# Total time elapsed: 208.6 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 5
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 213.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9745
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 32.2 seconds
# Total time elapsed: 245.5 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 6
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 249.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9745
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 31.8 seconds
# Total time elapsed: 281.5 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 7
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 285.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9745
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 30.9 seconds
# Total time elapsed: 316.7 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 8
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 320.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9745
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 27.4 seconds
# Total time elapsed: 347.5 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 9
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 351.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9745
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 27.0 seconds
# Total time elapsed: 378.4 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 9745
# Alignment error: 1.140
# ##############################
# Time elapsed from last time log: 3.0 seconds
# Total time elapsed: 381.4 seconds
# ##############################
# array([[-0.38115623, -0.52236279],
#        [-0.38172672, -0.51931039],
#        [-0.38275433, -0.51385629],
#        ...,
#        [ 0.3880311 ,  0.50927004],
#        [ 0.38759838,  0.51476505],
#        [ 0.38735458,  0.51783924]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/squarewithtwoholes//ldle.dat
