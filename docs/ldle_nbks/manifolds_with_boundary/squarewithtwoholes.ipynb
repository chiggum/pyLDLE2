# %% [markdown]
# ### Square with two holes

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
save_dir_root = '../data/pyLDLE2/squarewithtwoholes/'

# %%
X, labelsMat, ddX = datasets.Datasets().squarewithtwoholes()
# Out:
# X.shape =  (9169, 2)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LDLE', 'k': 35},
                  intermed_opts={'algo':'best', 'eta_min': 15},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 875 is created.
# Options provided:
# local_opts:
# {
#     "Atilde_method": "LDLE_1",
#     "N": 100,
#     "algo": "LDLE",
#     "alpha": 1,
#     "debug": true,
#     "delta": 0.9,
#     "gl_type": "unnorm",
#     "k": 35,
#     "k_nn": 49,
#     "k_nn0": 875,
#     "k_tune": 7,
#     "max_iter": 300,
#     "n_proc": 32,
#     "no_gamma": false,
#     "p": 0.99,
#     "pp_n_thresh": 32,
#     "reg": 0.0,
#     "tau": 50,
#     "to_postprocess": true,
#     "verbose": true
# }
# intermed_opts:
# {
#     "algo": "best",
#     "debug": true,
#     "eta_max": 25,
#     "eta_min": 15,
#     "len_S_thresh": 256,
#     "local_algo": "LDLE",
#     "n_proc": 32,
#     "n_times": 4,
#     "verbose": true
# }
# global_opts:
# {
#     "align_w_parent_only": true,
#     "alpha": 0.3,
#     "color_tear": true,
#     "compute_error": false,
#     "debug": true,
#     "eps": 1e-08,
#     "init_algo_name": "procrustes",
#     "k": 35,
#     "main_algo": "LDLE",
#     "max_internal_iter": 100,
#     "max_iter": 20,
#     "n_proc": 32,
#     "nu": 3,
#     "refine_algo_name": "rgd",
#     "to_tear": true,
#     "verbose": true,
#     "vis_before_init": false
# }

# %%
ldle.fit(X=X)
# Out:
# Constructing unnorm graph Laplacian + its eigendecomposition.
# Done.
# ##############################
# Time elapsed from last time log: 2.8 seconds
# Total time elapsed: 2.8 seconds
# ##############################
# Computing Atilde: Inner Prod of Grad of EigFuncs.
# FEM for Atilde.
# Atilde: 0 points processed...
# Atilde: 2292 points processed...
# Atilde: 4584 points processed...
# Atilde: 6876 points processed...
# Atilde: 9168 points processed...
# Atilde: all points processed...
# Done.
# ##############################
# Time elapsed from last time log: 1.2 seconds
# Total time elapsed: 4.0 seconds
# ##############################
# Computing LDLE.
# local_param: all 9169 points processed...
# max distortion is 23254.764580
# Done.
# ##############################
# Time elapsed from last time log: 1.6 seconds
# Total time elapsed: 5.7 seconds
# ##############################
# Posprocessing local parameterizations.
# #Param replaced: 8646, max distortion: 11.273144
# #Param replaced: 2027, max distortion: 9.858051
# #Param replaced: 200, max distortion: 9.858051
# #Param replaced: 13, max distortion: 9.858051
# #Param replaced: 0, max distortion: 9.858051
# Max local distortion after postprocessing: 9.858051170232223e+00
# Done.
# ##############################
# Time elapsed from last time log: 6.3 seconds
# Total time elapsed: 12.0 seconds
# ##############################
# Max local distortion = 9.858051170232223
# Constructing intermediate views.
# eta = 2.
# #non-empty views with sz < 2 = 9169
# #nodes in views with sz < 2 = 9169
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 12.8 seconds
# Total time elapsed: 13.5 seconds
# ##############################
# ctr=7043, total_len_S=45401, avg_len_S=6.446
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 213.0 seconds
# Total time elapsed: 226.4 seconds
# ##############################
# eta = 3.
# #non-empty views with sz < 3 = 519
# #nodes in views with sz < 3 = 1038
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 1.9 seconds
# Total time elapsed: 228.4 seconds
# ##############################
# ctr=925, total_len_S=20366, avg_len_S=22.017
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 14.3 seconds
# Total time elapsed: 242.7 seconds
# ##############################
# eta = 4.
# #non-empty views with sz < 4 = 374
# #nodes in views with sz < 4 = 1122
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 1.8 seconds
# Total time elapsed: 244.5 seconds
# ##############################
# ctr=1014, total_len_S=31048, avg_len_S=30.619
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 24.0 seconds
# Total time elapsed: 268.5 seconds
# ##############################
# eta = 5.
# #non-empty views with sz < 5 = 257
# #nodes in views with sz < 5 = 1028
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 1.7 seconds
# Total time elapsed: 270.2 seconds
# ##############################
# ctr=933, total_len_S=35382, avg_len_S=37.923
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 24.2 seconds
# Total time elapsed: 294.4 seconds
# ##############################
# eta = 6.
# #non-empty views with sz < 6 = 200
# #nodes in views with sz < 6 = 1000
# Costs computed when eta = 6.
# ##############################
# Time elapsed from last time log: 1.6 seconds
# Total time elapsed: 296.0 seconds
# ##############################
# ctr=951, total_len_S=41166, avg_len_S=43.287
# Remaining #nodes in views with sz < 6 = 0
# Done with eta = 6.
# ##############################
# Time elapsed from last time log: 30.1 seconds
# Total time elapsed: 326.1 seconds
# ##############################
# eta = 7.
# #non-empty views with sz < 7 = 141
# #nodes in views with sz < 7 = 846
# Costs computed when eta = 7.
# ##############################
# Time elapsed from last time log: 1.7 seconds
# Total time elapsed: 327.8 seconds
# ##############################
# ctr=767, total_len_S=37708, avg_len_S=49.163
# Remaining #nodes in views with sz < 7 = 0
# Done with eta = 7.
# ##############################
# Time elapsed from last time log: 23.1 seconds
# Total time elapsed: 350.9 seconds
# ##############################
# eta = 8.
# #non-empty views with sz < 8 = 91
# #nodes in views with sz < 8 = 637
# Costs computed when eta = 8.
# ##############################
# Time elapsed from last time log: 1.4 seconds
# Total time elapsed: 352.3 seconds
# ##############################
# ctr=614, total_len_S=32686, avg_len_S=53.235
# Remaining #nodes in views with sz < 8 = 0
# Done with eta = 8.
# ##############################
# Time elapsed from last time log: 19.2 seconds
# Total time elapsed: 371.5 seconds
# ##############################
# eta = 9.
# #non-empty views with sz < 9 = 95
# #nodes in views with sz < 9 = 760
# Costs computed when eta = 9.
# ##############################
# Time elapsed from last time log: 1.5 seconds
# Total time elapsed: 373.0 seconds
# ##############################
# ctr=687, total_len_S=40858, avg_len_S=59.473
# Remaining #nodes in views with sz < 9 = 0
# Done with eta = 9.
# ##############################
# Time elapsed from last time log: 27.6 seconds
# Total time elapsed: 400.6 seconds
# ##############################
# eta = 10.
# #non-empty views with sz < 10 = 59
# #nodes in views with sz < 10 = 531
# Costs computed when eta = 10.
# ##############################
# Time elapsed from last time log: 1.5 seconds
# Total time elapsed: 402.0 seconds
# ##############################
# ctr=516, total_len_S=32350, avg_len_S=62.694
# Remaining #nodes in views with sz < 10 = 0
# Done with eta = 10.
# ##############################
# Time elapsed from last time log: 16.0 seconds
# Total time elapsed: 418.1 seconds
# ##############################
# eta = 11.
# #non-empty views with sz < 11 = 52
# #nodes in views with sz < 11 = 520
# Costs computed when eta = 11.
# ##############################
# Time elapsed from last time log: 1.4 seconds
# Total time elapsed: 419.5 seconds
# ##############################
# ctr=493, total_len_S=30944, avg_len_S=62.767
# Remaining #nodes in views with sz < 11 = 0
# Done with eta = 11.
# ##############################
# Time elapsed from last time log: 15.8 seconds
# Total time elapsed: 435.3 seconds
# ##############################
# eta = 12.
# #non-empty views with sz < 12 = 37
# #nodes in views with sz < 12 = 407
# Costs computed when eta = 12.
# ##############################
# Time elapsed from last time log: 1.3 seconds
# Total time elapsed: 436.7 seconds
# ##############################
# ctr=390, total_len_S=27494, avg_len_S=70.497
# Remaining #nodes in views with sz < 12 = 0
# Done with eta = 12.
# ##############################
# Time elapsed from last time log: 12.7 seconds
# Total time elapsed: 449.4 seconds
# ##############################
# eta = 13.
# #non-empty views with sz < 13 = 29
# #nodes in views with sz < 13 = 348
# Costs computed when eta = 13.
# ##############################
# Time elapsed from last time log: 1.5 seconds
# Total time elapsed: 450.9 seconds
# ##############################
# ctr=358, total_len_S=25261, avg_len_S=70.561
# Remaining #nodes in views with sz < 13 = 0
# Done with eta = 13.
# ##############################
# Time elapsed from last time log: 11.6 seconds
# Total time elapsed: 462.5 seconds
# ##############################
# eta = 14.
# #non-empty views with sz < 14 = 23
# #nodes in views with sz < 14 = 299
# Costs computed when eta = 14.
# ##############################
# Time elapsed from last time log: 1.4 seconds
# Total time elapsed: 463.8 seconds
# ##############################
# ctr=267, total_len_S=19536, avg_len_S=73.169
# Remaining #nodes in views with sz < 14 = 4
# Done with eta = 14.
# ##############################
# Time elapsed from last time log: 7.8 seconds
# Total time elapsed: 471.6 seconds
# ##############################
# eta = 15.
# #non-empty views with sz < 15 = 19
# #nodes in views with sz < 15 = 242
# Costs computed when eta = 15.
# ##############################
# Time elapsed from last time log: 1.2 seconds
# Total time elapsed: 472.9 seconds
# ##############################
# ctr=218, total_len_S=17463, avg_len_S=80.106
# Remaining #nodes in views with sz < 15 = 14
# Done with eta = 15.
# ##############################
# Time elapsed from last time log: 6.2 seconds
# Total time elapsed: 479.1 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 479.6 seconds
# ##############################
# After clustering, max distortion is 11522.633095
# Computing laterations scores for overlaps b/w intermed views
# Done
# ##############################
# Time elapsed from last time log: 1.3 seconds
# Total time elapsed: 1.3 seconds
# ##############################
# Computing a lateration.
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 1
# Done.
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 1.3 seconds
# ##############################
# Computing initial embedding using: procrustes algorithm
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 1.3 seconds
# ##############################
# Initial alignment of 105 views completed
# Initial alignment of 210 views completed
# Initial alignment of 315 views completed
# Initial alignment of 420 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 1.8 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 3.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9169 + 421 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 3.0 seconds
# Total time elapsed: 6.2 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 6.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9169 + 421 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 3.1 seconds
# Total time elapsed: 10.0 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 10.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9169 + 421 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.9 seconds
# Total time elapsed: 13.6 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 14.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9169 + 421 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.9 seconds
# Total time elapsed: 17.2 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 17.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9169 + 421 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 3.1 seconds
# Total time elapsed: 21.0 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 5
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 21.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9169 + 421 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 3.0 seconds
# Total time elapsed: 24.6 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 6
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 25.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9169 + 421 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 3.0 seconds
# Total time elapsed: 28.3 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 7
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 29.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9169 + 421 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 3.1 seconds
# Total time elapsed: 32.1 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 8
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 32.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9169 + 421 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 3.0 seconds
# Total time elapsed: 35.8 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 9
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 36.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9169 + 421 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.9 seconds
# Total time elapsed: 39.3 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 10
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 40.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9169 + 421 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 3.1 seconds
# Total time elapsed: 43.2 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 11
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 43.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9169 + 421 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 3.1 seconds
# Total time elapsed: 47.1 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 12
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 47.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9169 + 421 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.9 seconds
# Total time elapsed: 50.7 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 13
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 51.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9169 + 421 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 3.1 seconds
# Total time elapsed: 54.5 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 14
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 55.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9169 + 421 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 3.1 seconds
# Total time elapsed: 58.4 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 15
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 59.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9169 + 421 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 3.0 seconds
# Total time elapsed: 62.1 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 16
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 62.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9169 + 421 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 3.1 seconds
# Total time elapsed: 65.8 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 17
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 66.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9169 + 421 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 3.2 seconds
# Total time elapsed: 69.7 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 18
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 70.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9169 + 421 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 3.3 seconds
# Total time elapsed: 73.7 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 19
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 74.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9169 + 421 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 3.1 seconds
# Total time elapsed: 77.5 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 9169 + 421 multiplied with B
# Computing svd
# Done
# Alignment error: 3.216
# ##############################
# Time elapsed from last time log: 1.0 seconds
# Total time elapsed: 78.5 seconds
# ##############################
# array([[ 0.65144772, -0.01076784],
#        [ 0.64903878, -0.01326688],
#        [ 0.64467948, -0.01773728],
#        ...,
#        [-0.63961695, -0.00205276],
#        [-0.64365139, -0.00681419],
#        [-0.6459747 , -0.00947869]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/squarewithtwoholes//ldle.dat
