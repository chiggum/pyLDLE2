# %% [markdown]
# ### Square with two holes

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
save_dir_root = '../data/pyLDLE2/squarewithtwoholes/'

# %%
X, labelsMat, ddX = datasets.Datasets().squarewithtwoholes()
# Out:
# X.shape =  (9169, 2)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LDLE'},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  intermed_opts={'eta_min': 15},
                  global_opts={
                      'max_iter': 10,
                      'init_algo_align_w_parent_only': True # Set this True for low noise
                  },
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 875 is created.

# %%
ldle.fit(X=X)
# Out:
# Constructing unnorm graph Laplacian + its eigendecomposition.
# Done.
# ##############################
# Time elapsed from last time log: 1.8 seconds
# Total time elapsed: 1.8 seconds
# ##############################
# Computing Atilde: Inner Prod of Grad of EigFuncs.
# FEM for Atilde.
# Atilde: 0 points processed...
# Atilde: 2292 points processed...
# Atilde: 4584 points processed...
# Atilde: 6876 points processed...
# Atilde: 9168 points processed...
# Atilde: all points processed...
# Done.
# ##############################
# Time elapsed from last time log: 0.7 seconds
# Total time elapsed: 2.5 seconds
# ##############################
# Computing LDLE.
# local_param: all 9169 points processed...
# max distortion is 23254.764580
# Done.
# ##############################
# Time elapsed from last time log: 1.1 seconds
# Total time elapsed: 3.7 seconds
# ##############################
# Posprocessing local parameterizations.
# #Param replaced: 8646, max distortion: 11.273144
# #Param replaced: 2027, max distortion: 9.858051
# #Param replaced: 200, max distortion: 9.858051
# #Param replaced: 13, max distortion: 9.858051
# #Param replaced: 0, max distortion: 9.858051
# Max local distortion after postprocessing: 9.858051170233233e+00
# Done.
# ##############################
# Time elapsed from last time log: 8.0 seconds
# Total time elapsed: 11.7 seconds
# ##############################
# Max local distortion = 9.858051170233233
# Constructing intermediate views.
# eta = 2.
# # non-empty views with sz < 2 = 9169
# #nodes in views with sz < 2 = 9169
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 18.2 seconds
# Total time elapsed: 18.3 seconds
# ##############################
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 167.5 seconds
# Total time elapsed: 185.8 seconds
# ##############################
# eta = 3.
# # non-empty views with sz < 3 = 522
# #nodes in views with sz < 3 = 1044
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 1.4 seconds
# Total time elapsed: 187.2 seconds
# ##############################
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 12.8 seconds
# Total time elapsed: 200.0 seconds
# ##############################
# eta = 4.
# # non-empty views with sz < 4 = 381
# #nodes in views with sz < 4 = 1143
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 1.3 seconds
# Total time elapsed: 201.4 seconds
# ##############################
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 20.2 seconds
# Total time elapsed: 221.6 seconds
# ##############################
# eta = 5.
# # non-empty views with sz < 5 = 261
# #nodes in views with sz < 5 = 1044
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 1.1 seconds
# Total time elapsed: 222.7 seconds
# ##############################
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 21.3 seconds
# Total time elapsed: 244.0 seconds
# ##############################
# eta = 6.
# # non-empty views with sz < 6 = 205
# #nodes in views with sz < 6 = 1025
# Costs computed when eta = 6.
# ##############################
# Time elapsed from last time log: 1.2 seconds
# Total time elapsed: 245.2 seconds
# ##############################
# Remaining #nodes in views with sz < 6 = 0
# Done with eta = 6.
# ##############################
# Time elapsed from last time log: 26.1 seconds
# Total time elapsed: 271.2 seconds
# ##############################
# eta = 7.
# # non-empty views with sz < 7 = 145
# #nodes in views with sz < 7 = 870
# Costs computed when eta = 7.
# ##############################
# Time elapsed from last time log: 0.9 seconds
# Total time elapsed: 272.2 seconds
# ##############################
# Remaining #nodes in views with sz < 7 = 0
# Done with eta = 7.
# ##############################
# Time elapsed from last time log: 19.7 seconds
# Total time elapsed: 291.8 seconds
# ##############################
# eta = 8.
# # non-empty views with sz < 8 = 91
# #nodes in views with sz < 8 = 637
# Costs computed when eta = 8.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 292.7 seconds
# ##############################
# Remaining #nodes in views with sz < 8 = 0
# Done with eta = 8.
# ##############################
# Time elapsed from last time log: 16.9 seconds
# Total time elapsed: 309.5 seconds
# ##############################
# eta = 9.
# # non-empty views with sz < 9 = 96
# #nodes in views with sz < 9 = 768
# Costs computed when eta = 9.
# ##############################
# Time elapsed from last time log: 0.9 seconds
# Total time elapsed: 310.5 seconds
# ##############################
# Remaining #nodes in views with sz < 9 = 0
# Done with eta = 9.
# ##############################
# Time elapsed from last time log: 24.0 seconds
# Total time elapsed: 334.5 seconds
# ##############################
# eta = 10.
# # non-empty views with sz < 10 = 50
# #nodes in views with sz < 10 = 450
# Costs computed when eta = 10.
# ##############################
# Time elapsed from last time log: 0.6 seconds
# Total time elapsed: 335.1 seconds
# ##############################
# Remaining #nodes in views with sz < 10 = 0
# Done with eta = 10.
# ##############################
# Time elapsed from last time log: 10.8 seconds
# Total time elapsed: 346.0 seconds
# ##############################
# eta = 11.
# # non-empty views with sz < 11 = 59
# #nodes in views with sz < 11 = 590
# Costs computed when eta = 11.
# ##############################
# Time elapsed from last time log: 0.7 seconds
# Total time elapsed: 346.6 seconds
# ##############################
# Remaining #nodes in views with sz < 11 = 0
# Done with eta = 11.
# ##############################
# Time elapsed from last time log: 16.5 seconds
# Total time elapsed: 363.1 seconds
# ##############################
# eta = 12.
# # non-empty views with sz < 12 = 37
# #nodes in views with sz < 12 = 407
# Costs computed when eta = 12.
# ##############################
# Time elapsed from last time log: 0.6 seconds
# Total time elapsed: 363.7 seconds
# ##############################
# Remaining #nodes in views with sz < 12 = 0
# Done with eta = 12.
# ##############################
# Time elapsed from last time log: 11.1 seconds
# Total time elapsed: 374.8 seconds
# ##############################
# eta = 13.
# # non-empty views with sz < 13 = 27
# #nodes in views with sz < 13 = 324
# Costs computed when eta = 13.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 375.2 seconds
# ##############################
# Remaining #nodes in views with sz < 13 = 0
# Done with eta = 13.
# ##############################
# Time elapsed from last time log: 6.8 seconds
# Total time elapsed: 382.0 seconds
# ##############################
# eta = 14.
# # non-empty views with sz < 14 = 21
# #nodes in views with sz < 14 = 273
# Costs computed when eta = 14.
# ##############################
# Time elapsed from last time log: 0.4 seconds
# Total time elapsed: 382.4 seconds
# ##############################
# Remaining #nodes in views with sz < 14 = 3
# Done with eta = 14.
# ##############################
# Time elapsed from last time log: 5.9 seconds
# Total time elapsed: 388.3 seconds
# ##############################
# eta = 15.
# # non-empty views with sz < 15 = 21
# #nodes in views with sz < 15 = 269
# Costs computed when eta = 15.
# ##############################
# Time elapsed from last time log: 0.4 seconds
# Total time elapsed: 388.7 seconds
# ##############################
# Remaining #nodes in views with sz < 15 = 18
# Done with eta = 15.
# ##############################
# Time elapsed from last time log: 5.7 seconds
# Total time elapsed: 394.5 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 0.4 seconds
# Total time elapsed: 394.9 seconds
# ##############################
# After clustering, max distortion is 290.306654
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 106 intermediate views
# Ambiguous overlaps checked for 212 intermediate views
# Ambiguous overlaps checked for 318 intermediate views
# Ambiguous overlaps checked for 424 points
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 1
# Computing initial embedding using: sequential algorithm
# ##############################
# Time elapsed from last time log: 1.6 seconds
# Total time elapsed: 1.6 seconds
# ##############################
# Initial alignment of 106 views completed
# Initial alignment of 212 views completed
# Initial alignment of 318 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 0.3 seconds
# Total time elapsed: 1.9 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 2.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9593 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.4 seconds
# Total time elapsed: 4.3 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 4.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9593 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.4 seconds
# Total time elapsed: 6.1 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 6.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9593 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.4 seconds
# Total time elapsed: 7.9 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 8.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9593 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.4 seconds
# Total time elapsed: 9.7 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 10.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9593 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.5 seconds
# Total time elapsed: 11.6 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 5
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 12.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9593 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.4 seconds
# Total time elapsed: 13.4 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 6
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 13.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9593 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.4 seconds
# Total time elapsed: 15.2 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 7
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 15.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9593 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.4 seconds
# Total time elapsed: 17.0 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 8
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 17.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9593 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.4 seconds
# Total time elapsed: 18.8 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 9
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 19.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9593 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.4 seconds
# Total time elapsed: 20.7 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 9593 multiplied with B
# Alignment error: 3.249
# ##############################
# Time elapsed from last time log: 0.6 seconds
# Total time elapsed: 21.2 seconds
# ##############################
# array([[-0.56786137, -0.28445202],
#        [-0.56693347, -0.2811073 ],
#        [-0.56522956, -0.27510025],
#        ...,
#        [ 0.57956374,  0.27667043],
#        [ 0.58043614,  0.28284998],
#        [ 0.58097985,  0.28634307]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/squarewithtwoholes//ldle.dat
