# %% [markdown]
# ### Rectangle

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
save_dir_root = '../data/pyLDLE2/rectangle/'

# %%
X, labelsMat, ddX = datasets.Datasets().rectanglegrid()
# Out:
# X.shape =  (10426, 2)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LDLE'},
                  intermed_opts={'eta_min': 5, 'algo': 'best'},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 700 is created.
# Options provided:
# local_opts:
# {
#     "Atilde_method": "LDLE_1",
#     "N": 100,
#     "algo": "LDLE",
#     "alpha": 1,
#     "debug": true,
#     "delta": 0.9,
#     "gl_type": "unnorm",
#     "k": 28,
#     "k_nn": 49,
#     "k_nn0": 700,
#     "k_tune": 7,
#     "max_iter": 300,
#     "n_proc": 32,
#     "no_gamma": false,
#     "p": 0.99,
#     "pp_n_thresh": 32,
#     "reg": 0.0,
#     "tau": 50,
#     "to_postprocess": true,
#     "verbose": true
# }
# intermed_opts:
# {
#     "algo": "best",
#     "debug": true,
#     "eta_max": 25,
#     "eta_min": 5,
#     "len_S_thresh": 256,
#     "local_algo": "LDLE",
#     "n_proc": 32,
#     "n_times": 4,
#     "verbose": true
# }
# global_opts:
# {
#     "align_w_parent_only": true,
#     "alpha": 0.3,
#     "color_tear": true,
#     "compute_error": false,
#     "debug": true,
#     "eps": 1e-08,
#     "init_algo_name": "procrustes",
#     "k": 28,
#     "main_algo": "LDLE",
#     "max_internal_iter": 100,
#     "max_iter": 20,
#     "n_proc": 32,
#     "nu": 3,
#     "refine_algo_name": "rgd",
#     "to_tear": true,
#     "verbose": true,
#     "vis_before_init": false
# }

# %%
ldle.fit(X=X)
# Out:
# Constructing unnorm graph Laplacian + its eigendecomposition.
# Done.
# ##############################
# Time elapsed from last time log: 3.5 seconds
# Total time elapsed: 3.5 seconds
# ##############################
# Computing Atilde: Inner Prod of Grad of EigFuncs.
# FEM for Atilde.
# Atilde: 0 points processed...
# Atilde: 2606 points processed...
# Atilde: 5212 points processed...
# Atilde: 7818 points processed...
# Atilde: 10424 points processed...
# Atilde: all points processed...
# Done.
# ##############################
# Time elapsed from last time log: 1.4 seconds
# Total time elapsed: 4.9 seconds
# ##############################
# Computing LDLE.
# local_param: all 10426 points processed...
# max distortion is 213904.378106
# Done.
# ##############################
# Time elapsed from last time log: 1.6 seconds
# Total time elapsed: 6.6 seconds
# ##############################
# Posprocessing local parameterizations.
# #Param replaced: 10072, max distortion: 18.295347
# #Param replaced: 6035, max distortion: 12.293183
# #Param replaced: 2103, max distortion: 10.242378
# #Param replaced: 456, max distortion: 10.242378
# #Param replaced: 77, max distortion: 10.241781
# #Param replaced: 15, max distortion: 10.241781
# #Param replaced: 0, max distortion: 10.241781
# Max local distortion after postprocessing: 1.024178057716913e+01
# Done.
# ##############################
# Time elapsed from last time log: 6.5 seconds
# Total time elapsed: 13.0 seconds
# ##############################
# Max local distortion = 10.24178057716913
# Constructing intermediate views.
# eta = 2.
# #non-empty views with sz < 2 = 10426
# #nodes in views with sz < 2 = 10426
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 9.3 seconds
# Total time elapsed: 10.1 seconds
# ##############################
# ctr=8035, total_len_S=60728, avg_len_S=7.558
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 201.4 seconds
# Total time elapsed: 211.5 seconds
# ##############################
# eta = 3.
# #non-empty views with sz < 3 = 697
# #nodes in views with sz < 3 = 1394
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 1.7 seconds
# Total time elapsed: 213.2 seconds
# ##############################
# ctr=1201, total_len_S=22877, avg_len_S=19.048
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 14.5 seconds
# Total time elapsed: 227.7 seconds
# ##############################
# eta = 4.
# #non-empty views with sz < 4 = 402
# #nodes in views with sz < 4 = 1206
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 1.6 seconds
# Total time elapsed: 229.3 seconds
# ##############################
# ctr=1061, total_len_S=29204, avg_len_S=27.525
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 18.7 seconds
# Total time elapsed: 248.0 seconds
# ##############################
# eta = 5.
# #non-empty views with sz < 5 = 326
# #nodes in views with sz < 5 = 1304
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 1.8 seconds
# Total time elapsed: 249.8 seconds
# ##############################
# ctr=1145, total_len_S=39391, avg_len_S=34.403
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 26.8 seconds
# Total time elapsed: 276.6 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 277.5 seconds
# ##############################
# After clustering, max distortion is 10.987030
# Computing laterations scores for overlaps b/w intermed views
# Done
# ##############################
# Time elapsed from last time log: 1.7 seconds
# Total time elapsed: 1.7 seconds
# ##############################
# Computing a lateration.
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 1
# Done.
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 1.7 seconds
# ##############################
# Computing initial embedding using: procrustes algorithm
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 1.7 seconds
# ##############################
# Initial alignment of 292 views completed
# Initial alignment of 584 views completed
# Initial alignment of 876 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 1.1 seconds
# Total time elapsed: 2.8 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 5.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10426 + 1168 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 6.8 seconds
# Total time elapsed: 11.8 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 13.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10426 + 1168 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 6.6 seconds
# Total time elapsed: 19.9 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 21.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10426 + 1168 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 6.5 seconds
# Total time elapsed: 27.7 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 28.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10426 + 1168 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 6.6 seconds
# Total time elapsed: 35.5 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 36.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10426 + 1168 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 6.6 seconds
# Total time elapsed: 43.3 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 5
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 44.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10426 + 1168 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 6.6 seconds
# Total time elapsed: 51.0 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 6
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 52.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10426 + 1168 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 6.9 seconds
# Total time elapsed: 59.1 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 7
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 60.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10426 + 1168 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 6.7 seconds
# Total time elapsed: 66.9 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 8
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 67.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10426 + 1168 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 6.6 seconds
# Total time elapsed: 74.6 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 9
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 75.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10426 + 1168 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 6.6 seconds
# Total time elapsed: 82.2 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 10
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 83.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10426 + 1168 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 6.8 seconds
# Total time elapsed: 89.9 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 11
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 90.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10426 + 1168 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 6.5 seconds
# Total time elapsed: 97.3 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 12
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 98.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10426 + 1168 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 6.8 seconds
# Total time elapsed: 105.0 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 13
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 105.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10426 + 1168 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 6.8 seconds
# Total time elapsed: 112.6 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 14
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 113.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10426 + 1168 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 6.8 seconds
# Total time elapsed: 120.3 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 15
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 121.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10426 + 1168 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 6.7 seconds
# Total time elapsed: 127.9 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 16
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 128.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10426 + 1168 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 6.7 seconds
# Total time elapsed: 135.2 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 17
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 136.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10426 + 1168 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 6.7 seconds
# Total time elapsed: 142.7 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 18
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 143.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10426 + 1168 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 6.7 seconds
# Total time elapsed: 150.2 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 19
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 151.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10426 + 1168 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 6.8 seconds
# Total time elapsed: 157.9 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 10426 + 1168 multiplied with B
# Computing svd
# Done
# Alignment error: 4.480
# ##############################
# Time elapsed from last time log: 3.2 seconds
# Total time elapsed: 161.1 seconds
# ##############################
# array([[-1.22482119, -1.08766456],
#        [-1.22878013, -1.08839198],
#        [-1.23586319, -1.08960141],
#        ...,
#        [ 1.40553498,  0.95825788],
#        [ 1.39903914,  0.95914557],
#        [ 1.39537788,  0.95959189]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/rectangle//ldle.dat
