# %% [markdown]
# ### Swissroll with noise = 0.01

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
noise = 0.01

# %%
save_dir_root = '../data/pyLDLE2/swissroll_with_noise_'+str(noise)+'/'

# %%
X, labelsMat, ddX = datasets.Datasets().noisyswissroll(noise=noise)
# Out:
# X.shape =  (10260, 3)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LDLE'},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  intermed_opts={'eta_min': 10},
                  global_opts={
                      'max_iter': 10,
                      'init_algo_align_w_parent_only': True # Set this True for low noise
                  },
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 875 is created.

# %%
ldle.fit(X=X)
# Out:
# Constructing unnorm graph Laplacian + its eigendecomposition.
# Done.
# ##############################
# Time elapsed from last time log: 2.1 seconds
# Total time elapsed: 2.1 seconds
# ##############################
# Computing Atilde: Inner Prod of Grad of EigFuncs.
# FEM for Atilde.
# Atilde: 0 points processed...
# Atilde: 2565 points processed...
# Atilde: 5130 points processed...
# Atilde: 7695 points processed...
# Atilde: all points processed...
# Done.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 2.9 seconds
# ##############################
# Computing LDLE.
# local_param: all 10260 points processed...
# max distortion is 1414.050642
# Done.
# ##############################
# Time elapsed from last time log: 1.2 seconds
# Total time elapsed: 4.2 seconds
# ##############################
# Posprocessing local parameterizations.
# #Param replaced: 9955, max distortion: 89.312755
# #Param replaced: 4038, max distortion: 75.867543
# #Param replaced: 826, max distortion: 75.867543
# #Param replaced: 177, max distortion: 69.991970
# #Param replaced: 30, max distortion: 69.991970
# #Param replaced: 1, max distortion: 69.991970
# #Param replaced: 1, max distortion: 69.991970
# #Param replaced: 1, max distortion: 69.991970
# #Param replaced: 0, max distortion: 69.991970
# Max local distortion after postprocessing: 6.999197013034652e+01
# Done.
# ##############################
# Time elapsed from last time log: 10.3 seconds
# Total time elapsed: 14.5 seconds
# ##############################
# Max local distortion = 69.99197013034652
# Constructing intermediate views.
# eta = 2.
# # non-empty views with sz < 2 = 10260
# #nodes in views with sz < 2 = 10260
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 20.9 seconds
# Total time elapsed: 21.0 seconds
# ##############################
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 130.7 seconds
# Total time elapsed: 151.8 seconds
# ##############################
# eta = 3.
# # non-empty views with sz < 3 = 958
# #nodes in views with sz < 3 = 1916
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 2.3 seconds
# Total time elapsed: 154.1 seconds
# ##############################
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 27.2 seconds
# Total time elapsed: 181.3 seconds
# ##############################
# eta = 4.
# # non-empty views with sz < 4 = 594
# #nodes in views with sz < 4 = 1782
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 2.1 seconds
# Total time elapsed: 183.4 seconds
# ##############################
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 36.0 seconds
# Total time elapsed: 219.4 seconds
# ##############################
# eta = 5.
# # non-empty views with sz < 5 = 371
# #nodes in views with sz < 5 = 1484
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 1.9 seconds
# Total time elapsed: 221.4 seconds
# ##############################
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 30.2 seconds
# Total time elapsed: 251.5 seconds
# ##############################
# eta = 6.
# # non-empty views with sz < 6 = 252
# #nodes in views with sz < 6 = 1260
# Costs computed when eta = 6.
# ##############################
# Time elapsed from last time log: 1.4 seconds
# Total time elapsed: 252.9 seconds
# ##############################
# Remaining #nodes in views with sz < 6 = 0
# Done with eta = 6.
# ##############################
# Time elapsed from last time log: 30.8 seconds
# Total time elapsed: 283.8 seconds
# ##############################
# eta = 7.
# # non-empty views with sz < 7 = 169
# #nodes in views with sz < 7 = 1014
# Costs computed when eta = 7.
# ##############################
# Time elapsed from last time log: 1.2 seconds
# Total time elapsed: 284.9 seconds
# ##############################
# Remaining #nodes in views with sz < 7 = 0
# Done with eta = 7.
# ##############################
# Time elapsed from last time log: 26.4 seconds
# Total time elapsed: 311.3 seconds
# ##############################
# eta = 8.
# # non-empty views with sz < 8 = 134
# #nodes in views with sz < 8 = 938
# Costs computed when eta = 8.
# ##############################
# Time elapsed from last time log: 1.0 seconds
# Total time elapsed: 312.4 seconds
# ##############################
# Remaining #nodes in views with sz < 8 = 0
# Done with eta = 8.
# ##############################
# Time elapsed from last time log: 26.7 seconds
# Total time elapsed: 339.1 seconds
# ##############################
# eta = 9.
# # non-empty views with sz < 9 = 92
# #nodes in views with sz < 9 = 736
# Costs computed when eta = 9.
# ##############################
# Time elapsed from last time log: 0.9 seconds
# Total time elapsed: 340.0 seconds
# ##############################
# Remaining #nodes in views with sz < 9 = 0
# Done with eta = 9.
# ##############################
# Time elapsed from last time log: 21.7 seconds
# Total time elapsed: 361.7 seconds
# ##############################
# eta = 10.
# # non-empty views with sz < 10 = 78
# #nodes in views with sz < 10 = 702
# Costs computed when eta = 10.
# ##############################
# Time elapsed from last time log: 0.9 seconds
# Total time elapsed: 362.5 seconds
# ##############################
# Remaining #nodes in views with sz < 10 = 0
# Done with eta = 10.
# ##############################
# Time elapsed from last time log: 18.7 seconds
# Total time elapsed: 381.3 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 0.6 seconds
# Total time elapsed: 381.8 seconds
# ##############################
# After clustering, max distortion is 200.702071
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 162 intermediate views
# Ambiguous overlaps checked for 324 intermediate views
# Ambiguous overlaps checked for 486 intermediate views
# Ambiguous overlaps checked for 648 intermediate views
# Ambiguous overlaps checked for 651 points
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 1
# Computing initial embedding using: sequential algorithm
# ##############################
# Time elapsed from last time log: 3.1 seconds
# Total time elapsed: 3.1 seconds
# ##############################
# Initial alignment of 162 views completed
# Initial alignment of 324 views completed
# Initial alignment of 486 views completed
# Initial alignment of 648 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 3.6 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 5.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10911 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 7.7 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 8.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10911 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.3 seconds
# Total time elapsed: 11.0 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 11.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10911 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 14.0 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 14.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10911 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.3 seconds
# Total time elapsed: 16.8 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 17.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10911 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.3 seconds
# Total time elapsed: 19.5 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 5
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 20.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10911 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.3 seconds
# Total time elapsed: 22.2 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 6
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 22.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10911 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.3 seconds
# Total time elapsed: 25.0 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 7
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 25.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10911 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.3 seconds
# Total time elapsed: 27.8 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 8
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 28.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10911 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.3 seconds
# Total time elapsed: 30.5 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 9
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 30.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10911 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.4 seconds
# Total time elapsed: 33.3 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 10911 multiplied with B
# Alignment error: 8.266
# ##############################
# Time elapsed from last time log: 1.0 seconds
# Total time elapsed: 34.4 seconds
# ##############################
# array([[-0.90616469,  0.27879849],
#        [-0.90729248,  0.27420782],
#        [-0.92123054,  0.25673277],
#        ...,
#        [ 0.88780188, -0.3422668 ],
#        [ 0.8904168 , -0.34545521],
#        [ 0.8991997 , -0.35780464]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/swissroll_with_noise_0.01//ldle.dat
