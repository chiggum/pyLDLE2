# %% [markdown]
# ### Swissroll with noise = 0.01

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
noise = 0.01

# %%
save_dir_root = '../data/pyLDLE2/swissroll_with_noise_'+str(noise)+'/'

# %%
X, labelsMat, ddX = datasets.Datasets().noisyswissroll(noise=noise)
# Out:
# X.shape =  (10260, 3)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LDLE'},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  intermed_opts={'eta_min': 10},
                  global_opts={
                      'max_iter': 10,
                      'init_algo_align_w_parent_only': True # Set this True for low noise
                  },
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 600 is created.

# %%
ldle.fit(X=X)
# Out:
# Constructing unnorm graph Laplacian + its eigendecomposition.
# Done.
# ##############################
# Time elapsed from last time log: 2.4 seconds
# Total time elapsed: 2.4 seconds
# ##############################
# Computing Atilde: Inner Prod of Grad of EigFuncs.
# FEM for Atilde.
# Atilde: 0 points processed...
# Atilde: 2565 points processed...
# Atilde: 5130 points processed...
# Atilde: 7695 points processed...
# Atilde: all points processed...
# Done.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 3.2 seconds
# ##############################
# Computing LDLE.
# local_param: all 10260 points processed...
# max distortion is 1564.151326
# Done.
# ##############################
# Time elapsed from last time log: 1.3 seconds
# Total time elapsed: 4.5 seconds
# ##############################
# Posprocessing LDLE.
# Iter 1, Param replaced: 9877, max distortion: 115.561208
# Iter 2, Param replaced: 4923, max distortion: 84.747643
# Iter 3, Param replaced: 1497, max distortion: 82.284299
# Iter 4, Param replaced: 408, max distortion: 82.284299
# Iter 5, Param replaced: 121, max distortion: 82.284299
# Iter 6, Param replaced: 33, max distortion: 82.284299
# Iter 7, Param replaced: 4, max distortion: 82.284299
# Iter 8, Param replaced: 1, max distortion: 82.284299
# Iter 9, Param replaced: 2, max distortion: 82.284299
# Iter 10, Param replaced: 0, max distortion: 82.284299
# Done.
# ##############################
# Time elapsed from last time log: 19.4 seconds
# Total time elapsed: 23.9 seconds
# ##############################
# Max local distortion = 82.28429865515078
# Constructing intermediate views.
# eta = 2.
# # non-empty views with sz < 2 = 10260
# #nodes in views with sz < 2 = 10260
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 11.1 seconds
# Total time elapsed: 11.2 seconds
# ##############################
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 121.0 seconds
# Total time elapsed: 132.2 seconds
# ##############################
# eta = 3.
# # non-empty views with sz < 3 = 486
# #nodes in views with sz < 3 = 972
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 133.0 seconds
# ##############################
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 4.8 seconds
# Total time elapsed: 137.8 seconds
# ##############################
# eta = 4.
# # non-empty views with sz < 4 = 367
# #nodes in views with sz < 4 = 1101
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 138.6 seconds
# ##############################
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 8.2 seconds
# Total time elapsed: 146.7 seconds
# ##############################
# eta = 5.
# # non-empty views with sz < 5 = 253
# #nodes in views with sz < 5 = 1012
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 147.5 seconds
# ##############################
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 9.7 seconds
# Total time elapsed: 157.3 seconds
# ##############################
# eta = 6.
# # non-empty views with sz < 6 = 210
# #nodes in views with sz < 6 = 1050
# Costs computed when eta = 6.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 158.1 seconds
# ##############################
# Remaining #nodes in views with sz < 6 = 0
# Done with eta = 6.
# ##############################
# Time elapsed from last time log: 13.2 seconds
# Total time elapsed: 171.3 seconds
# ##############################
# eta = 7.
# # non-empty views with sz < 7 = 176
# #nodes in views with sz < 7 = 1056
# Costs computed when eta = 7.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 172.1 seconds
# ##############################
# Remaining #nodes in views with sz < 7 = 0
# Done with eta = 7.
# ##############################
# Time elapsed from last time log: 13.7 seconds
# Total time elapsed: 185.8 seconds
# ##############################
# eta = 8.
# # non-empty views with sz < 8 = 124
# #nodes in views with sz < 8 = 868
# Costs computed when eta = 8.
# ##############################
# Time elapsed from last time log: 0.7 seconds
# Total time elapsed: 186.5 seconds
# ##############################
# Remaining #nodes in views with sz < 8 = 0
# Done with eta = 8.
# ##############################
# Time elapsed from last time log: 12.9 seconds
# Total time elapsed: 199.3 seconds
# ##############################
# eta = 9.
# # non-empty views with sz < 9 = 85
# #nodes in views with sz < 9 = 680
# Costs computed when eta = 9.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 199.9 seconds
# ##############################
# Remaining #nodes in views with sz < 9 = 0
# Done with eta = 9.
# ##############################
# Time elapsed from last time log: 9.5 seconds
# Total time elapsed: 209.3 seconds
# ##############################
# eta = 10.
# # non-empty views with sz < 10 = 87
# #nodes in views with sz < 10 = 783
# Costs computed when eta = 10.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 209.9 seconds
# ##############################
# Remaining #nodes in views with sz < 10 = 0
# Done with eta = 10.
# ##############################
# Time elapsed from last time log: 11.8 seconds
# Total time elapsed: 221.7 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 222.2 seconds
# ##############################
# After clustering, max distortion is 149.262993
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 163 intermediate views
# Ambiguous overlaps checked for 326 intermediate views
# Ambiguous overlaps checked for 489 intermediate views
# Ambiguous overlaps checked for 652 points
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 1
# Computing initial embedding using: sequential algorithm
# ##############################
# Time elapsed from last time log: 2.8 seconds
# Total time elapsed: 2.8 seconds
# ##############################
# Initial alignment of 163 views completed
# Initial alignment of 326 views completed
# Initial alignment of 489 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 0.2 seconds
# Total time elapsed: 3.0 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 11.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10912 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.1 seconds
# Total time elapsed: 13.8 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 18.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10912 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.0 seconds
# Total time elapsed: 20.3 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 24.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10912 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.0 seconds
# Total time elapsed: 26.7 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 31.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10912 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.0 seconds
# Total time elapsed: 33.2 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 37.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10912 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.0 seconds
# Total time elapsed: 39.8 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 5
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 44.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10912 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.1 seconds
# Total time elapsed: 46.4 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 6
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 50.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10912 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.0 seconds
# Total time elapsed: 52.8 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 7
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 57.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10912 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.9 seconds
# Total time elapsed: 59.3 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 8
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 63.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10912 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.9 seconds
# Total time elapsed: 65.6 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 9
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 70.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10912 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.0 seconds
# Total time elapsed: 72.1 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 10912 multiplied with B
# Alignment error: 4.380
# ##############################
# Time elapsed from last time log: 1.1 seconds
# Total time elapsed: 73.2 seconds
# ##############################
# array([[-0.61653224,  0.68299206],
#        [-0.61293303,  0.68540649],
#        [-0.60818339,  0.69737792],
#        ...,
#        [ 0.56698613, -0.78849401],
#        [ 0.55471696, -0.79048664],
#        [ 0.57673133, -0.79498213]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/swissroll_with_noise_0.01//ldle.dat
