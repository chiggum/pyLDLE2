# %% [markdown]
# ### Swissroll with noise = 0.01

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
noise = 0.01

# %%
save_dir_root = '../data/pyLDLE2/swissroll_with_noise_'+str(noise)+'/'

# %%
X, labelsMat, ddX = datasets.Datasets().noisyswissroll(noise=noise)
# Out:
# X.shape =  (10260, 3)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LDLE'},
                  intermed_opts={'eta_min': 10},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 700 is created.
# Options provided:
# local_opts:
# {
#     "Atilde_method": "LDLE_1",
#     "N": 100,
#     "algo": "LDLE",
#     "alpha": 1,
#     "debug": true,
#     "delta": 0.9,
#     "gl_type": "unnorm",
#     "k": 28,
#     "k_nn": 49,
#     "k_nn0": 700,
#     "k_tune": 7,
#     "max_iter": 300,
#     "n_proc": 32,
#     "no_gamma": false,
#     "p": 0.99,
#     "pp_n_thresh": 32,
#     "reg": 0.0,
#     "tau": 50,
#     "to_postprocess": true,
#     "verbose": true
# }
# intermed_opts:
# {
#     "algo": "best",
#     "debug": true,
#     "eta_max": 25,
#     "eta_min": 10,
#     "len_S_thresh": 256,
#     "local_algo": "LDLE",
#     "n_proc": 32,
#     "n_times": 4,
#     "verbose": true
# }
# global_opts:
# {
#     "align_w_parent_only": true,
#     "alpha": 0.3,
#     "color_tear": true,
#     "compute_error": false,
#     "debug": true,
#     "eps": 1e-08,
#     "init_algo_name": "procrustes",
#     "k": 28,
#     "main_algo": "LDLE",
#     "max_internal_iter": 100,
#     "max_iter": 20,
#     "n_proc": 32,
#     "nu": 3,
#     "refine_algo_name": "rgd",
#     "to_tear": true,
#     "verbose": true,
#     "vis_before_init": false
# }

# %%
ldle.fit(X=X)
# Out:
# Constructing unnorm graph Laplacian + its eigendecomposition.
# Done.
# ##############################
# Time elapsed from last time log: 3.9 seconds
# Total time elapsed: 3.9 seconds
# ##############################
# Computing Atilde: Inner Prod of Grad of EigFuncs.
# FEM for Atilde.
# Atilde: 0 points processed...
# Atilde: 2565 points processed...
# Atilde: 5130 points processed...
# Atilde: 7695 points processed...
# Atilde: all points processed...
# Done.
# ##############################
# Time elapsed from last time log: 1.4 seconds
# Total time elapsed: 5.3 seconds
# ##############################
# Computing LDLE.
# local_param: all 10260 points processed...
# max distortion is 953.780169
# Done.
# ##############################
# Time elapsed from last time log: 1.9 seconds
# Total time elapsed: 7.2 seconds
# ##############################
# Posprocessing local parameterizations.
# #Param replaced: 9919, max distortion: 87.080275
# #Param replaced: 4317, max distortion: 62.754921
# #Param replaced: 1199, max distortion: 62.382404
# #Param replaced: 251, max distortion: 62.382404
# #Param replaced: 57, max distortion: 62.382404
# #Param replaced: 18, max distortion: 62.382404
# #Param replaced: 5, max distortion: 62.382404
# #Param replaced: 0, max distortion: 62.382404
# Max local distortion after postprocessing: 62.382403593801
# Done.
# ##############################
# Time elapsed from last time log: 7.4 seconds
# Total time elapsed: 14.6 seconds
# ##############################
# Max local distortion = 62.382403593801
# Constructing intermediate views.
# eta = 2.
# #non-empty views with sz < 2 = 10260
# #nodes in views with sz < 2 = 10260
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 8.8 seconds
# Total time elapsed: 10.0 seconds
# ##############################
# ctr=7312, total_len_S=35123, avg_len_S=4.803
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 121.2 seconds
# Total time elapsed: 131.2 seconds
# ##############################
# eta = 3.
# #non-empty views with sz < 3 = 1025
# #nodes in views with sz < 3 = 2050
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 2.1 seconds
# Total time elapsed: 133.3 seconds
# ##############################
# ctr=1658, total_len_S=29603, avg_len_S=17.855
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 26.7 seconds
# Total time elapsed: 160.0 seconds
# ##############################
# eta = 4.
# #non-empty views with sz < 4 = 598
# #nodes in views with sz < 4 = 1794
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 2.0 seconds
# Total time elapsed: 162.0 seconds
# ##############################
# ctr=1549, total_len_S=40267, avg_len_S=25.995
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 33.4 seconds
# Total time elapsed: 195.4 seconds
# ##############################
# eta = 5.
# #non-empty views with sz < 5 = 351
# #nodes in views with sz < 5 = 1404
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 1.8 seconds
# Total time elapsed: 197.2 seconds
# ##############################
# ctr=1235, total_len_S=40738, avg_len_S=32.986
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 27.5 seconds
# Total time elapsed: 224.7 seconds
# ##############################
# eta = 6.
# #non-empty views with sz < 6 = 239
# #nodes in views with sz < 6 = 1195
# Costs computed when eta = 6.
# ##############################
# Time elapsed from last time log: 1.8 seconds
# Total time elapsed: 226.5 seconds
# ##############################
# ctr=1096, total_len_S=42162, avg_len_S=38.469
# Remaining #nodes in views with sz < 6 = 0
# Done with eta = 6.
# ##############################
# Time elapsed from last time log: 30.4 seconds
# Total time elapsed: 256.9 seconds
# ##############################
# eta = 7.
# #non-empty views with sz < 7 = 193
# #nodes in views with sz < 7 = 1158
# Costs computed when eta = 7.
# ##############################
# Time elapsed from last time log: 1.8 seconds
# Total time elapsed: 258.7 seconds
# ##############################
# ctr=1054, total_len_S=44734, avg_len_S=42.442
# Remaining #nodes in views with sz < 7 = 0
# Done with eta = 7.
# ##############################
# Time elapsed from last time log: 27.7 seconds
# Total time elapsed: 286.4 seconds
# ##############################
# eta = 8.
# #non-empty views with sz < 8 = 144
# #nodes in views with sz < 8 = 1008
# Costs computed when eta = 8.
# ##############################
# Time elapsed from last time log: 1.8 seconds
# Total time elapsed: 288.2 seconds
# ##############################
# ctr=909, total_len_S=43464, avg_len_S=47.815
# Remaining #nodes in views with sz < 8 = 0
# Done with eta = 8.
# ##############################
# Time elapsed from last time log: 29.1 seconds
# Total time elapsed: 317.2 seconds
# ##############################
# eta = 9.
# #non-empty views with sz < 9 = 83
# #nodes in views with sz < 9 = 664
# Costs computed when eta = 9.
# ##############################
# Time elapsed from last time log: 1.7 seconds
# Total time elapsed: 318.9 seconds
# ##############################
# ctr=563, total_len_S=28654, avg_len_S=50.895
# Remaining #nodes in views with sz < 9 = 0
# Done with eta = 9.
# ##############################
# Time elapsed from last time log: 16.3 seconds
# Total time elapsed: 335.2 seconds
# ##############################
# eta = 10.
# #non-empty views with sz < 10 = 83
# #nodes in views with sz < 10 = 747
# Costs computed when eta = 10.
# ##############################
# Time elapsed from last time log: 1.8 seconds
# Total time elapsed: 337.0 seconds
# ##############################
# ctr=700, total_len_S=38751, avg_len_S=55.359
# Remaining #nodes in views with sz < 10 = 0
# Done with eta = 10.
# ##############################
# Time elapsed from last time log: 23.6 seconds
# Total time elapsed: 360.6 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 0.9 seconds
# Total time elapsed: 361.5 seconds
# ##############################
# After clustering, max distortion is 98.701079
# Computing laterations scores for overlaps b/w intermed views
# Done
# ##############################
# Time elapsed from last time log: 1.7 seconds
# Total time elapsed: 1.7 seconds
# ##############################
# Computing a lateration.
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 1
# Done.
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 1.7 seconds
# ##############################
# Computing initial embedding using: procrustes algorithm
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 1.7 seconds
# ##############################
# Initial alignment of 163 views completed
# Initial alignment of 326 views completed
# Initial alignment of 489 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 2.5 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 5.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 652 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.6 seconds
# Total time elapsed: 9.6 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 10.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 652 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.4 seconds
# Total time elapsed: 15.2 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 16.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 652 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.5 seconds
# Total time elapsed: 20.6 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 21.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 652 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.4 seconds
# Total time elapsed: 25.8 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 26.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 652 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.4 seconds
# Total time elapsed: 30.8 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 5
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 31.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 652 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.5 seconds
# Total time elapsed: 36.1 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 6
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 36.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 652 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.5 seconds
# Total time elapsed: 41.3 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 7
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 42.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 652 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.4 seconds
# Total time elapsed: 46.4 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 8
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 47.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 652 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.5 seconds
# Total time elapsed: 51.7 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 9
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 52.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 652 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.4 seconds
# Total time elapsed: 56.7 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 10
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 57.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 652 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.6 seconds
# Total time elapsed: 62.0 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 11
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 62.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 652 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.4 seconds
# Total time elapsed: 67.2 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 12
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 68.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 652 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.8 seconds
# Total time elapsed: 72.7 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 13
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 73.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 652 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.5 seconds
# Total time elapsed: 77.8 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 14
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 78.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 652 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.5 seconds
# Total time elapsed: 82.9 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 15
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 83.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 652 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.7 seconds
# Total time elapsed: 88.4 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 16
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 89.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 652 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.6 seconds
# Total time elapsed: 93.7 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 17
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 94.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 652 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.6 seconds
# Total time elapsed: 99.1 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 18
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 99.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 652 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.5 seconds
# Total time elapsed: 104.3 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 19
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 104.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 652 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.4 seconds
# Total time elapsed: 109.3 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 10260 + 652 multiplied with B
# Computing svd
# Done
# Alignment error: 7.345
# ##############################
# Time elapsed from last time log: 1.7 seconds
# Total time elapsed: 110.9 seconds
# ##############################
# array([[-0.01421258, -0.98863335],
#        [-0.01922061, -0.9889051 ],
#        [-0.03102895, -0.99344761],
#        ...,
#        [-0.05634309,  1.00297156],
#        [-0.05885368,  1.00755414],
#        [-0.05570447,  1.01635984]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/swissroll_with_noise_0.01//ldle.dat
