# %% [markdown]
# ### Swissroll with noise = 0.02

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
noise = 0.02

# %%
save_dir_root = '../data/pyLDLE2/swissroll_with_noise_'+str(noise)+'/'

# %%
X, labelsMat, ddX = datasets.Datasets().noisyswissroll(noise=noise)
# Out:
# X.shape =  (10260, 3)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LDLE'},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  intermed_opts={'eta_min': 15},
                  global_opts={
                      'max_iter': 10,
                      'init_algo_align_w_parent_only': True # Set this True for low noise
                  },
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 600 is created.

# %%
ldle.fit(X=X)
# Out:
# Constructing unnorm graph Laplacian + its eigendecomposition.
# Done.
# ##############################
# Time elapsed from last time log: 1.9 seconds
# Total time elapsed: 1.9 seconds
# ##############################
# Computing Atilde: Inner Prod of Grad of EigFuncs.
# FEM for Atilde.
# Atilde: 0 points processed...
# Atilde: 2565 points processed...
# Atilde: 5130 points processed...
# Atilde: 7695 points processed...
# Atilde: all points processed...
# Done.
# ##############################
# Time elapsed from last time log: 0.7 seconds
# Total time elapsed: 2.7 seconds
# ##############################
# Computing LDLE.
# local_param: all 10260 points processed...
# max distortion is 5100.771547
# Done.
# ##############################
# Time elapsed from last time log: 1.2 seconds
# Total time elapsed: 3.9 seconds
# ##############################
# Posprocessing LDLE.
# Iter 1, Param replaced: 9796, max distortion: 83.363708
# Iter 2, Param replaced: 4538, max distortion: 59.156125
# Iter 3, Param replaced: 1411, max distortion: 59.063156
# Iter 4, Param replaced: 360, max distortion: 59.063156
# Iter 5, Param replaced: 101, max distortion: 58.384874
# Iter 6, Param replaced: 36, max distortion: 57.866327
# Iter 7, Param replaced: 10, max distortion: 57.866327
# Iter 8, Param replaced: 12, max distortion: 57.866327
# Iter 9, Param replaced: 3, max distortion: 57.866327
# Iter 10, Param replaced: 1, max distortion: 57.866327
# Iter 11, Param replaced: 1, max distortion: 57.866327
# Iter 12, Param replaced: 1, max distortion: 57.866327
# Iter 13, Param replaced: 0, max distortion: 57.866327
# Done.
# ##############################
# Time elapsed from last time log: 28.6 seconds
# Total time elapsed: 32.5 seconds
# ##############################
# Max local distortion = 57.86632694715084
# Constructing intermediate views.
# eta = 2.
# # non-empty views with sz < 2 = 10260
# #nodes in views with sz < 2 = 10260
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 11.1 seconds
# Total time elapsed: 11.2 seconds
# ##############################
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 105.0 seconds
# Total time elapsed: 116.2 seconds
# ##############################
# eta = 3.
# # non-empty views with sz < 3 = 576
# #nodes in views with sz < 3 = 1152
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 0.9 seconds
# Total time elapsed: 117.1 seconds
# ##############################
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 6.5 seconds
# Total time elapsed: 123.6 seconds
# ##############################
# eta = 4.
# # non-empty views with sz < 4 = 413
# #nodes in views with sz < 4 = 1239
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 1.0 seconds
# Total time elapsed: 124.7 seconds
# ##############################
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 12.5 seconds
# Total time elapsed: 137.1 seconds
# ##############################
# eta = 5.
# # non-empty views with sz < 5 = 348
# #nodes in views with sz < 5 = 1392
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 1.2 seconds
# Total time elapsed: 138.3 seconds
# ##############################
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 18.9 seconds
# Total time elapsed: 157.2 seconds
# ##############################
# eta = 6.
# # non-empty views with sz < 6 = 206
# #nodes in views with sz < 6 = 1030
# Costs computed when eta = 6.
# ##############################
# Time elapsed from last time log: 0.9 seconds
# Total time elapsed: 158.1 seconds
# ##############################
# Remaining #nodes in views with sz < 6 = 0
# Done with eta = 6.
# ##############################
# Time elapsed from last time log: 14.2 seconds
# Total time elapsed: 172.3 seconds
# ##############################
# eta = 7.
# # non-empty views with sz < 7 = 210
# #nodes in views with sz < 7 = 1260
# Costs computed when eta = 7.
# ##############################
# Time elapsed from last time log: 1.0 seconds
# Total time elapsed: 173.4 seconds
# ##############################
# Remaining #nodes in views with sz < 7 = 0
# Done with eta = 7.
# ##############################
# Time elapsed from last time log: 24.2 seconds
# Total time elapsed: 197.6 seconds
# ##############################
# eta = 8.
# # non-empty views with sz < 8 = 113
# #nodes in views with sz < 8 = 791
# Costs computed when eta = 8.
# ##############################
# Time elapsed from last time log: 0.7 seconds
# Total time elapsed: 198.3 seconds
# ##############################
# Remaining #nodes in views with sz < 8 = 0
# Done with eta = 8.
# ##############################
# Time elapsed from last time log: 15.0 seconds
# Total time elapsed: 213.3 seconds
# ##############################
# eta = 9.
# # non-empty views with sz < 9 = 96
# #nodes in views with sz < 9 = 768
# Costs computed when eta = 9.
# ##############################
# Time elapsed from last time log: 0.7 seconds
# Total time elapsed: 214.0 seconds
# ##############################
# Remaining #nodes in views with sz < 9 = 0
# Done with eta = 9.
# ##############################
# Time elapsed from last time log: 16.7 seconds
# Total time elapsed: 230.7 seconds
# ##############################
# eta = 10.
# # non-empty views with sz < 10 = 80
# #nodes in views with sz < 10 = 720
# Costs computed when eta = 10.
# ##############################
# Time elapsed from last time log: 0.7 seconds
# Total time elapsed: 231.4 seconds
# ##############################
# Remaining #nodes in views with sz < 10 = 0
# Done with eta = 10.
# ##############################
# Time elapsed from last time log: 17.7 seconds
# Total time elapsed: 249.1 seconds
# ##############################
# eta = 11.
# # non-empty views with sz < 11 = 81
# #nodes in views with sz < 11 = 810
# Costs computed when eta = 11.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 249.9 seconds
# ##############################
# Remaining #nodes in views with sz < 11 = 0
# Done with eta = 11.
# ##############################
# Time elapsed from last time log: 21.9 seconds
# Total time elapsed: 271.8 seconds
# ##############################
# eta = 12.
# # non-empty views with sz < 12 = 57
# #nodes in views with sz < 12 = 627
# Costs computed when eta = 12.
# ##############################
# Time elapsed from last time log: 0.7 seconds
# Total time elapsed: 272.5 seconds
# ##############################
# Remaining #nodes in views with sz < 12 = 2
# Done with eta = 12.
# ##############################
# Time elapsed from last time log: 15.0 seconds
# Total time elapsed: 287.5 seconds
# ##############################
# eta = 13.
# # non-empty views with sz < 13 = 41
# #nodes in views with sz < 13 = 482
# Costs computed when eta = 13.
# ##############################
# Time elapsed from last time log: 0.6 seconds
# Total time elapsed: 288.1 seconds
# ##############################
# Remaining #nodes in views with sz < 13 = 2
# Done with eta = 13.
# ##############################
# Time elapsed from last time log: 12.4 seconds
# Total time elapsed: 300.5 seconds
# ##############################
# eta = 14.
# # non-empty views with sz < 14 = 37
# #nodes in views with sz < 14 = 470
# Costs computed when eta = 14.
# ##############################
# Time elapsed from last time log: 0.4 seconds
# Total time elapsed: 300.9 seconds
# ##############################
# Remaining #nodes in views with sz < 14 = 4
# Done with eta = 14.
# ##############################
# Time elapsed from last time log: 10.2 seconds
# Total time elapsed: 311.1 seconds
# ##############################
# eta = 15.
# # non-empty views with sz < 15 = 28
# #nodes in views with sz < 15 = 368
# Costs computed when eta = 15.
# ##############################
# Time elapsed from last time log: 0.4 seconds
# Total time elapsed: 311.5 seconds
# ##############################
# Remaining #nodes in views with sz < 15 = 15
# Done with eta = 15.
# ##############################
# Time elapsed from last time log: 7.9 seconds
# Total time elapsed: 319.4 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 319.9 seconds
# ##############################
# After clustering, max distortion is 367.493986
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 120 intermediate views
# Ambiguous overlaps checked for 240 intermediate views
# Ambiguous overlaps checked for 360 intermediate views
# Ambiguous overlaps checked for 480 points
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 1
# Computing initial embedding using: sequential algorithm
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 2.2 seconds
# ##############################
# Initial alignment of 120 views completed
# Initial alignment of 240 views completed
# Initial alignment of 360 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 0.2 seconds
# Total time elapsed: 2.4 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 9.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10740
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 29.6 seconds
# Total time elapsed: 39.1 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 42.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10740
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 30.2 seconds
# Total time elapsed: 72.9 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 76.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10740
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 30.7 seconds
# Total time elapsed: 107.2 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 110.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10740
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 30.7 seconds
# Total time elapsed: 141.6 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 145.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10740
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 30.9 seconds
# Total time elapsed: 176.1 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 5
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 179.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10740
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 30.3 seconds
# Total time elapsed: 210.1 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 6
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 213.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10740
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 30.5 seconds
# Total time elapsed: 244.1 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 7
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 247.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10740
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 30.4 seconds
# Total time elapsed: 277.9 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 8
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 281.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10740
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 30.4 seconds
# Total time elapsed: 312.0 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 9
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 315.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10740
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 26.7 seconds
# Total time elapsed: 342.2 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 10740
# Alignment error: 77.648
# ##############################
# Time elapsed from last time log: 2.6 seconds
# Total time elapsed: 344.8 seconds
# ##############################
# array([[-0.52198385, -0.87211129],
#        [-0.51618957, -0.86881408],
#        [-0.48838705, -0.87454542],
#        ...,
#        [ 0.53691381,  0.79276381],
#        [ 0.53301121,  0.79654397],
#        [ 0.53290924,  0.8111102 ]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/swissroll_with_noise_0.02//ldle.dat
