# %% [markdown]
# ### Swissroll with noise = 0.02

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
noise = 0.02

# %%
save_dir_root = '../data/pyLDLE2/swissroll_with_noise_'+str(noise)+'/'

# %%
X, labelsMat, ddX = datasets.Datasets().noisyswissroll(noise=noise)
# Out:
# X.shape =  (10260, 3)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LDLE'},
                  intermed_opts={'eta_min': 10},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 700 is created.
# Options provided:
# local_opts:
# {
#     "Atilde_method": "LDLE_1",
#     "N": 100,
#     "algo": "LDLE",
#     "alpha": 1,
#     "debug": true,
#     "delta": 0.9,
#     "gl_type": "unnorm",
#     "k": 28,
#     "k_nn": 49,
#     "k_nn0": 700,
#     "k_tune": 7,
#     "max_iter": 300,
#     "n_proc": 32,
#     "no_gamma": false,
#     "p": 0.99,
#     "pp_n_thresh": 32,
#     "reg": 0.0,
#     "tau": 50,
#     "to_postprocess": true,
#     "verbose": true
# }
# intermed_opts:
# {
#     "algo": "best",
#     "debug": true,
#     "eta_max": 25,
#     "eta_min": 10,
#     "len_S_thresh": 256,
#     "local_algo": "LDLE",
#     "n_proc": 32,
#     "n_times": 4,
#     "verbose": true
# }
# global_opts:
# {
#     "align_w_parent_only": true,
#     "alpha": 0.3,
#     "color_tear": true,
#     "compute_error": false,
#     "debug": true,
#     "eps": 1e-08,
#     "init_algo_name": "procrustes",
#     "k": 28,
#     "main_algo": "LDLE",
#     "max_internal_iter": 100,
#     "max_iter": 20,
#     "n_proc": 32,
#     "nu": 3,
#     "refine_algo_name": "rgd",
#     "to_tear": true,
#     "verbose": true,
#     "vis_before_init": false
# }

# %%
ldle.fit(X=X)
# Out:
# Constructing unnorm graph Laplacian + its eigendecomposition.
# Done.
# ##############################
# Time elapsed from last time log: 3.8 seconds
# Total time elapsed: 3.8 seconds
# ##############################
# Computing Atilde: Inner Prod of Grad of EigFuncs.
# FEM for Atilde.
# Atilde: 0 points processed...
# Atilde: 2565 points processed...
# Atilde: 5130 points processed...
# Atilde: 7695 points processed...
# Atilde: all points processed...
# Done.
# ##############################
# Time elapsed from last time log: 1.6 seconds
# Total time elapsed: 5.5 seconds
# ##############################
# Computing LDLE.
# local_param: all 10260 points processed...
# max distortion is 1890.841660
# Done.
# ##############################
# Time elapsed from last time log: 1.8 seconds
# Total time elapsed: 7.3 seconds
# ##############################
# Posprocessing local parameterizations.
# #Param replaced: 9846, max distortion: 58.899614
# #Param replaced: 4087, max distortion: 49.377678
# #Param replaced: 1101, max distortion: 49.377678
# #Param replaced: 323, max distortion: 49.377678
# #Param replaced: 87, max distortion: 49.377678
# #Param replaced: 35, max distortion: 49.377678
# #Param replaced: 4, max distortion: 47.049139
# #Param replaced: 1, max distortion: 47.049139
# #Param replaced: 0, max distortion: 47.049139
# Max local distortion after postprocessing: 47.049138815721896
# Done.
# ##############################
# Time elapsed from last time log: 7.2 seconds
# Total time elapsed: 14.5 seconds
# ##############################
# Max local distortion = 47.049138815721896
# Constructing intermediate views.
# eta = 2.
# #non-empty views with sz < 2 = 10260
# #nodes in views with sz < 2 = 10260
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 10.3 seconds
# Total time elapsed: 11.5 seconds
# ##############################
# ctr=7084, total_len_S=31087, avg_len_S=4.388
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 108.6 seconds
# Total time elapsed: 120.2 seconds
# ##############################
# eta = 3.
# #non-empty views with sz < 3 = 1187
# #nodes in views with sz < 3 = 2374
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 2.3 seconds
# Total time elapsed: 122.5 seconds
# ##############################
# ctr=1897, total_len_S=32941, avg_len_S=17.365
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 37.9 seconds
# Total time elapsed: 160.4 seconds
# ##############################
# eta = 4.
# #non-empty views with sz < 4 = 682
# #nodes in views with sz < 4 = 2046
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 162.6 seconds
# ##############################
# ctr=1703, total_len_S=45436, avg_len_S=26.680
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 50.7 seconds
# Total time elapsed: 213.3 seconds
# ##############################
# eta = 5.
# #non-empty views with sz < 5 = 427
# #nodes in views with sz < 5 = 1708
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 2.0 seconds
# Total time elapsed: 215.3 seconds
# ##############################
# ctr=1457, total_len_S=48136, avg_len_S=33.038
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 50.6 seconds
# Total time elapsed: 265.9 seconds
# ##############################
# eta = 6.
# #non-empty views with sz < 6 = 245
# #nodes in views with sz < 6 = 1225
# Costs computed when eta = 6.
# ##############################
# Time elapsed from last time log: 1.9 seconds
# Total time elapsed: 267.7 seconds
# ##############################
# ctr=1073, total_len_S=42501, avg_len_S=39.610
# Remaining #nodes in views with sz < 6 = 0
# Done with eta = 6.
# ##############################
# Time elapsed from last time log: 38.6 seconds
# Total time elapsed: 306.3 seconds
# ##############################
# eta = 7.
# #non-empty views with sz < 7 = 192
# #nodes in views with sz < 7 = 1152
# Costs computed when eta = 7.
# ##############################
# Time elapsed from last time log: 1.9 seconds
# Total time elapsed: 308.3 seconds
# ##############################
# ctr=1035, total_len_S=46318, avg_len_S=44.752
# Remaining #nodes in views with sz < 7 = 0
# Done with eta = 7.
# ##############################
# Time elapsed from last time log: 42.2 seconds
# Total time elapsed: 350.4 seconds
# ##############################
# eta = 8.
# #non-empty views with sz < 8 = 116
# #nodes in views with sz < 8 = 812
# Costs computed when eta = 8.
# ##############################
# Time elapsed from last time log: 1.9 seconds
# Total time elapsed: 352.3 seconds
# ##############################
# ctr=732, total_len_S=36170, avg_len_S=49.413
# Remaining #nodes in views with sz < 8 = 0
# Done with eta = 8.
# ##############################
# Time elapsed from last time log: 32.4 seconds
# Total time elapsed: 384.7 seconds
# ##############################
# eta = 9.
# #non-empty views with sz < 9 = 114
# #nodes in views with sz < 9 = 912
# Costs computed when eta = 9.
# ##############################
# Time elapsed from last time log: 1.9 seconds
# Total time elapsed: 386.7 seconds
# ##############################
# ctr=800, total_len_S=45272, avg_len_S=56.590
# Remaining #nodes in views with sz < 9 = 0
# Done with eta = 9.
# ##############################
# Time elapsed from last time log: 36.0 seconds
# Total time elapsed: 422.7 seconds
# ##############################
# eta = 10.
# #non-empty views with sz < 10 = 79
# #nodes in views with sz < 10 = 711
# Costs computed when eta = 10.
# ##############################
# Time elapsed from last time log: 1.7 seconds
# Total time elapsed: 424.3 seconds
# ##############################
# ctr=655, total_len_S=40051, avg_len_S=61.147
# Remaining #nodes in views with sz < 10 = 0
# Done with eta = 10.
# ##############################
# Time elapsed from last time log: 36.5 seconds
# Total time elapsed: 460.8 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 461.6 seconds
# ##############################
# After clustering, max distortion is 87.912179
# Computing laterations scores for overlaps b/w intermed views
# Done
# ##############################
# Time elapsed from last time log: 1.7 seconds
# Total time elapsed: 1.7 seconds
# ##############################
# Computing a lateration.
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 1
# Done.
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 1.7 seconds
# ##############################
# Computing initial embedding using: procrustes algorithm
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 1.7 seconds
# ##############################
# Initial alignment of 172 views completed
# Initial alignment of 344 views completed
# Initial alignment of 516 views completed
# Initial alignment of 688 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 0.9 seconds
# Total time elapsed: 2.6 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 7.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 691 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.8 seconds
# Total time elapsed: 11.9 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 15.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 691 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.9 seconds
# Total time elapsed: 19.9 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 22.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 691 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.8 seconds
# Total time elapsed: 27.3 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 29.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 691 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.8 seconds
# Total time elapsed: 34.4 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 37.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 691 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.8 seconds
# Total time elapsed: 41.9 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 5
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 44.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 691 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.9 seconds
# Total time elapsed: 49.5 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 6
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 52.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 691 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.9 seconds
# Total time elapsed: 57.0 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 7
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 59.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 691 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.5 seconds
# Total time elapsed: 63.9 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 8
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 66.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 691 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.6 seconds
# Total time elapsed: 70.8 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 9
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 73.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 691 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.6 seconds
# Total time elapsed: 77.7 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 10
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 80.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 691 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.7 seconds
# Total time elapsed: 84.9 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 11
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 87.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 691 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.7 seconds
# Total time elapsed: 91.8 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 12
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 94.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 691 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.7 seconds
# Total time elapsed: 98.9 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 13
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 101.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 691 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.7 seconds
# Total time elapsed: 106.0 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 14
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 108.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 691 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.6 seconds
# Total time elapsed: 113.1 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 15
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 115.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 691 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.6 seconds
# Total time elapsed: 120.1 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 16
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 122.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 691 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.7 seconds
# Total time elapsed: 127.2 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 17
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 130.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 691 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.8 seconds
# Total time elapsed: 134.8 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 18
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 137.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 691 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.7 seconds
# Total time elapsed: 141.8 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 19
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 144.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 691 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.7 seconds
# Total time elapsed: 149.0 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 10260 + 691 multiplied with B
# Computing svd
# Done
# Alignment error: 105.020
# ##############################
# Time elapsed from last time log: 1.9 seconds
# Total time elapsed: 151.0 seconds
# ##############################
# array([[-0.58905252,  0.84923193],
#        [-0.5808715 ,  0.83954153],
#        [-0.54189042,  0.85975384],
#        ...,
#        [ 0.61157524, -0.86633422],
#        [ 0.60604728, -0.87089542],
#        [ 0.61904535, -0.89916462]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/swissroll_with_noise_0.02//ldle.dat
