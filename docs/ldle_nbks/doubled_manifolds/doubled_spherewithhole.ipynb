# %% [markdown]
# ### Doubled sphere with hole

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
save_dir_root = '../data/pyLDLE2/doubled_spherewithhole/'

# %%
X, labelsMat, ddX = datasets.Datasets().spherewithhole()
# Out:
# X.shape =  (9931, 3)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LDLE'},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  intermed_opts={'eta_min': 10},
                  global_opts={
                      'max_iter': 12,
                      'init_algo_align_w_parent_only': True # Set this True for low noise
                  },
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 875 is created.

# %%
ldle.fit(X=X, ddX=ddX)
# Out:
# Doubling manifold.
# No. of points on the boundary = 34
# /home/dhruv/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_base.py:199: EfficiencyWarning: Precomputed sparse input was not sorted by data.
#   warnings.warn(
# Done.
# ##############################
# Time elapsed from last time log: 23.9 seconds
# Total time elapsed: 23.9 seconds
# ##############################
# Constructing unnorm graph Laplacian + its eigendecomposition.
# Done.
# ##############################
# Time elapsed from last time log: 5.3 seconds
# Total time elapsed: 5.3 seconds
# ##############################
# Computing Atilde: Inner Prod of Grad of EigFuncs.
# FEM for Atilde.
# Atilde: 0 points processed...
# Atilde: 4957 points processed...
# Atilde: 9914 points processed...
# Atilde: 14871 points processed...
# Atilde: all points processed...
# Done.
# ##############################
# Time elapsed from last time log: 1.5 seconds
# Total time elapsed: 6.8 seconds
# ##############################
# Computing LDLE.
# local_param: all 19828 points processed...
# max distortion is 906.503098
# Done.
# ##############################
# Time elapsed from last time log: 2.3 seconds
# Total time elapsed: 9.2 seconds
# ##############################
# Posprocessing local parameterizations.
# #Param replaced: 18479, max distortion: 10.876970
# #Param replaced: 7304, max distortion: 3.537798
# #Param replaced: 2033, max distortion: 3.537798
# #Param replaced: 838, max distortion: 3.537798
# #Param replaced: 599, max distortion: 3.537798
# #Param replaced: 573, max distortion: 3.537798
# #Param replaced: 296, max distortion: 3.537798
# #Param replaced: 81, max distortion: 3.537798
# #Param replaced: 32, max distortion: 3.537798
# #Param replaced: 1, max distortion: 3.537798
# #Param replaced: 0, max distortion: 3.537798
# Max local distortion after postprocessing: 3.537798236263967e+00
# Done.
# ##############################
# Time elapsed from last time log: 24.3 seconds
# Total time elapsed: 33.5 seconds
# ##############################
# Halving objects.
# Done.
# ##############################
# Time elapsed from last time log: 8.0 seconds
# Total time elapsed: 51.7 seconds
# ##############################
# Max local distortion = 3.5377982362555067
# Constructing intermediate views.
# eta = 2.
# # non-empty views with sz < 2 = 9931
# #nodes in views with sz < 2 = 9931
# /home/dhruv/codebase/pyLDLE2/docs/ldle_nbks/doubled_manifolds/../../../pyLDLE2/intermed_views_.py:107: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   neigh_ind = np.array(neigh_ind)
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 20.1 seconds
# Total time elapsed: 20.2 seconds
# ##############################
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 239.7 seconds
# Total time elapsed: 259.9 seconds
# ##############################
# eta = 3.
# # non-empty views with sz < 3 = 375
# #nodes in views with sz < 3 = 750
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 1.2 seconds
# Total time elapsed: 261.1 seconds
# ##############################
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 7.8 seconds
# Total time elapsed: 268.9 seconds
# ##############################
# eta = 4.
# # non-empty views with sz < 4 = 312
# #nodes in views with sz < 4 = 936
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 1.5 seconds
# Total time elapsed: 270.4 seconds
# ##############################
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 18.1 seconds
# Total time elapsed: 288.5 seconds
# ##############################
# eta = 5.
# # non-empty views with sz < 5 = 231
# #nodes in views with sz < 5 = 924
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 1.3 seconds
# Total time elapsed: 289.8 seconds
# ##############################
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 24.7 seconds
# Total time elapsed: 314.5 seconds
# ##############################
# eta = 6.
# # non-empty views with sz < 6 = 168
# #nodes in views with sz < 6 = 840
# Costs computed when eta = 6.
# ##############################
# Time elapsed from last time log: 1.3 seconds
# Total time elapsed: 315.7 seconds
# ##############################
# Remaining #nodes in views with sz < 6 = 0
# Done with eta = 6.
# ##############################
# Time elapsed from last time log: 20.8 seconds
# Total time elapsed: 336.5 seconds
# ##############################
# eta = 7.
# # non-empty views with sz < 7 = 143
# #nodes in views with sz < 7 = 858
# Costs computed when eta = 7.
# ##############################
# Time elapsed from last time log: 1.2 seconds
# Total time elapsed: 337.8 seconds
# ##############################
# Remaining #nodes in views with sz < 7 = 0
# Done with eta = 7.
# ##############################
# Time elapsed from last time log: 28.3 seconds
# Total time elapsed: 366.1 seconds
# ##############################
# eta = 8.
# # non-empty views with sz < 8 = 91
# #nodes in views with sz < 8 = 637
# Costs computed when eta = 8.
# ##############################
# Time elapsed from last time log: 1.1 seconds
# Total time elapsed: 367.2 seconds
# ##############################
# Remaining #nodes in views with sz < 8 = 0
# Done with eta = 8.
# ##############################
# Time elapsed from last time log: 22.1 seconds
# Total time elapsed: 389.4 seconds
# ##############################
# eta = 9.
# # non-empty views with sz < 9 = 90
# #nodes in views with sz < 9 = 720
# Costs computed when eta = 9.
# ##############################
# Time elapsed from last time log: 1.0 seconds
# Total time elapsed: 390.4 seconds
# ##############################
# Remaining #nodes in views with sz < 9 = 0
# Done with eta = 9.
# ##############################
# Time elapsed from last time log: 26.2 seconds
# Total time elapsed: 416.5 seconds
# ##############################
# eta = 10.
# # non-empty views with sz < 10 = 62
# #nodes in views with sz < 10 = 558
# Costs computed when eta = 10.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 417.3 seconds
# ##############################
# Remaining #nodes in views with sz < 10 = 0
# Done with eta = 10.
# ##############################
# Time elapsed from last time log: 16.9 seconds
# Total time elapsed: 434.2 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 0.6 seconds
# Total time elapsed: 434.8 seconds
# ##############################
# After clustering, max distortion is 4.336268
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 153 intermediate views
# Ambiguous overlaps checked for 306 intermediate views
# Ambiguous overlaps checked for 459 intermediate views
# Ambiguous overlaps checked for 612 points
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 1
# Computing initial embedding using: sequential algorithm
# ##############################
# Time elapsed from last time log: 3.3 seconds
# Total time elapsed: 3.3 seconds
# ##############################
# Initial alignment of 153 views completed
# Initial alignment of 306 views completed
# Initial alignment of 459 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 3.8 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 6.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10543 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 8.5 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 10.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10543 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 12.7 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 14.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10543 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 16.8 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 18.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10543 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.3 seconds
# Total time elapsed: 20.8 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 22.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10543 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.3 seconds
# Total time elapsed: 24.7 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 5
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 26.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10543 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 28.5 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 6
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 30.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10543 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 32.2 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 7
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 33.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10543 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 36.0 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 8
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 37.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10543 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 39.7 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 9
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 41.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10543 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 43.3 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 10
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 44.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10543 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 46.9 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 11
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 48.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10543 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.3 seconds
# Total time elapsed: 50.5 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 10543 multiplied with B
# Alignment error: 59.672
# ##############################
# Time elapsed from last time log: 1.0 seconds
# Total time elapsed: 51.5 seconds
# ##############################
# array([[-0.2504951 , -0.33622296],
#        [ 0.11544219, -0.32862461],
#        [ 0.15195212, -0.46921562],
#        ...,
#        [-0.14862106,  0.29838629],
#        [-0.14991473,  0.31126578],
#        [-0.15434591,  0.3025418 ]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/doubled_spherewithhole//ldle.dat
