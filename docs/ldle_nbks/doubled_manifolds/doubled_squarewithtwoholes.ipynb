# %% [markdown]
# ### Doubled square with two holes

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
save_dir_root = '../data/pyLDLE2/doubled_squarewithtwoholes/'

# %%
X, labelsMat, ddX = datasets.Datasets().squarewithtwoholes()
# Out:
# X.shape =  (9169, 2)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LDLE'},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  intermed_opts={'eta_min': 10},
                  global_opts={
                      'max_iter': 12,
                      'init_algo_align_w_parent_only': True # Set this True for low noise
                  },
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 600 is created.

# %%
ldle.fit(X=X, ddX=ddX)
# Out:
# Doubling manifold.
# No. of points on the boundary = 540
# /home/dhruv/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_base.py:199: EfficiencyWarning: Precomputed sparse input was not sorted by data.
#   warnings.warn(
# Done.
# ##############################
# Time elapsed from last time log: 31.7 seconds
# Total time elapsed: 31.7 seconds
# ##############################
# Constructing unnorm graph Laplacian + its eigendecomposition.
# Done.
# ##############################
# Time elapsed from last time log: 5.1 seconds
# Total time elapsed: 5.1 seconds
# ##############################
# Computing Atilde: Inner Prod of Grad of EigFuncs.
# FEM for Atilde.
# Atilde: 0 points processed...
# Atilde: 4449 points processed...
# Atilde: 8898 points processed...
# Atilde: 13347 points processed...
# Atilde: 17796 points processed...
# Atilde: all points processed...
# Done.
# ##############################
# Time elapsed from last time log: 1.4 seconds
# Total time elapsed: 6.5 seconds
# ##############################
# Computing LDLE.
# local_param: all 17798 points processed...
# max distortion is 47043.183400
# Done.
# ##############################
# Time elapsed from last time log: 2.1 seconds
# Total time elapsed: 8.7 seconds
# ##############################
# Posprocessing LDLE.
# Iter 1, Param replaced: 16844, max distortion: 21.552712
# Iter 2, Param replaced: 8771, max distortion: 14.829681
# Iter 3, Param replaced: 3463, max distortion: 14.829681
# Iter 4, Param replaced: 1280, max distortion: 14.829681
# Iter 5, Param replaced: 401, max distortion: 14.829681
# Iter 6, Param replaced: 153, max distortion: 14.829681
# Iter 7, Param replaced: 49, max distortion: 14.829681
# Iter 8, Param replaced: 15, max distortion: 14.829681
# Iter 9, Param replaced: 2, max distortion: 14.829681
# Iter 10, Param replaced: 0, max distortion: 14.829681
# Done.
# ##############################
# Time elapsed from last time log: 31.8 seconds
# Total time elapsed: 40.5 seconds
# ##############################
# Halving objects.
# Done.
# ##############################
# Time elapsed from last time log: 5.9 seconds
# Total time elapsed: 55.0 seconds
# ##############################
# Max local distortion = 8.93279798770573e+00
# Constructing intermediate views.
# eta = 2.
# # non-empty views with sz < 2 = 9169
# #nodes in views with sz < 2 = 9169
# /home/dhruv/codebase/pyLDLE2/docs/ldle_nbks/doubled_manifolds/../../../pyLDLE2/intermed_views_.py:106: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   neigh_ind = np.array(neigh_ind)
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 9.3 seconds
# Total time elapsed: 9.4 seconds
# ##############################
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 99.6 seconds
# Total time elapsed: 109.0 seconds
# ##############################
# eta = 3.
# # non-empty views with sz < 3 = 328
# #nodes in views with sz < 3 = 656
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 0.6 seconds
# Total time elapsed: 109.5 seconds
# ##############################
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 2.7 seconds
# Total time elapsed: 112.2 seconds
# ##############################
# eta = 4.
# # non-empty views with sz < 4 = 334
# #nodes in views with sz < 4 = 1002
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 113.1 seconds
# ##############################
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 7.6 seconds
# Total time elapsed: 120.7 seconds
# ##############################
# eta = 5.
# # non-empty views with sz < 5 = 249
# #nodes in views with sz < 5 = 996
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 0.7 seconds
# Total time elapsed: 121.4 seconds
# ##############################
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 10.5 seconds
# Total time elapsed: 131.9 seconds
# ##############################
# eta = 6.
# # non-empty views with sz < 6 = 173
# #nodes in views with sz < 6 = 865
# Costs computed when eta = 6.
# ##############################
# Time elapsed from last time log: 0.6 seconds
# Total time elapsed: 132.5 seconds
# ##############################
# Remaining #nodes in views with sz < 6 = 0
# Done with eta = 6.
# ##############################
# Time elapsed from last time log: 8.9 seconds
# Total time elapsed: 141.5 seconds
# ##############################
# eta = 7.
# # non-empty views with sz < 7 = 133
# #nodes in views with sz < 7 = 798
# Costs computed when eta = 7.
# ##############################
# Time elapsed from last time log: 0.6 seconds
# Total time elapsed: 142.0 seconds
# ##############################
# Remaining #nodes in views with sz < 7 = 0
# Done with eta = 7.
# ##############################
# Time elapsed from last time log: 9.7 seconds
# Total time elapsed: 151.7 seconds
# ##############################
# eta = 8.
# # non-empty views with sz < 8 = 101
# #nodes in views with sz < 8 = 707
# Costs computed when eta = 8.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 152.2 seconds
# ##############################
# Remaining #nodes in views with sz < 8 = 0
# Done with eta = 8.
# ##############################
# Time elapsed from last time log: 8.6 seconds
# Total time elapsed: 160.8 seconds
# ##############################
# eta = 9.
# # non-empty views with sz < 9 = 91
# #nodes in views with sz < 9 = 728
# Costs computed when eta = 9.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 161.3 seconds
# ##############################
# Remaining #nodes in views with sz < 9 = 0
# Done with eta = 9.
# ##############################
# Time elapsed from last time log: 9.5 seconds
# Total time elapsed: 170.8 seconds
# ##############################
# eta = 10.
# # non-empty views with sz < 10 = 68
# #nodes in views with sz < 10 = 612
# Costs computed when eta = 10.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 171.4 seconds
# ##############################
# Remaining #nodes in views with sz < 10 = 0
# Done with eta = 10.
# ##############################
# Time elapsed from last time log: 9.6 seconds
# Total time elapsed: 180.9 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 0.4 seconds
# Total time elapsed: 181.3 seconds
# ##############################
# After clustering, max distortion is 15.169483
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 146 intermediate views
# Ambiguous overlaps checked for 292 intermediate views
# Ambiguous overlaps checked for 438 intermediate views
# Ambiguous overlaps checked for 584 intermediate views
# Ambiguous overlaps checked for 587 points
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 1
# Computing initial embedding using: sequential algorithm
# ##############################
# Time elapsed from last time log: 2.0 seconds
# Total time elapsed: 2.0 seconds
# ##############################
# Initial alignment of 146 views completed
# Initial alignment of 292 views completed
# Initial alignment of 438 views completed
# Initial alignment of 584 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 0.2 seconds
# Total time elapsed: 2.2 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 8.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9756 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.0 seconds
# Total time elapsed: 10.4 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 13.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9756 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.8 seconds
# Total time elapsed: 15.4 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 18.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9756 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.9 seconds
# Total time elapsed: 20.5 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 23.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9756 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.8 seconds
# Total time elapsed: 25.5 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 28.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9756 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.7 seconds
# Total time elapsed: 30.4 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 5
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 33.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9756 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.8 seconds
# Total time elapsed: 35.4 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 6
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 38.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9756 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.0 seconds
# Total time elapsed: 40.7 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 7
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 43.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9756 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.8 seconds
# Total time elapsed: 45.7 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 8
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 48.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9756 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.7 seconds
# Total time elapsed: 50.6 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 9
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 53.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9756 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.0 seconds
# Total time elapsed: 55.9 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 10
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 59.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9756 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.8 seconds
# Total time elapsed: 61.1 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 11
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 64.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9756 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.9 seconds
# Total time elapsed: 66.2 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 9756 multiplied with B
# Alignment error: 0.459
# ##############################
# Time elapsed from last time log: 0.7 seconds
# Total time elapsed: 66.9 seconds
# ##############################
# array([[-0.09598967,  0.60409452],
#        [-0.09860948,  0.60336666],
#        [-0.10166648,  0.6025233 ],
#        ...,
#        [ 0.09972052, -0.62646233],
#        [ 0.09406194, -0.62894953],
#        [ 0.09616843, -0.62809429]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/doubled_squarewithtwoholes//ldle.dat
