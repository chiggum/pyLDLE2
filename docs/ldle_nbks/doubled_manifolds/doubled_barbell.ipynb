# %% [markdown]
# ### Doubled barbell

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
save_dir_root = '../data/pyLDLE2/doubled_barbell/'

# %%
X, labelsMat, ddX = datasets.Datasets().barbell()
# Out:
# X.shape =  (10227, 2)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LDLE', 'N': 200, 'tau': 90},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  intermed_opts={'eta_min': 10},
                  global_opts={
                      'max_iter': 20,
                      'init_algo_align_w_parent_only': True # Set this True for low noise
                  },
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 875 is created.

# %%
ldle.fit(X=X, ddX=ddX)
# Out:
# Doubling manifold.
# No. of points on the boundary = 764
# /home/dhruv/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_base.py:199: EfficiencyWarning: Precomputed sparse input was not sorted by data.
#   warnings.warn(
# Done.
# ##############################
# Time elapsed from last time log: 54.4 seconds
# Total time elapsed: 54.4 seconds
# ##############################
# Constructing unnorm graph Laplacian + its eigendecomposition.
# Done.
# ##############################
# Time elapsed from last time log: 14.3 seconds
# Total time elapsed: 14.3 seconds
# ##############################
# Computing Atilde: Inner Prod of Grad of EigFuncs.
# FEM for Atilde.
# Atilde: 0 points processed...
# Atilde: 4922 points processed...
# Atilde: 9844 points processed...
# Atilde: 14766 points processed...
# Atilde: 19688 points processed...
# Atilde: all points processed...
# Done.
# ##############################
# Time elapsed from last time log: 4.4 seconds
# Total time elapsed: 18.7 seconds
# ##############################
# Computing LDLE.
# local_param: all 19690 points processed...
# max distortion is 110.986807
# Done.
# ##############################
# Time elapsed from last time log: 2.8 seconds
# Total time elapsed: 21.6 seconds
# ##############################
# Posprocessing local parameterizations.
# #Param replaced: 17065, max distortion: 13.853175
# #Param replaced: 2559, max distortion: 13.654778
# #Param replaced: 94, max distortion: 13.654778
# #Param replaced: 15, max distortion: 13.654778
# #Param replaced: 9, max distortion: 13.654778
# #Param replaced: 0, max distortion: 13.654778
# Max local distortion after postprocessing: 1.3654777548943395e+01
# Done.
# ##############################
# Time elapsed from last time log: 16.1 seconds
# Total time elapsed: 37.8 seconds
# ##############################
# Halving objects.
# Done.
# ##############################
# Time elapsed from last time log: 7.7 seconds
# Total time elapsed: 55.4 seconds
# ##############################
# Max local distortion = 13.396949385598063
# Constructing intermediate views.
# eta = 2.
# # non-empty views with sz < 2 = 10227
# #nodes in views with sz < 2 = 10227
# /home/dhruv/codebase/pyLDLE2/docs/ldle_nbks/doubled_manifolds/../../../pyLDLE2/intermed_views_.py:107: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   neigh_ind = np.array(neigh_ind)
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 19.2 seconds
# Total time elapsed: 19.3 seconds
# ##############################
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 154.1 seconds
# Total time elapsed: 173.4 seconds
# ##############################
# eta = 3.
# # non-empty views with sz < 3 = 612
# #nodes in views with sz < 3 = 1224
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 1.8 seconds
# Total time elapsed: 175.2 seconds
# ##############################
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 11.2 seconds
# Total time elapsed: 186.4 seconds
# ##############################
# eta = 4.
# # non-empty views with sz < 4 = 450
# #nodes in views with sz < 4 = 1350
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 1.5 seconds
# Total time elapsed: 187.9 seconds
# ##############################
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 20.6 seconds
# Total time elapsed: 208.5 seconds
# ##############################
# eta = 5.
# # non-empty views with sz < 5 = 308
# #nodes in views with sz < 5 = 1232
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 1.8 seconds
# Total time elapsed: 210.3 seconds
# ##############################
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 18.1 seconds
# Total time elapsed: 228.4 seconds
# ##############################
# eta = 6.
# # non-empty views with sz < 6 = 206
# #nodes in views with sz < 6 = 1030
# Costs computed when eta = 6.
# ##############################
# Time elapsed from last time log: 1.2 seconds
# Total time elapsed: 229.7 seconds
# ##############################
# Remaining #nodes in views with sz < 6 = 0
# Done with eta = 6.
# ##############################
# Time elapsed from last time log: 17.0 seconds
# Total time elapsed: 246.7 seconds
# ##############################
# eta = 7.
# # non-empty views with sz < 7 = 165
# #nodes in views with sz < 7 = 990
# Costs computed when eta = 7.
# ##############################
# Time elapsed from last time log: 1.2 seconds
# Total time elapsed: 247.8 seconds
# ##############################
# Remaining #nodes in views with sz < 7 = 0
# Done with eta = 7.
# ##############################
# Time elapsed from last time log: 18.8 seconds
# Total time elapsed: 266.7 seconds
# ##############################
# eta = 8.
# # non-empty views with sz < 8 = 113
# #nodes in views with sz < 8 = 791
# Costs computed when eta = 8.
# ##############################
# Time elapsed from last time log: 1.1 seconds
# Total time elapsed: 267.8 seconds
# ##############################
# Remaining #nodes in views with sz < 8 = 0
# Done with eta = 8.
# ##############################
# Time elapsed from last time log: 14.1 seconds
# Total time elapsed: 281.8 seconds
# ##############################
# eta = 9.
# # non-empty views with sz < 9 = 80
# #nodes in views with sz < 9 = 640
# Costs computed when eta = 9.
# ##############################
# Time elapsed from last time log: 1.0 seconds
# Total time elapsed: 282.8 seconds
# ##############################
# Remaining #nodes in views with sz < 9 = 0
# Done with eta = 9.
# ##############################
# Time elapsed from last time log: 11.6 seconds
# Total time elapsed: 294.4 seconds
# ##############################
# eta = 10.
# # non-empty views with sz < 10 = 91
# #nodes in views with sz < 10 = 819
# Costs computed when eta = 10.
# ##############################
# Time elapsed from last time log: 1.0 seconds
# Total time elapsed: 295.5 seconds
# ##############################
# Remaining #nodes in views with sz < 10 = 0
# Done with eta = 10.
# ##############################
# Time elapsed from last time log: 18.6 seconds
# Total time elapsed: 314.1 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 314.6 seconds
# ##############################
# After clustering, max distortion is 20.058667
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 166 intermediate views
# Ambiguous overlaps checked for 332 intermediate views
# Ambiguous overlaps checked for 498 intermediate views
# Ambiguous overlaps checked for 664 points
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 1
# Computing initial embedding using: sequential algorithm
# ##############################
# Time elapsed from last time log: 2.6 seconds
# Total time elapsed: 2.6 seconds
# ##############################
# Initial alignment of 166 views completed
# Initial alignment of 332 views completed
# Initial alignment of 498 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 3.1 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 4.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10891 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.6 seconds
# Total time elapsed: 6.8 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 7.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10891 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.6 seconds
# Total time elapsed: 10.0 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 10.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10891 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.7 seconds
# Total time elapsed: 13.2 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 13.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10891 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.7 seconds
# Total time elapsed: 16.3 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 16.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10891 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.7 seconds
# Total time elapsed: 19.5 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 5
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 19.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10891 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.8 seconds
# Total time elapsed: 22.7 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 6
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 23.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10891 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.7 seconds
# Total time elapsed: 25.8 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 7
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 26.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10891 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.7 seconds
# Total time elapsed: 28.9 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 8
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 29.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10891 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.6 seconds
# Total time elapsed: 32.0 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 9
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 32.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10891 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.7 seconds
# Total time elapsed: 35.1 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 10
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 35.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10891 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.7 seconds
# Total time elapsed: 38.3 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 11
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 38.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10891 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.6 seconds
# Total time elapsed: 41.3 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 12
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 41.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10891 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.7 seconds
# Total time elapsed: 44.4 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 13
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 44.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10891 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.7 seconds
# Total time elapsed: 47.5 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 14
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 48.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10891 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.5 seconds
# Total time elapsed: 50.6 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 15
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 51.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10891 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.7 seconds
# Total time elapsed: 53.7 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 16
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 54.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10891 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.6 seconds
# Total time elapsed: 56.7 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 17
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 57.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10891 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.6 seconds
# Total time elapsed: 59.8 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 18
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 60.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10891 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.6 seconds
# Total time elapsed: 62.9 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 19
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 63.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10891 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.6 seconds
# Total time elapsed: 65.9 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 10891 multiplied with B
# Alignment error: 1.560
# ##############################
# Time elapsed from last time log: 1.1 seconds
# Total time elapsed: 67.0 seconds
# ##############################
# array([[ 1.05994107,  0.76622174],
#        [ 1.06271448,  0.76375408],
#        [ 1.06897702,  0.75944995],
#        ...,
#        [-0.57843065, -0.36282859],
#        [-0.56758567, -0.35910527],
#        [-0.56140996, -0.36526419]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/doubled_barbell//ldle.dat
