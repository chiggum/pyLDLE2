# %% [markdown]
# ### Doubled swissroll with hole

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
save_dir_root = '../data/pyLDLE2/doubled_swissrollwithhole/'

# %%
X, labelsMat, ddX = datasets.Datasets().swissrollwithhole()
# Out:
# X.shape =  (9946, 3)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LDLE'},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  intermed_opts={'eta_min': 10},
                  global_opts={
                      'max_iter': 12,
                      'init_algo_align_w_parent_only': True # Set this True for low noise
                  },
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 875 is created.

# %%
ldle.fit(X=X, ddX=ddX)
# Out:
# Doubling manifold.
# No. of points on the boundary = 528
# /home/dhruv/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_base.py:199: EfficiencyWarning: Precomputed sparse input was not sorted by data.
#   warnings.warn(
# Done.
# ##############################
# Time elapsed from last time log: 56.8 seconds
# Total time elapsed: 56.8 seconds
# ##############################
# Constructing unnorm graph Laplacian + its eigendecomposition.
# Done.
# ##############################
# Time elapsed from last time log: 5.0 seconds
# Total time elapsed: 5.0 seconds
# ##############################
# Computing Atilde: Inner Prod of Grad of EigFuncs.
# FEM for Atilde.
# Atilde: 0 points processed...
# Atilde: 4841 points processed...
# Atilde: 9682 points processed...
# Atilde: 14523 points processed...
# Atilde: all points processed...
# Done.
# ##############################
# Time elapsed from last time log: 1.4 seconds
# Total time elapsed: 6.5 seconds
# ##############################
# Computing LDLE.
# local_param: all 19364 points processed...
# max distortion is 126248.892812
# Done.
# ##############################
# Time elapsed from last time log: 2.3 seconds
# Total time elapsed: 8.8 seconds
# ##############################
# Posprocessing local parameterizations.
# #Param replaced: 18409, max distortion: 8.593527
# #Param replaced: 8547, max distortion: 8.519761
# #Param replaced: 3325, max distortion: 8.519761
# #Param replaced: 1158, max distortion: 8.519761
# #Param replaced: 228, max distortion: 8.519761
# #Param replaced: 47, max distortion: 8.519761
# #Param replaced: 6, max distortion: 8.519761
# #Param replaced: 1, max distortion: 8.519761
# #Param replaced: 0, max distortion: 8.519761
# Max local distortion after postprocessing: 8.519761241969306e+00
# Done.
# ##############################
# Time elapsed from last time log: 20.9 seconds
# Total time elapsed: 29.7 seconds
# ##############################
# Halving objects.
# Done.
# ##############################
# Time elapsed from last time log: 7.4 seconds
# Total time elapsed: 47.0 seconds
# ##############################
# Max local distortion = 8.519761241932029
# Constructing intermediate views.
# eta = 2.
# # non-empty views with sz < 2 = 9946
# #nodes in views with sz < 2 = 9946
# /home/dhruv/codebase/pyLDLE2/docs/ldle_nbks/doubled_manifolds/../../../pyLDLE2/intermed_views_.py:107: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   neigh_ind = np.array(neigh_ind)
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 18.4 seconds
# Total time elapsed: 18.5 seconds
# ##############################
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 214.0 seconds
# Total time elapsed: 232.5 seconds
# ##############################
# eta = 3.
# # non-empty views with sz < 3 = 427
# #nodes in views with sz < 3 = 854
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 1.4 seconds
# Total time elapsed: 233.9 seconds
# ##############################
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 9.3 seconds
# Total time elapsed: 243.2 seconds
# ##############################
# eta = 4.
# # non-empty views with sz < 4 = 380
# #nodes in views with sz < 4 = 1140
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 1.4 seconds
# Total time elapsed: 244.7 seconds
# ##############################
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 20.5 seconds
# Total time elapsed: 265.2 seconds
# ##############################
# eta = 5.
# # non-empty views with sz < 5 = 233
# #nodes in views with sz < 5 = 932
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 1.2 seconds
# Total time elapsed: 266.4 seconds
# ##############################
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 18.2 seconds
# Total time elapsed: 284.6 seconds
# ##############################
# eta = 6.
# # non-empty views with sz < 6 = 187
# #nodes in views with sz < 6 = 935
# Costs computed when eta = 6.
# ##############################
# Time elapsed from last time log: 1.1 seconds
# Total time elapsed: 285.7 seconds
# ##############################
# Remaining #nodes in views with sz < 6 = 0
# Done with eta = 6.
# ##############################
# Time elapsed from last time log: 22.9 seconds
# Total time elapsed: 308.6 seconds
# ##############################
# eta = 7.
# # non-empty views with sz < 7 = 141
# #nodes in views with sz < 7 = 846
# Costs computed when eta = 7.
# ##############################
# Time elapsed from last time log: 1.1 seconds
# Total time elapsed: 309.7 seconds
# ##############################
# Remaining #nodes in views with sz < 7 = 1
# Done with eta = 7.
# ##############################
# Time elapsed from last time log: 23.9 seconds
# Total time elapsed: 333.6 seconds
# ##############################
# eta = 8.
# # non-empty views with sz < 8 = 108
# #nodes in views with sz < 8 = 750
# Costs computed when eta = 8.
# ##############################
# Time elapsed from last time log: 1.1 seconds
# Total time elapsed: 334.7 seconds
# ##############################
# Remaining #nodes in views with sz < 8 = 1
# Done with eta = 8.
# ##############################
# Time elapsed from last time log: 22.1 seconds
# Total time elapsed: 356.8 seconds
# ##############################
# eta = 9.
# # non-empty views with sz < 9 = 63
# #nodes in views with sz < 9 = 497
# Costs computed when eta = 9.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 357.6 seconds
# ##############################
# Remaining #nodes in views with sz < 9 = 1
# Done with eta = 9.
# ##############################
# Time elapsed from last time log: 12.7 seconds
# Total time elapsed: 370.3 seconds
# ##############################
# eta = 10.
# # non-empty views with sz < 10 = 56
# #nodes in views with sz < 10 = 496
# Costs computed when eta = 10.
# ##############################
# Time elapsed from last time log: 0.7 seconds
# Total time elapsed: 371.0 seconds
# ##############################
# Remaining #nodes in views with sz < 10 = 1
# Done with eta = 10.
# ##############################
# Time elapsed from last time log: 12.8 seconds
# Total time elapsed: 383.8 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 384.3 seconds
# ##############################
# After clustering, max distortion is 9.697269
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 152 intermediate views
# Ambiguous overlaps checked for 304 intermediate views
# Ambiguous overlaps checked for 456 intermediate views
# Ambiguous overlaps checked for 608 intermediate views
# Ambiguous overlaps checked for 610 points
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 1
# Computing initial embedding using: sequential algorithm
# ##############################
# Time elapsed from last time log: 2.9 seconds
# Total time elapsed: 2.9 seconds
# ##############################
# Initial alignment of 152 views completed
# Initial alignment of 304 views completed
# Initial alignment of 456 views completed
# Initial alignment of 608 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 3.3 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 4.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10556 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 6.6 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 7.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10556 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 9.4 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 10.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10556 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 12.3 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 12.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10556 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 15.0 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 15.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10556 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 17.7 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 5
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 18.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10556 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 20.3 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 6
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 20.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10556 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 22.9 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 7
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 23.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10556 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.3 seconds
# Total time elapsed: 25.6 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 8
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 26.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10556 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 28.2 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 9
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 28.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10556 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.3 seconds
# Total time elapsed: 30.9 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 10
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 31.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10556 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 33.6 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 11
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 34.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10556 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 36.1 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 10556 multiplied with B
# Alignment error: 0.672
# ##############################
# Time elapsed from last time log: 0.9 seconds
# Total time elapsed: 37.1 seconds
# ##############################
# array([[ 0.29574778, -0.84243331],
#        [ 0.29438483, -0.84454839],
#        [ 0.29009989, -0.84901228],
#        ...,
#        [-0.32872686,  0.81733708],
#        [-0.33043708,  0.81290095],
#        [-0.33140357,  0.81046532]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/doubled_swissrollwithhole//ldle.dat
