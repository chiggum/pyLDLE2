# %% [markdown]
# ### Doubled swissroll with hole

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
save_dir_root = '../data/pyLDLE2/doubled_swissrollwithhole/'

# %%
X, labelsMat, ddX = datasets.Datasets().swissrollwithhole()
# Out:
# X.shape =  (9946, 3)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LDLE'},
                  intermed_opts={'algo':'best', 'eta_min':5},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 700 is created.
# Options provided:
# local_opts:
# {
#     "Atilde_method": "LDLE_1",
#     "N": 100,
#     "algo": "LDLE",
#     "delta": 0.9,
#     "gl_type": "unnorm",
#     "k": 28,
#     "k_nn": 49,
#     "k_nn0": 700,
#     "k_tune": 7,
#     "n_proc": 32,
#     "no_gamma": false,
#     "p": 0.99,
#     "pp_n_thresh": 32,
#     "tau": 50,
#     "to_postprocess": true
# }
# intermed_opts:
# {
#     "algo": "best",
#     "eta_max": 25,
#     "eta_min": 5,
#     "len_S_thresh": 256,
#     "local_algo": "LDLE",
#     "n_proc": 32,
#     "n_times": 4
# }
# global_opts:
# {
#     "color_tear": true,
#     "compute_error": false,
#     "init_algo_align_w_parent_only": true,
#     "init_algo_name": "procrustes",
#     "k": 28,
#     "main_algo": "LDLE",
#     "max_iter": 20,
#     "n_proc": 32,
#     "nu": 3,
#     "refine_algo_alpha": 0.3,
#     "refine_algo_max_internal_iter": 100,
#     "refine_algo_name": "rgd",
#     "to_tear": true,
#     "vis_before_init": false
# }

# %%
ldle.fit(X=X, ddX=ddX)
# Out:
# Doubling manifold.
# No. of points on the boundary = 528
# /home/dhruv/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_base.py:199: EfficiencyWarning: Precomputed sparse input was not sorted by data.
#   warnings.warn(
# Done.
# ##############################
# Time elapsed from last time log: 172.4 seconds
# Total time elapsed: 172.4 seconds
# ##############################
# Constructing unnorm graph Laplacian + its eigendecomposition.
# Done.
# ##############################
# Time elapsed from last time log: 47.6 seconds
# Total time elapsed: 47.6 seconds
# ##############################
# Computing Atilde: Inner Prod of Grad of EigFuncs.
# FEM for Atilde.
# Atilde: 0 points processed...
# Atilde: 4841 points processed...
# Atilde: 9682 points processed...
# Atilde: 14523 points processed...
# Atilde: all points processed...
# Done.
# ##############################
# Time elapsed from last time log: 17.9 seconds
# Total time elapsed: 65.7 seconds
# ##############################
# Computing LDLE.
# local_param: all 19364 points processed...
# max distortion is 8452.413255
# Done.
# ##############################
# Time elapsed from last time log: 8.0 seconds
# Total time elapsed: 73.9 seconds
# ##############################
# Posprocessing local parameterizations.
# #Param replaced: 18160, max distortion: 8.375523
# #Param replaced: 9106, max distortion: 8.375523
# #Param replaced: 3493, max distortion: 8.375523
# #Param replaced: 1435, max distortion: 8.375523
# #Param replaced: 370, max distortion: 8.375523
# #Param replaced: 62, max distortion: 8.375523
# #Param replaced: 26, max distortion: 8.375523
# #Param replaced: 6, max distortion: 8.375523
# #Param replaced: 1, max distortion: 8.375523
# #Param replaced: 0, max distortion: 8.375523
# Max local distortion after postprocessing: 8.37552283498222
# Done.
# ##############################
# Time elapsed from last time log: 39.5 seconds
# Total time elapsed: 113.4 seconds
# ##############################
# Halving objects.
# Done.
# ##############################
# Time elapsed from last time log: 28.2 seconds
# Total time elapsed: 176.4 seconds
# ##############################
# Max local distortion = 8.324423492437292
# Constructing intermediate views.
# eta = 2.
# # non-empty views with sz < 2 = 9946
# #nodes in views with sz < 2 = 9946
# /home/dhruv/codebase/pyLDLE2/docs/ldle_nbks/doubled_manifolds/../../../pyLDLE2/intermed_views_.py:122: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   neigh_ind = np.array(neigh_ind)
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 24.5 seconds
# Total time elapsed: 26.7 seconds
# ##############################
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 592.3 seconds
# Total time elapsed: 619.0 seconds
# ##############################
# eta = 3.
# # non-empty views with sz < 3 = 447
# #nodes in views with sz < 3 = 894
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 6.6 seconds
# Total time elapsed: 625.6 seconds
# ##############################
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 22.9 seconds
# Total time elapsed: 648.5 seconds
# ##############################
# eta = 4.
# # non-empty views with sz < 4 = 364
# #nodes in views with sz < 4 = 1092
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 7.1 seconds
# Total time elapsed: 655.6 seconds
# ##############################
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 61.0 seconds
# Total time elapsed: 716.5 seconds
# ##############################
# eta = 5.
# # non-empty views with sz < 5 = 269
# #nodes in views with sz < 5 = 1076
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 7.8 seconds
# Total time elapsed: 724.3 seconds
# ##############################
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 78.0 seconds
# Total time elapsed: 802.3 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 2.7 seconds
# Total time elapsed: 805.2 seconds
# ##############################
# After clustering, max distortion is 8.288408
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 290 intermediate views
# Ambiguous overlaps checked for 580 intermediate views
# Ambiguous overlaps checked for 870 intermediate views
# Ambiguous overlaps checked for 1160 intermediate views
# Ambiguous overlaps checked for 1161 points
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 1
# Computing initial embedding using: procrustes algorithm
# ##############################
# Time elapsed from last time log: 30.2 seconds
# Total time elapsed: 30.2 seconds
# ##############################
# Initial alignment of 290 views completed
# Initial alignment of 580 views completed
# Initial alignment of 870 views completed
# Initial alignment of 1160 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 3.5 seconds
# Total time elapsed: 33.7 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 39.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11107 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 29.3 seconds
# Total time elapsed: 69.2 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 73.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11107 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 27.2 seconds
# Total time elapsed: 100.5 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 104.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11107 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 32.9 seconds
# Total time elapsed: 137.1 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 140.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11107 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 29.5 seconds
# Total time elapsed: 169.8 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 172.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11107 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 38.5 seconds
# Total time elapsed: 211.4 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 5
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 214.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11107 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 35.5 seconds
# Total time elapsed: 250.2 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 6
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 253.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11107 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 36.4 seconds
# Total time elapsed: 289.4 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 7
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 291.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11107 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 40.7 seconds
# Total time elapsed: 332.2 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 8
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 334.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11107 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 37.8 seconds
# Total time elapsed: 372.5 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 9
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 375.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11107 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 44.5 seconds
# Total time elapsed: 420.2 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 10
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 422.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11107 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 44.9 seconds
# Total time elapsed: 467.8 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 11
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 470.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11107 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 37.8 seconds
# Total time elapsed: 508.2 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 12
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 510.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11107 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 36.4 seconds
# Total time elapsed: 547.3 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 13
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 549.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11107 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 42.5 seconds
# Total time elapsed: 592.2 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 14
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 594.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11107 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 34.6 seconds
# Total time elapsed: 629.4 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 15
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 632.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11107 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 40.6 seconds
# Total time elapsed: 672.8 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 16
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 675.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11107 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 37.5 seconds
# Total time elapsed: 712.6 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 17
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 715.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11107 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 35.5 seconds
# Total time elapsed: 750.5 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 18
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 752.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11107 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 36.8 seconds
# Total time elapsed: 788.8 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 19
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 792.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11107 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 42.8 seconds
# Total time elapsed: 835.2 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 11107 multiplied with B
# Alignment error: 0.516
# ##############################
# Time elapsed from last time log: 20.0 seconds
# Total time elapsed: 855.2 seconds
# ##############################
# array([[-0.1205749 ,  0.90605467],
#        [-0.11822824,  0.9082613 ],
#        [-0.11154572,  0.91256014],
#        ...,
#        [ 0.05488788, -0.92412165],
#        [ 0.05952602, -0.9212469 ],
#        [ 0.06206461, -0.91963462]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/doubled_swissrollwithhole//ldle.dat
