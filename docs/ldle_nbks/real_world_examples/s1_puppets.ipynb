# %% [markdown]
# ### Puppets Data

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
save_dir_root = '../data/pyLDLE2/s1_puppets/'

# %%
X, labelsMat, img, img_shape = datasets.Datasets().puppets_data(dirpath='/home/dhruv/codebase/data/PuppetsData', prefix='s1', n_pca=100)
# Out:
# Applying PCA
# sum(explained_variance_ratio): 0.9808061709777028
# X.shape =  (8100, 100)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LDLE', 'N': 25},
                  intermed_opts={'eta_min': 5},
                  global_opts={'alpha':0.01},
                  vis_opts={'c': None, 'save_dir': save_dir_root},
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 700 is created.
# Options provided:
# local_opts:
# {
#     "Atilde_method": "LDLE_1",
#     "N": 25,
#     "algo": "LDLE",
#     "alpha": 1,
#     "debug": true,
#     "delta": 0.9,
#     "gl_type": "unnorm",
#     "k": 28,
#     "k_nn": 49,
#     "k_nn0": 700,
#     "k_tune": 7,
#     "max_iter": 300,
#     "n_proc": 32,
#     "no_gamma": false,
#     "p": 0.99,
#     "pp_n_thresh": 32,
#     "reg": 0.0,
#     "tau": 50,
#     "to_postprocess": true,
#     "verbose": true
# }
# intermed_opts:
# {
#     "algo": "best",
#     "debug": true,
#     "eta_max": 25,
#     "eta_min": 5,
#     "len_S_thresh": 256,
#     "local_algo": "LDLE",
#     "n_proc": 32,
#     "n_times": 4,
#     "verbose": true
# }
# global_opts:
# {
#     "align_w_parent_only": true,
#     "alpha": 0.01,
#     "color_tear": true,
#     "compute_error": false,
#     "debug": true,
#     "eps": 1e-08,
#     "init_algo_name": "procrustes",
#     "k": 28,
#     "main_algo": "LDLE",
# ...

# %%
ldle.fit(X=X)
# Out:
# Constructing unnorm graph Laplacian + its eigendecomposition.
# Done.
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 2.2 seconds
# ##############################
# Computing Atilde: Inner Prod of Grad of EigFuncs.
# FEM for Atilde.
# Atilde: 0 points processed...
# Atilde: 2025 points processed...
# Atilde: 4050 points processed...
# Atilde: 6075 points processed...
# Atilde: all points processed...
# Done.
# ##############################
# Time elapsed from last time log: 0.3 seconds
# Total time elapsed: 2.6 seconds
# ##############################
# Computing LDLE.
# local_param: all 8100 points processed...
# max distortion is 816.710770
# Done.
# ##############################
# Time elapsed from last time log: 2.5 seconds
# Total time elapsed: 5.1 seconds
# ##############################
# Posprocessing local parameterizations.
# #Param replaced: 7867, max distortion: 91.218573
# ...

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat*0, ldle, img, img_shape], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/s1_puppets//ldle.dat
