# %% [markdown]
# ### Sphere and swissroll with noise = 0.01

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
save_dir_root = '../data/pyLDLE2/sphere_and_swissoll/'

# %%
X, labelsMat, ddX = datasets.Datasets().sphere_and_swissroll()
# Out:
# X.shape =  (5000, 3)
# X.shape =  (5207, 3)
# X.shape =  (10207, 3)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LDLE'},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  intermed_opts={'eta_min': 10},
                  global_opts={
                      'max_iter': 10,
                      'init_algo_align_w_parent_only': True # Set this True for low noise
                  },
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 875 is created.

# %%
ldle.fit(X=X)
# Out:
# Constructing unnorm graph Laplacian + its eigendecomposition.
# Done.
# ##############################
# Time elapsed from last time log: 2.5 seconds
# Total time elapsed: 2.5 seconds
# ##############################
# Computing Atilde: Inner Prod of Grad of EigFuncs.
# FEM for Atilde.
# Atilde: 0 points processed...
# Atilde: 2551 points processed...
# Atilde: 5102 points processed...
# Atilde: 7653 points processed...
# Atilde: 10204 points processed...
# Atilde: all points processed...
# Done.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 3.3 seconds
# ##############################
# Computing LDLE.
# local_param: all 10207 points processed...
# max distortion is 861.710288
# Done.
# ##############################
# Time elapsed from last time log: 1.2 seconds
# Total time elapsed: 4.6 seconds
# ##############################
# Posprocessing local parameterizations.
# #Param replaced: 9761, max distortion: 69.310889
# #Param replaced: 4418, max distortion: 59.472039
# #Param replaced: 1634, max distortion: 59.472039
# #Param replaced: 914, max distortion: 59.472039
# #Param replaced: 618, max distortion: 59.472039
# #Param replaced: 168, max distortion: 59.472039
# #Param replaced: 67, max distortion: 59.472039
# #Param replaced: 23, max distortion: 59.472039
# #Param replaced: 24, max distortion: 59.472039
# #Param replaced: 41, max distortion: 59.472039
# #Param replaced: 7, max distortion: 59.472039
# #Param replaced: 0, max distortion: 59.472039
# Max local distortion after postprocessing: 5.9472038998357455e+01
# Done.
# ##############################
# Time elapsed from last time log: 13.8 seconds
# Total time elapsed: 18.4 seconds
# ##############################
# Max local distortion = 59.472038998357455
# Constructing intermediate views.
# eta = 2.
# # non-empty views with sz < 2 = 10207
# #nodes in views with sz < 2 = 10207
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 20.9 seconds
# Total time elapsed: 21.0 seconds
# ##############################
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 198.4 seconds
# Total time elapsed: 219.4 seconds
# ##############################
# eta = 3.
# # non-empty views with sz < 3 = 605
# #nodes in views with sz < 3 = 1210
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 2.3 seconds
# Total time elapsed: 221.7 seconds
# ##############################
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 16.1 seconds
# Total time elapsed: 237.8 seconds
# ##############################
# eta = 4.
# # non-empty views with sz < 4 = 436
# #nodes in views with sz < 4 = 1308
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 2.0 seconds
# Total time elapsed: 239.9 seconds
# ##############################
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 28.5 seconds
# Total time elapsed: 268.3 seconds
# ##############################
# eta = 5.
# # non-empty views with sz < 5 = 260
# #nodes in views with sz < 5 = 1040
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 1.5 seconds
# Total time elapsed: 269.9 seconds
# ##############################
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 23.4 seconds
# Total time elapsed: 293.3 seconds
# ##############################
# eta = 6.
# # non-empty views with sz < 6 = 205
# #nodes in views with sz < 6 = 1025
# Costs computed when eta = 6.
# ##############################
# Time elapsed from last time log: 1.2 seconds
# Total time elapsed: 294.5 seconds
# ##############################
# Remaining #nodes in views with sz < 6 = 0
# Done with eta = 6.
# ##############################
# Time elapsed from last time log: 25.9 seconds
# Total time elapsed: 320.5 seconds
# ##############################
# eta = 7.
# # non-empty views with sz < 7 = 135
# #nodes in views with sz < 7 = 810
# Costs computed when eta = 7.
# ##############################
# Time elapsed from last time log: 1.2 seconds
# Total time elapsed: 321.6 seconds
# ##############################
# Remaining #nodes in views with sz < 7 = 0
# Done with eta = 7.
# ##############################
# Time elapsed from last time log: 24.3 seconds
# Total time elapsed: 345.9 seconds
# ##############################
# eta = 8.
# # non-empty views with sz < 8 = 146
# #nodes in views with sz < 8 = 1022
# Costs computed when eta = 8.
# ##############################
# Time elapsed from last time log: 1.3 seconds
# Total time elapsed: 347.2 seconds
# ##############################
# Remaining #nodes in views with sz < 8 = 0
# Done with eta = 8.
# ##############################
# Time elapsed from last time log: 36.4 seconds
# Total time elapsed: 383.6 seconds
# ##############################
# eta = 9.
# # non-empty views with sz < 9 = 80
# #nodes in views with sz < 9 = 640
# Costs computed when eta = 9.
# ##############################
# Time elapsed from last time log: 1.1 seconds
# Total time elapsed: 384.7 seconds
# ##############################
# Remaining #nodes in views with sz < 9 = 0
# Done with eta = 9.
# ##############################
# Time elapsed from last time log: 20.0 seconds
# Total time elapsed: 404.7 seconds
# ##############################
# eta = 10.
# # non-empty views with sz < 10 = 82
# #nodes in views with sz < 10 = 738
# Costs computed when eta = 10.
# ##############################
# Time elapsed from last time log: 0.9 seconds
# Total time elapsed: 405.6 seconds
# ##############################
# Remaining #nodes in views with sz < 10 = 0
# Done with eta = 10.
# ##############################
# Time elapsed from last time log: 22.8 seconds
# Total time elapsed: 428.4 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 0.6 seconds
# Total time elapsed: 429.0 seconds
# ##############################
# After clustering, max distortion is 80.214175
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 155 intermediate views
# Ambiguous overlaps checked for 310 intermediate views
# Ambiguous overlaps checked for 465 intermediate views
# Ambiguous overlaps checked for 620 intermediate views
# Ambiguous overlaps checked for 622 points
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 2
# Multiple connected components detected
# Computing initial embedding using: sequential algorithm
# ##############################
# Time elapsed from last time log: 3.3 seconds
# Total time elapsed: 3.3 seconds
# ##############################
# Initial alignment of 155 views completed
# Initial alignment of 155 views completed
# Initial alignment of 310 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 3.7 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 6.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10829 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.1 seconds
# Total time elapsed: 8.1 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 9.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10829 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 12.0 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 13.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10829 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.1 seconds
# Total time elapsed: 15.6 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 17.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10829 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.1 seconds
# Total time elapsed: 19.2 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 20.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10829 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 22.7 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 5
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 24.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10829 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.1 seconds
# Total time elapsed: 26.1 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 6
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 27.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10829 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.1 seconds
# Total time elapsed: 29.6 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 7
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 30.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10829 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.1 seconds
# Total time elapsed: 33.0 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 8
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 34.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10829 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.1 seconds
# Total time elapsed: 36.4 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 9
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 37.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10829 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.3 seconds
# Total time elapsed: 40.1 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 10829 multiplied with B
# Alignment error: 122.023
# ##############################
# Time elapsed from last time log: 1.0 seconds
# Total time elapsed: 41.1 seconds
# ##############################
# array([[-0.20955449,  0.0425911 ],
#        [-0.2068539 ,  0.05648002],
#        [-0.19730351,  0.03804901],
#        ...,
#        [ 0.59762434,  0.7284985 ],
#        [ 0.57904195,  0.7349659 ],
#        [ 0.60555579,  0.73836544]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/sphere_and_swissoll//ldle.dat
