# %% [markdown]
# ### Sphere and swissroll with noise = 0.01

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
save_dir_root = '../data/pyLDLE2/sphere_and_swissoll/'

# %%
X, labelsMat, ddX = datasets.Datasets().sphere_and_swissroll()
# Out:
# X.shape =  (5000, 3)
# X.shape =  (5207, 3)
# X.shape =  (10207, 3)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LDLE'},
                  intermed_opts={'algo':'best', 'eta_min': 5},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 700 is created.
# Options provided:
# local_opts:
# {
#     "Atilde_method": "LDLE_1",
#     "N": 100,
#     "algo": "LDLE",
#     "delta": 0.9,
#     "gl_type": "unnorm",
#     "k": 28,
#     "k_nn": 49,
#     "k_nn0": 700,
#     "k_tune": 7,
#     "n_proc": 32,
#     "no_gamma": false,
#     "p": 0.99,
#     "pp_n_thresh": 32,
#     "tau": 50,
#     "to_postprocess": true
# }
# intermed_opts:
# {
#     "algo": "best",
#     "eta_max": 25,
#     "eta_min": 5,
#     "len_S_thresh": 256,
#     "local_algo": "LDLE",
#     "n_proc": 32,
#     "n_times": 4
# }
# global_opts:
# {
#     "color_tear": true,
#     "compute_error": false,
#     "init_algo_align_w_parent_only": true,
#     "init_algo_name": "procrustes",
#     "k": 28,
#     "main_algo": "LDLE",
#     "max_iter": 20,
#     "n_proc": 32,
#     "nu": 3,
#     "refine_algo_alpha": 0.3,
#     "refine_algo_max_internal_iter": 100,
#     "refine_algo_name": "rgd",
#     "to_tear": true,
#     "vis_before_init": false
# }

# %%
ldle.fit(X=X)
# Out:
# Constructing unnorm graph Laplacian + its eigendecomposition.
# Done.
# ##############################
# Time elapsed from last time log: 34.9 seconds
# Total time elapsed: 34.9 seconds
# ##############################
# Computing Atilde: Inner Prod of Grad of EigFuncs.
# FEM for Atilde.
# Atilde: 0 points processed...
# Atilde: 2551 points processed...
# Atilde: 5102 points processed...
# Atilde: 7653 points processed...
# Atilde: 10204 points processed...
# Atilde: all points processed...
# Done.
# ##############################
# Time elapsed from last time log: 15.5 seconds
# Total time elapsed: 50.5 seconds
# ##############################
# Computing LDLE.
# local_param: all 10207 points processed...
# max distortion is 1113.577956
# Done.
# ##############################
# Time elapsed from last time log: 7.1 seconds
# Total time elapsed: 57.8 seconds
# ##############################
# Posprocessing local parameterizations.
# #Param replaced: 9667, max distortion: 62.690580
# #Param replaced: 4684, max distortion: 61.993420
# #Param replaced: 1782, max distortion: 61.993420
# #Param replaced: 867, max distortion: 61.993420
# #Param replaced: 666, max distortion: 61.993420
# #Param replaced: 413, max distortion: 61.993420
# #Param replaced: 117, max distortion: 61.993420
# #Param replaced: 59, max distortion: 61.993420
# #Param replaced: 15, max distortion: 61.993420
# #Param replaced: 15, max distortion: 61.993420
# #Param replaced: 9, max distortion: 61.993420
# #Param replaced: 0, max distortion: 61.993420
# Max local distortion after postprocessing: 6.199341999595165e+01
# Done.
# ##############################
# Time elapsed from last time log: 45.1 seconds
# Total time elapsed: 102.9 seconds
# ##############################
# Max local distortion = 61.99341999595165
# Constructing intermediate views.
# eta = 2.
# # non-empty views with sz < 2 = 10207
# #nodes in views with sz < 2 = 10207
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 41.7 seconds
# Total time elapsed: 46.7 seconds
# ##############################
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 1090.6 seconds
# Total time elapsed: 1137.3 seconds
# ##############################
# eta = 3.
# # non-empty views with sz < 3 = 657
# #nodes in views with sz < 3 = 1314
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 9.1 seconds
# Total time elapsed: 1146.4 seconds
# ##############################
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 106.1 seconds
# Total time elapsed: 1252.5 seconds
# ##############################
# eta = 4.
# # non-empty views with sz < 4 = 437
# #nodes in views with sz < 4 = 1311
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 8.4 seconds
# Total time elapsed: 1260.8 seconds
# ##############################
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 136.5 seconds
# Total time elapsed: 1397.3 seconds
# ##############################
# eta = 5.
# # non-empty views with sz < 5 = 317
# #nodes in views with sz < 5 = 1268
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 6.2 seconds
# Total time elapsed: 1403.5 seconds
# ##############################
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 167.6 seconds
# Total time elapsed: 1571.1 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 7.2 seconds
# Total time elapsed: 1578.5 seconds
# ##############################
# After clustering, max distortion is 63.562487
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 308 intermediate views
# Ambiguous overlaps checked for 616 intermediate views
# Ambiguous overlaps checked for 924 intermediate views
# Ambiguous overlaps checked for 1232 intermediate views
# Ambiguous overlaps checked for 1234 points
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 2
# Multiple connected components detected
# Computing initial embedding using: procrustes algorithm
# ##############################
# Time elapsed from last time log: 75.3 seconds
# Total time elapsed: 75.3 seconds
# ##############################
# Initial alignment of 308 views completed
# Initial alignment of 308 views completed
# Initial alignment of 616 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 9.5 seconds
# Total time elapsed: 84.9 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 117.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11441 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 49.2 seconds
# Total time elapsed: 167.1 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 184.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11441 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 49.5 seconds
# Total time elapsed: 233.6 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 245.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11441 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 53.5 seconds
# Total time elapsed: 299.2 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 315.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11441 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 43.0 seconds
# Total time elapsed: 358.2 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 376.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11441 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 48.9 seconds
# Total time elapsed: 425.3 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 5
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 441.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11441 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 46.9 seconds
# Total time elapsed: 488.1 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 6
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 503.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11441 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 54.2 seconds
# Total time elapsed: 557.6 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 7
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 573.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11441 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 52.4 seconds
# Total time elapsed: 626.1 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 8
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 641.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11441 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 45.5 seconds
# Total time elapsed: 687.4 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 9
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 697.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11441 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 47.6 seconds
# Total time elapsed: 745.1 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 10
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 750.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11441 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 45.6 seconds
# Total time elapsed: 796.3 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 11
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 805.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11441 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 49.1 seconds
# Total time elapsed: 854.1 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 12
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 870.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11441 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 49.9 seconds
# Total time elapsed: 920.4 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 13
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 934.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11441 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 45.9 seconds
# Total time elapsed: 980.2 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 14
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 995.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11441 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 48.1 seconds
# Total time elapsed: 1044.0 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 15
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 1053.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11441 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 41.1 seconds
# Total time elapsed: 1094.6 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 16
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 1108.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11441 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 50.3 seconds
# Total time elapsed: 1158.5 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 17
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 1166.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11441 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 48.6 seconds
# Total time elapsed: 1215.1 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 18
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 1227.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11441 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 47.8 seconds
# Total time elapsed: 1275.7 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 19
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 1286.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11441 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 45.7 seconds
# Total time elapsed: 1332.0 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 11441 multiplied with B
# Alignment error: 89.258
# ##############################
# Time elapsed from last time log: 19.0 seconds
# Total time elapsed: 1351.1 seconds
# ##############################
# array([[-0.091874  , -0.14581924],
#        [-0.08177643, -0.15284835],
#        [-0.10232479, -0.15271081],
#        ...,
#        [ 0.7808871 ,  1.04106093],
#        [ 0.76417995,  1.02797498],
#        [ 0.77654896,  1.01136717]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/sphere_and_swissoll//ldle.dat
