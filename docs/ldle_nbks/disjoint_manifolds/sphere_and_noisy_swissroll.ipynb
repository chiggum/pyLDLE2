# %% [markdown]
# ### Sphere and swissroll with noise = 0.01

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
save_dir_root = '../data/pyLDLE2/sphere_and_swissoll/'

# %%
X, labelsMat, ddX = datasets.Datasets().sphere_and_swissroll()
# Out:
# X.shape =  (5000, 3)
# X.shape =  (5207, 3)
# X.shape =  (10207, 3)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LDLE'},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  intermed_opts={'eta_min': 10},
                  global_opts={
                      'max_iter': 10,
                      'init_algo_align_w_parent_only': True # Set this True for low noise
                  },
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 600 is created.

# %%
ldle.fit(X=X)
# Out:
# Constructing unnorm graph Laplacian + its eigendecomposition.
# Done.
# ##############################
# Time elapsed from last time log: 2.4 seconds
# Total time elapsed: 2.4 seconds
# ##############################
# Computing Atilde: Inner Prod of Grad of EigFuncs.
# FEM for Atilde.
# Atilde: 0 points processed...
# Atilde: 2551 points processed...
# Atilde: 5102 points processed...
# Atilde: 7653 points processed...
# Atilde: 10204 points processed...
# Atilde: all points processed...
# Done.
# ##############################
# Time elapsed from last time log: 0.7 seconds
# Total time elapsed: 3.1 seconds
# ##############################
# Computing LDLE.
# local_param: all 10207 points processed...
# max distortion is 3750.589015
# Done.
# ##############################
# Time elapsed from last time log: 1.3 seconds
# Total time elapsed: 4.4 seconds
# ##############################
# Posprocessing LDLE.
# Iter 1, Param replaced: 9701, max distortion: 107.224928
# Iter 2, Param replaced: 5207, max distortion: 76.563965
# Iter 3, Param replaced: 2400, max distortion: 65.733951
# Iter 4, Param replaced: 1020, max distortion: 60.749364
# Iter 5, Param replaced: 702, max distortion: 60.749364
# Iter 6, Param replaced: 563, max distortion: 60.749364
# Iter 7, Param replaced: 230, max distortion: 60.749364
# Iter 8, Param replaced: 72, max distortion: 60.749364
# Iter 9, Param replaced: 30, max distortion: 60.749364
# Iter 10, Param replaced: 20, max distortion: 60.749364
# Iter 11, Param replaced: 24, max distortion: 60.749364
# Iter 12, Param replaced: 34, max distortion: 60.749364
# Iter 13, Param replaced: 34, max distortion: 60.749364
# Iter 14, Param replaced: 18, max distortion: 60.749364
# Iter 15, Param replaced: 7, max distortion: 60.749364
# Iter 16, Param replaced: 3, max distortion: 60.749364
# Iter 17, Param replaced: 0, max distortion: 60.749364
# Done.
# ##############################
# Time elapsed from last time log: 30.6 seconds
# Total time elapsed: 35.0 seconds
# ##############################
# Max local distortion = 6.0749363507337335e+01
# Constructing intermediate views.
# eta = 2.
# # non-empty views with sz < 2 = 10207
# #nodes in views with sz < 2 = 10207
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 10.7 seconds
# Total time elapsed: 10.7 seconds
# ##############################
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 114.8 seconds
# Total time elapsed: 125.5 seconds
# ##############################
# eta = 3.
# # non-empty views with sz < 3 = 422
# #nodes in views with sz < 3 = 844
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 126.3 seconds
# ##############################
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 4.0 seconds
# Total time elapsed: 130.3 seconds
# ##############################
# eta = 4.
# # non-empty views with sz < 4 = 307
# #nodes in views with sz < 4 = 921
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 131.1 seconds
# ##############################
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 6.9 seconds
# Total time elapsed: 138.0 seconds
# ##############################
# eta = 5.
# # non-empty views with sz < 5 = 261
# #nodes in views with sz < 5 = 1044
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 138.8 seconds
# ##############################
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 10.6 seconds
# Total time elapsed: 149.5 seconds
# ##############################
# eta = 6.
# # non-empty views with sz < 6 = 191
# #nodes in views with sz < 6 = 955
# Costs computed when eta = 6.
# ##############################
# Time elapsed from last time log: 0.7 seconds
# Total time elapsed: 150.1 seconds
# ##############################
# Remaining #nodes in views with sz < 6 = 0
# Done with eta = 6.
# ##############################
# Time elapsed from last time log: 12.1 seconds
# Total time elapsed: 162.2 seconds
# ##############################
# eta = 7.
# # non-empty views with sz < 7 = 152
# #nodes in views with sz < 7 = 912
# Costs computed when eta = 7.
# ##############################
# Time elapsed from last time log: 0.6 seconds
# Total time elapsed: 162.9 seconds
# ##############################
# Remaining #nodes in views with sz < 7 = 0
# Done with eta = 7.
# ##############################
# Time elapsed from last time log: 12.2 seconds
# Total time elapsed: 175.1 seconds
# ##############################
# eta = 8.
# # non-empty views with sz < 8 = 114
# #nodes in views with sz < 8 = 798
# Costs computed when eta = 8.
# ##############################
# Time elapsed from last time log: 0.7 seconds
# Total time elapsed: 175.7 seconds
# ##############################
# Remaining #nodes in views with sz < 8 = 0
# Done with eta = 8.
# ##############################
# Time elapsed from last time log: 11.7 seconds
# Total time elapsed: 187.4 seconds
# ##############################
# eta = 9.
# # non-empty views with sz < 9 = 106
# #nodes in views with sz < 9 = 848
# Costs computed when eta = 9.
# ##############################
# Time elapsed from last time log: 0.7 seconds
# Total time elapsed: 188.1 seconds
# ##############################
# Remaining #nodes in views with sz < 9 = 0
# Done with eta = 9.
# ##############################
# Time elapsed from last time log: 14.2 seconds
# Total time elapsed: 202.3 seconds
# ##############################
# eta = 10.
# # non-empty views with sz < 10 = 80
# #nodes in views with sz < 10 = 720
# Costs computed when eta = 10.
# ##############################
# Time elapsed from last time log: 0.6 seconds
# Total time elapsed: 203.0 seconds
# ##############################
# Remaining #nodes in views with sz < 10 = 0
# Done with eta = 10.
# ##############################
# Time elapsed from last time log: 13.1 seconds
# Total time elapsed: 216.1 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 216.6 seconds
# ##############################
# After clustering, max distortion is 113.230179
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 161 intermediate views
# Ambiguous overlaps checked for 322 intermediate views
# Ambiguous overlaps checked for 483 intermediate views
# Ambiguous overlaps checked for 644 intermediate views
# Ambiguous overlaps checked for 645 points
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 2
# Multiple connected components detected
# Computing initial embedding using: sequential algorithm
# ##############################
# Time elapsed from last time log: 2.6 seconds
# Total time elapsed: 2.6 seconds
# ##############################
# Initial alignment of 161 views completed
# Initial alignment of 161 views completed
# Initial alignment of 322 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 0.2 seconds
# Total time elapsed: 2.8 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 11.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10852
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 29.3 seconds
# Total time elapsed: 40.2 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 44.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10852
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 28.7 seconds
# Total time elapsed: 73.2 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 77.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10852
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 28.7 seconds
# Total time elapsed: 106.2 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 110.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10852
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 28.7 seconds
# Total time elapsed: 139.2 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 143.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10852
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 29.7 seconds
# Total time elapsed: 173.1 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 5
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 177.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10852
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 29.2 seconds
# Total time elapsed: 206.5 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 6
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 210.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10852
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 30.3 seconds
# Total time elapsed: 241.1 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 7
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 246.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10852
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 33.1 seconds
# Total time elapsed: 279.1 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 8
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 284.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10852
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 34.2 seconds
# Total time elapsed: 318.6 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 9
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 323.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10852
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 34.9 seconds
# Total time elapsed: 357.9 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 10852
# Alignment error: 74.140
# ##############################
# Time elapsed from last time log: 3.4 seconds
# Total time elapsed: 361.3 seconds
# ##############################
# array([[-0.93680708, -0.0633731 ],
#        [-0.94438865, -0.05149292],
#        [-0.92455893, -0.05815557],
#        ...,
#        [ 0.56411792, -0.8430988 ],
#        [ 0.56033338, -0.84726515],
#        [ 0.58104957, -0.8432838 ]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/sphere_and_swissoll//ldle.dat
