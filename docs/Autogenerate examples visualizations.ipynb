# %%
import sys
sys.path.insert(0,'..')
import nbformat as nbf
from nbconvert.preprocessors import ExecutePreprocessor

process_all = 0 # bypass individual 'processed' flags
exs = [
    {'title': '# Doubled square with two holes - further visualizations',
     'nbk_dir': 'ldle_nbks/doubled_manifolds',
     'nbk_name': 'doubled_squarewithtwoholes_vis.ipynb',
     'data_path': '../data/pyLDLE2/doubled_squarewithtwoholes/ldle.dat',
     'processed': 1
    },
    {'title': '# Doubled barbell - further visualizations',
     'nbk_dir': 'ldle_nbks/doubled_manifolds',
     'nbk_name': 'doubled_barbell_vis.ipynb',
     'data_path': '../data/pyLDLE2/doubled_barbell/ldle.dat',
     'processed': 1
    },
    {'title': '# Doubled swissroll with hole - further visualizations',
     'nbk_dir': 'ldle_nbks/doubled_manifolds',
     'nbk_name': 'doubled_swissrollwithhole_vis.ipynb',
     'data_path': '../data/pyLDLE2/doubled_swissrollwithhole/ldle.dat',
     'processed': 1
    },
    {'title': '# Doubled sphere with hole - further visualizations',
     'nbk_dir': 'ldle_nbks/doubled_manifolds',
     'nbk_name': 'doubled_spherewithhole_vis.ipynb',
     'data_path': '../data/pyLDLE2/doubled_spherewithhole/ldle.dat',
     'processed': 1
    },
    {'title': '# Doubled rectangle - further visualizations',
     'nbk_dir': 'ldle_nbks/doubled_manifolds',
     'nbk_name': 'doubled_rectangle_vis.ipynb',
     'data_path': '../data/pyLDLE2/doubled_rectangle/ldle.dat',
     'processed': 1
    },
    {'title': '# Sphere - further visualizations',
     'nbk_dir': 'ldle_nbks/closed_manifolds',
     'nbk_name': 'sphere_vis.ipynb',
     'data_path': '../data/pyLDLE2/sphere/ldle.dat',
     'processed': 1
    },
    {'title': '# Flat torus - further visualizations',
     'nbk_dir': 'ldle_nbks/closed_manifolds',
     'nbk_name': 'flattorus4d_vis.ipynb',
     'data_path': '../data/pyLDLE2/flattorus4d/ldle.dat',
     'processed': 1
    },
    {'title': '# Curved torus - further visualizations',
     'nbk_dir': 'ldle_nbks/closed_manifolds',
     'nbk_name': 'curvedtorus3d_vis.ipynb',
     'data_path': '../data/pyLDLE2/curvedtorus3d/ldle.dat',
     'processed': 1
    },
    {'title': '# Klein bottle - further visualizations',
     'nbk_dir': 'ldle_nbks/non_orientable_manifolds',
     'nbk_name': 'kleinbottle4d_vis.ipynb',
     'data_path': '../data/pyLDLE2/kleinbottle4d/ldle.dat',
     'processed': 1
    },
    {'title': '# Mobius strip - further visualizations',
     'nbk_dir': 'ldle_nbks/non_orientable_manifolds',
     'nbk_name': 'mobiusstrip3d_vis.ipynb',
     'data_path': '../data/pyLDLE2/mobiusstrip3d/ldle.dat',
     'processed': 1
    },
    {'title': '# Rectangle - further visualizations',
     'nbk_dir': 'ldle_nbks/manifolds_with_boundary',
     'nbk_name': 'rectangle_vis.ipynb',
     'data_path': '../data/pyLDLE2/rectangle/ldle.dat',
     'processed': 1
    },
    {'title': '# Barbell - further visualizations',
     'nbk_dir': 'ldle_nbks/manifolds_with_boundary',
     'nbk_name': 'barbell_vis.ipynb',
     'data_path': '../data/pyLDLE2/barbell/ldle.dat',
     'processed': 1
    },
    {'title': '# Square with two holes - further visualizations',
     'nbk_dir': 'ldle_nbks/manifolds_with_boundary',
     'nbk_name': 'squarewithtwoholes_vis.ipynb',
     'data_path': '../data/pyLDLE2/squarewithtwoholes/ldle.dat',
     'processed': 1
    },
    {'title': '# Sphere with hole - further visualizations',
     'nbk_dir': 'ldle_nbks/manifolds_with_boundary',
     'nbk_name': 'spherewithhole_vis.ipynb',
     'data_path': '../data/pyLDLE2/spherewithhole/ldle.dat',
     'processed': 1
    },
    {'title': '# Swissroll with hole - further visualizations',
     'nbk_dir': 'ldle_nbks/manifolds_with_boundary',
     'nbk_name': 'swissrollwithhole_vis.ipynb',
     'data_path': '../data/pyLDLE2/swissrollwithhole/ldle.dat',
     'processed': 1
    },
    {'title': '# Swissroll with noise = 0.01 - further visualizations',
     'nbk_dir': 'ldle_nbks/noisy_manifolds',
     'nbk_name': 'noisy_swissroll_1_vis.ipynb',
     'data_path': '../data/pyLDLE2/swissroll_with_noise_0.01/ldle.dat',
     'processed': 1
    },
    {'title': '# Swissroll with noise = 0.02 - further visualizations',
     'nbk_dir': 'ldle_nbks/noisy_manifolds',
     'nbk_name': 'noisy_swissroll_3_vis.ipynb',
     'data_path': '../data/pyLDLE2/swissroll_with_noise_0.02/ldle.dat',
     'processed': 1
    },
    {'title': '# Sphere - further visualizations',
     'nbk_dir': 'lpca_nbks/closed_manifolds',
     'nbk_name': 'sphere_vis.ipynb',
     'data_path': '../data/pyLDLE2/sphere/ldle.dat',
     'processed': 1
    },
    {'title': '# Flat torus - further visualizations',
     'nbk_dir': 'lpca_nbks/closed_manifolds',
     'nbk_name': 'flattorus4d_vis.ipynb',
     'data_path': '../data/pyLDLE2/flattorus4d/ldle.dat',
     'processed': 1
    },
    {'title': '# Curved torus - further visualizations',
     'nbk_dir': 'lpca_nbks/closed_manifolds',
     'nbk_name': 'curvedtorus3d_vis.ipynb',
     'data_path': '../data/pyLDLE2/curvedtorus3d/ldle.dat',
     'processed': 1
    },
    {'title': '# Klein bottle - further visualizations',
     'nbk_dir': 'lpca_nbks/non_orientable_manifolds',
     'nbk_name': 'kleinbottle4d_vis.ipynb',
     'data_path': '../data/pyLDLE2/kleinbottle4d/ldle.dat',
     'processed': 1
    },
    {'title': '# Mobius strip - further visualizations',
     'nbk_dir': 'lpca_nbks/non_orientable_manifolds',
     'nbk_name': 'mobiusstrip3d_vis.ipynb',
     'data_path': '../data/pyLDLE2/mobiusstrip3d/ldle.dat',
     'processed': 1
    },
    {'title': '# Rectangle - further visualizations',
     'nbk_dir': 'lpca_nbks/manifolds_with_boundary',
     'nbk_name': 'rectangle_vis.ipynb',
     'data_path': '../data/pyLDLE2/rectangle/ldle.dat',
     'processed': 1
    },
    {'title': '# Barbell - further visualizations',
     'nbk_dir': 'lpca_nbks/manifolds_with_boundary',
     'nbk_name': 'barbell_vis.ipynb',
     'data_path': '../data/pyLDLE2/barbell/ldle.dat',
     'processed': 1
    },
    {'title': '# Square with two holes - further visualizations',
     'nbk_dir': 'lpca_nbks/manifolds_with_boundary',
     'nbk_name': 'squarewithtwoholes_vis.ipynb',
     'data_path': '../data/pyLDLE2/squarewithtwoholes/ldle.dat',
     'processed': 1
    },
    {'title': '# Sphere with hole - further visualizations',
     'nbk_dir': 'lpca_nbks/manifolds_with_boundary',
     'nbk_name': 'spherewithhole_vis.ipynb',
     'data_path': '../data/pyLDLE2/spherewithhole/ldle.dat',
     'processed': 1
    },
    {'title': '# Swissroll with hole - further visualizations',
     'nbk_dir': 'lpca_nbks/manifolds_with_boundary',
     'nbk_name': 'swissrollwithhole_vis.ipynb',
     'data_path': '../data/pyLDLE2/swissrollwithhole/ldle.dat',
     'processed': 1
    },
    {'title': '# Swissroll with noise = 0.01 - further visualizations',
     'nbk_dir': 'lpca_nbks/noisy_manifolds',
     'nbk_name': 'noisy_swissroll_1_vis.ipynb',
     'data_path': '../data/pyLDLE2/swissroll_with_noise_0.01/ldle.dat',
     'processed': 1
    },
    {'title': '# Swissroll with noise = 0.02 - further visualizations',
     'nbk_dir': 'lpca_nbks/noisy_manifolds',
     'nbk_name': 'noisy_swissroll_3_vis.ipynb',
     'data_path': '../data/pyLDLE2/swissroll_with_noise_0.02/ldle.dat',
     'processed': 0
    },
    {'title': '# Puppets data - further visualizations',
     'nbk_dir': 'ldle_nbks/real_world_examples',
     'nbk_name': 's1_puppets_vis.ipynb',
     'data_path': '../data/pyLDLE2/s1_puppets/ldle.dat',
     'processed': 1
    },
    {'title': '# Puppets data - further visualizations',
     'nbk_dir': 'lpca_nbks/real_world_examples',
     'nbk_name': 's1_puppets_vis.ipynb',
     'data_path': '../data/pyLDLE2/s1_puppets_data/ldle.dat',
     'processed': 1
    },
    {'title': '# Sphere and swiss roll with noise = 0.01 - further visualizations',
     'nbk_dir': 'ldle_nbks/disjoint_manifolds',
     'nbk_name': 'sphere_and_noisy_swissroll_vis.ipynb',
     'data_path': '../data/pyLDLE2/sphere_and_swissoll/ldle.dat',
     'processed': 1
    },
    {'title': '# Sphere and swiss roll with noise = 0.01 - further visualizations',
     'nbk_dir': 'lpca_nbks/disjoint_manifolds',
     'nbk_name': 'sphere_and_noisy_swissroll_vis.ipynb',
     'data_path': '../data/pyLDLE2/sphere_and_swissoll/ldle.dat',
     'processed': 1
    },
    {'title': '# Production epochs data - further visualizations',
     'nbk_dir': 'lpca_nbks/real_world_examples',
     'nbk_name': '_trash_production_epochs_vis.ipynb',
     'data_path': '../data/pyLDLE2/production_epochs/ldle.dat',
     'processed': 1
    },
    {'title': '# Measurement epochs data - further visualizations',
     'nbk_dir': 'lpca_nbks/real_world_examples',
     'nbk_name': '_trash_measurement_epochs_vis.ipynb',
     'data_path': '../data/pyLDLE2/measurement_epochs/ldle.dat',
     'processed': 1
    },
]

code_prefix = """\
# Not really required
import sys
sys.path.insert(0, '../../..')

from pyLDLE2 import visualize_all
visualize_all.visualize('"""

def gen_code(fpath):
    code = code_prefix
    code += fpath
    code += "')"
    return code

for ex in exs:
    if ex['processed'] and (process_all==0): # already processed
        continue
    
    print('Processing', ex['nbk_dir'], ex['nbk_name'])
    nb = nbf.v4.new_notebook()
    nb['cells'] = [nbf.v4.new_markdown_cell(ex['title']),
                   nbf.v4.new_code_cell(gen_code(ex['data_path']))]
    with open(ex['nbk_dir']+'/'+ex['nbk_name'], 'w') as f:
        nbf.write(nb, f)
    
    with open(ex['nbk_dir']+'/'+ex['nbk_name']) as ff:
        nb = nbf.read(ff, as_version=4)

    ep = ExecutePreprocessor(timeout=-1, kernel_name='python3')
    ep.preprocess(nb, {'metadata': {'path': ex['nbk_dir']}})
    
    with open(ex['nbk_dir']+'/'+ex['nbk_name'], 'w', encoding='utf-8') as f:
        nbf.write(nb, f)
# Out:
# Processing ltsa_nbks/noisy_manifolds noisy_swissroll_3_vis.ipynb
