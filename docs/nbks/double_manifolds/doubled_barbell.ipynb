# %% [markdown]
# ### Doubled barbell

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
save_dir_root = '../data/pyLDLE2/doubled_barbell/'

# %%
X, labelsMat, ddX = datasets.Datasets().barbell()
# Out:
# X.shape =  (10227, 2)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LDLE', 'N': 200, 'tau': 90},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  intermed_opts={'eta_min': 10},
                  global_opts={
                      'max_iter': 15,
                      'init_algo_align_w_parent_only': True # Set this True for low noise
                  },
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 600 is created.

# %%
ldle.fit(X=X, ddX=ddX)
# Out:
# Doubling manifold.
# No. of points on the boundary = 764
# /home/dhruv/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_base.py:199: EfficiencyWarning: Precomputed sparse input was not sorted by data.
#   warnings.warn(
# Done.
# ##############################
# Time elapsed from last time log: 33.0 seconds
# Total time elapsed: 33.0 seconds
# ##############################
# Constructing unnorm graph Laplacian + its eigendecomposition.
# Done.
# ##############################
# Time elapsed from last time log: 14.6 seconds
# Total time elapsed: 14.6 seconds
# ##############################
# Computing Atilde: Inner Prod of Grad of EigFuncs.
# FEM for Atilde.
# Atilde: 0 points processed...
# Atilde: 4922 points processed...
# Atilde: 9844 points processed...
# Atilde: 14766 points processed...
# Atilde: 19688 points processed...
# Atilde: all points processed...
# Done.
# ##############################
# Time elapsed from last time log: 4.5 seconds
# Total time elapsed: 19.2 seconds
# ##############################
# Computing LDLE.
# local_param: all 19690 points processed...
# max distortion is 17003.805139
# Done.
# ##############################
# Time elapsed from last time log: 3.1 seconds
# Total time elapsed: 22.4 seconds
# ##############################
# Posprocessing LDLE.
# Iter 1, Param replaced: 16699, max distortion: 21.391765
# Iter 2, Param replaced: 4308, max distortion: 21.391765
# Iter 3, Param replaced: 380, max distortion: 21.391765
# Iter 4, Param replaced: 30, max distortion: 21.391765
# Iter 5, Param replaced: 5, max distortion: 21.391765
# Iter 6, Param replaced: 0, max distortion: 21.391765
# Done.
# ##############################
# Time elapsed from last time log: 29.2 seconds
# Total time elapsed: 51.6 seconds
# ##############################
# Halving objects.
# Done.
# ##############################
# Time elapsed from last time log: 6.7 seconds
# Total time elapsed: 67.7 seconds
# ##############################
# Max local distortion = 1.2129229284304403e+01
# Constructing intermediate views.
# eta = 2.
# # non-empty views with sz < 2 = 10227
# #nodes in views with sz < 2 = 10227
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 11.9 seconds
# Total time elapsed: 12.0 seconds
# ##############################
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 100.6 seconds
# Total time elapsed: 112.6 seconds
# ##############################
# eta = 3.
# # non-empty views with sz < 3 = 414
# #nodes in views with sz < 3 = 828
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 1.0 seconds
# Total time elapsed: 113.6 seconds
# ##############################
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 3.0 seconds
# Total time elapsed: 116.5 seconds
# ##############################
# eta = 4.
# # non-empty views with sz < 4 = 334
# #nodes in views with sz < 4 = 1002
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 1.0 seconds
# Total time elapsed: 117.6 seconds
# ##############################
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 6.4 seconds
# Total time elapsed: 124.0 seconds
# ##############################
# eta = 5.
# # non-empty views with sz < 5 = 262
# #nodes in views with sz < 5 = 1048
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 1.0 seconds
# Total time elapsed: 125.0 seconds
# ##############################
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 7.6 seconds
# Total time elapsed: 132.6 seconds
# ##############################
# eta = 6.
# # non-empty views with sz < 6 = 184
# #nodes in views with sz < 6 = 920
# Costs computed when eta = 6.
# ##############################
# Time elapsed from last time log: 0.9 seconds
# Total time elapsed: 133.5 seconds
# ##############################
# Remaining #nodes in views with sz < 6 = 0
# Done with eta = 6.
# ##############################
# Time elapsed from last time log: 7.6 seconds
# Total time elapsed: 141.1 seconds
# ##############################
# eta = 7.
# # non-empty views with sz < 7 = 150
# #nodes in views with sz < 7 = 900
# Costs computed when eta = 7.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 141.9 seconds
# ##############################
# Remaining #nodes in views with sz < 7 = 0
# Done with eta = 7.
# ##############################
# Time elapsed from last time log: 9.2 seconds
# Total time elapsed: 151.1 seconds
# ##############################
# eta = 8.
# # non-empty views with sz < 8 = 115
# #nodes in views with sz < 8 = 805
# Costs computed when eta = 8.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 152.0 seconds
# ##############################
# Remaining #nodes in views with sz < 8 = 0
# Done with eta = 8.
# ##############################
# Time elapsed from last time log: 7.9 seconds
# Total time elapsed: 159.9 seconds
# ##############################
# eta = 9.
# # non-empty views with sz < 9 = 93
# #nodes in views with sz < 9 = 744
# Costs computed when eta = 9.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 160.7 seconds
# ##############################
# Remaining #nodes in views with sz < 9 = 0
# Done with eta = 9.
# ##############################
# Time elapsed from last time log: 6.7 seconds
# Total time elapsed: 167.4 seconds
# ##############################
# eta = 10.
# # non-empty views with sz < 10 = 83
# #nodes in views with sz < 10 = 747
# Costs computed when eta = 10.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 168.3 seconds
# ##############################
# Remaining #nodes in views with sz < 10 = 0
# Done with eta = 10.
# ##############################
# Time elapsed from last time log: 8.8 seconds
# Total time elapsed: 177.1 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 0.4 seconds
# Total time elapsed: 177.5 seconds
# ##############################
# After clustering, max distortion is 16.813483
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 166 intermediate views
# Ambiguous overlaps checked for 332 intermediate views
# Ambiguous overlaps checked for 498 intermediate views
# Ambiguous overlaps checked for 664 intermediate views
# Ambiguous overlaps checked for 665 points
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 1
# Computing initial embedding using: sequential algorithm
# ##############################
# Time elapsed from last time log: 2.6 seconds
# Total time elapsed: 2.6 seconds
# ##############################
# Initial alignment of 166 views completed
# Initial alignment of 332 views completed
# Initial alignment of 498 views completed
# Initial alignment of 664 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 0.2 seconds
# Total time elapsed: 2.8 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 10.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10892
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 74.9 seconds
# Total time elapsed: 85.8 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 90.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10892
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 77.3 seconds
# Total time elapsed: 167.3 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 171.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10892
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 76.2 seconds
# Total time elapsed: 247.7 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 251.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10892
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 75.9 seconds
# Total time elapsed: 327.7 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 331.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10892
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 75.9 seconds
# Total time elapsed: 407.7 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 5
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 411.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10892
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 76.7 seconds
# Total time elapsed: 488.6 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 6
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 492.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10892
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 76.1 seconds
# Total time elapsed: 568.8 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 7
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 573.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10892
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 77.0 seconds
# Total time elapsed: 650.0 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 8
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 654.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10892
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 76.8 seconds
# Total time elapsed: 731.0 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 9
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 735.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10892
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 80.7 seconds
# Total time elapsed: 815.9 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 10
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 820.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10892
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 76.4 seconds
# Total time elapsed: 896.5 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 11
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 900.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10892
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 76.6 seconds
# Total time elapsed: 977.2 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 12
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 981.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10892
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 76.7 seconds
# Total time elapsed: 1058.1 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 13
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 1062.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10892
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 76.2 seconds
# Total time elapsed: 1138.4 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 14
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 1142.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10892
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 79.1 seconds
# Total time elapsed: 1221.6 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 10892
# Alignment error: 0.733
# ##############################
# Time elapsed from last time log: 3.0 seconds
# Total time elapsed: 1224.6 seconds
# ##############################
# array([[ 3.07265301e-01, -1.25918761e+00],
#        [ 3.15986175e-01, -1.25336820e+00],
#        [ 3.22345755e-01, -1.24911588e+00],
#        ...,
#        [-5.78905381e-03,  6.58454476e-01],
#        [ 6.60049092e-04,  6.55700002e-01],
#        [ 9.11146258e-03,  6.53245477e-01]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/doubled_barbell//ldle.dat
