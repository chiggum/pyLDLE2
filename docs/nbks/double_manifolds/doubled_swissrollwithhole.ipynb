# %% [markdown]
# ### Doubled swissroll with hole

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_

# %%
save_dir_root = '../data/pyLDLE2/doubled_swissrollwithhole/'

# %%
X, labelsMat, ddX = datasets.Datasets().swissrollwithhole()
# Out:
# X.shape =  (9946, 3)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LDLE'},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  intermed_opts={'eta_min': 10},
                  global_opts={
                      'max_iter': 12,
                      'init_algo_align_w_parent_only': True # Set this True for low noise
                  },
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 600 is created.

# %%
ldle.fit(X=X, ddX=ddX)
# Out:
# Doubling manifold.
# No. of points on the boundary = 528
# /home/dhruv/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_base.py:199: EfficiencyWarning: Precomputed sparse input was not sorted by data.
#   warnings.warn(
# Done.
# ##############################
# Time elapsed from last time log: 31.5 seconds
# Total time elapsed: 32.2 seconds
# ##############################
# Constructing unnorm graph Laplacian + its eigendecomposition.
# Done.
# ##############################
# Time elapsed from last time log: 6.1 seconds
# Total time elapsed: 6.1 seconds
# ##############################
# Computing Atilde: Inner Prod of Grad of EigFuncs.
# FEM for Atilde.
# Atilde: 0 points processed...
# Atilde: 4841 points processed...
# Atilde: 9682 points processed...
# Atilde: 14523 points processed...
# Atilde: all points processed...
# Done.
# ##############################
# Time elapsed from last time log: 2.1 seconds
# Total time elapsed: 8.1 seconds
# ##############################
# Computing LDLE.
# local_param: all 19364 points processed...
# max distortion is 274191.970629
# Done.
# ##############################
# Time elapsed from last time log: 1.8 seconds
# Total time elapsed: 9.9 seconds
# ##############################
# Posprocessing LDLE.
# Iter 1, Param replaced: 18154, max distortion: 10.231067
# Iter 2, Param replaced: 9683, max distortion: 9.928547
# Iter 3, Param replaced: 4494, max distortion: 9.894366
# Iter 4, Param replaced: 2422, max distortion: 9.894366
# Iter 5, Param replaced: 1087, max distortion: 9.894366
# Iter 6, Param replaced: 515, max distortion: 9.894366
# Iter 7, Param replaced: 86, max distortion: 9.894366
# Iter 8, Param replaced: 35, max distortion: 9.894366
# Iter 9, Param replaced: 21, max distortion: 9.894366
# Iter 10, Param replaced: 9, max distortion: 9.894366
# Iter 11, Param replaced: 8, max distortion: 9.894366
# Iter 12, Param replaced: 10, max distortion: 9.894366
# Iter 13, Param replaced: 2, max distortion: 9.894366
# Iter 14, Param replaced: 3, max distortion: 9.894366
# Iter 15, Param replaced: 0, max distortion: 9.894366
# Done.
# ##############################
# Time elapsed from last time log: 52.5 seconds
# Total time elapsed: 62.5 seconds
# ##############################
# Halving objects.
# Done.
# ##############################
# Time elapsed from last time log: 6.8 seconds
# Total time elapsed: 79.3 seconds
# ##############################
# Max local distortion = 7.3547206587423535
# Constructing intermediate views.
# eta = 2.
# # non-empty views with sz < 2 = 9946
# #nodes in views with sz < 2 = 9946
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 6.5 seconds
# Total time elapsed: 6.5 seconds
# ##############################
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 124.8 seconds
# Total time elapsed: 131.4 seconds
# ##############################
# eta = 3.
# # non-empty views with sz < 3 = 248
# #nodes in views with sz < 3 = 496
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 0.9 seconds
# Total time elapsed: 132.3 seconds
# ##############################
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 2.5 seconds
# Total time elapsed: 134.8 seconds
# ##############################
# eta = 4.
# # non-empty views with sz < 4 = 333
# #nodes in views with sz < 4 = 999
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 1.0 seconds
# Total time elapsed: 135.8 seconds
# ##############################
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 9.1 seconds
# Total time elapsed: 144.9 seconds
# ##############################
# eta = 5.
# # non-empty views with sz < 5 = 200
# #nodes in views with sz < 5 = 800
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 145.8 seconds
# ##############################
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 8.5 seconds
# Total time elapsed: 154.2 seconds
# ##############################
# eta = 6.
# # non-empty views with sz < 6 = 198
# #nodes in views with sz < 6 = 990
# Costs computed when eta = 6.
# ##############################
# Time elapsed from last time log: 0.9 seconds
# Total time elapsed: 155.1 seconds
# ##############################
# Remaining #nodes in views with sz < 6 = 0
# Done with eta = 6.
# ##############################
# Time elapsed from last time log: 13.3 seconds
# Total time elapsed: 168.4 seconds
# ##############################
# eta = 7.
# # non-empty views with sz < 7 = 118
# #nodes in views with sz < 7 = 708
# Costs computed when eta = 7.
# ##############################
# Time elapsed from last time log: 1.0 seconds
# Total time elapsed: 169.4 seconds
# ##############################
# Remaining #nodes in views with sz < 7 = 0
# Done with eta = 7.
# ##############################
# Time elapsed from last time log: 9.2 seconds
# Total time elapsed: 178.6 seconds
# ##############################
# eta = 8.
# # non-empty views with sz < 8 = 89
# #nodes in views with sz < 8 = 623
# Costs computed when eta = 8.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 179.4 seconds
# ##############################
# Remaining #nodes in views with sz < 8 = 0
# Done with eta = 8.
# ##############################
# Time elapsed from last time log: 7.9 seconds
# Total time elapsed: 187.3 seconds
# ##############################
# eta = 9.
# # non-empty views with sz < 9 = 102
# #nodes in views with sz < 9 = 816
# Costs computed when eta = 9.
# ##############################
# Time elapsed from last time log: 0.9 seconds
# Total time elapsed: 188.1 seconds
# ##############################
# Remaining #nodes in views with sz < 9 = 0
# Done with eta = 9.
# ##############################
# Time elapsed from last time log: 13.9 seconds
# Total time elapsed: 202.0 seconds
# ##############################
# eta = 10.
# # non-empty views with sz < 10 = 78
# #nodes in views with sz < 10 = 702
# Costs computed when eta = 10.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 202.8 seconds
# ##############################
# Remaining #nodes in views with sz < 10 = 0
# Done with eta = 10.
# ##############################
# Time elapsed from last time log: 11.3 seconds
# Total time elapsed: 214.2 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 0.4 seconds
# Total time elapsed: 214.6 seconds
# ##############################
# After clustering, max distortion is 13.642098
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 150 intermediate views
# Ambiguous overlaps checked for 300 intermediate views
# Ambiguous overlaps checked for 450 intermediate views
# Ambiguous overlaps checked for 600 intermediate views
# Ambiguous overlaps checked for 601 points
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 1
# Computing initial embedding using: sequential algorithm
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 2.2 seconds
# ##############################
# Initial alignment of 150 views completed
# Initial alignment of 300 views completed
# Initial alignment of 450 views completed
# Initial alignment of 600 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 0.2 seconds
# Total time elapsed: 2.5 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 10.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10547
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 79.0 seconds
# Total time elapsed: 89.2 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 93.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10547
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 80.3 seconds
# Total time elapsed: 173.6 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 177.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10547
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 79.7 seconds
# Total time elapsed: 257.3 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 261.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10547
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 80.0 seconds
# Total time elapsed: 341.3 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 345.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10547
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 81.8 seconds
# Total time elapsed: 427.1 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 5
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 431.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10547
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 81.5 seconds
# Total time elapsed: 512.6 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 6
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 516.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10547
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 82.4 seconds
# Total time elapsed: 599.0 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 7
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 603.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10547
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 81.3 seconds
# Total time elapsed: 684.3 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 8
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 688.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10547
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 81.9 seconds
# Total time elapsed: 770.1 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 9
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 774.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10547
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 81.2 seconds
# Total time elapsed: 855.2 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 10
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 859.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10547
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 81.1 seconds
# Total time elapsed: 940.3 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 11
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 944.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10547
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 82.5 seconds
# Total time elapsed: 1026.8 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 10547
# Alignment error: 0.306
# ##############################
# Time elapsed from last time log: 2.9 seconds
# Total time elapsed: 1029.7 seconds
# ##############################
# array([[-0.88174326,  0.09493359],
#        [-0.88221821,  0.09635508],
#        [-0.8827401 ,  0.1000175 ],
#        ...,
#        [ 0.85459296, -0.01227057],
#        [ 0.85272437, -0.01053769],
#        [ 0.85170481, -0.00957158]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/doubled_swissrolewithhole//ldle.dat
