# %% [markdown]
# ### Sphere

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
save_dir_root = '../data/pyLDLE2/sphere/'

# %%
X, labelsMat, ddX = datasets.Datasets().sphere()
# Out:
# X.shape =  (10000, 3)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LTSA'},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  intermed_opts={'eta_min': 5},
                  global_opts={
                      'max_iter': 12,
                      'init_algo_align_w_parent_only': True # Set this True for low noise
                  },
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 600 is created.

# %%
ldle.fit(X=X)
# Out:
# Constructing local views using LTSA.
# local_param: 0 points processed...
# local_param: 2500 points processed...
# local_param: 5000 points processed...
# local_param: 7500 points processed...
# local_param: all 10000 points processed...
# Done.
# ##############################
# Time elapsed from last time log: 6.9 seconds
# Total time elapsed: 6.9 seconds
# ##############################
# Max local distortion = 1.00822529547895
# Constructing intermediate views.
# eta = 2.
# # non-empty views with sz < 2 = 10000
# #nodes in views with sz < 2 = 10000
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 11.1 seconds
# Total time elapsed: 11.1 seconds
# ##############################
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 47.8 seconds
# Total time elapsed: 58.9 seconds
# ##############################
# eta = 3.
# # non-empty views with sz < 3 = 2894
# #nodes in views with sz < 3 = 5788
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 5.3 seconds
# Total time elapsed: 64.2 seconds
# ##############################
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 70.1 seconds
# Total time elapsed: 134.3 seconds
# ##############################
# eta = 4.
# # non-empty views with sz < 4 = 1248
# #nodes in views with sz < 4 = 3744
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 4.3 seconds
# Total time elapsed: 138.6 seconds
# ##############################
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 46.7 seconds
# Total time elapsed: 185.3 seconds
# ##############################
# eta = 5.
# # non-empty views with sz < 5 = 384
# #nodes in views with sz < 5 = 1536
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 0.9 seconds
# Total time elapsed: 186.2 seconds
# ##############################
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 10.4 seconds
# Total time elapsed: 196.5 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 1.0 seconds
# Total time elapsed: 197.5 seconds
# ##############################
# After clustering, max distortion is 1.009423
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 388 intermediate views
# Ambiguous overlaps checked for 776 intermediate views
# Ambiguous overlaps checked for 1164 intermediate views
# Ambiguous overlaps checked for 1552 intermediate views
# Ambiguous overlaps checked for 1553 points
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 1
# Computing initial embedding using: sequential algorithm
# ##############################
# Time elapsed from last time log: 27.2 seconds
# Total time elapsed: 27.2 seconds
# ##############################
# Initial alignment of 388 views completed
# Initial alignment of 776 views completed
# Initial alignment of 1164 views completed
# Initial alignment of 1552 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 0.9 seconds
# Total time elapsed: 28.1 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 80.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11553
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 45.7 seconds
# Total time elapsed: 126.3 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 159.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11553
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 86.2 seconds
# Total time elapsed: 245.4 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 288.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11553
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 110.0 seconds
# Total time elapsed: 398.0 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 454.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11553
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 146.4 seconds
# Total time elapsed: 600.9 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 663.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11553
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 151.4 seconds
# Total time elapsed: 815.1 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 5
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 878.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11553
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 148.4 seconds
# Total time elapsed: 1026.5 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 6
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 1069.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11553
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 82.7 seconds
# Total time elapsed: 1152.5 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 7
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 1188.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11553
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 67.6 seconds
# Total time elapsed: 1256.2 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 8
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 1294.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11553
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 75.9 seconds
# Total time elapsed: 1369.9 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 9
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 1412.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11553
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 54.1 seconds
# Total time elapsed: 1466.1 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 10
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 1484.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11553
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 32.2 seconds
# Total time elapsed: 1516.3 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 11
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 1536.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11553
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 26.4 seconds
# Total time elapsed: 1563.3 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 11553
# Alignment error: 22.525
# ##############################
# Time elapsed from last time log: 4.7 seconds
# Total time elapsed: 1567.9 seconds
# ##############################
# array([[ 0.44192532, -0.07250299],
#        [ 0.44768363, -0.06407013],
#        [ 0.4316204 , -0.06632565],
#        ...,
#        [-0.41065757,  0.00053043],
#        [-0.42680613, -0.0024092 ],
#        [-0.42113834,  0.00608475]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/sphere//ldle.dat
