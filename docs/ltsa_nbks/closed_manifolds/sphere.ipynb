# %% [markdown]
# ### Sphere

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
save_dir_root = '../data/pyLDLE2/sphere/'

# %%
X, labelsMat, ddX = datasets.Datasets().sphere()
# Out:
# X.shape =  (10000, 3)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LTSA'},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  intermed_opts={'eta_min': 10},
                  global_opts={
                      'max_iter': 12,
                      'init_algo_align_w_parent_only': True # Set this True for low noise
                  },
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 875 is created.

# %%
ldle.fit(X=X)
# Out:
# Constructing local views using LTSA.
# local_param: all 10000 points processed...
# max distortion is 1.005497
# Done.
# ##############################
# Time elapsed from last time log: 1.2 seconds
# Total time elapsed: 1.2 seconds
# ##############################
# Posprocessing local parameterizations.
# #Param replaced: 0, max distortion: 1.005497
# Max local distortion after postprocessing: 1.0054971350542092
# Done.
# ##############################
# Time elapsed from last time log: 3.8 seconds
# Total time elapsed: 4.9 seconds
# ##############################
# Max local distortion = 1.0054971350542092
# Constructing intermediate views.
# eta = 2.
# # non-empty views with sz < 2 = 10000
# #nodes in views with sz < 2 = 10000
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 21.6 seconds
# Total time elapsed: 21.7 seconds
# ##############################
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 63.9 seconds
# Total time elapsed: 85.6 seconds
# ##############################
# eta = 3.
# # non-empty views with sz < 3 = 2608
# #nodes in views with sz < 3 = 5216
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 7.9 seconds
# Total time elapsed: 93.5 seconds
# ##############################
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 148.3 seconds
# Total time elapsed: 241.8 seconds
# ##############################
# eta = 4.
# # non-empty views with sz < 4 = 1014
# #nodes in views with sz < 4 = 3042
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 4.5 seconds
# Total time elapsed: 246.4 seconds
# ##############################
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 68.3 seconds
# Total time elapsed: 314.7 seconds
# ##############################
# eta = 5.
# # non-empty views with sz < 5 = 518
# #nodes in views with sz < 5 = 2072
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 3.1 seconds
# Total time elapsed: 317.7 seconds
# ##############################
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 35.1 seconds
# Total time elapsed: 352.8 seconds
# ##############################
# eta = 6.
# # non-empty views with sz < 6 = 374
# #nodes in views with sz < 6 = 1870
# Costs computed when eta = 6.
# ##############################
# Time elapsed from last time log: 1.9 seconds
# Total time elapsed: 354.7 seconds
# ##############################
# Remaining #nodes in views with sz < 6 = 0
# Done with eta = 6.
# ##############################
# Time elapsed from last time log: 37.0 seconds
# Total time elapsed: 391.7 seconds
# ##############################
# eta = 7.
# # non-empty views with sz < 7 = 394
# #nodes in views with sz < 7 = 2364
# Costs computed when eta = 7.
# ##############################
# Time elapsed from last time log: 2.8 seconds
# Total time elapsed: 394.5 seconds
# ##############################
# Remaining #nodes in views with sz < 7 = 0
# Done with eta = 7.
# ##############################
# Time elapsed from last time log: 44.8 seconds
# Total time elapsed: 439.2 seconds
# ##############################
# eta = 8.
# # non-empty views with sz < 8 = 156
# #nodes in views with sz < 8 = 1092
# Costs computed when eta = 8.
# ##############################
# Time elapsed from last time log: 1.3 seconds
# Total time elapsed: 440.5 seconds
# ##############################
# Remaining #nodes in views with sz < 8 = 0
# Done with eta = 8.
# ##############################
# Time elapsed from last time log: 18.7 seconds
# Total time elapsed: 459.2 seconds
# ##############################
# eta = 9.
# # non-empty views with sz < 9 = 158
# #nodes in views with sz < 9 = 1264
# Costs computed when eta = 9.
# ##############################
# Time elapsed from last time log: 1.3 seconds
# Total time elapsed: 460.5 seconds
# ##############################
# Remaining #nodes in views with sz < 9 = 0
# Done with eta = 9.
# ##############################
# Time elapsed from last time log: 18.2 seconds
# Total time elapsed: 478.7 seconds
# ##############################
# eta = 10.
# # non-empty views with sz < 10 = 62
# #nodes in views with sz < 10 = 558
# Costs computed when eta = 10.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 479.5 seconds
# ##############################
# Remaining #nodes in views with sz < 10 = 0
# Done with eta = 10.
# ##############################
# Time elapsed from last time log: 8.9 seconds
# Total time elapsed: 488.4 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 0.6 seconds
# Total time elapsed: 488.9 seconds
# ##############################
# After clustering, max distortion is 1.019080
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 197 intermediate views
# Ambiguous overlaps checked for 394 intermediate views
# Ambiguous overlaps checked for 591 intermediate views
# Ambiguous overlaps checked for 788 points
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 1
# Computing initial embedding using: sequential algorithm
# ##############################
# Time elapsed from last time log: 3.4 seconds
# Total time elapsed: 3.4 seconds
# ##############################
# Initial alignment of 197 views completed
# Initial alignment of 394 views completed
# Initial alignment of 591 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 0.6 seconds
# Total time elapsed: 4.0 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 6.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10788 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.5 seconds
# Total time elapsed: 9.2 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 11.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10788 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.5 seconds
# Total time elapsed: 13.7 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 15.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10788 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.4 seconds
# Total time elapsed: 17.9 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 19.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10788 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.5 seconds
# Total time elapsed: 22.0 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 23.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10788 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.5 seconds
# Total time elapsed: 25.9 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 5
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 27.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10788 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.4 seconds
# Total time elapsed: 29.6 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 6
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 30.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10788 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.5 seconds
# Total time elapsed: 33.4 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 7
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 34.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10788 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.5 seconds
# Total time elapsed: 37.1 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 8
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 38.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10788 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.5 seconds
# Total time elapsed: 40.8 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 9
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 41.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10788 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.5 seconds
# Total time elapsed: 44.4 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 10
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 45.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10788 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.5 seconds
# Total time elapsed: 48.0 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 11
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 49.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10788 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.5 seconds
# Total time elapsed: 51.5 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 10788 multiplied with B
# Alignment error: 38.845
# ##############################
# Time elapsed from last time log: 1.2 seconds
# Total time elapsed: 52.7 seconds
# ##############################
# array([[ 0.27104346, -0.04164665],
#        [ 0.27033118, -0.05183133],
#        [ 0.26178096, -0.03978744],
#        ...,
#        [-0.27331953,  0.0463489 ],
#        [-0.2703572 ,  0.06081908],
#        [-0.278285  ,  0.05438597]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/sphere//ldle.dat
