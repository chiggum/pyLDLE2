# %% [markdown]
# ### Curved Torus

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
save_dir_root = '../data/pyLDLE2/curvedtorus3d/'

# %%
X, labelsMat, ddX = datasets.Datasets().curvedtorus3d()
# Out:
# X.shape =  (10000, 3)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LTSA', 'k': 17},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  intermed_opts={'eta_min': 10},
                  global_opts={
                      'max_iter': 10,
                      'init_algo_align_w_parent_only': True # Set this True for low noise
                  },
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 425 is created.

# %%
ldle.fit(X=X)
# Out:
# Constructing local views using LTSA.
# local_param: 0 points processed...
# local_param: 2500 points processed...
# local_param: 5000 points processed...
# local_param: 7500 points processed...
# local_param: all 10000 points processed...
# Done.
# ##############################
# Time elapsed from last time log: 7.0 seconds
# Total time elapsed: 7.0 seconds
# ##############################
# Max local distortion = 1.110761077691963
# Constructing intermediate views.
# eta = 2.
# # non-empty views with sz < 2 = 10000
# #nodes in views with sz < 2 = 10000
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 6.8 seconds
# Total time elapsed: 6.9 seconds
# ##############################
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 31.4 seconds
# Total time elapsed: 38.3 seconds
# ##############################
# eta = 3.
# # non-empty views with sz < 3 = 1048
# #nodes in views with sz < 3 = 2096
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 39.1 seconds
# ##############################
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 6.8 seconds
# Total time elapsed: 45.9 seconds
# ##############################
# eta = 4.
# # non-empty views with sz < 4 = 554
# #nodes in views with sz < 4 = 1662
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 0.6 seconds
# Total time elapsed: 46.5 seconds
# ##############################
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 7.5 seconds
# Total time elapsed: 54.0 seconds
# ##############################
# eta = 5.
# # non-empty views with sz < 5 = 432
# #nodes in views with sz < 5 = 1728
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 0.6 seconds
# Total time elapsed: 54.5 seconds
# ##############################
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 9.9 seconds
# Total time elapsed: 64.5 seconds
# ##############################
# eta = 6.
# # non-empty views with sz < 6 = 247
# #nodes in views with sz < 6 = 1235
# Costs computed when eta = 6.
# ##############################
# Time elapsed from last time log: 0.4 seconds
# Total time elapsed: 64.9 seconds
# ##############################
# Remaining #nodes in views with sz < 6 = 0
# Done with eta = 6.
# ##############################
# Time elapsed from last time log: 7.8 seconds
# Total time elapsed: 72.7 seconds
# ##############################
# eta = 7.
# # non-empty views with sz < 7 = 166
# #nodes in views with sz < 7 = 996
# Costs computed when eta = 7.
# ##############################
# Time elapsed from last time log: 0.3 seconds
# Total time elapsed: 73.0 seconds
# ##############################
# Remaining #nodes in views with sz < 7 = 0
# Done with eta = 7.
# ##############################
# Time elapsed from last time log: 7.3 seconds
# Total time elapsed: 80.3 seconds
# ##############################
# eta = 8.
# # non-empty views with sz < 8 = 107
# #nodes in views with sz < 8 = 749
# Costs computed when eta = 8.
# ##############################
# Time elapsed from last time log: 0.3 seconds
# Total time elapsed: 80.6 seconds
# ##############################
# Remaining #nodes in views with sz < 8 = 0
# Done with eta = 8.
# ##############################
# Time elapsed from last time log: 6.1 seconds
# Total time elapsed: 86.7 seconds
# ##############################
# eta = 9.
# # non-empty views with sz < 9 = 98
# #nodes in views with sz < 9 = 784
# Costs computed when eta = 9.
# ##############################
# Time elapsed from last time log: 0.3 seconds
# Total time elapsed: 87.0 seconds
# ##############################
# Remaining #nodes in views with sz < 9 = 0
# Done with eta = 9.
# ##############################
# Time elapsed from last time log: 6.7 seconds
# Total time elapsed: 93.7 seconds
# ##############################
# eta = 10.
# # non-empty views with sz < 10 = 73
# #nodes in views with sz < 10 = 657
# Costs computed when eta = 10.
# ##############################
# Time elapsed from last time log: 0.2 seconds
# Total time elapsed: 93.9 seconds
# ##############################
# Remaining #nodes in views with sz < 10 = 1
# Done with eta = 10.
# ##############################
# Time elapsed from last time log: 5.7 seconds
# Total time elapsed: 99.6 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 0.4 seconds
# Total time elapsed: 100.0 seconds
# ##############################
# After clustering, max distortion is 1.122996
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 161 intermediate views
# Ambiguous overlaps checked for 322 intermediate views
# Ambiguous overlaps checked for 483 intermediate views
# Ambiguous overlaps checked for 644 intermediate views
# Ambiguous overlaps checked for 645 points
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 1
# Computing initial embedding using: sequential algorithm
# ##############################
# Time elapsed from last time log: 2.9 seconds
# Total time elapsed: 2.9 seconds
# ##############################
# Initial alignment of 161 views completed
# Initial alignment of 322 views completed
# Initial alignment of 483 views completed
# Initial alignment of 644 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 0.3 seconds
# Total time elapsed: 3.1 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 13.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10645 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.1 seconds
# Total time elapsed: 15.2 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 20.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10645 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 22.3 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 27.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10645 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.0 seconds
# Total time elapsed: 29.3 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 34.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10645 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.9 seconds
# Total time elapsed: 36.2 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 41.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10645 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.0 seconds
# Total time elapsed: 43.1 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 5
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 48.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10645 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.0 seconds
# Total time elapsed: 50.1 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 6
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 55.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10645 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.9 seconds
# Total time elapsed: 57.2 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 7
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 62.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10645 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.0 seconds
# Total time elapsed: 64.2 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 8
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 69.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10645 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.0 seconds
# Total time elapsed: 71.4 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 9
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 76.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10645 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.0 seconds
# Total time elapsed: 78.4 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 10645 multiplied with B
# Alignment error: 21.529
# ##############################
# Time elapsed from last time log: 1.1 seconds
# Total time elapsed: 79.4 seconds
# ##############################
# array([[ 0.52894664, -0.02357429],
#        [-0.02021373, -0.198547  ],
#        [ 0.54584185,  0.16234909],
#        ...,
#        [-0.10385764,  0.09408295],
#        [-0.41826269, -0.33184717],
#        [-0.01366443, -0.25708433]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/curvedtorus3d//ldle.dat
