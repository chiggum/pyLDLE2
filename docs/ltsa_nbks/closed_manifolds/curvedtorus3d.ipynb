# %% [markdown]
# ### Curved Torus

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
save_dir_root = '../data/pyLDLE2/curvedtorus3d/'

# %%
X, labelsMat, ddX = datasets.Datasets().curvedtorus3d()
# Out:
# X.shape =  (10000, 3)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LTSA'},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  intermed_opts={'eta_min': 15},
                  global_opts={
                      'max_iter': 10,
                      'init_algo_align_w_parent_only': True # Set this True for low noise
                  },
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 875 is created.

# %%
ldle.fit(X=X)
# Out:
# Constructing local views using LTSA.
# local_param: all 10000 points processed...
# max distortion is 1.085231
# Done.
# ##############################
# Time elapsed from last time log: 1.2 seconds
# Total time elapsed: 1.2 seconds
# ##############################
# Posprocessing local parameterizations.
# #Param replaced: 6163, max distortion: 1.078006
# #Param replaced: 365, max distortion: 1.072659
# #Param replaced: 46, max distortion: 1.072659
# #Param replaced: 2, max distortion: 1.072659
# #Param replaced: 0, max distortion: 1.072659
# Max local distortion after postprocessing: 1.0726593453280375
# Done.
# ##############################
# Time elapsed from last time log: 7.0 seconds
# Total time elapsed: 8.2 seconds
# ##############################
# Max local distortion = 1.0726593453280375
# Constructing intermediate views.
# eta = 2.
# # non-empty views with sz < 2 = 10000
# #nodes in views with sz < 2 = 10000
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 22.9 seconds
# Total time elapsed: 23.0 seconds
# ##############################
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 68.5 seconds
# Total time elapsed: 91.6 seconds
# ##############################
# eta = 3.
# # non-empty views with sz < 3 = 1348
# #nodes in views with sz < 3 = 2696
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 3.8 seconds
# Total time elapsed: 95.3 seconds
# ##############################
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 57.8 seconds
# Total time elapsed: 153.1 seconds
# ##############################
# eta = 4.
# # non-empty views with sz < 4 = 743
# #nodes in views with sz < 4 = 2229
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 2.6 seconds
# Total time elapsed: 155.7 seconds
# ##############################
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 64.3 seconds
# Total time elapsed: 220.0 seconds
# ##############################
# eta = 5.
# # non-empty views with sz < 5 = 371
# #nodes in views with sz < 5 = 1484
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 1.9 seconds
# Total time elapsed: 221.9 seconds
# ##############################
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 40.6 seconds
# Total time elapsed: 262.5 seconds
# ##############################
# eta = 6.
# # non-empty views with sz < 6 = 235
# #nodes in views with sz < 6 = 1175
# Costs computed when eta = 6.
# ##############################
# Time elapsed from last time log: 1.6 seconds
# Total time elapsed: 264.1 seconds
# ##############################
# Remaining #nodes in views with sz < 6 = 0
# Done with eta = 6.
# ##############################
# Time elapsed from last time log: 38.5 seconds
# Total time elapsed: 302.6 seconds
# ##############################
# eta = 7.
# # non-empty views with sz < 7 = 204
# #nodes in views with sz < 7 = 1224
# Costs computed when eta = 7.
# ##############################
# Time elapsed from last time log: 1.5 seconds
# Total time elapsed: 304.0 seconds
# ##############################
# Remaining #nodes in views with sz < 7 = 0
# Done with eta = 7.
# ##############################
# Time elapsed from last time log: 41.9 seconds
# Total time elapsed: 345.9 seconds
# ##############################
# eta = 8.
# # non-empty views with sz < 8 = 124
# #nodes in views with sz < 8 = 868
# Costs computed when eta = 8.
# ##############################
# Time elapsed from last time log: 1.1 seconds
# Total time elapsed: 347.0 seconds
# ##############################
# Remaining #nodes in views with sz < 8 = 0
# Done with eta = 8.
# ##############################
# Time elapsed from last time log: 27.0 seconds
# Total time elapsed: 374.0 seconds
# ##############################
# eta = 9.
# # non-empty views with sz < 9 = 98
# #nodes in views with sz < 9 = 784
# Costs computed when eta = 9.
# ##############################
# Time elapsed from last time log: 1.1 seconds
# Total time elapsed: 375.2 seconds
# ##############################
# Remaining #nodes in views with sz < 9 = 0
# Done with eta = 9.
# ##############################
# Time elapsed from last time log: 31.7 seconds
# Total time elapsed: 406.8 seconds
# ##############################
# eta = 10.
# # non-empty views with sz < 10 = 78
# #nodes in views with sz < 10 = 702
# Costs computed when eta = 10.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 407.6 seconds
# ##############################
# Remaining #nodes in views with sz < 10 = 0
# Done with eta = 10.
# ##############################
# Time elapsed from last time log: 27.3 seconds
# Total time elapsed: 434.9 seconds
# ##############################
# eta = 11.
# # non-empty views with sz < 11 = 61
# #nodes in views with sz < 11 = 610
# Costs computed when eta = 11.
# ##############################
# Time elapsed from last time log: 0.7 seconds
# Total time elapsed: 435.6 seconds
# ##############################
# Remaining #nodes in views with sz < 11 = 0
# Done with eta = 11.
# ##############################
# Time elapsed from last time log: 20.0 seconds
# Total time elapsed: 455.6 seconds
# ##############################
# eta = 12.
# # non-empty views with sz < 12 = 51
# #nodes in views with sz < 12 = 561
# Costs computed when eta = 12.
# ##############################
# Time elapsed from last time log: 0.7 seconds
# Total time elapsed: 456.3 seconds
# ##############################
# Remaining #nodes in views with sz < 12 = 0
# Done with eta = 12.
# ##############################
# Time elapsed from last time log: 24.0 seconds
# Total time elapsed: 480.3 seconds
# ##############################
# eta = 13.
# # non-empty views with sz < 13 = 53
# #nodes in views with sz < 13 = 636
# Costs computed when eta = 13.
# ##############################
# Time elapsed from last time log: 0.6 seconds
# Total time elapsed: 480.9 seconds
# ##############################
# Remaining #nodes in views with sz < 13 = 3
# Done with eta = 13.
# ##############################
# Time elapsed from last time log: 26.3 seconds
# Total time elapsed: 507.2 seconds
# ##############################
# eta = 14.
# # non-empty views with sz < 14 = 35
# #nodes in views with sz < 14 = 445
# Costs computed when eta = 14.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 507.6 seconds
# ##############################
# Remaining #nodes in views with sz < 14 = 5
# Done with eta = 14.
# ##############################
# Time elapsed from last time log: 14.8 seconds
# Total time elapsed: 522.4 seconds
# ##############################
# eta = 15.
# # non-empty views with sz < 15 = 24
# #nodes in views with sz < 15 = 299
# Costs computed when eta = 15.
# ##############################
# Time elapsed from last time log: 0.3 seconds
# Total time elapsed: 522.7 seconds
# ##############################
# Remaining #nodes in views with sz < 15 = 7
# Done with eta = 15.
# ##############################
# Time elapsed from last time log: 7.6 seconds
# Total time elapsed: 530.3 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 0.6 seconds
# Total time elapsed: 530.9 seconds
# ##############################
# After clustering, max distortion is 1.717187
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 115 intermediate views
# Ambiguous overlaps checked for 230 intermediate views
# Ambiguous overlaps checked for 345 intermediate views
# Ambiguous overlaps checked for 460 points
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 1
# Computing initial embedding using: sequential algorithm
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 2.2 seconds
# ##############################
# Initial alignment of 115 views completed
# Initial alignment of 230 views completed
# Initial alignment of 345 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 0.4 seconds
# Total time elapsed: 2.5 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 4.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10460 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.6 seconds
# Total time elapsed: 6.3 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 8.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10460 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.7 seconds
# Total time elapsed: 9.7 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 11.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10460 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.6 seconds
# Total time elapsed: 13.0 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 14.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10460 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.6 seconds
# Total time elapsed: 16.4 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 17.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10460 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.7 seconds
# Total time elapsed: 19.6 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 5
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 21.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10460 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.6 seconds
# Total time elapsed: 22.8 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 6
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 24.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10460 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.6 seconds
# Total time elapsed: 26.0 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 7
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 27.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10460 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.6 seconds
# Total time elapsed: 29.2 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 8
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 30.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10460 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.6 seconds
# Total time elapsed: 32.3 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 9
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 33.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10460 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.7 seconds
# Total time elapsed: 35.6 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 10460 multiplied with B
# Alignment error: 129.986
# ##############################
# Time elapsed from last time log: 0.9 seconds
# Total time elapsed: 36.4 seconds
# ##############################
# array([[ 0.10764896, -0.39127198],
#        [ 0.06563953,  0.0518854 ],
#        [ 0.65943631,  0.13322554],
#        ...,
#        [-0.08102161, -0.24191751],
#        [-0.30323128,  0.28127265],
#        [ 0.07461662,  0.10815177]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/curvedtorus3d//ldle.dat
