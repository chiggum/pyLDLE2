# %% [markdown]
# ### Flat Torus

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
save_dir_root = '../data/pyLDLE2/flattorus4d/'

# %%
X, labelsMat, ddX = datasets.Datasets().flattorus4d()
# Out:
# X.shape =  (10000, 4)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LTSA', 'k': 17},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  intermed_opts={'eta_min': 10},
                  global_opts={
                      'max_iter': 5,
                      'init_algo_align_w_parent_only': True # Set this True for low noise
                  },
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 425 is created.

# %%
ldle.fit(X=X)
# Out:
# Constructing local views using LTSA.
# local_param: all 10000 points processed...
# max distortion is 1.018032
# Done.
# ##############################
# Time elapsed from last time log: 1.0 seconds
# Total time elapsed: 1.0 seconds
# ##############################
# Posprocessing local parameterizations.
# #Param replaced: 7417, max distortion: 1.018032
# #Param replaced: 2015, max distortion: 1.018032
# #Param replaced: 17, max distortion: 1.018032
# #Param replaced: 0, max distortion: 1.018032
# Max local distortion after postprocessing: 1.0180321481900068
# Done.
# ##############################
# Time elapsed from last time log: 3.9 seconds
# Total time elapsed: 4.9 seconds
# ##############################
# Max local distortion = 1.0180321481900068
# Constructing intermediate views.
# eta = 2.
# # non-empty views with sz < 2 = 10000
# #nodes in views with sz < 2 = 10000
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 6.6 seconds
# Total time elapsed: 6.6 seconds
# ##############################
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 31.0 seconds
# Total time elapsed: 37.6 seconds
# ##############################
# eta = 3.
# # non-empty views with sz < 3 = 672
# #nodes in views with sz < 3 = 1344
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 0.7 seconds
# Total time elapsed: 38.3 seconds
# ##############################
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 4.0 seconds
# Total time elapsed: 42.3 seconds
# ##############################
# eta = 4.
# # non-empty views with sz < 4 = 604
# #nodes in views with sz < 4 = 1812
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 43.1 seconds
# ##############################
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 9.3 seconds
# Total time elapsed: 52.4 seconds
# ##############################
# eta = 5.
# # non-empty views with sz < 5 = 479
# #nodes in views with sz < 5 = 1916
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 53.1 seconds
# ##############################
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 13.4 seconds
# Total time elapsed: 66.5 seconds
# ##############################
# eta = 6.
# # non-empty views with sz < 6 = 210
# #nodes in views with sz < 6 = 1050
# Costs computed when eta = 6.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 67.0 seconds
# ##############################
# Remaining #nodes in views with sz < 6 = 0
# Done with eta = 6.
# ##############################
# Time elapsed from last time log: 8.4 seconds
# Total time elapsed: 75.4 seconds
# ##############################
# eta = 7.
# # non-empty views with sz < 7 = 194
# #nodes in views with sz < 7 = 1164
# Costs computed when eta = 7.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 75.9 seconds
# ##############################
# Remaining #nodes in views with sz < 7 = 0
# Done with eta = 7.
# ##############################
# Time elapsed from last time log: 9.9 seconds
# Total time elapsed: 85.8 seconds
# ##############################
# eta = 8.
# # non-empty views with sz < 8 = 103
# #nodes in views with sz < 8 = 721
# Costs computed when eta = 8.
# ##############################
# Time elapsed from last time log: 0.4 seconds
# Total time elapsed: 86.2 seconds
# ##############################
# Remaining #nodes in views with sz < 8 = 0
# Done with eta = 8.
# ##############################
# Time elapsed from last time log: 7.7 seconds
# Total time elapsed: 93.8 seconds
# ##############################
# eta = 9.
# # non-empty views with sz < 9 = 98
# #nodes in views with sz < 9 = 784
# Costs computed when eta = 9.
# ##############################
# Time elapsed from last time log: 0.4 seconds
# Total time elapsed: 94.3 seconds
# ##############################
# Remaining #nodes in views with sz < 9 = 0
# Done with eta = 9.
# ##############################
# Time elapsed from last time log: 9.1 seconds
# Total time elapsed: 103.4 seconds
# ##############################
# eta = 10.
# # non-empty views with sz < 10 = 74
# #nodes in views with sz < 10 = 666
# Costs computed when eta = 10.
# ##############################
# Time elapsed from last time log: 0.4 seconds
# Total time elapsed: 103.8 seconds
# ##############################
# Remaining #nodes in views with sz < 10 = 0
# Done with eta = 10.
# ##############################
# Time elapsed from last time log: 7.5 seconds
# Total time elapsed: 111.4 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 0.4 seconds
# Total time elapsed: 111.8 seconds
# ##############################
# After clustering, max distortion is 1.056987
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 185 intermediate views
# Ambiguous overlaps checked for 370 intermediate views
# Ambiguous overlaps checked for 555 intermediate views
# Ambiguous overlaps checked for 740 intermediate views
# Ambiguous overlaps checked for 742 points
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 1
# Computing initial embedding using: sequential algorithm
# ##############################
# Time elapsed from last time log: 3.0 seconds
# Total time elapsed: 3.0 seconds
# ##############################
# Initial alignment of 185 views completed
# Initial alignment of 370 views completed
# Initial alignment of 555 views completed
# Initial alignment of 740 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 3.6 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 5.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10742 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.5 seconds
# Total time elapsed: 7.9 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 9.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10742 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.5 seconds
# Total time elapsed: 12.1 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 13.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10742 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.4 seconds
# Total time elapsed: 16.2 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 18.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10742 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.5 seconds
# Total time elapsed: 20.5 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 22.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10742 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.5 seconds
# Total time elapsed: 24.7 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 10742 multiplied with B
# Alignment error: 123.084
# ##############################
# Time elapsed from last time log: 1.2 seconds
# Total time elapsed: 26.0 seconds
# ##############################
# array([[-0.43155381,  0.14891506],
#        [-0.43110411,  0.13901765],
#        [-0.43116429,  0.12911239],
#        ...,
#        [-0.42124554,  0.17863909],
#        [-0.42159748,  0.16872902],
#        [-0.42159565,  0.15882381]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/flattorus4d//ldle.dat
