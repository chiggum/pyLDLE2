# %% [markdown]
# ### Flat Torus

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
save_dir_root = '../data/pyLDLE2/flattorus4d/'

# %%
X, labelsMat, ddX = datasets.Datasets().flattorus4d()
# Out:
# X.shape =  (10000, 4)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LTSA'},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 700 is created.
# Options provided:
# local_opts:
# {
#     "Atilde_method": "LDLE_1",
#     "N": 100,
#     "algo": "LTSA",
#     "delta": 0.9,
#     "gl_type": "unnorm",
#     "k": 28,
#     "k_nn": 49,
#     "k_nn0": 700,
#     "k_tune": 7,
#     "n_proc": 32,
#     "no_gamma": false,
#     "p": 0.99,
#     "pp_n_thresh": 32,
#     "tau": 50,
#     "to_postprocess": true
# }
# intermed_opts:
# {
#     "algo": "best",
#     "eta_max": 25,
#     "eta_min": 5,
#     "len_S_thresh": 256,
#     "local_algo": "LTSA",
#     "n_proc": 32,
#     "n_times": 4
# }
# global_opts:
# {
#     "color_tear": true,
#     "compute_error": false,
#     "init_algo_align_w_parent_only": true,
#     "init_algo_name": "procrustes",
#     "k": 28,
#     "main_algo": "LDLE",
#     "max_iter": 20,
#     "n_proc": 32,
#     "nu": 3,
#     "refine_algo_alpha": 0.3,
#     "refine_algo_max_internal_iter": 100,
#     "refine_algo_name": "rgd",
#     "to_tear": true,
#     "vis_before_init": false
# }

# %%
ldle.fit(X=X)
# Out:
# Constructing local views using LTSA.
# local_param: all 10000 points processed...
# max distortion is 1.051459
# Done.
# ##############################
# Time elapsed from last time log: 1.3 seconds
# Total time elapsed: 1.3 seconds
# ##############################
# Posprocessing local parameterizations.
# #Param replaced: 6638, max distortion: 1.051459
# #Param replaced: 1305, max distortion: 1.051459
# #Param replaced: 428, max distortion: 1.051459
# #Param replaced: 64, max distortion: 1.051459
# #Param replaced: 0, max distortion: 1.051459
# Max local distortion after postprocessing: 1.0514588127278814
# Done.
# ##############################
# Time elapsed from last time log: 4.8 seconds
# Total time elapsed: 6.1 seconds
# ##############################
# Max local distortion = 1.0514588127278814
# Constructing intermediate views.
# eta = 2.
# # non-empty views with sz < 2 = 10000
# #nodes in views with sz < 2 = 10000
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 8.9 seconds
# Total time elapsed: 9.5 seconds
# ##############################
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 97.8 seconds
# Total time elapsed: 107.3 seconds
# ##############################
# eta = 3.
# # non-empty views with sz < 3 = 553
# #nodes in views with sz < 3 = 1106
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 1.3 seconds
# Total time elapsed: 108.6 seconds
# ##############################
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 11.2 seconds
# Total time elapsed: 119.7 seconds
# ##############################
# eta = 4.
# # non-empty views with sz < 4 = 348
# #nodes in views with sz < 4 = 1044
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 1.2 seconds
# Total time elapsed: 120.9 seconds
# ##############################
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 16.7 seconds
# Total time elapsed: 137.6 seconds
# ##############################
# eta = 5.
# # non-empty views with sz < 5 = 192
# #nodes in views with sz < 5 = 768
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 1.0 seconds
# Total time elapsed: 138.6 seconds
# ##############################
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 13.1 seconds
# Total time elapsed: 151.6 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 0.9 seconds
# Total time elapsed: 152.5 seconds
# ##############################
# After clustering, max distortion is 1.071302
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 288 intermediate views
# Ambiguous overlaps checked for 576 intermediate views
# Ambiguous overlaps checked for 864 intermediate views
# Ambiguous overlaps checked for 1152 intermediate views
# Ambiguous overlaps checked for 1155 points
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 1
# Computing initial embedding using: procrustes algorithm
# ##############################
# Time elapsed from last time log: 9.4 seconds
# Total time elapsed: 9.4 seconds
# ##############################
# Initial alignment of 288 views completed
# Initial alignment of 576 views completed
# Initial alignment of 864 views completed
# Initial alignment of 1152 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 0.9 seconds
# Total time elapsed: 10.4 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 16.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11155 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 5.7 seconds
# Total time elapsed: 22.3 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 28.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11155 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 5.9 seconds
# Total time elapsed: 34.1 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 40.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11155 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 6.0 seconds
# Total time elapsed: 46.5 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 52.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11155 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 5.7 seconds
# Total time elapsed: 58.6 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 64.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11155 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 5.8 seconds
# Total time elapsed: 70.3 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 5
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 76.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11155 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 5.8 seconds
# Total time elapsed: 82.2 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 6
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 88.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11155 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 6.0 seconds
# Total time elapsed: 94.1 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 7
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 100.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11155 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 5.7 seconds
# Total time elapsed: 106.2 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 8
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 112.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11155 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 5.9 seconds
# Total time elapsed: 118.2 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 9
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 124.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11155 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 5.7 seconds
# Total time elapsed: 129.9 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 10
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 136.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11155 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 5.7 seconds
# Total time elapsed: 141.8 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 11
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 148.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11155 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 5.9 seconds
# Total time elapsed: 153.9 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 12
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 159.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11155 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 5.7 seconds
# Total time elapsed: 165.4 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 13
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 171.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11155 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 5.9 seconds
# Total time elapsed: 177.4 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 14
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 183.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11155 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 5.9 seconds
# Total time elapsed: 189.6 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 15
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 195.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11155 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 5.9 seconds
# Total time elapsed: 201.3 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 16
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 207.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11155 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 5.9 seconds
# Total time elapsed: 213.3 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 17
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 219.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11155 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 5.8 seconds
# Total time elapsed: 225.0 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 18
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 231.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11155 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 5.9 seconds
# Total time elapsed: 237.4 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 19
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 243.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11155 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 6.0 seconds
# Total time elapsed: 249.3 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 11155 multiplied with B
# Alignment error: 188.776
# ##############################
# Time elapsed from last time log: 3.2 seconds
# Total time elapsed: 252.6 seconds
# ##############################
# array([[ 0.94877438, -0.10865654],
#        [ 0.94870373, -0.09882754],
#        [ 0.948481  , -0.08899992],
#        ...,
#        [-1.0267642 ,  0.34968333],
#        [ 0.95870917, -0.12834635],
#        [ 0.95867955, -0.11851907]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/flattorus4d//ldle.dat
