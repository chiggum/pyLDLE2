# %% [markdown]
# ### Flat Torus

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
save_dir_root = '../data/pyLDLE2/flattorus4d/'

# %%
X, labelsMat, ddX = datasets.Datasets().flattorus4d()
# Out:
# X.shape =  (10000, 4)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LTSA', 'k': 17},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  intermed_opts={'eta_min': 5},
                  global_opts={
                      'max_iter': 5,
                      'init_algo_align_w_parent_only': True # Set this True for low noise
                  },
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 425 is created.

# %%
ldle.fit(X=X)
# Out:
# Constructing local views using LTSA.
# local_param: 0 points processed...
# local_param: 2500 points processed...
# local_param: 5000 points processed...
# local_param: 7500 points processed...
# local_param: all 10000 points processed...
# Done.
# ##############################
# Time elapsed from last time log: 6.8 seconds
# Total time elapsed: 6.8 seconds
# ##############################
# Max local distortion = 1.1051835787551811
# Constructing intermediate views.
# eta = 2.
# # non-empty views with sz < 2 = 10000
# #nodes in views with sz < 2 = 10000
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 6.4 seconds
# Total time elapsed: 6.4 seconds
# ##############################
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 39.0 seconds
# Total time elapsed: 45.5 seconds
# ##############################
# eta = 3.
# # non-empty views with sz < 3 = 397
# #nodes in views with sz < 3 = 794
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 46.0 seconds
# ##############################
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 2.4 seconds
# Total time elapsed: 48.4 seconds
# ##############################
# eta = 4.
# # non-empty views with sz < 4 = 322
# #nodes in views with sz < 4 = 966
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 48.9 seconds
# ##############################
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 4.4 seconds
# Total time elapsed: 53.3 seconds
# ##############################
# eta = 5.
# # non-empty views with sz < 5 = 262
# #nodes in views with sz < 5 = 1048
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 53.9 seconds
# ##############################
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 6.5 seconds
# Total time elapsed: 60.3 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 61.1 seconds
# ##############################
# After clustering, max distortion is 1.036745
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 340 intermediate views
# Ambiguous overlaps checked for 680 intermediate views
# Ambiguous overlaps checked for 1020 intermediate views
# Ambiguous overlaps checked for 1360 intermediate views
# Ambiguous overlaps checked for 1361 points
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 1
# Computing initial embedding using: sequential algorithm
# ##############################
# Time elapsed from last time log: 11.0 seconds
# Total time elapsed: 11.0 seconds
# ##############################
# Initial alignment of 340 views completed
# Initial alignment of 680 views completed
# Initial alignment of 1020 views completed
# Initial alignment of 1360 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 11.5 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 34.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11361 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.5 seconds
# Total time elapsed: 38.8 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 50.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11361 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.8 seconds
# Total time elapsed: 55.0 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 66.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11361 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.8 seconds
# Total time elapsed: 71.3 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 82.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11361 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.6 seconds
# Total time elapsed: 87.4 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 98.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11361 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.4 seconds
# Total time elapsed: 103.1 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 11361 multiplied with B
# Alignment error: 64.982
# ##############################
# Time elapsed from last time log: 2.5 seconds
# Total time elapsed: 105.6 seconds
# ##############################
# array([[0.11529068, 0.56631086],
#        [0.10538047, 0.56639853],
#        [0.09546727, 0.566293  ],
#        ...,
#        [0.14503558, 0.55644934],
#        [0.13512952, 0.55642047],
#        [0.12522016, 0.55638282]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/flattorus4d//ldle.dat
