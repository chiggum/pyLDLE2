# %% [markdown]
# ### Square with two holes

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
save_dir_root = '../data/pyLDLE2/squarewithtwoholes/'

# %%
X, labelsMat, ddX = datasets.Datasets().squarewithtwoholes()
# Out:
# X.shape =  (9169, 2)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LTSA'},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  intermed_opts={'eta_min': 10},
                  global_opts={
                      'max_iter': 10,
                      'init_algo_align_w_parent_only': True # Set this True for low noise
                  },
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 600 is created.

# %%
ldle.fit(X=X)
# Out:
# Constructing local views using LTSA.
# local_param: 0 points processed...
# local_param: 2292 points processed...
# local_param: 4584 points processed...
# local_param: 6876 points processed...
# local_param: 9168 points processed...
# local_param: all 9169 points processed...
# Done.
# ##############################
# Time elapsed from last time log: 5.1 seconds
# Total time elapsed: 5.1 seconds
# ##############################
# Max local distortion = 0.9999999999990017
# Constructing intermediate views.
# eta = 2.
# # non-empty views with sz < 2 = 9169
# #nodes in views with sz < 2 = 9169
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 12.7 seconds
# Total time elapsed: 12.8 seconds
# ##############################
# Remaining #nodes in views with sz < 2 = 1
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 256.2 seconds
# Total time elapsed: 269.0 seconds
# ##############################
# eta = 3.
# # non-empty views with sz < 3 = 35
# #nodes in views with sz < 3 = 69
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 0.2 seconds
# Total time elapsed: 269.2 seconds
# ##############################
# Remaining #nodes in views with sz < 3 = 6
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 0.6 seconds
# Total time elapsed: 269.7 seconds
# ##############################
# eta = 4.
# # non-empty views with sz < 4 = 32
# #nodes in views with sz < 4 = 90
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 0.3 seconds
# Total time elapsed: 270.0 seconds
# ##############################
# Remaining #nodes in views with sz < 4 = 9
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 1.0 seconds
# Total time elapsed: 271.1 seconds
# ##############################
# eta = 5.
# # non-empty views with sz < 5 = 18
# #nodes in views with sz < 5 = 61
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 0.2 seconds
# Total time elapsed: 271.3 seconds
# ##############################
# Remaining #nodes in views with sz < 5 = 25
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 0.2 seconds
# Total time elapsed: 271.4 seconds
# ##############################
# eta = 6.
# # non-empty views with sz < 6 = 16
# #nodes in views with sz < 6 = 60
# Costs computed when eta = 6.
# ##############################
# Time elapsed from last time log: 0.2 seconds
# Total time elapsed: 271.6 seconds
# ##############################
# Remaining #nodes in views with sz < 6 = 30
# Done with eta = 6.
# ##############################
# Time elapsed from last time log: 0.2 seconds
# Total time elapsed: 271.8 seconds
# ##############################
# eta = 7.
# # non-empty views with sz < 7 = 18
# #nodes in views with sz < 7 = 78
# Costs computed when eta = 7.
# ##############################
# Time elapsed from last time log: 0.2 seconds
# Total time elapsed: 272.0 seconds
# ##############################
# Remaining #nodes in views with sz < 7 = 36
# Done with eta = 7.
# ##############################
# Time elapsed from last time log: 0.3 seconds
# Total time elapsed: 272.2 seconds
# ##############################
# eta = 8.
# # non-empty views with sz < 8 = 14
# #nodes in views with sz < 8 = 57
# Costs computed when eta = 8.
# ##############################
# Time elapsed from last time log: 0.1 seconds
# Total time elapsed: 272.4 seconds
# ##############################
# Remaining #nodes in views with sz < 8 = 42
# Done with eta = 8.
# ##############################
# Time elapsed from last time log: 0.1 seconds
# Total time elapsed: 272.5 seconds
# ##############################
# eta = 9.
# # non-empty views with sz < 9 = 16
# #nodes in views with sz < 9 = 74
# Costs computed when eta = 9.
# ##############################
# Time elapsed from last time log: 0.2 seconds
# Total time elapsed: 272.7 seconds
# ##############################
# Remaining #nodes in views with sz < 9 = 58
# Done with eta = 9.
# ##############################
# Time elapsed from last time log: 0.1 seconds
# Total time elapsed: 272.7 seconds
# ##############################
# eta = 10.
# # non-empty views with sz < 10 = 16
# #nodes in views with sz < 10 = 76
# Costs computed when eta = 10.
# ##############################
# Time elapsed from last time log: 0.2 seconds
# Total time elapsed: 272.9 seconds
# ##############################
# Remaining #nodes in views with sz < 10 = 71
# Done with eta = 10.
# ##############################
# Time elapsed from last time log: 0.1 seconds
# Total time elapsed: 272.9 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 0.9 seconds
# Total time elapsed: 273.8 seconds
# ##############################
# After clustering, max distortion is 1.000000
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 97 intermediate views
# Ambiguous overlaps checked for 194 intermediate views
# Ambiguous overlaps checked for 291 intermediate views
# Ambiguous overlaps checked for 388 intermediate views
# Ambiguous overlaps checked for 390 points
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 1
# Computing initial embedding using: sequential algorithm
# ##############################
# Time elapsed from last time log: 2.8 seconds
# Total time elapsed: 2.8 seconds
# ##############################
# Initial alignment of 97 views completed
# Initial alignment of 194 views completed
# Initial alignment of 291 views completed
# Initial alignment of 388 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 0.4 seconds
# Total time elapsed: 3.1 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 14.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9559
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 27.9 seconds
# Total time elapsed: 42.9 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 47.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9559
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 55.2 seconds
# Total time elapsed: 103.0 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 108.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9559
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 66.0 seconds
# Total time elapsed: 174.3 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 180.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9559
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 56.4 seconds
# Total time elapsed: 237.3 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 249.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9559
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 66.6 seconds
# Total time elapsed: 316.2 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 5
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 321.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9559
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 72.4 seconds
# Total time elapsed: 394.2 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 6
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 398.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9559
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 69.5 seconds
# Total time elapsed: 468.1 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 7
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 475.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9559
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 101.9 seconds
# Total time elapsed: 577.1 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 8
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 589.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9559
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 59.4 seconds
# Total time elapsed: 648.6 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 9
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 656.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 9559
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 93.3 seconds
# Total time elapsed: 749.3 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 9559
# Alignment error: -0.000
# ##############################
# Time elapsed from last time log: 38.8 seconds
# Total time elapsed: 788.1 seconds
# ##############################
# array([[-0.49033633,  0.49497093],
#        [-0.48033633,  0.49497093],
#        [-0.47033633,  0.49497093],
#        ...,
#        [ 0.48966367, -0.50502907],
#        [ 0.49966367, -0.50502907],
#        [ 0.50966367, -0.50502907]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/squarewithtwoholes//ldle.dat
