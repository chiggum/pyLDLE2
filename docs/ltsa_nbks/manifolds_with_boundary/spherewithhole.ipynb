# %% [markdown]
# ### Sphere with hole

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
save_dir_root = '../data/pyLDLE2/spherewithhole/'

# %%
X, labelsMat, ddX = datasets.Datasets().spherewithhole()
# Out:
# X.shape =  (9931, 3)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LTSA'},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 700 is created.
# Options provided:
# local_opts:
# {
#     "Atilde_method": "LDLE_1",
#     "N": 100,
#     "algo": "LTSA",
#     "delta": 0.9,
#     "gl_type": "unnorm",
#     "k": 28,
#     "k_nn": 49,
#     "k_nn0": 700,
#     "k_tune": 7,
#     "n_proc": 32,
#     "no_gamma": false,
#     "p": 0.99,
#     "pp_n_thresh": 32,
#     "tau": 50,
#     "to_postprocess": true
# }
# intermed_opts:
# {
#     "algo": "best",
#     "eta_max": 25,
#     "eta_min": 5,
#     "len_S_thresh": 256,
#     "local_algo": "LTSA",
#     "n_proc": 32,
#     "n_times": 4
# }
# global_opts:
# {
#     "color_tear": true,
#     "compute_error": false,
#     "init_algo_align_w_parent_only": true,
#     "init_algo_name": "procrustes",
#     "k": 28,
#     "main_algo": "LDLE",
#     "max_iter": 20,
#     "n_proc": 32,
#     "nu": 3,
#     "refine_algo_alpha": 0.3,
#     "refine_algo_max_internal_iter": 100,
#     "refine_algo_name": "rgd",
#     "to_tear": true,
#     "vis_before_init": false
# }

# %%
ldle.fit(X=X)
# Out:
# Constructing local views using LTSA.
# local_param: all 9931 points processed...
# max distortion is 1.007297
# Done.
# ##############################
# Time elapsed from last time log: 1.2 seconds
# Total time elapsed: 1.2 seconds
# ##############################
# Posprocessing local parameterizations.
# #Param replaced: 0, max distortion: 1.007297
# Max local distortion after postprocessing: 1.0072970662257368
# Done.
# ##############################
# Time elapsed from last time log: 2.3 seconds
# Total time elapsed: 3.5 seconds
# ##############################
# Max local distortion = 1.0072970662257368
# Constructing intermediate views.
# eta = 2.
# # non-empty views with sz < 2 = 9931
# #nodes in views with sz < 2 = 9931
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 8.4 seconds
# Total time elapsed: 9.0 seconds
# ##############################
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 95.8 seconds
# Total time elapsed: 104.8 seconds
# ##############################
# eta = 3.
# # non-empty views with sz < 3 = 3022
# #nodes in views with sz < 3 = 6044
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 4.6 seconds
# Total time elapsed: 109.4 seconds
# ##############################
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 158.2 seconds
# Total time elapsed: 267.6 seconds
# ##############################
# eta = 4.
# # non-empty views with sz < 4 = 1181
# #nodes in views with sz < 4 = 3543
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 2.8 seconds
# Total time elapsed: 270.3 seconds
# ##############################
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 89.9 seconds
# Total time elapsed: 360.2 seconds
# ##############################
# eta = 5.
# # non-empty views with sz < 5 = 551
# #nodes in views with sz < 5 = 2204
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 2.6 seconds
# Total time elapsed: 362.9 seconds
# ##############################
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 43.9 seconds
# Total time elapsed: 406.8 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 407.6 seconds
# ##############################
# After clustering, max distortion is 1.014745
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 370 intermediate views
# Ambiguous overlaps checked for 740 intermediate views
# Ambiguous overlaps checked for 1110 intermediate views
# Ambiguous overlaps checked for 1480 intermediate views
# Ambiguous overlaps checked for 1481 points
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 1
# Computing initial embedding using: procrustes algorithm
# ##############################
# Time elapsed from last time log: 8.2 seconds
# Total time elapsed: 8.2 seconds
# ##############################
# Initial alignment of 370 views completed
# Initial alignment of 740 views completed
# Initial alignment of 1110 views completed
# Initial alignment of 1480 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 1.5 seconds
# Total time elapsed: 9.8 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 16.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11412 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 8.9 seconds
# Total time elapsed: 25.3 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 30.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11412 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 8.6 seconds
# Total time elapsed: 38.9 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 44.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11412 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 9.0 seconds
# Total time elapsed: 53.9 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 59.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11412 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 8.5 seconds
# Total time elapsed: 68.2 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 73.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11412 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 9.0 seconds
# Total time elapsed: 82.5 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 5
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 86.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11412 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 9.4 seconds
# Total time elapsed: 95.7 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 6
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 100.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11412 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 9.0 seconds
# Total time elapsed: 109.7 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 7
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 114.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11412 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 9.1 seconds
# Total time elapsed: 123.3 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 8
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 126.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11412 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 6.9 seconds
# Total time elapsed: 133.1 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 9
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 135.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11412 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 7.1 seconds
# Total time elapsed: 142.9 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 10
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 146.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11412 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 8.7 seconds
# Total time elapsed: 154.9 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 11
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 159.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11412 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 10.0 seconds
# Total time elapsed: 169.9 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 12
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 173.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11412 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 8.7 seconds
# Total time elapsed: 182.6 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 13
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 187.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11412 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 9.3 seconds
# Total time elapsed: 196.6 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 14
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 201.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11412 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 9.5 seconds
# Total time elapsed: 211.0 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 15
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 214.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11412 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 9.1 seconds
# Total time elapsed: 223.4 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 16
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 228.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11412 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 10.0 seconds
# Total time elapsed: 238.2 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 17
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 243.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11412 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 10.1 seconds
# Total time elapsed: 253.7 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 18
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 259.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11412 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 9.2 seconds
# Total time elapsed: 268.2 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 19
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 271.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11412 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 10.2 seconds
# Total time elapsed: 281.9 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 11412 multiplied with B
# Alignment error: 32.321
# ##############################
# Time elapsed from last time log: 4.7 seconds
# Total time elapsed: 286.6 seconds
# ##############################
# array([[ 0.13687114, -0.33632811],
#        [ 0.00588705, -0.33157147],
#        [ 0.08941765, -0.36293338],
#        ...,
#        [-0.04324383,  0.32374985],
#        [-0.06150383,  0.32588912],
#        [-0.04948117,  0.33084626]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/spherewithhole//ldle.dat
