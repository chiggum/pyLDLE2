# %% [markdown]
# ### Sphere with hole

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
save_dir_root = '../data/pyLDLE2/spherewithhole/'

# %%
X, labelsMat, ddX = datasets.Datasets().spherewithhole()
# Out:
# X.shape =  (9931, 3)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LTSA'},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  intermed_opts={'eta_min': 10},
                  global_opts={
                      'max_iter': 10,
                      'init_algo_align_w_parent_only': True # Set this True for low noise
                  },
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 600 is created.

# %%
ldle.fit(X=X)
# Out:
# Constructing local views using LTSA.
# local_param: 0 points processed...
# local_param: 2482 points processed...
# local_param: 4964 points processed...
# local_param: 7446 points processed...
# local_param: 9928 points processed...
# local_param: all 9931 points processed...
# Done.
# ##############################
# Time elapsed from last time log: 8.2 seconds
# Total time elapsed: 8.2 seconds
# ##############################
# Max local distortion = 1.0123509023527675
# Constructing intermediate views.
# eta = 2.
# # non-empty views with sz < 2 = 9931
# #nodes in views with sz < 2 = 9931
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 14.3 seconds
# Total time elapsed: 14.4 seconds
# ##############################
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 55.0 seconds
# Total time elapsed: 69.4 seconds
# ##############################
# eta = 3.
# # non-empty views with sz < 3 = 2878
# #nodes in views with sz < 3 = 5756
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 8.7 seconds
# Total time elapsed: 78.1 seconds
# ##############################
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 110.6 seconds
# Total time elapsed: 188.8 seconds
# ##############################
# eta = 4.
# # non-empty views with sz < 4 = 1244
# #nodes in views with sz < 4 = 3732
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 5.9 seconds
# Total time elapsed: 194.7 seconds
# ##############################
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 90.4 seconds
# Total time elapsed: 285.1 seconds
# ##############################
# eta = 5.
# # non-empty views with sz < 5 = 387
# #nodes in views with sz < 5 = 1548
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 2.1 seconds
# Total time elapsed: 287.2 seconds
# ##############################
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 18.8 seconds
# Total time elapsed: 306.0 seconds
# ##############################
# eta = 6.
# # non-empty views with sz < 6 = 433
# #nodes in views with sz < 6 = 2165
# Costs computed when eta = 6.
# ##############################
# Time elapsed from last time log: 1.5 seconds
# Total time elapsed: 307.5 seconds
# ##############################
# Remaining #nodes in views with sz < 6 = 0
# Done with eta = 6.
# ##############################
# Time elapsed from last time log: 38.2 seconds
# Total time elapsed: 345.6 seconds
# ##############################
# eta = 7.
# # non-empty views with sz < 7 = 262
# #nodes in views with sz < 7 = 1572
# Costs computed when eta = 7.
# ##############################
# Time elapsed from last time log: 2.4 seconds
# Total time elapsed: 348.0 seconds
# ##############################
# Remaining #nodes in views with sz < 7 = 0
# Done with eta = 7.
# ##############################
# Time elapsed from last time log: 59.8 seconds
# Total time elapsed: 407.8 seconds
# ##############################
# eta = 8.
# # non-empty views with sz < 8 = 156
# #nodes in views with sz < 8 = 1092
# Costs computed when eta = 8.
# ##############################
# Time elapsed from last time log: 1.8 seconds
# Total time elapsed: 409.6 seconds
# ##############################
# Remaining #nodes in views with sz < 8 = 0
# Done with eta = 8.
# ##############################
# Time elapsed from last time log: 50.5 seconds
# Total time elapsed: 460.1 seconds
# ##############################
# eta = 9.
# # non-empty views with sz < 9 = 121
# #nodes in views with sz < 9 = 968
# Costs computed when eta = 9.
# ##############################
# Time elapsed from last time log: 1.1 seconds
# Total time elapsed: 461.3 seconds
# ##############################
# Remaining #nodes in views with sz < 9 = 0
# Done with eta = 9.
# ##############################
# Time elapsed from last time log: 26.4 seconds
# Total time elapsed: 487.6 seconds
# ##############################
# eta = 10.
# # non-empty views with sz < 10 = 156
# #nodes in views with sz < 10 = 1404
# Costs computed when eta = 10.
# ##############################
# Time elapsed from last time log: 2.9 seconds
# Total time elapsed: 490.6 seconds
# ##############################
# Remaining #nodes in views with sz < 10 = 0
# Done with eta = 10.
# ##############################
# Time elapsed from last time log: 55.5 seconds
# Total time elapsed: 546.0 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 1.8 seconds
# Total time elapsed: 547.8 seconds
# ##############################
# After clustering, max distortion is 1.015716
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 191 intermediate views
# Ambiguous overlaps checked for 382 intermediate views
# Ambiguous overlaps checked for 573 intermediate views
# Ambiguous overlaps checked for 764 points
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 1
# Computing initial embedding using: sequential algorithm
# ##############################
# Time elapsed from last time log: 16.6 seconds
# Total time elapsed: 16.6 seconds
# ##############################
# Initial alignment of 191 views completed
# Initial alignment of 382 views completed
# Initial alignment of 573 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 1.2 seconds
# Total time elapsed: 17.8 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 60.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10695
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 109.4 seconds
# Total time elapsed: 169.9 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 200.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10695
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 133.3 seconds
# Total time elapsed: 333.4 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 344.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10695
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 95.2 seconds
# Total time elapsed: 439.6 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 462.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10695
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 102.0 seconds
# Total time elapsed: 563.9 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 575.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10695
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 51.7 seconds
# Total time elapsed: 627.7 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 5
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 640.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10695
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 49.2 seconds
# Total time elapsed: 690.0 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 6
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 706.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10695
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 45.8 seconds
# Total time elapsed: 752.5 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 7
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 763.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10695
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 33.5 seconds
# Total time elapsed: 796.9 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 8
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 813.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10695
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 50.7 seconds
# Total time elapsed: 863.7 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 9
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 881.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10695
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 40.8 seconds
# Total time elapsed: 922.1 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 10695
# Alignment error: 21.386
# ##############################
# Time elapsed from last time log: 12.3 seconds
# Total time elapsed: 934.4 seconds
# ##############################
# array([[ 0.00571984,  0.34050957],
#        [-0.08314817,  0.3769617 ],
#        [-0.04956821,  0.33213756],
#        ...,
#        [ 0.03420029, -0.33088675],
#        [ 0.01956165, -0.3327362 ],
#        [ 0.02897364, -0.32877256]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/spherewithhole//ldle.dat
