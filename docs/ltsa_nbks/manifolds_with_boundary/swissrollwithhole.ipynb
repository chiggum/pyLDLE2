# %% [markdown]
# ### Swissroll with hole

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
save_dir_root = '../data/pyLDLE2/swissrollwithhole/'

# %%
X, labelsMat, ddX = datasets.Datasets().swissrollwithhole()
# Out:
# X.shape =  (9946, 3)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LTSA'},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  intermed_opts={'eta_min': 10},
                  global_opts={
                      'max_iter': 10,
                      'init_algo_align_w_parent_only': True # Set this True for low noise
                  },
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 600 is created.

# %%
ldle.fit(X=X)
# Out:
# Constructing local views using LTSA.
# local_param: 0 points processed...
# local_param: 2486 points processed...
# local_param: 4972 points processed...
# local_param: 7458 points processed...
# local_param: 9944 points processed...
# local_param: all 9946 points processed...
# Done.
# ##############################
# Time elapsed from last time log: 8.2 seconds
# Total time elapsed: 8.2 seconds
# ##############################
# Max local distortion = 1.1123413627389216
# Constructing intermediate views.
# eta = 2.
# # non-empty views with sz < 2 = 9946
# #nodes in views with sz < 2 = 9946
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 12.2 seconds
# Total time elapsed: 12.3 seconds
# ##############################
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 78.5 seconds
# Total time elapsed: 90.7 seconds
# ##############################
# eta = 3.
# # non-empty views with sz < 3 = 774
# #nodes in views with sz < 3 = 1548
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 1.8 seconds
# Total time elapsed: 92.5 seconds
# ##############################
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 23.8 seconds
# Total time elapsed: 116.3 seconds
# ##############################
# eta = 4.
# # non-empty views with sz < 4 = 391
# #nodes in views with sz < 4 = 1173
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 1.9 seconds
# Total time elapsed: 118.2 seconds
# ##############################
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 17.6 seconds
# Total time elapsed: 135.7 seconds
# ##############################
# eta = 5.
# # non-empty views with sz < 5 = 202
# #nodes in views with sz < 5 = 808
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 0.9 seconds
# Total time elapsed: 136.6 seconds
# ##############################
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 11.9 seconds
# Total time elapsed: 148.5 seconds
# ##############################
# eta = 6.
# # non-empty views with sz < 6 = 204
# #nodes in views with sz < 6 = 1020
# Costs computed when eta = 6.
# ##############################
# Time elapsed from last time log: 1.6 seconds
# Total time elapsed: 150.1 seconds
# ##############################
# Remaining #nodes in views with sz < 6 = 0
# Done with eta = 6.
# ##############################
# Time elapsed from last time log: 24.7 seconds
# Total time elapsed: 174.8 seconds
# ##############################
# eta = 7.
# # non-empty views with sz < 7 = 206
# #nodes in views with sz < 7 = 1236
# Costs computed when eta = 7.
# ##############################
# Time elapsed from last time log: 1.3 seconds
# Total time elapsed: 176.2 seconds
# ##############################
# Remaining #nodes in views with sz < 7 = 0
# Done with eta = 7.
# ##############################
# Time elapsed from last time log: 46.6 seconds
# Total time elapsed: 222.8 seconds
# ##############################
# eta = 8.
# # non-empty views with sz < 8 = 138
# #nodes in views with sz < 8 = 966
# Costs computed when eta = 8.
# ##############################
# Time elapsed from last time log: 1.6 seconds
# Total time elapsed: 224.3 seconds
# ##############################
# Remaining #nodes in views with sz < 8 = 0
# Done with eta = 8.
# ##############################
# Time elapsed from last time log: 41.3 seconds
# Total time elapsed: 265.7 seconds
# ##############################
# eta = 9.
# # non-empty views with sz < 9 = 96
# #nodes in views with sz < 9 = 768
# Costs computed when eta = 9.
# ##############################
# Time elapsed from last time log: 1.2 seconds
# Total time elapsed: 266.9 seconds
# ##############################
# Remaining #nodes in views with sz < 9 = 0
# Done with eta = 9.
# ##############################
# Time elapsed from last time log: 31.0 seconds
# Total time elapsed: 297.9 seconds
# ##############################
# eta = 10.
# # non-empty views with sz < 10 = 61
# #nodes in views with sz < 10 = 549
# Costs computed when eta = 10.
# ##############################
# Time elapsed from last time log: 0.9 seconds
# Total time elapsed: 298.8 seconds
# ##############################
# Remaining #nodes in views with sz < 10 = 0
# Done with eta = 10.
# ##############################
# Time elapsed from last time log: 23.7 seconds
# Total time elapsed: 322.5 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 1.2 seconds
# Total time elapsed: 323.7 seconds
# ##############################
# After clustering, max distortion is 1.044794
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 145 intermediate views
# Ambiguous overlaps checked for 290 intermediate views
# Ambiguous overlaps checked for 435 intermediate views
# Ambiguous overlaps checked for 580 points
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 1
# Computing initial embedding using: sequential algorithm
# ##############################
# Time elapsed from last time log: 8.1 seconds
# Total time elapsed: 8.1 seconds
# ##############################
# Initial alignment of 145 views completed
# Initial alignment of 290 views completed
# Initial alignment of 435 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 0.9 seconds
# Total time elapsed: 9.0 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 39.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10526
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 69.8 seconds
# Total time elapsed: 109.0 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 119.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10526
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 76.1 seconds
# Total time elapsed: 196.0 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 208.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10526
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 80.8 seconds
# Total time elapsed: 289.2 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 305.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10526
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 93.6 seconds
# Total time elapsed: 399.0 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 413.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10526
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 127.9 seconds
# Total time elapsed: 541.6 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 5
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 549.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10526
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 96.4 seconds
# Total time elapsed: 645.8 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 6
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 655.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10526
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 89.6 seconds
# Total time elapsed: 744.6 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 7
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 753.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10526
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 52.6 seconds
# Total time elapsed: 805.8 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 8
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 816.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10526
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 48.0 seconds
# Total time elapsed: 864.2 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 9
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 870.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10526
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 39.2 seconds
# Total time elapsed: 909.7 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 10526
# Alignment error: 0.000
# ##############################
# Time elapsed from last time log: 19.1 seconds
# Total time elapsed: 928.9 seconds
# ##############################
# array([[-0.89286097, -0.290242  ],
#        [-0.89302658, -0.28025318],
#        [-0.89319219, -0.27026435],
#        ...,
#        [ 0.88392226,  0.26855751],
#        [ 0.88382819,  0.27854727],
#        [ 0.88373413,  0.28853703]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/swissrollwithhole//ldle.dat
