# %% [markdown]
# ### Swissroll with hole

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
save_dir_root = '../data/pyLDLE2/swissrollwithhole/'

# %%
X, labelsMat, ddX = datasets.Datasets().swissrollwithhole()
# Out:
# X.shape =  (9946, 3)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LTSA'},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  intermed_opts={'eta_min': 10},
                  global_opts={
                      'max_iter': 10,
                      'init_algo_align_w_parent_only': True # Set this True for low noise
                  },
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 875 is created.

# %%
ldle.fit(X=X)
# Out:
# Constructing local views using LTSA.
# local_param: all 9946 points processed...
# max distortion is 1.067609
# Done.
# ##############################
# Time elapsed from last time log: 1.2 seconds
# Total time elapsed: 1.2 seconds
# ##############################
# Posprocessing local parameterizations.
# #Param replaced: 7040, max distortion: 1.065439
# #Param replaced: 2663, max distortion: 1.065439
# #Param replaced: 1956, max distortion: 1.065439
# #Param replaced: 1695, max distortion: 1.065439
# #Param replaced: 1558, max distortion: 1.065439
# #Param replaced: 1495, max distortion: 1.065439
# #Param replaced: 1353, max distortion: 1.065439
# #Param replaced: 1277, max distortion: 1.065439
# #Param replaced: 1047, max distortion: 1.065439
# #Param replaced: 362, max distortion: 1.065439
# #Param replaced: 300, max distortion: 1.065439
# #Param replaced: 280, max distortion: 1.065439
# #Param replaced: 245, max distortion: 1.065439
# #Param replaced: 231, max distortion: 1.065439
# #Param replaced: 221, max distortion: 1.065439
# #Param replaced: 213, max distortion: 1.065439
# #Param replaced: 208, max distortion: 1.065439
# #Param replaced: 193, max distortion: 1.065439
# #Param replaced: 71, max distortion: 1.065439
# #Param replaced: 14, max distortion: 1.065439
# #Param replaced: 2, max distortion: 1.065439
# #Param replaced: 0, max distortion: 1.065439
# Max local distortion after postprocessing: 1.0654393156904713
# Done.
# ##############################
# Time elapsed from last time log: 17.1 seconds
# Total time elapsed: 18.3 seconds
# ##############################
# Max local distortion = 1.0654393156904713
# Constructing intermediate views.
# eta = 2.
# # non-empty views with sz < 2 = 9946
# #nodes in views with sz < 2 = 9946
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 22.3 seconds
# Total time elapsed: 22.4 seconds
# ##############################
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 116.1 seconds
# Total time elapsed: 138.5 seconds
# ##############################
# eta = 3.
# # non-empty views with sz < 3 = 1116
# #nodes in views with sz < 3 = 2232
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 10.0 seconds
# Total time elapsed: 148.5 seconds
# ##############################
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 103.2 seconds
# Total time elapsed: 251.7 seconds
# ##############################
# eta = 4.
# # non-empty views with sz < 4 = 432
# #nodes in views with sz < 4 = 1296
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 4.6 seconds
# Total time elapsed: 256.3 seconds
# ##############################
# Remaining #nodes in views with sz < 4 = 2
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 59.6 seconds
# Total time elapsed: 315.9 seconds
# ##############################
# eta = 5.
# # non-empty views with sz < 5 = 162
# #nodes in views with sz < 5 = 646
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 1.8 seconds
# Total time elapsed: 317.7 seconds
# ##############################
# Remaining #nodes in views with sz < 5 = 2
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 16.1 seconds
# Total time elapsed: 333.8 seconds
# ##############################
# eta = 6.
# # non-empty views with sz < 6 = 157
# #nodes in views with sz < 6 = 782
# Costs computed when eta = 6.
# ##############################
# Time elapsed from last time log: 1.7 seconds
# Total time elapsed: 335.5 seconds
# ##############################
# Remaining #nodes in views with sz < 6 = 2
# Done with eta = 6.
# ##############################
# Time elapsed from last time log: 26.0 seconds
# Total time elapsed: 361.5 seconds
# ##############################
# eta = 7.
# # non-empty views with sz < 7 = 65
# #nodes in views with sz < 7 = 386
# Costs computed when eta = 7.
# ##############################
# Time elapsed from last time log: 1.0 seconds
# Total time elapsed: 362.4 seconds
# ##############################
# Remaining #nodes in views with sz < 7 = 2
# Done with eta = 7.
# ##############################
# Time elapsed from last time log: 11.6 seconds
# Total time elapsed: 374.1 seconds
# ##############################
# eta = 8.
# # non-empty views with sz < 8 = 68
# #nodes in views with sz < 8 = 471
# Costs computed when eta = 8.
# ##############################
# Time elapsed from last time log: 1.1 seconds
# Total time elapsed: 375.1 seconds
# ##############################
# Remaining #nodes in views with sz < 8 = 2
# Done with eta = 8.
# ##############################
# Time elapsed from last time log: 17.0 seconds
# Total time elapsed: 392.2 seconds
# ##############################
# eta = 9.
# # non-empty views with sz < 9 = 51
# #nodes in views with sz < 9 = 402
# Costs computed when eta = 9.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 392.9 seconds
# ##############################
# Remaining #nodes in views with sz < 9 = 2
# Done with eta = 9.
# ##############################
# Time elapsed from last time log: 11.2 seconds
# Total time elapsed: 404.2 seconds
# ##############################
# eta = 10.
# # non-empty views with sz < 10 = 30
# #nodes in views with sz < 10 = 263
# Costs computed when eta = 10.
# ##############################
# Time elapsed from last time log: 0.6 seconds
# Total time elapsed: 404.7 seconds
# ##############################
# Remaining #nodes in views with sz < 10 = 5
# Done with eta = 10.
# ##############################
# Time elapsed from last time log: 7.2 seconds
# Total time elapsed: 411.9 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 0.6 seconds
# Total time elapsed: 412.5 seconds
# ##############################
# After clustering, max distortion is 1.100053
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 128 intermediate views
# Ambiguous overlaps checked for 256 intermediate views
# Ambiguous overlaps checked for 384 intermediate views
# Ambiguous overlaps checked for 512 intermediate views
# Ambiguous overlaps checked for 515 points
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 1
# Computing initial embedding using: sequential algorithm
# ##############################
# Time elapsed from last time log: 2.7 seconds
# Total time elapsed: 2.7 seconds
# ##############################
# Initial alignment of 128 views completed
# Initial alignment of 256 views completed
# Initial alignment of 384 views completed
# Initial alignment of 512 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 0.4 seconds
# Total time elapsed: 3.1 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 3.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10461 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.7 seconds
# Total time elapsed: 5.5 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 5.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10461 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.9 seconds
# Total time elapsed: 7.7 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 8.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10461 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.8 seconds
# Total time elapsed: 9.9 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 10.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10461 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.8 seconds
# Total time elapsed: 12.2 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 12.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10461 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.8 seconds
# Total time elapsed: 14.3 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 5
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 14.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10461 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.7 seconds
# Total time elapsed: 16.4 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 6
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 16.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10461 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.8 seconds
# Total time elapsed: 18.6 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 7
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 19.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10461 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.7 seconds
# Total time elapsed: 20.8 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 8
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 21.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10461 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.8 seconds
# Total time elapsed: 23.0 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 9
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 23.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10461 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.8 seconds
# Total time elapsed: 25.2 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 10461 multiplied with B
# Alignment error: 0.000
# ##############################
# Time elapsed from last time log: 0.9 seconds
# Total time elapsed: 26.1 seconds
# ##############################
# array([[ 0.85029134, -0.3947956 ],
#        [ 0.8437133 , -0.4024104 ],
#        [ 0.83702663, -0.40983269],
#        ...,
#        [-0.82851809,  0.40410747],
#        [-0.83525439,  0.39673013],
#        [-0.84198793,  0.38934868]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/swissrollwithhole//ldle.dat
