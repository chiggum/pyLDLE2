# %% [markdown]
# ### Klein Bottle

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
save_dir_root = '../data/pyLDLE2/kleinbottle4d/'

# %%
X, labelsMat, ddX = datasets.Datasets().kleinbottle4d()
# Out:
# X.shape =  (10000, 4)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LTSA'},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  intermed_opts={'eta_min': 10},
                  global_opts={
                      'max_iter': 10,
                      'init_algo_align_w_parent_only': True # Set this True for low noise
                  },
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 600 is created.

# %%
ldle.fit(X=X)
# Out:
# Constructing local views using LTSA.
# local_param: 0 points processed...
# local_param: 2500 points processed...
# local_param: 5000 points processed...
# local_param: 7500 points processed...
# local_param: all 10000 points processed...
# Done.
# ##############################
# Time elapsed from last time log: 6.7 seconds
# Total time elapsed: 6.7 seconds
# ##############################
# Max local distortion = 1.1184407278136708
# Constructing intermediate views.
# eta = 2.
# # non-empty views with sz < 2 = 10000
# #nodes in views with sz < 2 = 10000
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 10.3 seconds
# Total time elapsed: 10.4 seconds
# ##############################
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 23.7 seconds
# Total time elapsed: 34.1 seconds
# ##############################
# eta = 3.
# # non-empty views with sz < 3 = 1886
# #nodes in views with sz < 3 = 3772
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 2.6 seconds
# Total time elapsed: 36.6 seconds
# ##############################
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 26.3 seconds
# Total time elapsed: 63.0 seconds
# ##############################
# eta = 4.
# # non-empty views with sz < 4 = 1115
# #nodes in views with sz < 4 = 3345
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 2.0 seconds
# Total time elapsed: 65.0 seconds
# ##############################
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 32.7 seconds
# Total time elapsed: 97.7 seconds
# ##############################
# eta = 5.
# # non-empty views with sz < 5 = 620
# #nodes in views with sz < 5 = 2480
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 1.6 seconds
# Total time elapsed: 99.3 seconds
# ##############################
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 26.4 seconds
# Total time elapsed: 125.7 seconds
# ##############################
# eta = 6.
# # non-empty views with sz < 6 = 364
# #nodes in views with sz < 6 = 1820
# Costs computed when eta = 6.
# ##############################
# Time elapsed from last time log: 1.2 seconds
# Total time elapsed: 126.9 seconds
# ##############################
# Remaining #nodes in views with sz < 6 = 0
# Done with eta = 6.
# ##############################
# Time elapsed from last time log: 20.5 seconds
# Total time elapsed: 147.4 seconds
# ##############################
# eta = 7.
# # non-empty views with sz < 7 = 266
# #nodes in views with sz < 7 = 1596
# Costs computed when eta = 7.
# ##############################
# Time elapsed from last time log: 1.0 seconds
# Total time elapsed: 148.4 seconds
# ##############################
# Remaining #nodes in views with sz < 7 = 0
# Done with eta = 7.
# ##############################
# Time elapsed from last time log: 22.3 seconds
# Total time elapsed: 170.7 seconds
# ##############################
# eta = 8.
# # non-empty views with sz < 8 = 161
# #nodes in views with sz < 8 = 1127
# Costs computed when eta = 8.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 171.5 seconds
# ##############################
# Remaining #nodes in views with sz < 8 = 0
# Done with eta = 8.
# ##############################
# Time elapsed from last time log: 15.3 seconds
# Total time elapsed: 186.8 seconds
# ##############################
# eta = 9.
# # non-empty views with sz < 9 = 149
# #nodes in views with sz < 9 = 1192
# Costs computed when eta = 9.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 187.6 seconds
# ##############################
# Remaining #nodes in views with sz < 9 = 0
# Done with eta = 9.
# ##############################
# Time elapsed from last time log: 19.1 seconds
# Total time elapsed: 206.7 seconds
# ##############################
# eta = 10.
# # non-empty views with sz < 10 = 102
# #nodes in views with sz < 10 = 918
# Costs computed when eta = 10.
# ##############################
# Time elapsed from last time log: 0.7 seconds
# Total time elapsed: 207.4 seconds
# ##############################
# Remaining #nodes in views with sz < 10 = 0
# Done with eta = 10.
# ##############################
# Time elapsed from last time log: 16.0 seconds
# Total time elapsed: 223.4 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 0.6 seconds
# Total time elapsed: 224.0 seconds
# ##############################
# After clustering, max distortion is 1.105286
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 190 intermediate views
# Ambiguous overlaps checked for 380 intermediate views
# Ambiguous overlaps checked for 570 intermediate views
# Ambiguous overlaps checked for 760 intermediate views
# Ambiguous overlaps checked for 761 points
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 1
# Computing initial embedding using: sequential algorithm
# ##############################
# Time elapsed from last time log: 3.7 seconds
# Total time elapsed: 3.7 seconds
# ##############################
# Initial alignment of 190 views completed
# Initial alignment of 380 views completed
# Initial alignment of 570 views completed
# Initial alignment of 760 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 0.3 seconds
# Total time elapsed: 4.0 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 13.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10761
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 13.2 seconds
# Total time elapsed: 26.5 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 31.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10761
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 14.4 seconds
# Total time elapsed: 45.7 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 50.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10761
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 14.5 seconds
# Total time elapsed: 64.9 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 69.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10761
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 14.2 seconds
# Total time elapsed: 83.8 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 88.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10761
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 14.2 seconds
# Total time elapsed: 102.6 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 5
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 107.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10761
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 14.2 seconds
# Total time elapsed: 121.5 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 6
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 126.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10761
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 14.0 seconds
# Total time elapsed: 140.1 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 7
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 144.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10761
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 14.3 seconds
# Total time elapsed: 159.0 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 8
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 163.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10761
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 14.4 seconds
# Total time elapsed: 178.2 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 9
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 182.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10761
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 14.3 seconds
# Total time elapsed: 197.2 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 10761
# Alignment error: 164.535
# ##############################
# Time elapsed from last time log: 2.9 seconds
# Total time elapsed: 200.1 seconds
# ##############################
# array([[ 0.86066199, -0.14663659],
#        [ 0.86056108, -0.13707675],
#        [ 0.86509746, -0.12686444],
#        ...,
#        [ 0.84573737, -0.11675737],
#        [ 0.85285529, -0.12641691],
#        [ 0.84813064, -0.13612186]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/kleinbottle4d//ldle.dat
