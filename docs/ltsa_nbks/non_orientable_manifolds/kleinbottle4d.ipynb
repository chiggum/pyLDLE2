# %% [markdown]
# ### Klein Bottle

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
save_dir_root = '../data/pyLDLE2/kleinbottle4d/'

# %%
X, labelsMat, ddX = datasets.Datasets().kleinbottle4d()
# Out:
# X.shape =  (10000, 4)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LTSA'},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  intermed_opts={'eta_min': 5},
                  global_opts={
                      'max_iter': 10,
                      'init_algo_align_w_parent_only': True # Set this True for low noise
                  },
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 875 is created.

# %%
ldle.fit(X=X)
# Out:
# Constructing local views using LTSA.
# local_param: all 10000 points processed...
# max distortion is 1.061578
# Done.
# ##############################
# Time elapsed from last time log: 1.2 seconds
# Total time elapsed: 1.2 seconds
# ##############################
# Posprocessing local parameterizations.
# #Param replaced: 6800, max distortion: 1.060738
# #Param replaced: 3736, max distortion: 1.060738
# #Param replaced: 1835, max distortion: 1.060738
# #Param replaced: 1180, max distortion: 1.060738
# #Param replaced: 616, max distortion: 1.060738
# #Param replaced: 367, max distortion: 1.060738
# #Param replaced: 364, max distortion: 1.060738
# #Param replaced: 16, max distortion: 1.060738
# #Param replaced: 0, max distortion: 1.060738
# Max local distortion after postprocessing: 1.0607377858967908
# Done.
# ##############################
# Time elapsed from last time log: 11.0 seconds
# Total time elapsed: 12.2 seconds
# ##############################
# Max local distortion = 1.0607377858967908
# Constructing intermediate views.
# eta = 2.
# # non-empty views with sz < 2 = 10000
# #nodes in views with sz < 2 = 10000
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 22.1 seconds
# Total time elapsed: 22.2 seconds
# ##############################
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 40.4 seconds
# Total time elapsed: 62.6 seconds
# ##############################
# eta = 3.
# # non-empty views with sz < 3 = 2217
# #nodes in views with sz < 3 = 4434
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 5.9 seconds
# Total time elapsed: 68.5 seconds
# ##############################
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 107.9 seconds
# Total time elapsed: 176.4 seconds
# ##############################
# eta = 4.
# # non-empty views with sz < 4 = 1109
# #nodes in views with sz < 4 = 3327
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 3.8 seconds
# Total time elapsed: 180.3 seconds
# ##############################
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 85.7 seconds
# Total time elapsed: 266.0 seconds
# ##############################
# eta = 5.
# # non-empty views with sz < 5 = 580
# #nodes in views with sz < 5 = 2320
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 2.7 seconds
# Total time elapsed: 268.7 seconds
# ##############################
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 56.6 seconds
# Total time elapsed: 325.3 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 1.0 seconds
# Total time elapsed: 326.4 seconds
# ##############################
# After clustering, max distortion is 1.082148
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 374 intermediate views
# Ambiguous overlaps checked for 748 intermediate views
# Ambiguous overlaps checked for 1122 intermediate views
# Ambiguous overlaps checked for 1496 intermediate views
# Ambiguous overlaps checked for 1498 points
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 1
# Computing initial embedding using: sequential algorithm
# ##############################
# Time elapsed from last time log: 11.9 seconds
# Total time elapsed: 11.9 seconds
# ##############################
# Initial alignment of 374 views completed
# Initial alignment of 748 views completed
# Initial alignment of 1122 views completed
# Initial alignment of 1496 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 1.1 seconds
# Total time elapsed: 13.0 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 21.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11498 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 6.1 seconds
# Total time elapsed: 27.0 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 34.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11498 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 5.7 seconds
# Total time elapsed: 39.7 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 46.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11498 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 5.8 seconds
# Total time elapsed: 52.2 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 58.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11498 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 5.8 seconds
# Total time elapsed: 64.4 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 70.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11498 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 5.9 seconds
# Total time elapsed: 76.5 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 5
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 82.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11498 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 5.9 seconds
# Total time elapsed: 88.5 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 6
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 94.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11498 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 5.8 seconds
# Total time elapsed: 100.0 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 7
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 105.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11498 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 5.7 seconds
# Total time elapsed: 111.4 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 8
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 117.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11498 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 5.7 seconds
# Total time elapsed: 122.8 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 9
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 128.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11498 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 8.1 seconds
# Total time elapsed: 137.0 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 11498 multiplied with B
# Alignment error: 128.105
# ##############################
# Time elapsed from last time log: 3.5 seconds
# Total time elapsed: 140.5 seconds
# ##############################
# array([[-0.04763205, -0.37029611],
#        [-0.03899369, -0.37004917],
#        [-0.03024013, -0.37158116],
#        ...,
#        [-0.02134183, -0.36347393],
#        [-0.02875495, -0.35925855],
#        [-0.03760571, -0.3576474 ]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/kleinbottle4d//ldle.dat
