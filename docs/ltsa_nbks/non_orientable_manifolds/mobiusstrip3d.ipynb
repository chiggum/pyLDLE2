# %% [markdown]
# ### Mobius strip

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
save_dir_root = '../data/pyLDLE2/mobiusstrip3d/'

# %%
X, labelsMat, ddX = datasets.Datasets().mobiusstrip3d()
# Out:
# X.shape =  (10580, 3)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LTSA'},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  intermed_opts={'eta_min': 10},
                  global_opts={
                      'max_iter': 10,
                      'init_algo_align_w_parent_only': True # Set this True for low noise
                  },
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 600 is created.

# %%
ldle.fit(X=X)
# Out:
# Constructing local views using LTSA.
# local_param: 0 points processed...
# local_param: 2645 points processed...
# local_param: 5290 points processed...
# local_param: 7935 points processed...
# local_param: all 10580 points processed...
# Done.
# ##############################
# Time elapsed from last time log: 12.0 seconds
# Total time elapsed: 12.0 seconds
# ##############################
# Max local distortion = 1.001450514862415
# Constructing intermediate views.
# eta = 2.
# # non-empty views with sz < 2 = 10580
# #nodes in views with sz < 2 = 10580
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 16.3 seconds
# Total time elapsed: 16.4 seconds
# ##############################
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 33.4 seconds
# Total time elapsed: 49.9 seconds
# ##############################
# eta = 3.
# # non-empty views with sz < 3 = 3717
# #nodes in views with sz < 3 = 7434
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 8.4 seconds
# Total time elapsed: 58.3 seconds
# ##############################
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 125.2 seconds
# Total time elapsed: 183.5 seconds
# ##############################
# eta = 4.
# # non-empty views with sz < 4 = 375
# #nodes in views with sz < 4 = 1125
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 1.6 seconds
# Total time elapsed: 185.1 seconds
# ##############################
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 23.6 seconds
# Total time elapsed: 208.7 seconds
# ##############################
# eta = 5.
# # non-empty views with sz < 5 = 1545
# #nodes in views with sz < 5 = 6180
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 5.6 seconds
# Total time elapsed: 214.3 seconds
# ##############################
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 165.4 seconds
# Total time elapsed: 379.8 seconds
# ##############################
# eta = 6.
# # non-empty views with sz < 6 = 231
# #nodes in views with sz < 6 = 1155
# Costs computed when eta = 6.
# ##############################
# Time elapsed from last time log: 2.1 seconds
# Total time elapsed: 381.8 seconds
# ##############################
# Remaining #nodes in views with sz < 6 = 0
# Done with eta = 6.
# ##############################
# Time elapsed from last time log: 45.8 seconds
# Total time elapsed: 427.6 seconds
# ##############################
# eta = 7.
# # non-empty views with sz < 7 = 181
# #nodes in views with sz < 7 = 1086
# Costs computed when eta = 7.
# ##############################
# Time elapsed from last time log: 1.9 seconds
# Total time elapsed: 429.5 seconds
# ##############################
# Remaining #nodes in views with sz < 7 = 0
# Done with eta = 7.
# ##############################
# Time elapsed from last time log: 59.4 seconds
# Total time elapsed: 488.9 seconds
# ##############################
# eta = 8.
# # non-empty views with sz < 8 = 182
# #nodes in views with sz < 8 = 1274
# Costs computed when eta = 8.
# ##############################
# Time elapsed from last time log: 2.4 seconds
# Total time elapsed: 491.3 seconds
# ##############################
# Remaining #nodes in views with sz < 8 = 0
# Done with eta = 8.
# ##############################
# Time elapsed from last time log: 71.1 seconds
# Total time elapsed: 562.4 seconds
# ##############################
# eta = 9.
# # non-empty views with sz < 9 = 307
# #nodes in views with sz < 9 = 2456
# Costs computed when eta = 9.
# ##############################
# Time elapsed from last time log: 2.8 seconds
# Total time elapsed: 565.2 seconds
# ##############################
# Remaining #nodes in views with sz < 9 = 0
# Done with eta = 9.
# ##############################
# Time elapsed from last time log: 221.0 seconds
# Total time elapsed: 786.3 seconds
# ##############################
# eta = 10.
# # non-empty views with sz < 10 = 58
# #nodes in views with sz < 10 = 522
# Costs computed when eta = 10.
# ##############################
# Time elapsed from last time log: 1.9 seconds
# Total time elapsed: 788.2 seconds
# ##############################
# Remaining #nodes in views with sz < 10 = 0
# Done with eta = 10.
# ##############################
# Time elapsed from last time log: 23.3 seconds
# Total time elapsed: 811.6 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 1.0 seconds
# Total time elapsed: 812.6 seconds
# ##############################
# After clustering, max distortion is 1.000962
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 177 intermediate views
# Ambiguous overlaps checked for 354 intermediate views
# Ambiguous overlaps checked for 531 intermediate views
# Ambiguous overlaps checked for 708 points
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 1
# Computing initial embedding using: sequential algorithm
# ##############################
# Time elapsed from last time log: 5.6 seconds
# Total time elapsed: 5.6 seconds
# ##############################
# Initial alignment of 177 views completed
# Initial alignment of 354 views completed
# Initial alignment of 531 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 6.1 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 43.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11288
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 128.7 seconds
# Total time elapsed: 172.3 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 193.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11288
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 42.8 seconds
# Total time elapsed: 236.0 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 249.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11288
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 70.9 seconds
# Total time elapsed: 320.8 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 330.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11288
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 53.3 seconds
# Total time elapsed: 383.3 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 396.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11288
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 32.9 seconds
# Total time elapsed: 429.3 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 5
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 439.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11288
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 40.2 seconds
# Total time elapsed: 480.1 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 6
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 492.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11288
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 47.6 seconds
# Total time elapsed: 539.6 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 7
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 551.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11288
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 42.4 seconds
# Total time elapsed: 593.8 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 8
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 602.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11288
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 34.2 seconds
# Total time elapsed: 637.0 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 9
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 643.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11288
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 22.2 seconds
# Total time elapsed: 666.0 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 11288
# Alignment error: 18.907
# ##############################
# Time elapsed from last time log: 5.0 seconds
# Total time elapsed: 671.0 seconds
# ##############################
# array([[-2.26841261, -0.87546343],
#        [-2.27393887, -0.87603326],
#        [-2.27946512, -0.87660308],
#        ...,
#        [ 2.30622336,  0.86288107],
#        [ 2.30068483,  0.86245439],
#        [ 2.29514631,  0.8620277 ]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/mobiusstrip3d//ldle.dat
