# %% [markdown]
# ### Mobius strip

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
save_dir_root = '../data/pyLDLE2/mobiusstrip3d/'

# %%
X, labelsMat, ddX = datasets.Datasets().mobiusstrip3d()
# Out:
# X.shape =  (10580, 3)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LTSA'},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 700 is created.
# Options provided:
# local_opts:
# {
#     "Atilde_method": "LDLE_1",
#     "N": 100,
#     "algo": "LTSA",
#     "alpha": 1,
#     "debug": true,
#     "delta": 0.9,
#     "gl_type": "unnorm",
#     "k": 28,
#     "k_nn": 49,
#     "k_nn0": 700,
#     "k_tune": 7,
#     "max_iter": 300,
#     "n_proc": 32,
#     "no_gamma": false,
#     "p": 0.99,
#     "pp_n_thresh": 32,
#     "reg": 0.0,
#     "tau": 50,
#     "to_postprocess": true,
#     "verbose": true
# }
# intermed_opts:
# {
#     "algo": "best",
#     "debug": true,
#     "eta_max": 25,
#     "eta_min": 5,
#     "len_S_thresh": 256,
#     "local_algo": "LTSA",
#     "n_proc": 32,
#     "n_times": 4,
#     "verbose": true
# }
# global_opts:
# {
#     "align_w_parent_only": true,
#     "alpha": 0.3,
#     "color_tear": true,
#     "compute_error": false,
#     "debug": true,
#     "eps": 1e-08,
#     "init_algo_name": "procrustes",
#     "k": 28,
#     "main_algo": "LDLE",
#     "max_internal_iter": 100,
#     "max_iter": 20,
#     "n_proc": 32,
#     "nu": 3,
#     "refine_algo_name": "rgd",
#     "to_tear": true,
#     "verbose": true,
#     "vis_before_init": false
# }

# %%
ldle.fit(X=X)
# Out:
# Constructing local views using LTSA
# local_param: all 10580 points processed...
# max distortion is 1.000931
# Done.
# ##############################
# Time elapsed from last time log: 1.2 seconds
# Total time elapsed: 1.2 seconds
# ##############################
# Posprocessing local parameterizations.
# #Param replaced: 1726, max distortion: 1.000788
# #Param replaced: 0, max distortion: 1.000788
# Max local distortion after postprocessing: 1.0007877615215603
# Done.
# ##############################
# Time elapsed from last time log: 4.0 seconds
# Total time elapsed: 5.2 seconds
# ##############################
# Max local distortion = 1.0007877615215603
# Constructing intermediate views.
# eta = 2.
# #non-empty views with sz < 2 = 10580
# #nodes in views with sz < 2 = 10580
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 9.8 seconds
# Total time elapsed: 10.8 seconds
# ##############################
# ctr=6155, total_len_S=20214, avg_len_S=3.284
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 46.4 seconds
# Total time elapsed: 57.2 seconds
# ##############################
# eta = 3.
# #non-empty views with sz < 3 = 3708
# #nodes in views with sz < 3 = 7416
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 3.1 seconds
# Total time elapsed: 60.4 seconds
# ##############################
# ctr=3790, total_len_S=62623, avg_len_S=16.523
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 188.3 seconds
# Total time elapsed: 248.7 seconds
# ##############################
# eta = 4.
# #non-empty views with sz < 4 = 376
# #nodes in views with sz < 4 = 1128
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 0.9 seconds
# Total time elapsed: 249.6 seconds
# ##############################
# ctr=781, total_len_S=19493, avg_len_S=24.959
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 15.8 seconds
# Total time elapsed: 265.4 seconds
# ##############################
# eta = 5.
# #non-empty views with sz < 5 = 1534
# #nodes in views with sz < 5 = 6136
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 1.9 seconds
# Total time elapsed: 267.3 seconds
# ##############################
# ctr=3564, total_len_S=100337, avg_len_S=28.153
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 124.6 seconds
# Total time elapsed: 391.9 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 392.7 seconds
# ##############################
# After clustering, max distortion is 1.001140
# Computing laterations scores for overlaps b/w intermed views
# Done
# ##############################
# Time elapsed from last time log: 0.9 seconds
# Total time elapsed: 0.9 seconds
# ##############################
# Computing a lateration.
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 1
# Done.
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 0.9 seconds
# ##############################
# Computing initial embedding using: procrustes algorithm
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 0.9 seconds
# ##############################
# Initial alignment of 346 views completed
# Initial alignment of 692 views completed
# Initial alignment of 1038 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 1.3 seconds
# Total time elapsed: 2.1 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 3.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10580 + 1384 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 7.1 seconds
# Total time elapsed: 10.5 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 11.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10580 + 1384 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 6.9 seconds
# Total time elapsed: 18.4 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 19.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10580 + 1384 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 6.9 seconds
# Total time elapsed: 26.3 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 27.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10580 + 1384 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 6.8 seconds
# Total time elapsed: 34.0 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 35.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10580 + 1384 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 6.6 seconds
# Total time elapsed: 41.6 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 5
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 42.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10580 + 1384 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 6.7 seconds
# Total time elapsed: 49.4 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 6
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 50.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10580 + 1384 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 6.8 seconds
# Total time elapsed: 57.1 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 7
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 58.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10580 + 1384 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 6.8 seconds
# Total time elapsed: 64.9 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 8
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 65.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10580 + 1384 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 6.7 seconds
# Total time elapsed: 72.7 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 9
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 73.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10580 + 1384 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 6.8 seconds
# Total time elapsed: 80.4 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 10
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 81.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10580 + 1384 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 6.7 seconds
# Total time elapsed: 88.1 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 11
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 89.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10580 + 1384 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 6.8 seconds
# Total time elapsed: 95.8 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 12
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 96.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10580 + 1384 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 6.8 seconds
# Total time elapsed: 103.5 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 13
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 104.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10580 + 1384 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 7.0 seconds
# Total time elapsed: 111.5 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 14
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 112.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10580 + 1384 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 6.8 seconds
# Total time elapsed: 119.2 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 15
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 120.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10580 + 1384 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 6.8 seconds
# Total time elapsed: 127.0 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 16
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 128.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10580 + 1384 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 6.7 seconds
# Total time elapsed: 134.7 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 17
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 135.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10580 + 1384 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 6.8 seconds
# Total time elapsed: 142.4 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 18
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 143.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10580 + 1384 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 6.7 seconds
# Total time elapsed: 150.1 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 19
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 151.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10580 + 1384 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 6.9 seconds
# Total time elapsed: 158.0 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 10580 + 1384 multiplied with B
# Computing svd
# Done
# Alignment error: 1.867
# ##############################
# Time elapsed from last time log: 3.7 seconds
# Total time elapsed: 161.7 seconds
# ##############################
# array([[0.26598812, 0.88782865],
#        [0.26752945, 0.89316611],
#        [0.26907078, 0.89850358],
#        ...,
#        [0.2456806 , 0.90491885],
#        [0.24428383, 0.89954175],
#        [0.24288626, 0.89416325]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/mobiusstrip3d//ldle.dat
