# %% [markdown]
# ### Swissroll with noise = 0.02

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
noise = 0.02

# %%
save_dir_root = '../data/pyLDLE2/swissroll_with_noise_'+str(noise)+'/'

# %%
X, labelsMat, ddX = datasets.Datasets().noisyswissroll(noise=noise)
# Out:
# X.shape =  (10260, 3)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LTSA', 'k': 30},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  intermed_opts={'eta_min': 10},
                  global_opts={
                      'max_iter': 10,
                      'init_algo_align_w_parent_only': True # Set this True for low noise
                  },
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 750 is created.

# %%
ldle.fit(X=X)
# Out:
# Constructing local views using LTSA.
# local_param: 0 points processed...
# local_param: 2565 points processed...
# local_param: 5130 points processed...
# local_param: 7695 points processed...
# local_param: all 10260 points processed...
# Done.
# ##############################
# Time elapsed from last time log: 7.3 seconds
# Total time elapsed: 7.3 seconds
# ##############################
# Max local distortion = 1388.835363969667
# Constructing intermediate views.
# eta = 2.
# # non-empty views with sz < 2 = 10260
# #nodes in views with sz < 2 = 10260
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 16.7 seconds
# Total time elapsed: 16.8 seconds
# ##############################
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 225.3 seconds
# Total time elapsed: 242.1 seconds
# ##############################
# eta = 3.
# # non-empty views with sz < 3 = 293
# #nodes in views with sz < 3 = 586
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 0.9 seconds
# Total time elapsed: 242.9 seconds
# ##############################
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 4.7 seconds
# Total time elapsed: 247.6 seconds
# ##############################
# eta = 4.
# # non-empty views with sz < 4 = 213
# #nodes in views with sz < 4 = 639
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 0.9 seconds
# Total time elapsed: 248.5 seconds
# ##############################
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 8.9 seconds
# Total time elapsed: 257.5 seconds
# ##############################
# eta = 5.
# # non-empty views with sz < 5 = 172
# #nodes in views with sz < 5 = 688
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 0.9 seconds
# Total time elapsed: 258.4 seconds
# ##############################
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 13.4 seconds
# Total time elapsed: 271.8 seconds
# ##############################
# eta = 6.
# # non-empty views with sz < 6 = 142
# #nodes in views with sz < 6 = 710
# Costs computed when eta = 6.
# ##############################
# Time elapsed from last time log: 1.1 seconds
# Total time elapsed: 272.9 seconds
# ##############################
# Remaining #nodes in views with sz < 6 = 0
# Done with eta = 6.
# ##############################
# Time elapsed from last time log: 16.5 seconds
# Total time elapsed: 289.4 seconds
# ##############################
# eta = 7.
# # non-empty views with sz < 7 = 91
# #nodes in views with sz < 7 = 546
# Costs computed when eta = 7.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 290.2 seconds
# ##############################
# Remaining #nodes in views with sz < 7 = 0
# Done with eta = 7.
# ##############################
# Time elapsed from last time log: 12.8 seconds
# Total time elapsed: 303.1 seconds
# ##############################
# eta = 8.
# # non-empty views with sz < 8 = 79
# #nodes in views with sz < 8 = 553
# Costs computed when eta = 8.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 303.9 seconds
# ##############################
# Remaining #nodes in views with sz < 8 = 0
# Done with eta = 8.
# ##############################
# Time elapsed from last time log: 20.3 seconds
# Total time elapsed: 324.2 seconds
# ##############################
# eta = 9.
# # non-empty views with sz < 9 = 63
# #nodes in views with sz < 9 = 504
# Costs computed when eta = 9.
# ##############################
# Time elapsed from last time log: 0.9 seconds
# Total time elapsed: 325.0 seconds
# ##############################
# Remaining #nodes in views with sz < 9 = 0
# Done with eta = 9.
# ##############################
# Time elapsed from last time log: 16.7 seconds
# Total time elapsed: 341.8 seconds
# ##############################
# eta = 10.
# # non-empty views with sz < 10 = 57
# #nodes in views with sz < 10 = 513
# Costs computed when eta = 10.
# ##############################
# Time elapsed from last time log: 0.7 seconds
# Total time elapsed: 342.5 seconds
# ##############################
# Remaining #nodes in views with sz < 10 = 0
# Done with eta = 10.
# ##############################
# Time elapsed from last time log: 19.9 seconds
# Total time elapsed: 362.4 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 0.7 seconds
# Total time elapsed: 363.1 seconds
# ##############################
# After clustering, max distortion is 28.207488
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 157 intermediate views
# Ambiguous overlaps checked for 314 intermediate views
# Ambiguous overlaps checked for 471 intermediate views
# Ambiguous overlaps checked for 628 intermediate views
# Ambiguous overlaps checked for 630 points
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 1
# Computing initial embedding using: sequential algorithm
# ##############################
# Time elapsed from last time log: 3.5 seconds
# Total time elapsed: 3.5 seconds
# ##############################
# Initial alignment of 157 views completed
# Initial alignment of 314 views completed
# Initial alignment of 471 views completed
# Initial alignment of 628 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 0.3 seconds
# Total time elapsed: 3.7 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 12.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10890 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.8 seconds
# Total time elapsed: 14.0 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 18.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10890 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.9 seconds
# Total time elapsed: 20.2 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 24.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10890 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.1 seconds
# Total time elapsed: 26.6 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 31.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10890 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.0 seconds
# Total time elapsed: 33.0 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 37.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10890 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.9 seconds
# Total time elapsed: 39.3 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 5
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 43.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10890 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.0 seconds
# Total time elapsed: 45.6 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 6
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 49.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10890 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.9 seconds
# Total time elapsed: 51.8 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 7
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 56.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10890 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.8 seconds
# Total time elapsed: 57.9 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 8
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 62.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10890 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.8 seconds
# Total time elapsed: 64.1 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 9
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 68.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10890 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 1.8 seconds
# Total time elapsed: 70.3 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 10890 multiplied with B
# Alignment error: 101.419
# ##############################
# Time elapsed from last time log: 0.9 seconds
# Total time elapsed: 71.2 seconds
# ##############################
# array([[-0.66421715, -0.59591274],
#        [-0.64894128, -0.57877913],
#        [-0.66057631, -0.55083115],
#        ...,
#        [ 0.66978761,  0.60376067],
#        [ 0.67565542,  0.61207674],
#        [ 0.71558986,  0.61279532]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/swissroll_with_noise_0.02//ldle.dat
