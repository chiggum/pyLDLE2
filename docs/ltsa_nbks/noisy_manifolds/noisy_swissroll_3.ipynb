# %% [markdown]
# ### Swissroll with noise = 0.02

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
noise = 0.02

# %%
save_dir_root = '../data/pyLDLE2/swissroll_with_noise_'+str(noise)+'/'

# %%
X, labelsMat, ddX = datasets.Datasets().noisyswissroll(noise=noise)
# Out:
# X.shape =  (10260, 3)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LTSA', 'k': 30},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  intermed_opts={'eta_min': 10},
                  global_opts={
                      'max_iter': 10,
                      'init_algo_align_w_parent_only': True # Set this True for low noise
                  },
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 750 is created.

# %%
ldle.fit(X=X)
# Out:
# Constructing local views using LTSA.
# local_param: all 10260 points processed...
# max distortion is 665.079910
# Done.
# ##############################
# Time elapsed from last time log: 1.1 seconds
# Total time elapsed: 1.1 seconds
# ##############################
# Posprocessing local parameterizations.
# #Param replaced: 9656, max distortion: 12.126575
# #Param replaced: 3902, max distortion: 11.786790
# #Param replaced: 1216, max distortion: 11.786790
# #Param replaced: 395, max distortion: 11.786790
# #Param replaced: 125, max distortion: 11.786790
# #Param replaced: 36, max distortion: 11.786790
# #Param replaced: 10, max distortion: 11.786790
# #Param replaced: 2, max distortion: 11.786790
# #Param replaced: 0, max distortion: 11.786790
# Max local distortion after postprocessing: 11.786789895305622
# Done.
# ##############################
# Time elapsed from last time log: 9.7 seconds
# Total time elapsed: 10.9 seconds
# ##############################
# Max local distortion = 11.786789895305622
# Constructing intermediate views.
# eta = 2.
# # non-empty views with sz < 2 = 10260
# #nodes in views with sz < 2 = 10260
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 17.7 seconds
# Total time elapsed: 17.9 seconds
# ##############################
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 78.1 seconds
# Total time elapsed: 95.9 seconds
# ##############################
# eta = 3.
# # non-empty views with sz < 3 = 1343
# #nodes in views with sz < 3 = 2686
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 3.4 seconds
# Total time elapsed: 99.3 seconds
# ##############################
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 45.6 seconds
# Total time elapsed: 144.9 seconds
# ##############################
# eta = 4.
# # non-empty views with sz < 4 = 684
# #nodes in views with sz < 4 = 2052
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 2.5 seconds
# Total time elapsed: 147.5 seconds
# ##############################
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 51.4 seconds
# Total time elapsed: 198.9 seconds
# ##############################
# eta = 5.
# # non-empty views with sz < 5 = 355
# #nodes in views with sz < 5 = 1420
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 1.7 seconds
# Total time elapsed: 200.6 seconds
# ##############################
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 38.0 seconds
# Total time elapsed: 238.6 seconds
# ##############################
# eta = 6.
# # non-empty views with sz < 6 = 292
# #nodes in views with sz < 6 = 1460
# Costs computed when eta = 6.
# ##############################
# Time elapsed from last time log: 2.3 seconds
# Total time elapsed: 240.9 seconds
# ##############################
# Remaining #nodes in views with sz < 6 = 0
# Done with eta = 6.
# ##############################
# Time elapsed from last time log: 47.6 seconds
# Total time elapsed: 288.6 seconds
# ##############################
# eta = 7.
# # non-empty views with sz < 7 = 163
# #nodes in views with sz < 7 = 978
# Costs computed when eta = 7.
# ##############################
# Time elapsed from last time log: 1.6 seconds
# Total time elapsed: 290.2 seconds
# ##############################
# Remaining #nodes in views with sz < 7 = 0
# Done with eta = 7.
# ##############################
# Time elapsed from last time log: 32.2 seconds
# Total time elapsed: 322.4 seconds
# ##############################
# eta = 8.
# # non-empty views with sz < 8 = 160
# #nodes in views with sz < 8 = 1120
# Costs computed when eta = 8.
# ##############################
# Time elapsed from last time log: 1.6 seconds
# Total time elapsed: 324.0 seconds
# ##############################
# Remaining #nodes in views with sz < 8 = 0
# Done with eta = 8.
# ##############################
# Time elapsed from last time log: 47.1 seconds
# Total time elapsed: 371.2 seconds
# ##############################
# eta = 9.
# # non-empty views with sz < 9 = 105
# #nodes in views with sz < 9 = 840
# Costs computed when eta = 9.
# ##############################
# Time elapsed from last time log: 1.4 seconds
# Total time elapsed: 372.6 seconds
# ##############################
# Remaining #nodes in views with sz < 9 = 0
# Done with eta = 9.
# ##############################
# Time elapsed from last time log: 34.0 seconds
# Total time elapsed: 406.5 seconds
# ##############################
# eta = 10.
# # non-empty views with sz < 10 = 68
# #nodes in views with sz < 10 = 612
# Costs computed when eta = 10.
# ##############################
# Time elapsed from last time log: 1.0 seconds
# Total time elapsed: 407.6 seconds
# ##############################
# Remaining #nodes in views with sz < 10 = 0
# Done with eta = 10.
# ##############################
# Time elapsed from last time log: 25.6 seconds
# Total time elapsed: 433.1 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 0.7 seconds
# Total time elapsed: 433.8 seconds
# ##############################
# After clustering, max distortion is 30.041284
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 168 intermediate views
# Ambiguous overlaps checked for 336 intermediate views
# Ambiguous overlaps checked for 504 intermediate views
# Ambiguous overlaps checked for 672 intermediate views
# Ambiguous overlaps checked for 675 points
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 1
# Computing initial embedding using: sequential algorithm
# ##############################
# Time elapsed from last time log: 5.4 seconds
# Total time elapsed: 5.4 seconds
# ##############################
# Initial alignment of 168 views completed
# Initial alignment of 336 views completed
# Initial alignment of 504 views completed
# Initial alignment of 672 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 5.9 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 8.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10935 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.3 seconds
# Total time elapsed: 10.8 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 12.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10935 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.3 seconds
# Total time elapsed: 15.0 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 17.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10935 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 19.3 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 21.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10935 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.4 seconds
# Total time elapsed: 23.5 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 25.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10935 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.3 seconds
# Total time elapsed: 27.7 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 5
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 29.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10935 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 31.9 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 6
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 33.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10935 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 36.1 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 7
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 38.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10935 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.3 seconds
# Total time elapsed: 40.3 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 8
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 42.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10935 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 44.5 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 9
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 46.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10935 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 48.6 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 10935 multiplied with B
# Alignment error: 101.283
# ##############################
# Time elapsed from last time log: 1.1 seconds
# Total time elapsed: 49.7 seconds
# ##############################
# array([[-0.22382053,  0.84506479],
#        [-0.23246789,  0.8374997 ],
#        [-0.20457546,  0.83103391],
#        ...,
#        [ 0.24684857, -0.86668926],
#        [ 0.25137475, -0.87660419],
#        [ 0.22642244, -0.92136356]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/swissroll_with_noise_0.02//ldle.dat
