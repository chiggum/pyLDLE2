# %% [markdown]
# ### Swissroll with noise = 0.02

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
noise = 0.02

# %%
save_dir_root = '../data/pyLDLE2/swissroll_with_noise_'+str(noise)+'/'

# %%
X, labelsMat, ddX = datasets.Datasets().noisyswissroll(noise=noise)
# Out:
# X.shape =  (10260, 3)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LTSA'},
                  intermed_opts={'eta_min': 10},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 700 is created.
# Options provided:
# local_opts:
# {
#     "Atilde_method": "LDLE_1",
#     "N": 100,
#     "algo": "LTSA",
#     "alpha": 1,
#     "debug": true,
#     "delta": 0.9,
#     "gl_type": "unnorm",
#     "k": 28,
#     "k_nn": 49,
#     "k_nn0": 700,
#     "k_tune": 7,
#     "max_iter": 300,
#     "n_proc": 32,
#     "no_gamma": false,
#     "p": 0.99,
#     "pp_n_thresh": 32,
#     "reg": 0.0,
#     "tau": 50,
#     "to_postprocess": true,
#     "verbose": true
# }
# intermed_opts:
# {
#     "algo": "best",
#     "debug": true,
#     "eta_max": 25,
#     "eta_min": 10,
#     "len_S_thresh": 256,
#     "local_algo": "LTSA",
#     "n_proc": 32,
#     "n_times": 4,
#     "verbose": true
# }
# global_opts:
# {
#     "align_w_parent_only": true,
#     "alpha": 0.3,
#     "color_tear": true,
#     "compute_error": false,
#     "debug": true,
#     "eps": 1e-08,
#     "init_algo_name": "procrustes",
#     "k": 28,
#     "main_algo": "LDLE",
#     "max_internal_iter": 100,
#     "max_iter": 20,
#     "n_proc": 32,
#     "nu": 3,
#     "refine_algo_name": "rgd",
#     "to_tear": true,
#     "verbose": true,
#     "vis_before_init": false
# }

# %%
ldle.fit(X=X)
# Out:
# Constructing local views using LTSA
# local_param: all 10260 points processed...
# max distortion is 1696.282054
# Done.
# ##############################
# Time elapsed from last time log: 1.3 seconds
# Total time elapsed: 1.3 seconds
# ##############################
# Posprocessing local parameterizations.
# #Param replaced: 9615, max distortion: 11.080966
# #Param replaced: 3828, max distortion: 10.082597
# #Param replaced: 1319, max distortion: 10.006978
# #Param replaced: 434, max distortion: 9.778689
# #Param replaced: 151, max distortion: 9.778689
# #Param replaced: 42, max distortion: 9.778689
# #Param replaced: 10, max distortion: 9.717145
# #Param replaced: 5, max distortion: 9.717145
# #Param replaced: 0, max distortion: 9.717145
# Max local distortion after postprocessing: 9.717144625463142
# Done.
# ##############################
# Time elapsed from last time log: 7.4 seconds
# Total time elapsed: 8.7 seconds
# ##############################
# Max local distortion = 9.717144625463142
# Constructing intermediate views.
# eta = 2.
# #non-empty views with sz < 2 = 10260
# #nodes in views with sz < 2 = 10260
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 11.3 seconds
# Total time elapsed: 12.2 seconds
# ##############################
# ctr=7035, total_len_S=29652, avg_len_S=4.215
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 121.7 seconds
# Total time elapsed: 134.0 seconds
# ##############################
# eta = 3.
# #non-empty views with sz < 3 = 1297
# #nodes in views with sz < 3 = 2594
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 136.2 seconds
# ##############################
# ctr=2027, total_len_S=36547, avg_len_S=18.030
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 56.6 seconds
# Total time elapsed: 192.7 seconds
# ##############################
# eta = 4.
# #non-empty views with sz < 4 = 673
# #nodes in views with sz < 4 = 2019
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 1.7 seconds
# Total time elapsed: 194.4 seconds
# ##############################
# ctr=1669, total_len_S=45759, avg_len_S=27.417
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 62.4 seconds
# Total time elapsed: 256.9 seconds
# ##############################
# eta = 5.
# #non-empty views with sz < 5 = 407
# #nodes in views with sz < 5 = 1628
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 1.5 seconds
# Total time elapsed: 258.4 seconds
# ##############################
# ctr=1377, total_len_S=47827, avg_len_S=34.733
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 53.3 seconds
# Total time elapsed: 311.7 seconds
# ##############################
# eta = 6.
# #non-empty views with sz < 6 = 269
# #nodes in views with sz < 6 = 1345
# Costs computed when eta = 6.
# ##############################
# Time elapsed from last time log: 1.4 seconds
# Total time elapsed: 313.0 seconds
# ##############################
# ctr=1219, total_len_S=53184, avg_len_S=43.629
# Remaining #nodes in views with sz < 6 = 0
# Done with eta = 6.
# ##############################
# Time elapsed from last time log: 62.0 seconds
# Total time elapsed: 375.0 seconds
# ##############################
# eta = 7.
# #non-empty views with sz < 7 = 186
# #nodes in views with sz < 7 = 1116
# Costs computed when eta = 7.
# ##############################
# Time elapsed from last time log: 1.5 seconds
# Total time elapsed: 376.5 seconds
# ##############################
# ctr=979, total_len_S=48421, avg_len_S=49.460
# Remaining #nodes in views with sz < 7 = 0
# Done with eta = 7.
# ##############################
# Time elapsed from last time log: 48.7 seconds
# Total time elapsed: 425.2 seconds
# ##############################
# eta = 8.
# #non-empty views with sz < 8 = 134
# #nodes in views with sz < 8 = 938
# Costs computed when eta = 8.
# ##############################
# Time elapsed from last time log: 1.4 seconds
# Total time elapsed: 426.6 seconds
# ##############################
# ctr=861, total_len_S=47707, avg_len_S=55.409
# Remaining #nodes in views with sz < 8 = 0
# Done with eta = 8.
# ##############################
# Time elapsed from last time log: 48.9 seconds
# Total time elapsed: 475.5 seconds
# ##############################
# eta = 9.
# #non-empty views with sz < 9 = 106
# #nodes in views with sz < 9 = 848
# Costs computed when eta = 9.
# ##############################
# Time elapsed from last time log: 1.3 seconds
# Total time elapsed: 476.8 seconds
# ##############################
# ctr=769, total_len_S=48801, avg_len_S=63.460
# Remaining #nodes in views with sz < 9 = 0
# Done with eta = 9.
# ##############################
# Time elapsed from last time log: 49.6 seconds
# Total time elapsed: 526.4 seconds
# ##############################
# eta = 10.
# #non-empty views with sz < 10 = 85
# #nodes in views with sz < 10 = 765
# Costs computed when eta = 10.
# ##############################
# Time elapsed from last time log: 1.2 seconds
# Total time elapsed: 527.7 seconds
# ##############################
# ctr=726, total_len_S=47442, avg_len_S=65.347
# Remaining #nodes in views with sz < 10 = 0
# Done with eta = 10.
# ##############################
# Time elapsed from last time log: 41.1 seconds
# Total time elapsed: 568.8 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 1.0 seconds
# Total time elapsed: 569.8 seconds
# ##############################
# After clustering, max distortion is 23.849702
# Computing laterations scores for overlaps b/w intermed views
# Done
# ##############################
# Time elapsed from last time log: 1.1 seconds
# Total time elapsed: 1.1 seconds
# ##############################
# Computing a lateration.
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 1
# Done.
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 1.1 seconds
# ##############################
# Computing initial embedding using: procrustes algorithm
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 1.1 seconds
# ##############################
# Initial alignment of 164 views completed
# Initial alignment of 328 views completed
# Initial alignment of 492 views completed
# Initial alignment of 656 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 0.9 seconds
# Total time elapsed: 2.0 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 6.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 657 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.2 seconds
# Total time elapsed: 10.7 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 13.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 657 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.0 seconds
# Total time elapsed: 17.6 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 20.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 657 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 3.9 seconds
# Total time elapsed: 24.1 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 26.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 657 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.1 seconds
# Total time elapsed: 30.7 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 33.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 657 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.1 seconds
# Total time elapsed: 37.4 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 5
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 39.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 657 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.0 seconds
# Total time elapsed: 43.8 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 6
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 46.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 657 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.1 seconds
# Total time elapsed: 50.3 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 7
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 52.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 657 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.2 seconds
# Total time elapsed: 56.8 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 8
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 59.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 657 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.3 seconds
# Total time elapsed: 63.6 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 9
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 66.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 657 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.3 seconds
# Total time elapsed: 70.4 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 10
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 73.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 657 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.0 seconds
# Total time elapsed: 77.1 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 11
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 79.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 657 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 3.9 seconds
# Total time elapsed: 83.6 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 12
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 86.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 657 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.1 seconds
# Total time elapsed: 90.1 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 13
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 92.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 657 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.1 seconds
# Total time elapsed: 96.7 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 14
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 99.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 657 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.0 seconds
# Total time elapsed: 103.2 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 15
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 105.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 657 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.3 seconds
# Total time elapsed: 110.0 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 16
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 112.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 657 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.2 seconds
# Total time elapsed: 116.7 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 17
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 119.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 657 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.4 seconds
# Total time elapsed: 123.6 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 18
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 126.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 657 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.3 seconds
# Total time elapsed: 130.3 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 19
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 133.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10260 + 657 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 4.1 seconds
# Total time elapsed: 137.1 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 10260 + 657 multiplied with B
# Computing svd
# Done
# Alignment error: 94.280
# ##############################
# Time elapsed from last time log: 2.0 seconds
# Total time elapsed: 139.1 seconds
# ##############################
# array([[-0.14503041,  0.34587243],
#        [-0.13768902,  0.32853069],
#        [-0.14869097,  0.30031254],
#        ...,
#        [ 0.1744076 , -0.34438737],
#        [ 0.19460425, -0.34955109],
#        [ 0.23187444, -0.34320208]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/swissroll_with_noise_0.02//ldle.dat
