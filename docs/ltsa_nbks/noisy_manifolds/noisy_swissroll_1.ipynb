# %% [markdown]
# ### Swissroll with noise = 0.01

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
noise = 0.01

# %%
save_dir_root = '../data/pyLDLE2/swissroll_with_noise_'+str(noise)+'/'

# %%
X, labelsMat, ddX = datasets.Datasets().noisyswissroll(noise=noise)
# Out:
# X.shape =  (10260, 3)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LTSA'},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  intermed_opts={'eta_min': 10},
                  global_opts={
                      'max_iter': 10,
                      'init_algo_align_w_parent_only': True # Set this True for low noise
                  },
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 875 is created.

# %%
ldle.fit(X=X)
# Out:
# Constructing local views using LTSA.
# local_param: all 10260 points processed...
# max distortion is 471.342342
# Done.
# ##############################
# Time elapsed from last time log: 1.2 seconds
# Total time elapsed: 1.2 seconds
# ##############################
# Posprocessing local parameterizations.
# #Param replaced: 9981, max distortion: 12.353080
# #Param replaced: 4680, max distortion: 9.169937
# #Param replaced: 1508, max distortion: 9.169937
# #Param replaced: 544, max distortion: 9.169937
# #Param replaced: 211, max distortion: 9.169937
# #Param replaced: 75, max distortion: 9.169937
# #Param replaced: 19, max distortion: 9.169937
# #Param replaced: 1, max distortion: 9.169937
# #Param replaced: 0, max distortion: 9.169937
# Max local distortion after postprocessing: 9.169936787823193
# Done.
# ##############################
# Time elapsed from last time log: 12.5 seconds
# Total time elapsed: 13.7 seconds
# ##############################
# Max local distortion = 9.169936787823193
# Constructing intermediate views.
# eta = 2.
# # non-empty views with sz < 2 = 10260
# #nodes in views with sz < 2 = 10260
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 23.3 seconds
# Total time elapsed: 23.5 seconds
# ##############################
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 139.7 seconds
# Total time elapsed: 163.1 seconds
# ##############################
# eta = 3.
# # non-empty views with sz < 3 = 1039
# #nodes in views with sz < 3 = 2078
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 2.9 seconds
# Total time elapsed: 166.0 seconds
# ##############################
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 34.9 seconds
# Total time elapsed: 200.9 seconds
# ##############################
# eta = 4.
# # non-empty views with sz < 4 = 586
# #nodes in views with sz < 4 = 1758
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 2.1 seconds
# Total time elapsed: 203.0 seconds
# ##############################
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 39.0 seconds
# Total time elapsed: 242.0 seconds
# ##############################
# eta = 5.
# # non-empty views with sz < 5 = 398
# #nodes in views with sz < 5 = 1592
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 1.8 seconds
# Total time elapsed: 243.8 seconds
# ##############################
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 42.0 seconds
# Total time elapsed: 285.8 seconds
# ##############################
# eta = 6.
# # non-empty views with sz < 6 = 232
# #nodes in views with sz < 6 = 1160
# Costs computed when eta = 6.
# ##############################
# Time elapsed from last time log: 1.4 seconds
# Total time elapsed: 287.2 seconds
# ##############################
# Remaining #nodes in views with sz < 6 = 0
# Done with eta = 6.
# ##############################
# Time elapsed from last time log: 35.0 seconds
# Total time elapsed: 322.2 seconds
# ##############################
# eta = 7.
# # non-empty views with sz < 7 = 184
# #nodes in views with sz < 7 = 1104
# Costs computed when eta = 7.
# ##############################
# Time elapsed from last time log: 1.6 seconds
# Total time elapsed: 323.8 seconds
# ##############################
# Remaining #nodes in views with sz < 7 = 0
# Done with eta = 7.
# ##############################
# Time elapsed from last time log: 35.7 seconds
# Total time elapsed: 359.5 seconds
# ##############################
# eta = 8.
# # non-empty views with sz < 8 = 129
# #nodes in views with sz < 8 = 903
# Costs computed when eta = 8.
# ##############################
# Time elapsed from last time log: 1.2 seconds
# Total time elapsed: 360.7 seconds
# ##############################
# Remaining #nodes in views with sz < 8 = 0
# Done with eta = 8.
# ##############################
# Time elapsed from last time log: 26.5 seconds
# Total time elapsed: 387.2 seconds
# ##############################
# eta = 9.
# # non-empty views with sz < 9 = 93
# #nodes in views with sz < 9 = 744
# Costs computed when eta = 9.
# ##############################
# Time elapsed from last time log: 1.0 seconds
# Total time elapsed: 388.1 seconds
# ##############################
# Remaining #nodes in views with sz < 9 = 0
# Done with eta = 9.
# ##############################
# Time elapsed from last time log: 24.1 seconds
# Total time elapsed: 412.3 seconds
# ##############################
# eta = 10.
# # non-empty views with sz < 10 = 71
# #nodes in views with sz < 10 = 639
# Costs computed when eta = 10.
# ##############################
# Time elapsed from last time log: 1.0 seconds
# Total time elapsed: 413.3 seconds
# ##############################
# Remaining #nodes in views with sz < 10 = 0
# Done with eta = 10.
# ##############################
# Time elapsed from last time log: 23.1 seconds
# Total time elapsed: 436.3 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 0.6 seconds
# Total time elapsed: 437.0 seconds
# ##############################
# After clustering, max distortion is 14.756533
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 162 intermediate views
# Ambiguous overlaps checked for 324 intermediate views
# Ambiguous overlaps checked for 486 intermediate views
# Ambiguous overlaps checked for 648 intermediate views
# Ambiguous overlaps checked for 651 points
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 1
# Computing initial embedding using: sequential algorithm
# ##############################
# Time elapsed from last time log: 3.6 seconds
# Total time elapsed: 3.6 seconds
# ##############################
# Initial alignment of 162 views completed
# Initial alignment of 324 views completed
# Initial alignment of 486 views completed
# Initial alignment of 648 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 4.1 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 4.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10911 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.1 seconds
# Total time elapsed: 7.0 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 7.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10911 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.3 seconds
# Total time elapsed: 9.8 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 10.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10911 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 12.4 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 12.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10911 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.1 seconds
# Total time elapsed: 15.0 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 15.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10911 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 17.8 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 5
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 18.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10911 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.3 seconds
# Total time elapsed: 20.6 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 6
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 21.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10911 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.3 seconds
# Total time elapsed: 23.3 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 7
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 23.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10911 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 26.0 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 8
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 26.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10911 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 28.7 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 9
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 29.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10911 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 31.4 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 10911 multiplied with B
# Alignment error: 0.616
# ##############################
# Time elapsed from last time log: 1.2 seconds
# Total time elapsed: 32.5 seconds
# ##############################
# array([[-0.69372627, -0.56957641],
#        [-0.68727544, -0.55635667],
#        [-0.69640701, -0.53897159],
#        ...,
#        [ 0.71190371,  0.56047904],
#        [ 0.71321057,  0.56975953],
#        [ 0.73640313,  0.56970604]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/swissroll_with_noise_0.01//ldle.dat
