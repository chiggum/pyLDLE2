# %% [markdown]
# ### Swissroll with noise = 0.01

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
noise = 0.01

# %%
save_dir_root = '../data/pyLDLE2/swissroll_with_noise_'+str(noise)+'/'

# %%
X, labelsMat, ddX = datasets.Datasets().noisyswissroll(noise=noise)
# Out:
# X.shape =  (10260, 3)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LTSA'},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 700 is created.
# Options provided:
# local_opts:
# {
#     "Atilde_method": "LDLE_1",
#     "N": 100,
#     "algo": "LTSA",
#     "delta": 0.9,
#     "gl_type": "unnorm",
#     "k": 28,
#     "k_nn": 49,
#     "k_nn0": 700,
#     "k_tune": 7,
#     "n_proc": 32,
#     "no_gamma": false,
#     "p": 0.99,
#     "pp_n_thresh": 32,
#     "tau": 50,
#     "to_postprocess": true
# }
# intermed_opts:
# {
#     "algo": "best",
#     "eta_max": 25,
#     "eta_min": 5,
#     "len_S_thresh": 256,
#     "local_algo": "LTSA",
#     "n_proc": 32,
#     "n_times": 4
# }
# global_opts:
# {
#     "color_tear": true,
#     "compute_error": false,
#     "init_algo_align_w_parent_only": true,
#     "init_algo_name": "procrustes",
#     "k": 28,
#     "main_algo": "LDLE",
#     "max_iter": 20,
#     "n_proc": 32,
#     "nu": 3,
#     "refine_algo_alpha": 0.3,
#     "refine_algo_max_internal_iter": 100,
#     "refine_algo_name": "rgd",
#     "to_tear": true,
#     "vis_before_init": false
# }

# %%
ldle.fit(X=X)
# Out:
# Constructing local views using LTSA.
# local_param: all 10260 points processed...
# max distortion is 496.599157
# Done.
# ##############################
# Time elapsed from last time log: 1.4 seconds
# Total time elapsed: 1.4 seconds
# ##############################
# Posprocessing local parameterizations.
# #Param replaced: 9863, max distortion: 9.775126
# #Param replaced: 4272, max distortion: 8.197607
# #Param replaced: 1344, max distortion: 7.955536
# #Param replaced: 415, max distortion: 7.955536
# #Param replaced: 139, max distortion: 7.955536
# #Param replaced: 30, max distortion: 7.955536
# #Param replaced: 2, max distortion: 7.955536
# #Param replaced: 0, max distortion: 7.955536
# Max local distortion after postprocessing: 7.955535873238164
# Done.
# ##############################
# Time elapsed from last time log: 7.2 seconds
# Total time elapsed: 8.6 seconds
# ##############################
# Max local distortion = 7.955535873238164
# Constructing intermediate views.
# eta = 2.
# # non-empty views with sz < 2 = 10260
# #nodes in views with sz < 2 = 10260
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 11.2 seconds
# Total time elapsed: 12.4 seconds
# ##############################
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 173.6 seconds
# Total time elapsed: 186.0 seconds
# ##############################
# eta = 3.
# # non-empty views with sz < 3 = 1163
# #nodes in views with sz < 3 = 2326
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 2.5 seconds
# Total time elapsed: 188.5 seconds
# ##############################
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 52.1 seconds
# Total time elapsed: 240.5 seconds
# ##############################
# eta = 4.
# # non-empty views with sz < 4 = 686
# #nodes in views with sz < 4 = 2058
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 2.7 seconds
# Total time elapsed: 243.3 seconds
# ##############################
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 68.8 seconds
# Total time elapsed: 312.1 seconds
# ##############################
# eta = 5.
# # non-empty views with sz < 5 = 394
# #nodes in views with sz < 5 = 1576
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 2.8 seconds
# Total time elapsed: 314.9 seconds
# ##############################
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 52.6 seconds
# Total time elapsed: 367.5 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 2.1 seconds
# Total time elapsed: 369.7 seconds
# ##############################
# After clustering, max distortion is 13.611357
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 322 intermediate views
# Ambiguous overlaps checked for 644 intermediate views
# Ambiguous overlaps checked for 966 intermediate views
# Ambiguous overlaps checked for 1288 intermediate views
# Ambiguous overlaps checked for 1289 points
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 1
# Computing initial embedding using: procrustes algorithm
# ##############################
# Time elapsed from last time log: 15.7 seconds
# Total time elapsed: 15.7 seconds
# ##############################
# Initial alignment of 322 views completed
# Initial alignment of 644 views completed
# Initial alignment of 966 views completed
# Initial alignment of 1288 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 1.4 seconds
# Total time elapsed: 17.1 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 18.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11549 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 10.7 seconds
# Total time elapsed: 29.4 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 30.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11549 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 8.3 seconds
# Total time elapsed: 38.9 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 40.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11549 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 9.9 seconds
# Total time elapsed: 50.2 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 51.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11549 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 10.5 seconds
# Total time elapsed: 62.0 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 63.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11549 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 9.5 seconds
# Total time elapsed: 72.9 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 5
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 74.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11549 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 13.6 seconds
# Total time elapsed: 87.8 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 6
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 89.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11549 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 11.9 seconds
# Total time elapsed: 101.3 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 7
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 102.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11549 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 9.9 seconds
# Total time elapsed: 112.7 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 8
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 114.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11549 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 9.8 seconds
# Total time elapsed: 123.7 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 9
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 125.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11549 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 11.8 seconds
# Total time elapsed: 136.8 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 10
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 137.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11549 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 10.8 seconds
# Total time elapsed: 148.4 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 11
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 149.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11549 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 13.7 seconds
# Total time elapsed: 163.0 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 12
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 164.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11549 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 11.5 seconds
# Total time elapsed: 176.1 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 13
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 177.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11549 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 14.8 seconds
# Total time elapsed: 192.2 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 14
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 193.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11549 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 9.7 seconds
# Total time elapsed: 203.5 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 15
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 205.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11549 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 13.3 seconds
# Total time elapsed: 218.4 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 16
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 219.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11549 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 8.9 seconds
# Total time elapsed: 228.4 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 17
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 229.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11549 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 8.2 seconds
# Total time elapsed: 237.6 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 18
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 238.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11549 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 10.6 seconds
# Total time elapsed: 249.5 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 19
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 250.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11549 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 11.3 seconds
# Total time elapsed: 261.9 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 11549 multiplied with B
# Alignment error: 0.569
# ##############################
# Time elapsed from last time log: 4.0 seconds
# Total time elapsed: 265.9 seconds
# ##############################
# array([[ 0.43697667, -0.79617086],
#        [ 0.43743309, -0.78260762],
#        [ 0.45054469, -0.76762383],
#        ...,
#        [-0.43977937,  0.79299806],
#        [-0.43661909,  0.80478699],
#        [-0.46054484,  0.80805715]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/swissroll_with_noise_0.01//ldle.dat
