# %% [markdown]
# ### Sphere and swissroll with noise = 0.01

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
save_dir_root = '../data/pyLDLE2/sphere_and_swissoll/'

# %%
X, labelsMat, ddX = datasets.Datasets().sphere_and_swissroll()
# Out:
# X.shape =  (5000, 3)
# X.shape =  (5207, 3)
# X.shape =  (10207, 3)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LTSA'},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  intermed_opts={'eta_min': 10},
                  global_opts={
                      'max_iter': 10,
                      'init_algo_align_w_parent_only': True # Set this True for low noise
                  },
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 600 is created.

# %%
ldle.fit(X=X)
# Out:
# Constructing local views using LTSA.
# local_param: 0 points processed...
# local_param: 2551 points processed...
# local_param: 5102 points processed...
# local_param: 7653 points processed...
# local_param: 10204 points processed...
# local_param: all 10207 points processed...
# Done.
# ##############################
# Time elapsed from last time log: 7.7 seconds
# Total time elapsed: 7.7 seconds
# ##############################
# Max local distortion = 684.2374107858084
# Constructing intermediate views.
# eta = 2.
# # non-empty views with sz < 2 = 10207
# #nodes in views with sz < 2 = 10207
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 12.8 seconds
# Total time elapsed: 12.9 seconds
# ##############################
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 116.9 seconds
# Total time elapsed: 129.8 seconds
# ##############################
# eta = 3.
# # non-empty views with sz < 3 = 551
# #nodes in views with sz < 3 = 1102
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 1.1 seconds
# Total time elapsed: 131.0 seconds
# ##############################
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 5.7 seconds
# Total time elapsed: 136.7 seconds
# ##############################
# eta = 4.
# # non-empty views with sz < 4 = 371
# #nodes in views with sz < 4 = 1113
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 1.0 seconds
# Total time elapsed: 137.6 seconds
# ##############################
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 8.0 seconds
# Total time elapsed: 145.7 seconds
# ##############################
# eta = 5.
# # non-empty views with sz < 5 = 247
# #nodes in views with sz < 5 = 988
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 146.5 seconds
# ##############################
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 8.3 seconds
# Total time elapsed: 154.9 seconds
# ##############################
# eta = 6.
# # non-empty views with sz < 6 = 161
# #nodes in views with sz < 6 = 805
# Costs computed when eta = 6.
# ##############################
# Time elapsed from last time log: 0.6 seconds
# Total time elapsed: 155.5 seconds
# ##############################
# Remaining #nodes in views with sz < 6 = 0
# Done with eta = 6.
# ##############################
# Time elapsed from last time log: 8.6 seconds
# Total time elapsed: 164.1 seconds
# ##############################
# eta = 7.
# # non-empty views with sz < 7 = 139
# #nodes in views with sz < 7 = 834
# Costs computed when eta = 7.
# ##############################
# Time elapsed from last time log: 0.6 seconds
# Total time elapsed: 164.7 seconds
# ##############################
# Remaining #nodes in views with sz < 7 = 0
# Done with eta = 7.
# ##############################
# Time elapsed from last time log: 9.8 seconds
# Total time elapsed: 174.6 seconds
# ##############################
# eta = 8.
# # non-empty views with sz < 8 = 93
# #nodes in views with sz < 8 = 651
# Costs computed when eta = 8.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 175.0 seconds
# ##############################
# Remaining #nodes in views with sz < 8 = 0
# Done with eta = 8.
# ##############################
# Time elapsed from last time log: 8.0 seconds
# Total time elapsed: 183.1 seconds
# ##############################
# eta = 9.
# # non-empty views with sz < 9 = 66
# #nodes in views with sz < 9 = 528
# Costs computed when eta = 9.
# ##############################
# Time elapsed from last time log: 0.4 seconds
# Total time elapsed: 183.4 seconds
# ##############################
# Remaining #nodes in views with sz < 9 = 0
# Done with eta = 9.
# ##############################
# Time elapsed from last time log: 6.5 seconds
# Total time elapsed: 189.9 seconds
# ##############################
# eta = 10.
# # non-empty views with sz < 10 = 63
# #nodes in views with sz < 10 = 567
# Costs computed when eta = 10.
# ##############################
# Time elapsed from last time log: 0.7 seconds
# Total time elapsed: 190.6 seconds
# ##############################
# Remaining #nodes in views with sz < 10 = 0
# Done with eta = 10.
# ##############################
# Time elapsed from last time log: 8.3 seconds
# Total time elapsed: 198.9 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 199.4 seconds
# ##############################
# After clustering, max distortion is 30.183138
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 157 intermediate views
# Ambiguous overlaps checked for 314 intermediate views
# Ambiguous overlaps checked for 471 intermediate views
# Ambiguous overlaps checked for 628 intermediate views
# Ambiguous overlaps checked for 630 points
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 2
# Multiple connected components detected
# Computing initial embedding using: sequential algorithm
# ##############################
# Time elapsed from last time log: 2.8 seconds
# Total time elapsed: 2.8 seconds
# ##############################
# Initial alignment of 157 views completed
# Initial alignment of 314 views completed
# Initial alignment of 157 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 0.3 seconds
# Total time elapsed: 3.1 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 11.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10837
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 15.3 seconds
# Total time elapsed: 27.0 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 31.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10837
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 18.0 seconds
# Total time elapsed: 49.6 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 54.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10837
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 16.3 seconds
# Total time elapsed: 70.4 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 75.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10837
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 17.9 seconds
# Total time elapsed: 92.9 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 97.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10837
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 18.6 seconds
# Total time elapsed: 115.9 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 5
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 120.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10837
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 18.1 seconds
# Total time elapsed: 138.3 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 6
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 142.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10837
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 12.6 seconds
# Total time elapsed: 155.1 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 7
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 159.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10837
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 12.6 seconds
# Total time elapsed: 171.8 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 8
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 175.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10837
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 13.2 seconds
# Total time elapsed: 189.1 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 9
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 193.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10837
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 13.6 seconds
# Total time elapsed: 206.8 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 10837
# Alignment error: 49.606
# ##############################
# Time elapsed from last time log: 2.8 seconds
# Total time elapsed: 209.7 seconds
# ##############################
# array([[-0.39936847,  0.10356593],
#        [-0.40346419,  0.10449231],
#        [-0.4118521 ,  0.11557587],
#        ...,
#        [ 0.84693369,  0.87583067],
#        [ 0.84245368,  0.89013056],
#        [ 0.86114783,  0.86559651]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/sphere_and_swissoll//ldle.dat
