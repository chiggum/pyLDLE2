# %% [markdown]
# ### Sphere and swissroll with noise = 0.01

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
save_dir_root = '../data/pyLDLE2/sphere_and_swissoll/'

# %%
X, labelsMat, ddX = datasets.Datasets().sphere_and_swissroll()
# Out:
# X.shape =  (5000, 3)
# X.shape =  (5207, 3)
# X.shape =  (10207, 3)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LTSA'},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 700 is created.
# Options provided:
# local_opts:
# {
#     "Atilde_method": "LDLE_1",
#     "N": 100,
#     "algo": "LTSA",
#     "delta": 0.9,
#     "gl_type": "unnorm",
#     "k": 28,
#     "k_nn": 49,
#     "k_nn0": 700,
#     "k_tune": 7,
#     "n_proc": 32,
#     "no_gamma": false,
#     "p": 0.99,
#     "pp_n_thresh": 32,
#     "tau": 50,
#     "to_postprocess": true
# }
# intermed_opts:
# {
#     "algo": "best",
#     "eta_max": 25,
#     "eta_min": 5,
#     "len_S_thresh": 256,
#     "local_algo": "LTSA",
#     "n_proc": 32,
#     "n_times": 4
# }
# global_opts:
# {
#     "color_tear": true,
#     "compute_error": false,
#     "init_algo_align_w_parent_only": true,
#     "init_algo_name": "procrustes",
#     "k": 28,
#     "main_algo": "LDLE",
#     "max_iter": 20,
#     "n_proc": 32,
#     "nu": 3,
#     "refine_algo_alpha": 0.3,
#     "refine_algo_max_internal_iter": 100,
#     "refine_algo_name": "rgd",
#     "to_tear": true,
#     "vis_before_init": false
# }

# %%
ldle.fit(X=X)
# Out:
# Constructing local views using LTSA.
# local_param: all 10207 points processed...
# max distortion is 356.763826
# Done.
# ##############################
# Time elapsed from last time log: 4.1 seconds
# Total time elapsed: 4.1 seconds
# ##############################
# Posprocessing local parameterizations.
# #Param replaced: 9102, max distortion: 10.992541
# #Param replaced: 2132, max distortion: 10.992541
# #Param replaced: 613, max distortion: 10.992541
# #Param replaced: 201, max distortion: 10.992541
# #Param replaced: 61, max distortion: 10.992541
# #Param replaced: 20, max distortion: 10.992541
# #Param replaced: 14, max distortion: 10.992541
# #Param replaced: 5, max distortion: 10.992541
# #Param replaced: 1, max distortion: 10.992541
# #Param replaced: 2, max distortion: 10.992541
# #Param replaced: 0, max distortion: 10.992541
# Max local distortion after postprocessing: 10.992541434320666
# Done.
# ##############################
# Time elapsed from last time log: 28.7 seconds
# Total time elapsed: 32.8 seconds
# ##############################
# Max local distortion = 10.992541434320666
# Constructing intermediate views.
# eta = 2.
# # non-empty views with sz < 2 = 10207
# #nodes in views with sz < 2 = 10207
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 34.9 seconds
# Total time elapsed: 37.1 seconds
# ##############################
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 480.6 seconds
# Total time elapsed: 517.6 seconds
# ##############################
# eta = 3.
# # non-empty views with sz < 3 = 1227
# #nodes in views with sz < 3 = 2454
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 6.3 seconds
# Total time elapsed: 524.0 seconds
# ##############################
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 209.4 seconds
# Total time elapsed: 733.4 seconds
# ##############################
# eta = 4.
# # non-empty views with sz < 4 = 674
# #nodes in views with sz < 4 = 2022
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 6.3 seconds
# Total time elapsed: 739.7 seconds
# ##############################
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 203.1 seconds
# Total time elapsed: 942.8 seconds
# ##############################
# eta = 5.
# # non-empty views with sz < 5 = 380
# #nodes in views with sz < 5 = 1520
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 7.2 seconds
# Total time elapsed: 950.0 seconds
# ##############################
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 189.9 seconds
# Total time elapsed: 1139.9 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 6.5 seconds
# Total time elapsed: 1146.6 seconds
# ##############################
# After clustering, max distortion is 14.617359
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 333 intermediate views
# Ambiguous overlaps checked for 666 intermediate views
# Ambiguous overlaps checked for 999 intermediate views
# Ambiguous overlaps checked for 1332 intermediate views
# Ambiguous overlaps checked for 1333 points
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 2
# Multiple connected components detected
# Computing initial embedding using: procrustes algorithm
# ##############################
# Time elapsed from last time log: 68.5 seconds
# Total time elapsed: 68.5 seconds
# ##############################
# Initial alignment of 333 views completed
# Initial alignment of 333 views completed
# Initial alignment of 666 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 9.1 seconds
# Total time elapsed: 77.6 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 108.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11540 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 47.7 seconds
# Total time elapsed: 156.4 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 176.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11540 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 48.5 seconds
# Total time elapsed: 225.4 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 247.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11540 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 43.1 seconds
# Total time elapsed: 290.1 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 306.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11540 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 49.5 seconds
# Total time elapsed: 356.4 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 376.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11540 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 46.5 seconds
# Total time elapsed: 423.2 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 5
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 439.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11540 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 40.2 seconds
# Total time elapsed: 479.6 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 6
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 492.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11540 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 39.2 seconds
# Total time elapsed: 531.8 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 7
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 544.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11540 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 37.7 seconds
# Total time elapsed: 582.6 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 8
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 594.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11540 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 50.0 seconds
# Total time elapsed: 644.3 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 9
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 660.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11540 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 45.7 seconds
# Total time elapsed: 706.6 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 10
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 715.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11540 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 47.6 seconds
# Total time elapsed: 762.6 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 11
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 775.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11540 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 45.6 seconds
# Total time elapsed: 820.9 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 12
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 827.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11540 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 50.8 seconds
# Total time elapsed: 878.0 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 13
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 892.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11540 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 52.2 seconds
# Total time elapsed: 944.3 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 14
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 955.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11540 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 44.5 seconds
# Total time elapsed: 999.5 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 15
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 1011.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11540 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 48.3 seconds
# Total time elapsed: 1059.6 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 16
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 1070.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11540 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 63.6 seconds
# Total time elapsed: 1133.7 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 17
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 1147.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11540 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 50.7 seconds
# Total time elapsed: 1197.8 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 18
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 1210.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11540 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 49.3 seconds
# Total time elapsed: 1260.0 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 19
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 1272.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 11540 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 48.1 seconds
# Total time elapsed: 1320.3 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 11540 multiplied with B
# Alignment error: 65.454
# ##############################
# Time elapsed from last time log: 30.8 seconds
# Total time elapsed: 1351.1 seconds
# ##############################
# array([[ 1.6060569 , -0.10452476],
#        [ 1.59776578, -0.11983847],
#        [ 1.60775121, -0.09646934],
#        ...,
#        [-1.09199291, -0.43692929],
#        [-1.10652548, -0.44632572],
#        [-1.10097989, -0.41597947]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/sphere_and_swissoll//ldle.dat
