# %% [markdown]
# ### Sphere and swissroll with noise = 0.01

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
save_dir_root = '../data/pyLDLE2/sphere_and_swissoll/'

# %%
X, labelsMat, ddX = datasets.Datasets().sphere_and_swissroll()
# Out:
# X.shape =  (5000, 3)
# X.shape =  (5207, 3)
# X.shape =  (10207, 3)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LTSA'},
                  vis_opts={'c': labelsMat[:,0], 'save_dir': save_dir_root},
                  intermed_opts={'eta_min': 10},
                  global_opts={
                      'max_iter': 10,
                      'init_algo_align_w_parent_only': True # Set this True for low noise
                  },
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 875 is created.

# %%
ldle.fit(X=X)
# Out:
# Constructing local views using LTSA.
# local_param: all 10207 points processed...
# max distortion is 873.497415
# Done.
# ##############################
# Time elapsed from last time log: 1.1 seconds
# Total time elapsed: 1.1 seconds
# ##############################
# Posprocessing local parameterizations.
# #Param replaced: 9165, max distortion: 15.699808
# #Param replaced: 2340, max distortion: 15.699808
# #Param replaced: 755, max distortion: 13.139606
# #Param replaced: 243, max distortion: 13.139606
# #Param replaced: 70, max distortion: 12.788737
# #Param replaced: 21, max distortion: 12.788737
# #Param replaced: 2, max distortion: 12.788737
# #Param replaced: 0, max distortion: 12.788737
# Max local distortion after postprocessing: 12.788736878213264
# Done.
# ##############################
# Time elapsed from last time log: 11.4 seconds
# Total time elapsed: 12.5 seconds
# ##############################
# Max local distortion = 12.788736878213264
# Constructing intermediate views.
# eta = 2.
# # non-empty views with sz < 2 = 10207
# #nodes in views with sz < 2 = 10207
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 22.5 seconds
# Total time elapsed: 22.6 seconds
# ##############################
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 107.6 seconds
# Total time elapsed: 130.2 seconds
# ##############################
# eta = 3.
# # non-empty views with sz < 3 = 1192
# #nodes in views with sz < 3 = 2384
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 3.3 seconds
# Total time elapsed: 133.5 seconds
# ##############################
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 38.9 seconds
# Total time elapsed: 172.3 seconds
# ##############################
# eta = 4.
# # non-empty views with sz < 4 = 681
# #nodes in views with sz < 4 = 2043
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 2.5 seconds
# Total time elapsed: 174.8 seconds
# ##############################
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 47.0 seconds
# Total time elapsed: 221.8 seconds
# ##############################
# eta = 5.
# # non-empty views with sz < 5 = 381
# #nodes in views with sz < 5 = 1524
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 1.7 seconds
# Total time elapsed: 223.5 seconds
# ##############################
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 35.4 seconds
# Total time elapsed: 259.0 seconds
# ##############################
# eta = 6.
# # non-empty views with sz < 6 = 259
# #nodes in views with sz < 6 = 1295
# Costs computed when eta = 6.
# ##############################
# Time elapsed from last time log: 1.4 seconds
# Total time elapsed: 260.4 seconds
# ##############################
# Remaining #nodes in views with sz < 6 = 0
# Done with eta = 6.
# ##############################
# Time elapsed from last time log: 35.2 seconds
# Total time elapsed: 295.5 seconds
# ##############################
# eta = 7.
# # non-empty views with sz < 7 = 175
# #nodes in views with sz < 7 = 1050
# Costs computed when eta = 7.
# ##############################
# Time elapsed from last time log: 1.2 seconds
# Total time elapsed: 296.8 seconds
# ##############################
# Remaining #nodes in views with sz < 7 = 0
# Done with eta = 7.
# ##############################
# Time elapsed from last time log: 29.4 seconds
# Total time elapsed: 326.1 seconds
# ##############################
# eta = 8.
# # non-empty views with sz < 8 = 134
# #nodes in views with sz < 8 = 938
# Costs computed when eta = 8.
# ##############################
# Time elapsed from last time log: 1.1 seconds
# Total time elapsed: 327.3 seconds
# ##############################
# Remaining #nodes in views with sz < 8 = 0
# Done with eta = 8.
# ##############################
# Time elapsed from last time log: 25.6 seconds
# Total time elapsed: 352.8 seconds
# ##############################
# eta = 9.
# # non-empty views with sz < 9 = 109
# #nodes in views with sz < 9 = 872
# Costs computed when eta = 9.
# ##############################
# Time elapsed from last time log: 1.2 seconds
# Total time elapsed: 354.0 seconds
# ##############################
# Remaining #nodes in views with sz < 9 = 0
# Done with eta = 9.
# ##############################
# Time elapsed from last time log: 27.4 seconds
# Total time elapsed: 381.4 seconds
# ##############################
# eta = 10.
# # non-empty views with sz < 10 = 84
# #nodes in views with sz < 10 = 756
# Costs computed when eta = 10.
# ##############################
# Time elapsed from last time log: 0.8 seconds
# Total time elapsed: 382.2 seconds
# ##############################
# Remaining #nodes in views with sz < 10 = 0
# Done with eta = 10.
# ##############################
# Time elapsed from last time log: 22.4 seconds
# Total time elapsed: 404.6 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 0.6 seconds
# Total time elapsed: 405.2 seconds
# ##############################
# After clustering, max distortion is 46.311878
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 163 intermediate views
# Ambiguous overlaps checked for 326 intermediate views
# Ambiguous overlaps checked for 489 intermediate views
# Ambiguous overlaps checked for 652 points
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 2
# Multiple connected components detected
# Computing initial embedding using: sequential algorithm
# ##############################
# Time elapsed from last time log: 3.3 seconds
# Total time elapsed: 3.3 seconds
# ##############################
# Initial alignment of 163 views completed
# Initial alignment of 326 views completed
# Initial alignment of 163 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 0.5 seconds
# Total time elapsed: 3.7 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 5.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10859 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.0 seconds
# Total time elapsed: 7.8 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 9.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10859 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.1 seconds
# Total time elapsed: 11.4 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 12.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10859 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.1 seconds
# Total time elapsed: 15.0 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 16.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10859 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.1 seconds
# Total time elapsed: 18.5 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 19.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10859 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.1 seconds
# Total time elapsed: 21.8 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 5
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 23.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10859 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 25.4 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 6
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 26.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10859 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 28.9 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 7
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 30.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10859 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 32.3 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 8
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 33.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10859 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 35.8 seconds
# ##############################
# Refining with retraction algorithm for 100 iterations.
# Refinement iteration: 9
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 37.1 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 10859 multiplied with B
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 2.2 seconds
# Total time elapsed: 39.3 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 10859 multiplied with B
# Alignment error: 92.552
# ##############################
# Time elapsed from last time log: 1.0 seconds
# Total time elapsed: 40.4 seconds
# ##############################
# array([[-0.08454767, -0.06513209],
#        [-0.07146093, -0.08098926],
#        [-0.08873271, -0.07196671],
#        ...,
#        [ 0.62583914,  0.67562944],
#        [ 0.61888281,  0.69215048],
#        [ 0.65045404,  0.69008723]])

# %%
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/sphere_and_swissoll//ldle.dat
