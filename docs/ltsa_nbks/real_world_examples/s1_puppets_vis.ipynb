# %% [markdown]
# # Puppets data - further visualizations

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

from pyLDLE2 import visualize_all
visualize_all.visualize('../data/pyLDLE2/s1_puppets_data/ldle.dat')
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline
# ##################################################
# Data
# ##################################################
# Cannot plot because input data has more than 3 features.
# Eigenvalues
# Local views were constructed using LTSA
# ##################################################
# Eigenvectors on data
# ##################################################
# Local views were constructed using LTSA
# ##################################################
# Eigenvectors on embedding
# ##################################################
# Local views were constructed using LTSA
# ##################################################
# gamma on  data
# ##################################################
# Local views were constructed using LTSA
# ##################################################
# gamma on embedding
# ##################################################
# Local views were constructed using LTSA
# ...
