# %% [markdown]
# ### Puppets Data

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
save_dir_root = '../data/pyLDLE2/s1_puppets_data/'

# %%
X, labelsMat, img, img_shape = datasets.Datasets().puppets_data(dirpath='/home/dhruv/codebase/data/PuppetsData/', prefix='s1', n_pca=200)
# Out:
# Applying PCA
# explained_variance_ratio: [3.35301380e-01 1.07958810e-01 7.93514727e-02 6.30933241e-02
#  5.64016995e-02 4.14165032e-02 3.04283478e-02 2.46359953e-02
#  2.12428034e-02 1.89268469e-02 1.78850481e-02 1.42923966e-02
#  1.09639386e-02 1.00090213e-02 9.83736959e-03 8.48709253e-03
#  8.26903898e-03 7.45026954e-03 6.95006240e-03 6.25023565e-03
#  5.89887852e-03 5.36820143e-03 5.10618307e-03 5.00063686e-03
#  4.54576128e-03 4.47221583e-03 4.19312314e-03 3.90108114e-03
#  3.43195273e-03 3.31598231e-03 3.06556097e-03 2.93942588e-03
#  2.69657012e-03 2.41710948e-03 2.25843318e-03 2.08757516e-03
#  2.01765020e-03 1.92638257e-03 1.91569419e-03 1.85284827e-03
#  1.82347468e-03 1.62682119e-03 1.54346949e-03 1.51040729e-03
#  1.40852959e-03 1.34025206e-03 1.29848084e-03 1.19540590e-03
#  1.15903036e-03 1.09382602e-03 1.01407066e-03 9.78357882e-04
#  8.97788731e-04 8.61027289e-04 8.13847930e-04 7.36541853e-04
#  7.31719904e-04 6.92665215e-04 6.50670507e-04 5.89322671e-04
# ...

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LTSA', 'k': 25},
                  vis_opts={'c': None, 'save_dir': save_dir_root},
                  intermed_opts={'eta_min': 5},
                  global_opts={
                      'max_iter': 20,
                      'init_algo_align_w_parent_only': True # Set this True for low noise
                  },
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 625 is created.

# %%
# %matplotlib inline
ldle.fit(X=X)
# Out:
# Constructing local views using LTSA.
# local_param: all 8100 points processed...
# max distortion is 1929.808235
# Done.
# ##############################
# Time elapsed from last time log: 1.3 seconds
# Total time elapsed: 1.3 seconds
# ##############################
# Posprocessing local parameterizations.
# #Param replaced: 6293, max distortion: 22.551733
# #Param replaced: 178, max distortion: 22.551733
# #Param replaced: 16, max distortion: 22.551733
# #Param replaced: 0, max distortion: 22.551733
# Max local distortion after postprocessing: 22.55173290237254
# Done.
# ##############################
# Time elapsed from last time log: 4.5 seconds
# Total time elapsed: 5.8 seconds
# ##############################
# Max local distortion = 22.55173290237254
# Constructing intermediate views.
# eta = 2.
# # non-empty views with sz < 2 = 8100
# #nodes in views with sz < 2 = 8100
# Costs computed when eta = 2.
# ##############################
# ...

# %%
# %matplotlib inline
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat*0, ldle, img, img_shape], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/s1_puppets_data//ldle.dat
