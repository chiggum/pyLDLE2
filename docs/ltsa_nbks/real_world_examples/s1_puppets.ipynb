# %% [markdown]
# ### Puppets Data

# %%
# %matplotlib inline

# %%
# Not really required
import sys
sys.path.insert(0, '../../..')

# %%
from pyLDLE2 import datasets
from pyLDLE2 import ldle_
# Out:
# matplotlib.get_backend() =  module://matplotlib_inline.backend_inline

# %%
save_dir_root = '../data/pyLDLE2/s1_puppets_data/'

# %%
X, labelsMat, img, img_shape = datasets.Datasets().puppets_data(dirpath='/home/dhruv/codebase/data/PuppetsData/', prefix='s1', n_pca=100)
# Out:
# Applying PCA
# sum(explained_variance_ratio): 0.9808061709777035
# X.shape =  (8100, 100)

# %%
# The supplied options would override the default options
ldle = ldle_.LDLE(local_opts={'algo':'LTSA', 'k': 35},
                  intermed_opts={'eta_min': 5},
                  vis_opts={'c': None, 'save_dir': save_dir_root},
                  verbose=True, debug=True)
# Out:
# local_opts['k_nn0'] = 875 is created.
# Options provided:
# local_opts:
# {
#     "Atilde_method": "LDLE_1",
#     "N": 100,
#     "algo": "LTSA",
#     "alpha": 1,
#     "debug": true,
#     "delta": 0.9,
#     "gl_type": "unnorm",
#     "k": 35,
#     "k_nn": 49,
#     "k_nn0": 875,
#     "k_tune": 7,
#     "max_iter": 300,
#     "n_proc": 32,
#     "no_gamma": false,
#     "p": 0.99,
#     "pp_n_thresh": 32,
#     "reg": 0.0,
#     "tau": 50,
#     "to_postprocess": true,
#     "verbose": true
# }
# intermed_opts:
# {
#     "algo": "best",
#     "debug": true,
#     "eta_max": 25,
#     "eta_min": 5,
#     "len_S_thresh": 256,
#     "local_algo": "LTSA",
#     "n_proc": 32,
#     "n_times": 4,
#     "verbose": true
# }
# global_opts:
# {
#     "align_w_parent_only": true,
#     "alpha": 0.3,
#     "color_tear": true,
#     "compute_error": false,
#     "debug": true,
#     "eps": 1e-08,
#     "init_algo_name": "procrustes",
#     "k": 35,
#     "main_algo": "LDLE",
#     "max_internal_iter": 100,
#     "max_iter": 20,
#     "n_proc": 32,
#     "nu": 3,
#     "refine_algo_name": "rgd",
#     "to_tear": true,
#     "verbose": true,
#     "vis_before_init": false
# }

# %%
# %matplotlib inline
ldle.fit(X=X)
# Out:
# Constructing local views using LTSA
# local_param: all 8100 points processed...
# max distortion is 1200.932377
# Done.
# ##############################
# Time elapsed from last time log: 2.7 seconds
# Total time elapsed: 2.7 seconds
# ##############################
# Posprocessing local parameterizations.
# #Param replaced: 6636, max distortion: 30.996092
# #Param replaced: 135, max distortion: 29.446183
# #Param replaced: 14, max distortion: 29.446183
# #Param replaced: 0, max distortion: 29.446183
# Max local distortion after postprocessing: 29.44618317142052
# Done.
# ##############################
# Time elapsed from last time log: 5.8 seconds
# Total time elapsed: 8.5 seconds
# ##############################
# Max local distortion = 29.44618317142052
# Constructing intermediate views.
# eta = 2.
# #non-empty views with sz < 2 = 8100
# #nodes in views with sz < 2 = 8100
# Costs computed when eta = 2.
# ##############################
# Time elapsed from last time log: 10.8 seconds
# Total time elapsed: 11.4 seconds
# ##############################
# ctr=5527, total_len_S=22366, avg_len_S=4.047
# Remaining #nodes in views with sz < 2 = 0
# Done with eta = 2.
# ##############################
# Time elapsed from last time log: 112.9 seconds
# Total time elapsed: 124.3 seconds
# ##############################
# eta = 3.
# #non-empty views with sz < 3 = 1033
# #nodes in views with sz < 3 = 2066
# Costs computed when eta = 3.
# ##############################
# Time elapsed from last time log: 3.1 seconds
# Total time elapsed: 127.4 seconds
# ##############################
# ctr=1638, total_len_S=33904, avg_len_S=20.698
# Remaining #nodes in views with sz < 3 = 0
# Done with eta = 3.
# ##############################
# Time elapsed from last time log: 53.6 seconds
# Total time elapsed: 181.0 seconds
# ##############################
# eta = 4.
# #non-empty views with sz < 4 = 515
# #nodes in views with sz < 4 = 1545
# Costs computed when eta = 4.
# ##############################
# Time elapsed from last time log: 2.7 seconds
# Total time elapsed: 183.8 seconds
# ##############################
# ctr=1271, total_len_S=37325, avg_len_S=29.367
# Remaining #nodes in views with sz < 4 = 0
# Done with eta = 4.
# ##############################
# Time elapsed from last time log: 46.4 seconds
# Total time elapsed: 230.1 seconds
# ##############################
# eta = 5.
# #non-empty views with sz < 5 = 325
# #nodes in views with sz < 5 = 1300
# Costs computed when eta = 5.
# ##############################
# Time elapsed from last time log: 2.8 seconds
# Total time elapsed: 233.0 seconds
# ##############################
# ctr=1067, total_len_S=38941, avg_len_S=36.496
# Remaining #nodes in views with sz < 5 = 0
# Done with eta = 5.
# ##############################
# Time elapsed from last time log: 40.9 seconds
# Total time elapsed: 273.8 seconds
# ##############################
# Pruning and cleaning up.
# Done.
# ##############################
# Time elapsed from last time log: 1.2 seconds
# Total time elapsed: 275.1 seconds
# ##############################
# After clustering, max distortion is 79.436057
# Computing laterations scores for overlaps b/w intermed views
# Done
# ##############################
# Time elapsed from last time log: 2.4 seconds
# Total time elapsed: 2.5 seconds
# ##############################
# Computing a lateration.
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 1
# Done.
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 2.5 seconds
# ##############################
# Computing initial embedding using: procrustes algorithm
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 2.5 seconds
# ##############################
# Initial alignment of 270 views completed
# Initial alignment of 540 views completed
# Initial alignment of 810 views completed
# Initial alignment of 1080 views completed
# Embedding initialized.
# ##############################
# Time elapsed from last time log: 1.2 seconds
# Total time elapsed: 3.7 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 0
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 11.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 8100 + 1083 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 7.2 seconds
# Total time elapsed: 18.2 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 1
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 22.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 8100 + 1083 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 7.0 seconds
# Total time elapsed: 29.8 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 2
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 34.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 8100 + 1083 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 7.4 seconds
# Total time elapsed: 41.8 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 3
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 46.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 8100 + 1083 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 7.2 seconds
# Total time elapsed: 53.6 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 4
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 57.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 8100 + 1083 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 7.4 seconds
# Total time elapsed: 65.0 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 5
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 69.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 8100 + 1083 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 7.4 seconds
# Total time elapsed: 76.3 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 6
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 80.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 8100 + 1083 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 7.1 seconds
# Total time elapsed: 87.6 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 7
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 92.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 8100 + 1083 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 7.3 seconds
# Total time elapsed: 99.5 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 8
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 103.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 8100 + 1083 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 7.4 seconds
# Total time elapsed: 110.8 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 9
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 114.8 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 8100 + 1083 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 7.5 seconds
# Total time elapsed: 122.3 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 10
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 126.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 8100 + 1083 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 7.3 seconds
# Total time elapsed: 133.7 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 11
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 137.9 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 8100 + 1083 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 7.1 seconds
# Total time elapsed: 145.0 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 12
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 149.2 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 8100 + 1083 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 7.3 seconds
# Total time elapsed: 156.5 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 13
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 160.6 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 8100 + 1083 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 7.1 seconds
# Total time elapsed: 167.7 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 14
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 171.4 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 8100 + 1083 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 7.4 seconds
# Total time elapsed: 178.7 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 15
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 182.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 8100 + 1083 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 7.2 seconds
# Total time elapsed: 189.8 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 16
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 193.7 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 8100 + 1083 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 7.5 seconds
# Total time elapsed: 201.3 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 17
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 205.3 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 8100 + 1083 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 7.1 seconds
# Total time elapsed: 212.4 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 18
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 216.5 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 8100 + 1083 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 7.2 seconds
# Total time elapsed: 223.7 seconds
# ##############################
# Refining with rgd algorithm for 100 iterations.
# Refinement iteration: 19
# ##############################
# Time elapsed from last time log: 0.0 seconds
# Total time elapsed: 228.0 seconds
# ##############################
# Computing Pseudoinverse of a matrix of L of size 8100 + 1083 multiplied with B
# Computing svd
# Done
# Descent starts
# Done.
# ##############################
# Time elapsed from last time log: 7.2 seconds
# Total time elapsed: 235.2 seconds
# ##############################
# Computing error.
# Computing Pseudoinverse of a matrix of L of size 8100 + 1083 multiplied with B
# Computing svd
# Done
# Alignment error: 7821.003
# ##############################
# Time elapsed from last time log: 3.1 seconds
# Total time elapsed: 238.3 seconds
# ##############################
# array([[-3.18001297, -0.09792677],
#        [-1.92767044, -0.19216586],
#        [-0.95744419, -0.09793827],
#        ...,
#        [-0.61296483, -1.56285654],
#        [ 0.47308657, -1.33029141],
#        [ 1.03365438, -0.77360192]])

# %%
# %matplotlib inline
ldle.GlobalViews.vis_embedding(ldle.GlobalViews.y_final, ldle.vis, ldle.vis_opts,
                               ldle.GlobalViews.color_of_pts_on_tear_final,
                               title='Final global embedding', )

# %%
# save for further visualization
import pickle
save_path = save_dir_root+'/ldle.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat*0, ldle, img, img_shape], f)
print('Saved', save_path)
# Out:
# Saved ../data/pyLDLE2/s1_puppets_data//ldle.dat
